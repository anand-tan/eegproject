# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization
    6. Spectral Edge Frequency 95%
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        sync_scores = []
        for li, ri in PAIRS_LR:
            c = np.corrcoef(X[li], X[ri])[0, 1]
            sync_scores.append(c)
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        df = np.diff(freqs)
        df = np.r_[df, df[-1]]
        power_bins = psd * df
        cumulative_power = np.cumsum(power_bins, axis=1)
        total_power = cumulative_power[:, -1]
        sef_indices = np.argmax(cumulative_power >= 0.95 * total_power[:, None], axis=1)
        avg_sef95 = freqs[sef_indices].mean()

        features.append([ta_ratio, complexity, line_length, rms, avg_sync])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb06) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_24.edf"},

]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/18 files; last epochs=2880
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/18 files; last epochs=2880
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/18 files; last epochs=606
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40757/4108038344.py:33: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 18/18 files; last epochs=2880
# Loading complete.

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.9442   0.0044   0.0514
# State 1   0.0044   0.9849   0.0107
# State 2   0.0300   0.0132   0.9567

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : -0.503
#   PermEntropy : +1.033
#   LineLength  : +0.686
#   RMS         : -0.010
#   Avg Sync    : -0.822
#
# State 1 means:
#   TA_ratio    : +0.209
#   PermEntropy : -0.782
#   LineLength  : -0.702
#   RMS         : -0.134
#   Avg Sync    : +0.431
#
# State 2 means:
#   TA_ratio    : +0.091
#   PermEntropy : +0.188
#   LineLength  : +0.318
#   RMS         : +0.149
#   Avg Sync    : +0.054

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy,
# [2] LineLength, [3] RMS

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3

# Ictal: high line length + high RMS
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# Baseline: highest entropy among remaining states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
baseline_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_ENT])]
)

# Pre-ictal: whatever state is left (for 3-state HMM)
preictal_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, baseline_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb06_01.edf    | Pre-Ictal  | 0            | 35
# chb06_01.edf    | Ictal      | 35           | 60
# chb06_01.edf    | Ictal      | 90           | 130
# chb06_01.edf    | Ictal      | 155          | 180
# chb06_01.edf    | Pre-Ictal  | 180          | 225
# chb06_01.edf    | Ictal      | 225          | 260
# chb06_01.edf    | Pre-Ictal  | 260          | 295
# chb06_01.edf    | Ictal      | 295          | 335
# chb06_01.edf    | Pre-Ictal  | 335          | 370
# chb06_01.edf    | Ictal      | 370          | 395
# chb06_01.edf    | Pre-Ictal  | 395          | 420
# chb06_01.edf    | Ictal      | 420          | 455
# chb06_01.edf    | Ictal      | 475          | 590
# chb06_01.edf    | Pre-Ictal  | 590          | 655
# chb06_01.edf    | Ictal      | 655          | 720
# chb06_01.edf    | Pre-Ictal  | 750          | 805
# chb06_01.edf    | Ictal      | 805          | 875
# chb06_01.edf    | Pre-Ictal  | 875          | 915
# chb06_01.edf    | Ictal      | 915          | 955
# chb06_01.edf    | Ictal      | 1035         | 1075
# chb06_01.edf    | Ictal      | 1100         | 1125
# chb06_01.edf    | Pre-Ictal  | 1125         | 1170
# chb06_01.edf    | Ictal      | 1170         | 1205
# chb06_01.edf    | Pre-Ictal  | 1225         | 1265
# chb06_01.edf    | Ictal      | 1265         | 1295
# chb06_01.edf    | Pre-Ictal  | 1295         | 1390
# chb06_01.edf    | Ictal      | 1390         | 1425
# chb06_01.edf    | Ictal      | 1475         | 1515
# chb06_01.edf    | Pre-Ictal  | 1540         | 1635
# chb06_01.edf    | Ictal      | 1635         | 1655
# chb06_01.edf    | Pre-Ictal  | 1655         | 1700
# chb06_01.edf    | Ictal      | 1700         | 1760
# chb06_01.edf    | Pre-Ictal  | 1760         | 2405
# chb06_01.edf    | Pre-Ictal  | 2435         | 2770
# chb06_01.edf    | Pre-Ictal  | 2805         | 3025
# chb06_01.edf    | Ictal      | 3055         | 3080
# chb06_01.edf    | Ictal      | 3340         | 3390
# chb06_01.edf    | Pre-Ictal  | 3405         | 3835
# chb06_01.edf    | Ictal      | 3860         | 3885
# chb06_01.edf    | Pre-Ictal  | 4005         | 4085
# chb06_01.edf    | Pre-Ictal  | 4350         | 4425
# chb06_01.edf    | Ictal      | 4450         | 4480
# chb06_01.edf    | Pre-Ictal  | 4780         | 4900
# chb06_01.edf    | Pre-Ictal  | 4965         | 5010
# chb06_01.edf    | Ictal      | 5250         | 5270
# chb06_01.edf    | Ictal      | 5415         | 5455
# chb06_01.edf    | Pre-Ictal  | 5480         | 5535
# chb06_01.edf    | Ictal      | 5680         | 5715
# chb06_01.edf    | Pre-Ictal  | 5770         | 5855
# chb06_01.edf    | Pre-Ictal  | 6060         | 6130
# chb06_01.edf    | Ictal      | 6150         | 6180
# chb06_01.edf    | Pre-Ictal  | 6215         | 6385
# chb06_01.edf    | Pre-Ictal  | 6510         | 6565
# chb06_01.edf    | Pre-Ictal  | 6620         | 6650
# chb06_01.edf    | Ictal      | 6710         | 6765
# chb06_01.edf    | Ictal      | 6805         | 6840
# chb06_01.edf    | Pre-Ictal  | 6915         | 6970
# chb06_01.edf    | Ictal      | 7030         | 7090
# chb06_01.edf    | Ictal      | 7110         | 7135
# chb06_01.edf    | Ictal      | 7290         | 7315
# chb06_01.edf    | Ictal      | 7355         | 7415
# chb06_01.edf    | Pre-Ictal  | 7485         | 8385
# chb06_01.edf    | Ictal      | 8400         | 8415
# chb06_01.edf    | Pre-Ictal  | 8485         | 8560
# chb06_01.edf    | Ictal      | 8770         | 8805
# chb06_01.edf    | Pre-Ictal  | 9145         | 9205
# chb06_01.edf    | Ictal      | 9340         | 9370
# chb06_01.edf    | Ictal      | 9405         | 9430
# chb06_01.edf    | Ictal      | 9460         | 9475
# chb06_01.edf    | Pre-Ictal  | 10515        | 10580
# chb06_01.edf    | Pre-Ictal  | 10625        | 10680
# chb06_01.edf    | Pre-Ictal  | 10770        | 10815
# chb06_01.edf    | Pre-Ictal  | 11065        | 11100
# chb06_01.edf    | Ictal      | 11270        | 11350
# chb06_01.edf    | Ictal      | 11440        | 11470
# chb06_01.edf    | Ictal      | 11510        | 11535
# chb06_01.edf    | Ictal      | 11590        | 11630
# chb06_01.edf    | Ictal      | 11680        | 11700
# chb06_01.edf    | Ictal      | 11780        | 11905
# chb06_01.edf    | Ictal      | 11940        | 11965
# chb06_01.edf    | Ictal      | 12095        | 12130
# chb06_01.edf    | Ictal      | 12185        | 12345
# chb06_01.edf    | Ictal      | 12395        | 12430
# chb06_01.edf    | Ictal      | 12560        | 12615
# chb06_01.edf    | Ictal      | 12660        | 12690
# chb06_01.edf    | Ictal      | 12780        | 12900
# chb06_01.edf    | Ictal      | 13150        | 13220
# chb06_01.edf    | Ictal      | 13260        | 13410
# chb06_01.edf    | Ictal      | 13540        | 13560
# chb06_01.edf    | Pre-Ictal  | 13560        | 13690
# chb06_01.edf    | Ictal      | 13725        | 13755
# chb06_01.edf    | Pre-Ictal  | 13915        | 13970
# chb06_01.edf    | Pre-Ictal  | 14175        | 14375
# chb06_02.edf    | Ictal      | 385          | 470
# chb06_02.edf    | Ictal      | 530          | 585
# chb06_02.edf    | Ictal      | 1015         | 1040
# chb06_02.edf    | Ictal      | 1385         | 1490
# chb06_02.edf    | Ictal      | 2260         | 2295
# chb06_02.edf    | Ictal      | 2660         | 2700
# chb06_02.edf    | Ictal      | 2750         | 2880
# chb06_02.edf    | Ictal      | 2975         | 3005
# chb06_02.edf    | Ictal      | 3030         | 3050
# chb06_02.edf    | Ictal      | 3140         | 3175
# chb06_02.edf    | Ictal      | 3355         | 3405
# chb06_02.edf    | Ictal      | 3485         | 3555
# chb06_02.edf    | Ictal      | 3935         | 3955
# chb06_02.edf    | Ictal      | 4000         | 4115
# chb06_02.edf    | Ictal      | 4200         | 4250
# chb06_02.edf    | Ictal      | 4370         | 4400
# chb06_02.edf    | Ictal      | 4500         | 4525
# chb06_02.edf    | Ictal      | 4650         | 4725
# chb06_02.edf    | Ictal      | 4830         | 4880
# chb06_02.edf    | Ictal      | 4935         | 4955
# chb06_02.edf    | Ictal      | 5010         | 5180
# chb06_02.edf    | Ictal      | 5230         | 5315
# chb06_02.edf    | Ictal      | 5455         | 5535
# chb06_02.edf    | Ictal      | 5785         | 5845
# chb06_02.edf    | Ictal      | 6160         | 6200
# chb06_02.edf    | Ictal      | 6290         | 6320
# chb06_02.edf    | Ictal      | 6390         | 6460
# chb06_02.edf    | Pre-Ictal  | 6575         | 6665
# chb06_02.edf    | Ictal      | 6800         | 6835
# chb06_02.edf    | Ictal      | 6885         | 7010
# chb06_02.edf    | Ictal      | 7155         | 7300
# chb06_02.edf    | Ictal      | 7490         | 7520
# chb06_02.edf    | Ictal      | 7540         | 7570
# chb06_02.edf    | Ictal      | 7700         | 7780
# chb06_02.edf    | Ictal      | 7900         | 7945
# chb06_02.edf    | Ictal      | 8010         | 8120
# chb06_02.edf    | Ictal      | 8155         | 8175
# chb06_02.edf    | Ictal      | 8205         | 8245
# chb06_02.edf    | Ictal      | 8370         | 8400
# chb06_02.edf    | Ictal      | 8620         | 8650
# chb06_02.edf    | Pre-Ictal  | 8665         | 8690
# chb06_02.edf    | Pre-Ictal  | 8810         | 14400
# chb06_03.edf    | Pre-Ictal  | 0            | 25
# chb06_03.edf    | Ictal      | 115          | 165
# chb06_03.edf    | Ictal      | 545          | 570
# chb06_03.edf    | Pre-Ictal  | 1765         | 1810
# chb06_03.edf    | Pre-Ictal  | 3040         | 3090
# chb06_03.edf    | Pre-Ictal  | 3855         | 3995
# chb06_03.edf    | Ictal      | 3995         | 4025
# chb06_03.edf    | Pre-Ictal  | 4025         | 4670
# chb06_03.edf    | Pre-Ictal  | 4730         | 4775
# chb06_03.edf    | Ictal      | 5065         | 5090
# chb06_03.edf    | Pre-Ictal  | 5090         | 5115
# chb06_03.edf    | Ictal      | 5435         | 5460
# chb06_03.edf    | Ictal      | 6105         | 6130
# chb06_03.edf    | Ictal      | 6430         | 6465
# chb06_03.edf    | Pre-Ictal  | 6720         | 6750
# chb06_03.edf    | Pre-Ictal  | 6815         | 6890
# chb06_03.edf    | Ictal      | 6920         | 6955
# chb06_03.edf    | Pre-Ictal  | 7025         | 7055
# chb06_03.edf    | Ictal      | 7170         | 7210
# chb06_03.edf    | Pre-Ictal  | 7290         | 7320
# chb06_03.edf    | Ictal      | 7320         | 7715
# chb06_03.edf    | Pre-Ictal  | 7715         | 7740
# chb06_03.edf    | Ictal      | 7740         | 7995
# chb06_03.edf    | Ictal      | 8040         | 8095
# chb06_03.edf    | Ictal      | 8125         | 8200
# chb06_03.edf    | Pre-Ictal  | 8215         | 8260
# chb06_03.edf    | Ictal      | 8355         | 8440
# chb06_03.edf    | Ictal      | 8470         | 8495
# chb06_03.edf    | Ictal      | 8535         | 8635
# chb06_03.edf    | Ictal      | 8865         | 8890
# chb06_03.edf    | Ictal      | 10010        | 10030
# chb06_03.edf    | Ictal      | 10425        | 10450
# chb06_03.edf    | Pre-Ictal  | 10720        | 10785
# chb06_03.edf    | Ictal      | 10785        | 10810
# chb06_03.edf    | Ictal      | 10895        | 10920
# chb06_03.edf    | Ictal      | 11345        | 11385
# chb06_03.edf    | Ictal      | 12085        | 12110
# chb06_03.edf    | Ictal      | 12530        | 12640
# chb06_03.edf    | Pre-Ictal  | 12670        | 12710
# chb06_03.edf    | Pre-Ictal  | 12850        | 12895
# chb06_03.edf    | Ictal      | 12895        | 12920
# chb06_03.edf    | Pre-Ictal  | 12995        | 13045
# chb06_03.edf    | Ictal      | 13045        | 13080
# chb06_03.edf    | Pre-Ictal  | 13080        | 13120
# chb06_03.edf    | Ictal      | 13120        | 13165
# chb06_03.edf    | Pre-Ictal  | 13165        | 13185
# chb06_03.edf    | Ictal      | 13185        | 13215
# chb06_03.edf    | Pre-Ictal  | 13215        | 13255
# chb06_03.edf    | Ictal      | 13255        | 13420
# chb06_03.edf    | Ictal      | 13450        | 13495
# chb06_03.edf    | Pre-Ictal  | 13505        | 13590
# chb06_03.edf    | Ictal      | 13590        | 13770
# chb06_03.edf    | Pre-Ictal  | 13840        | 13865
# chb06_03.edf    | Ictal      | 13865        | 13900
# chb06_03.edf    | Ictal      | 13940        | 13990
# chb06_03.edf    | Ictal      | 14200        | 14275
# chb06_04.edf    | Pre-Ictal  | 0            | 6430
# chb06_04.edf    | Ictal      | 6430         | 13260
# chb06_05.edf    | Ictal      | 0            | 5280
# chb06_05.edf    | Pre-Ictal  | 5285         | 5490
# chb06_05.edf    | Pre-Ictal  | 5560         | 5640
# chb06_05.edf    | Pre-Ictal  | 5670         | 6150
# chb06_05.edf    | Pre-Ictal  | 6240         | 8155
# chb06_05.edf    | Pre-Ictal  | 8205         | 14400
# chb06_06.edf    | Pre-Ictal  | 0            | 6580
# chb06_06.edf    | Ictal      | 6580         | 6610
# chb06_06.edf    | Pre-Ictal  | 6635         | 6685
# chb06_06.edf    | Ictal      | 6765         | 6795
# chb06_06.edf    | Ictal      | 6850         | 6915
# chb06_06.edf    | Ictal      | 6935         | 7000
# chb06_06.edf    | Ictal      | 7035         | 7080
# chb06_06.edf    | Ictal      | 7180         | 7250
# chb06_06.edf    | Ictal      | 7275         | 7295
# chb06_06.edf    | Ictal      | 7335         | 7390
# chb06_06.edf    | Ictal      | 7490         | 7695
# chb06_06.edf    | Ictal      | 7730         | 7890
# chb06_06.edf    | Ictal      | 7915         | 8300
# chb06_06.edf    | Ictal      | 8340         | 8420
# chb06_06.edf    | Ictal      | 8535         | 8565
# chb06_06.edf    | Ictal      | 8615         | 8635
# chb06_06.edf    | Ictal      | 8660         | 8905
# chb06_06.edf    | Ictal      | 8965         | 9465
# chb06_06.edf    | Ictal      | 9520         | 9650
# chb06_06.edf    | Ictal      | 9680         | 9955
# chb06_06.edf    | Ictal      | 9990         | 10275
# chb06_06.edf    | Ictal      | 10330        | 10460
# chb06_06.edf    | Ictal      | 10490        | 11080
# chb06_06.edf    | Ictal      | 11110        | 11200
# chb06_06.edf    | Ictal      | 11265        | 11380
# chb06_06.edf    | Ictal      | 11415        | 11435
# chb06_06.edf    | Ictal      | 11490        | 11785
# chb06_06.edf    | Ictal      | 11855        | 11880
# chb06_06.edf    | Ictal      | 11985        | 12125
# chb06_06.edf    | Ictal      | 12160        | 12215
# chb06_06.edf    | Ictal      | 12265        | 12365
# chb06_06.edf    | Ictal      | 12415        | 12470
# chb06_06.edf    | Ictal      | 12600        | 12660
# chb06_06.edf    | Ictal      | 12715        | 12745
# chb06_06.edf    | Ictal      | 12780        | 12800
# chb06_06.edf    | Ictal      | 12975        | 13110
# chb06_06.edf    | Ictal      | 13200        | 13275
# chb06_06.edf    | Ictal      | 13350        | 13435
# chb06_06.edf    | Ictal      | 13470        | 13565
# chb06_06.edf    | Ictal      | 13600        | 13635
# chb06_06.edf    | Ictal      | 13685        | 13775
# chb06_06.edf    | Ictal      | 13805        | 13955
# chb06_06.edf    | Ictal      | 13995        | 14140
# chb06_06.edf    | Ictal      | 14175        | 14350
# chb06_07.edf    | Ictal      | 0            | 85
# chb06_07.edf    | Ictal      | 110          | 140
# chb06_07.edf    | Ictal      | 175          | 235
# chb06_07.edf    | Ictal      | 280          | 320
# chb06_07.edf    | Ictal      | 380          | 440
# chb06_07.edf    | Ictal      | 465          | 495
# chb06_07.edf    | Ictal      | 510          | 545
# chb06_07.edf    | Ictal      | 575          | 595
# chb06_07.edf    | Ictal      | 720          | 775
# chb06_07.edf    | Ictal      | 885          | 920
# chb06_07.edf    | Ictal      | 945          | 1065
# chb06_07.edf    | Ictal      | 1130         | 1175
# chb06_07.edf    | Ictal      | 1230         | 1250
# chb06_07.edf    | Ictal      | 1295         | 1430
# chb06_07.edf    | Ictal      | 1490         | 1525
# chb06_07.edf    | Ictal      | 1645         | 1675
# chb06_07.edf    | Ictal      | 1705         | 1805
# chb06_07.edf    | Ictal      | 1840         | 1895
# chb06_07.edf    | Ictal      | 1925         | 2125
# chb06_07.edf    | Pre-Ictal  | 2205         | 5285
# chb06_07.edf    | Pre-Ictal  | 5325         | 5365
# chb06_07.edf    | Ictal      | 5365         | 5395
# chb06_07.edf    | Pre-Ictal  | 5425         | 5580
# chb06_07.edf    | Pre-Ictal  | 5750         | 5810
# chb06_07.edf    | Ictal      | 6090         | 6150
# chb06_07.edf    | Ictal      | 6230         | 6260
# chb06_07.edf    | Ictal      | 6355         | 6460
# chb06_07.edf    | Ictal      | 6645         | 6690
# chb06_07.edf    | Ictal      | 7010         | 7070
# chb06_07.edf    | Ictal      | 7175         | 7230
# chb06_07.edf    | Ictal      | 7395         | 7430
# chb06_07.edf    | Ictal      | 7600         | 7620
# chb06_07.edf    | Ictal      | 7680         | 7710
# chb06_07.edf    | Ictal      | 7850         | 7880
# chb06_07.edf    | Ictal      | 7975         | 8005
# chb06_07.edf    | Ictal      | 8050         | 8075
# chb06_07.edf    | Ictal      | 8110         | 8140
# chb06_07.edf    | Ictal      | 8330         | 8365
# chb06_07.edf    | Ictal      | 8465         | 8495
# chb06_07.edf    | Ictal      | 8595         | 8620
# chb06_07.edf    | Ictal      | 8890         | 8925
# chb06_07.edf    | Ictal      | 8960         | 8995
# chb06_07.edf    | Ictal      | 9085         | 9115
# chb06_07.edf    | Ictal      | 9405         | 9430
# chb06_07.edf    | Pre-Ictal  | 9740         | 9790
# chb06_07.edf    | Ictal      | 10080        | 10105
# chb06_07.edf    | Ictal      | 10265        | 10290
# chb06_07.edf    | Ictal      | 10365        | 10420
# chb06_07.edf    | Ictal      | 10495        | 10535
# chb06_07.edf    | Pre-Ictal  | 10660        | 10690
# chb06_07.edf    | Ictal      | 10950        | 10980
# chb06_07.edf    | Ictal      | 11595        | 11640
# chb06_07.edf    | Ictal      | 11705        | 11740
# chb06_07.edf    | Pre-Ictal  | 11900        | 11950
# chb06_07.edf    | Ictal      | 11965        | 11995
# chb06_07.edf    | Ictal      | 12175        | 12200
# chb06_07.edf    | Ictal      | 12235        | 12315
# chb06_07.edf    | Ictal      | 12955        | 12985
# chb06_07.edf    | Ictal      | 13505        | 13530
# chb06_07.edf    | Ictal      | 13680        | 13735
# chb06_07.edf    | Ictal      | 13765        | 13795
# chb06_07.edf    | Ictal      | 13995        | 14110
# chb06_07.edf    | Ictal      | 14145        | 14180
# chb06_07.edf    | Ictal      | 14330        | 14350
# chb06_08.edf    | Ictal      | 0            | 395
# chb06_08.edf    | Ictal      | 415          | 680
# chb06_08.edf    | Ictal      | 740          | 1225
# chb06_08.edf    | Ictal      | 1265         | 1320
# chb06_08.edf    | Ictal      | 1370         | 1530
# chb06_08.edf    | Ictal      | 1605         | 1790
# chb06_08.edf    | Ictal      | 1845         | 1875
# chb06_08.edf    | Ictal      | 1940         | 2690
# chb06_08.edf    | Ictal      | 2730         | 3400
# chb06_08.edf    | Ictal      | 3470         | 3780
# chb06_08.edf    | Ictal      | 4010         | 4305
# chb06_08.edf    | Ictal      | 4350         | 4420
# chb06_08.edf    | Ictal      | 4470         | 4485
# chb06_08.edf    | Ictal      | 4565         | 4645
# chb06_08.edf    | Ictal      | 4675         | 4710
# chb06_08.edf    | Ictal      | 4805         | 4830
# chb06_08.edf    | Ictal      | 4875         | 4910
# chb06_08.edf    | Ictal      | 4975         | 5005
# chb06_08.edf    | Ictal      | 5125         | 5165
# chb06_08.edf    | Pre-Ictal  | 5460         | 6435
# chb06_08.edf    | Ictal      | 6435         | 6465
# chb06_08.edf    | Pre-Ictal  | 6465         | 13990
# chb06_08.edf    | Ictal      | 13990        | 14015
# chb06_08.edf    | Pre-Ictal  | 14015        | 14400
# chb06_09.edf    | Pre-Ictal  | 0            | 615
# chb06_09.edf    | Pre-Ictal  | 705          | 765
# chb06_09.edf    | Pre-Ictal  | 795          | 870
# chb06_09.edf    | Pre-Ictal  | 975          | 1420
# chb06_09.edf    | Pre-Ictal  | 1465         | 1790
# chb06_09.edf    | Ictal      | 1790         | 1815
# chb06_09.edf    | Pre-Ictal  | 1875         | 2315
# chb06_09.edf    | Pre-Ictal  | 2345         | 2795
# chb06_09.edf    | Ictal      | 2795         | 2820
# chb06_09.edf    | Pre-Ictal  | 2820         | 4145
# chb06_09.edf    | Pre-Ictal  | 4245         | 4390
# chb06_09.edf    | Pre-Ictal  | 4435         | 4585
# chb06_09.edf    | Pre-Ictal  | 4660         | 4715
# chb06_09.edf    | Pre-Ictal  | 4850         | 4935
# chb06_09.edf    | Pre-Ictal  | 5075         | 5150
# chb06_09.edf    | Pre-Ictal  | 5200         | 6710
# chb06_09.edf    | Ictal      | 6710         | 6735
# chb06_09.edf    | Pre-Ictal  | 6735         | 7745
# chb06_09.edf    | Pre-Ictal  | 7930         | 8090
# chb06_09.edf    | Ictal      | 8090         | 8210
# chb06_09.edf    | Pre-Ictal  | 8220         | 8315
# chb06_09.edf    | Ictal      | 8335         | 8365
# chb06_09.edf    | Ictal      | 8485         | 8690
# chb06_09.edf    | Ictal      | 8785         | 9245
# chb06_09.edf    | Pre-Ictal  | 9325         | 9405
# chb06_09.edf    | Ictal      | 10110        | 10250
# chb06_09.edf    | Ictal      | 10305        | 10355
# chb06_09.edf    | Ictal      | 10395        | 10605
# chb06_09.edf    | Pre-Ictal  | 10680        | 10740
# chb06_09.edf    | Ictal      | 10740        | 12345
# chb06_09.edf    | Ictal      | 12380        | 12640
# chb06_09.edf    | Ictal      | 12860        | 12890
# chb06_09.edf    | Ictal      | 13075        | 13100
# chb06_09.edf    | Pre-Ictal  | 13640        | 14400
# chb06_10.edf    | Pre-Ictal  | 0            | 7155
# chb06_10.edf    | Pre-Ictal  | 7190         | 10585
# chb06_10.edf    | Pre-Ictal  | 10920        | 12380
# chb06_10.edf    | Ictal      | 12380        | 14400
# chb06_12.edf    | Pre-Ictal  | 70           | 275
# chb06_12.edf    | Pre-Ictal  | 330          | 850
# chb06_12.edf    | Ictal      | 960          | 970
# chb06_12.edf    | Pre-Ictal  | 970          | 1005
# chb06_12.edf    | Ictal      | 1160         | 1195
# chb06_12.edf    | Ictal      | 1810         | 1825
# chb06_12.edf    | Ictal      | 1945         | 1965
# chb06_12.edf    | Ictal      | 2075         | 2130
# chb06_12.edf    | Ictal      | 2295         | 2305
# chb06_12.edf    | Pre-Ictal  | 2305         | 2335
# chb06_12.edf    | Pre-Ictal  | 2405         | 2455
# chb06_12.edf    | Pre-Ictal  | 2485         | 2520
# chb06_12.edf    | Ictal      | 2645         | 2670
# chb06_12.edf    | Pre-Ictal  | 2670         | 2780
# chb06_12.edf    | Ictal      | 2855         | 2875
# chb06_12.edf    | Pre-Ictal  | 2885         | 2945
# chb06_12.edf    | Ictal      | 2945         | 2965
# chb06_12.edf    | Ictal      | 2985         | 3025
# chb06_12.edf    | Ictal      | 3065         | 3080
# chb06_12.edf    | Pre-Ictal  | 3080         | 3225
# chb06_12.edf    | Ictal      | 3240         | 3265
# chb06_12.edf    | Ictal      | 3395         | 3455
# chb06_12.edf    | Ictal      | 3630         | 3660
# chb06_12.edf    | Pre-Ictal  | 3680         | 3730
# chb06_12.edf    | Pre-Ictal  | 3855         | 4025
# chb06_12.edf    | Pre-Ictal  | 4225         | 4315
# chb06_12.edf    | Ictal      | 4315         | 4340
# chb06_12.edf    | Pre-Ictal  | 4495         | 4530
# chb06_12.edf    | Ictal      | 4530         | 4560
# chb06_12.edf    | Pre-Ictal  | 4560         | 4655
# chb06_12.edf    | Ictal      | 4655         | 4695
# chb06_12.edf    | Ictal      | 4875         | 4915
# chb06_12.edf    | Pre-Ictal  | 4955         | 5080
# chb06_12.edf    | Ictal      | 5080         | 5090
# chb06_12.edf    | Pre-Ictal  | 5230         | 5295
# chb06_12.edf    | Ictal      | 5295         | 5310
# chb06_12.edf    | Ictal      | 5365         | 5390
# chb06_12.edf    | Pre-Ictal  | 5400         | 5455
# chb06_12.edf    | Ictal      | 5455         | 5485
# chb06_12.edf    | Pre-Ictal  | 5615         | 5665
# chb06_12.edf    | Ictal      | 5730         | 5765
# chb06_12.edf    | Pre-Ictal  | 5780         | 6005
# chb06_12.edf    | Pre-Ictal  | 6040         | 6235
# chb06_12.edf    | Ictal      | 6290         | 6315
# chb06_12.edf    | Pre-Ictal  | 6395         | 6420
# chb06_12.edf    | Ictal      | 6515         | 6560
# chb06_12.edf    | Pre-Ictal  | 6670         | 6830
# chb06_12.edf    | Ictal      | 6830         | 6850
# chb06_12.edf    | Pre-Ictal  | 6885         | 6945
# chb06_12.edf    | Ictal      | 6945         | 6965
# chb06_12.edf    | Pre-Ictal  | 7095         | 7175
# chb06_12.edf    | Pre-Ictal  | 7210         | 7435
# chb06_12.edf    | Ictal      | 7435         | 7470
# chb06_12.edf    | Pre-Ictal  | 7500         | 7540
# chb06_12.edf    | Pre-Ictal  | 7620         | 7825
# chb06_12.edf    | Pre-Ictal  | 7955         | 7990
# chb06_12.edf    | Ictal      | 7990         | 8010
# chb06_12.edf    | Pre-Ictal  | 8045         | 8170
# chb06_12.edf    | Ictal      | 8170         | 8200
# chb06_12.edf    | Ictal      | 8305         | 8330
# chb06_12.edf    | Pre-Ictal  | 8345         | 8375
# chb06_12.edf    | Ictal      | 8390         | 8415
# chb06_12.edf    | Ictal      | 8460         | 8490
# chb06_12.edf    | Pre-Ictal  | 8725         | 8865
# chb06_12.edf    | Ictal      | 8865         | 8885
# chb06_12.edf    | Pre-Ictal  | 8885         | 8955
# chb06_12.edf    | Pre-Ictal  | 8995         | 9045
# chb06_12.edf    | Pre-Ictal  | 9100         | 9215
# chb06_12.edf    | Pre-Ictal  | 9265         | 9380
# chb06_12.edf    | Ictal      | 9405         | 9440
# chb06_12.edf    | Pre-Ictal  | 9440         | 9480
# chb06_12.edf    | Pre-Ictal  | 9510         | 9540
# chb06_12.edf    | Ictal      | 9560         | 9580
# chb06_12.edf    | Ictal      | 9830         | 9855
# chb06_12.edf    | Pre-Ictal  | 10060        | 10195
# chb06_12.edf    | Ictal      | 10485        | 10510
# chb06_12.edf    | Pre-Ictal  | 10520        | 10575
# chb06_12.edf    | Ictal      | 10645        | 10665
# chb06_12.edf    | Pre-Ictal  | 10700        | 10755
# chb06_12.edf    | Pre-Ictal  | 10785        | 10825
# chb06_12.edf    | Ictal      | 10985        | 10995
# chb06_12.edf    | Pre-Ictal  | 11115        | 11170
# chb06_12.edf    | Ictal      | 11170        | 11285
# chb06_12.edf    | Ictal      | 11325        | 11355
# chb06_12.edf    | Ictal      | 11475        | 11510
# chb06_12.edf    | Ictal      | 11630        | 11735
# chb06_12.edf    | Ictal      | 11825        | 11880
# chb06_12.edf    | Ictal      | 11970        | 12000
# chb06_12.edf    | Ictal      | 12035        | 12060
# chb06_12.edf    | Ictal      | 12090        | 12115
# chb06_12.edf    | Ictal      | 12280        | 12400
# chb06_12.edf    | Ictal      | 12470        | 12510
# chb06_12.edf    | Ictal      | 12735        | 12760
# chb06_12.edf    | Ictal      | 12795        | 12825
# chb06_12.edf    | Ictal      | 13210        | 13230
# chb06_12.edf    | Ictal      | 13385        | 13500
# chb06_12.edf    | Ictal      | 13545        | 13560
# chb06_12.edf    | Pre-Ictal  | 13615        | 13660
# chb06_12.edf    | Ictal      | 13685        | 13705
# chb06_12.edf    | Ictal      | 13970        | 13995
# chb06_12.edf    | Ictal      | 14015        | 14045
# chb06_12.edf    | Ictal      | 14125        | 14150
# chb06_12.edf    | Ictal      | 14330        | 14360
# chb06_13.edf    | Ictal      | 140          | 170
# chb06_13.edf    | Pre-Ictal  | 250          | 350
# chb06_13.edf    | Pre-Ictal  | 535          | 720
# chb06_13.edf    | Pre-Ictal  | 745          | 935
# chb06_13.edf    | Ictal      | 945          | 965
# chb06_13.edf    | Pre-Ictal  | 1125         | 1170
# chb06_13.edf    | Pre-Ictal  | 1220         | 1410
# chb06_13.edf    | Pre-Ictal  | 1590         | 1965
# chb06_13.edf    | Pre-Ictal  | 2010         | 2170
# chb06_13.edf    | Pre-Ictal  | 2770         | 2850
# chb06_13.edf    | Pre-Ictal  | 2900         | 2945
# chb06_13.edf    | Pre-Ictal  | 3120         | 3165
# chb06_13.edf    | Ictal      | 3195         | 3210
# chb06_13.edf    | Pre-Ictal  | 3305         | 3330
# chb06_13.edf    | Pre-Ictal  | 3580         | 3610
# chb06_13.edf    | Pre-Ictal  | 3665         | 3690
# chb06_13.edf    | Pre-Ictal  | 3730         | 3755
# chb06_13.edf    | Pre-Ictal  | 4335         | 4390
# chb06_13.edf    | Pre-Ictal  | 4415         | 4470
# chb06_13.edf    | Ictal      | 4500         | 4520
# chb06_13.edf    | Pre-Ictal  | 4615         | 4695
# chb06_13.edf    | Ictal      | 4890         | 4925
# chb06_13.edf    | Ictal      | 4945         | 5075
# chb06_13.edf    | Ictal      | 5165         | 5205
# chb06_13.edf    | Pre-Ictal  | 5215         | 5300
# chb06_13.edf    | Ictal      | 5385         | 5410
# chb06_13.edf    | Pre-Ictal  | 5580         | 5625
# chb06_13.edf    | Pre-Ictal  | 5715         | 5830
# chb06_13.edf    | Ictal      | 5985         | 6010
# chb06_13.edf    | Pre-Ictal  | 6105         | 6140
# chb06_13.edf    | Pre-Ictal  | 6165         | 6210
# chb06_13.edf    | Pre-Ictal  | 6265         | 6300
# chb06_13.edf    | Ictal      | 6360         | 6380
# chb06_13.edf    | Pre-Ictal  | 6455         | 6485
# chb06_13.edf    | Pre-Ictal  | 6825         | 6840
# chb06_13.edf    | Ictal      | 6840         | 6870
# chb06_13.edf    | Pre-Ictal  | 6885         | 6925
# chb06_13.edf    | Pre-Ictal  | 7015         | 7045
# chb06_13.edf    | Ictal      | 7415         | 7440
# chb06_13.edf    | Pre-Ictal  | 7615         | 7745
# chb06_13.edf    | Ictal      | 7960         | 7995
# chb06_13.edf    | Ictal      | 8110         | 8125
# chb06_13.edf    | Ictal      | 8245         | 8280
# chb06_13.edf    | Ictal      | 8350         | 8380
# chb06_13.edf    | Pre-Ictal  | 8470         | 8545
# chb06_13.edf    | Pre-Ictal  | 8670         | 8700
# chb06_13.edf    | Ictal      | 8760         | 8780
# chb06_13.edf    | Pre-Ictal  | 8805         | 8880
# chb06_13.edf    | Ictal      | 8915         | 8935
# chb06_13.edf    | Ictal      | 9085         | 9105
# chb06_13.edf    | Ictal      | 9150         | 9230
# chb06_13.edf    | Ictal      | 9360         | 9465
# chb06_13.edf    | Pre-Ictal  | 9555         | 9590
# chb06_13.edf    | Ictal      | 9620         | 9650
# chb06_13.edf    | Pre-Ictal  | 9675         | 9820
# chb06_13.edf    | Ictal      | 9945         | 10020
# chb06_13.edf    | Ictal      | 10140        | 10215
# chb06_13.edf    | Ictal      | 10240        | 10270
# chb06_13.edf    | Pre-Ictal  | 10270        | 10355
# chb06_13.edf    | Ictal      | 10485        | 10540
# chb06_13.edf    | Ictal      | 10715        | 10735
# chb06_13.edf    | Ictal      | 10830        | 10855
# chb06_13.edf    | Pre-Ictal  | 10950        | 11005
# chb06_13.edf    | Ictal      | 11025        | 11060
# chb06_13.edf    | Ictal      | 11200        | 11245
# chb06_13.edf    | Ictal      | 11325        | 11360
# chb06_13.edf    | Ictal      | 11380        | 11405
# chb06_13.edf    | Ictal      | 11550        | 11575
# chb06_13.edf    | Ictal      | 11830        | 11845
# chb06_13.edf    | Ictal      | 11945        | 11960
# chb06_13.edf    | Pre-Ictal  | 12105        | 12130
# chb06_13.edf    | Pre-Ictal  | 12205        | 12230
# chb06_13.edf    | Ictal      | 12335        | 12380
# chb06_13.edf    | Pre-Ictal  | 12525        | 12565
# chb06_13.edf    | Ictal      | 12670        | 12710
# chb06_13.edf    | Ictal      | 12735        | 12765
# chb06_13.edf    | Ictal      | 12800        | 12880
# chb06_13.edf    | Ictal      | 12920        | 13025
# chb06_13.edf    | Pre-Ictal  | 13080        | 13180
# chb06_13.edf    | Pre-Ictal  | 13255        | 13325
# chb06_13.edf    | Pre-Ictal  | 13375        | 13405
# chb06_13.edf    | Ictal      | 13490        | 13520
# chb06_13.edf    | Pre-Ictal  | 13615        | 13800
# chb06_13.edf    | Ictal      | 13835        | 13885
# chb06_13.edf    | Ictal      | 13970        | 13985
# chb06_13.edf    | Ictal      | 14070        | 14100
# chb06_13.edf    | Ictal      | 14145        | 14185
# chb06_13.edf    | Pre-Ictal  | 14245        | 14290
# chb06_13.edf    | Pre-Ictal  | 14355        | 14380
# chb06_13.edf    | Ictal      | 14380        | 14400
# chb06_14.edf    | Ictal      | 20           | 40
# chb06_14.edf    | Ictal      | 775          | 795
# chb06_14.edf    | Ictal      | 1790         | 1815
# chb06_14.edf    | Ictal      | 2350         | 2375
# chb06_14.edf    | Ictal      | 2490         | 2540
# chb06_14.edf    | Ictal      | 2565         | 2585
# chb06_14.edf    | Ictal      | 2790         | 2815
# chb06_14.edf    | Ictal      | 3125         | 3145
# chb06_14.edf    | Ictal      | 3270         | 3285
# chb06_14.edf    | Ictal      | 3365         | 3470
# chb06_14.edf    | Ictal      | 3635         | 3655
# chb06_14.edf    | Ictal      | 3755         | 3770
# chb06_14.edf    | Ictal      | 3905         | 3940
# chb06_14.edf    | Ictal      | 4030         | 4095
# chb06_14.edf    | Ictal      | 4355         | 4440
# chb06_14.edf    | Ictal      | 4485         | 4510
# chb06_14.edf    | Ictal      | 4860         | 4920
# chb06_14.edf    | Ictal      | 4980         | 5005
# chb06_14.edf    | Ictal      | 5035         | 5065
# chb06_14.edf    | Ictal      | 5315         | 5345
# chb06_14.edf    | Ictal      | 5525         | 5575
# chb06_14.edf    | Ictal      | 5785         | 5810
# chb06_14.edf    | Ictal      | 6200         | 6230
# chb06_14.edf    | Ictal      | 6345         | 6360
# chb06_14.edf    | Ictal      | 6590         | 6615
# chb06_14.edf    | Ictal      | 6750         | 6815
# chb06_14.edf    | Ictal      | 7100         | 7170
# chb06_14.edf    | Ictal      | 7190         | 7235
# chb06_14.edf    | Ictal      | 7260         | 7665
# chb06_14.edf    | Ictal      | 7720         | 7735
# chb06_14.edf    | Ictal      | 7920         | 7965
# chb06_14.edf    | Ictal      | 8035         | 8205
# chb06_14.edf    | Ictal      | 8355         | 8390
# chb06_14.edf    | Ictal      | 8530         | 8575
# chb06_14.edf    | Ictal      | 8640         | 8675
# chb06_14.edf    | Ictal      | 8785         | 8820
# chb06_14.edf    | Ictal      | 8880         | 9225
# chb06_14.edf    | Ictal      | 9315         | 9575
# chb06_14.edf    | Ictal      | 9755         | 9785
# chb06_14.edf    | Ictal      | 9815         | 9835
# chb06_14.edf    | Ictal      | 9935         | 9995
# chb06_14.edf    | Pre-Ictal  | 10125        | 10160
# chb06_14.edf    | Ictal      | 10160        | 10195
# chb06_14.edf    | Pre-Ictal  | 10255        | 10315
# chb06_14.edf    | Ictal      | 10330        | 10345
# chb06_14.edf    | Pre-Ictal  | 10405        | 10440
# chb06_14.edf    | Pre-Ictal  | 10580        | 10660
# chb06_14.edf    | Ictal      | 10660        | 10690
# chb06_14.edf    | Pre-Ictal  | 10690        | 10720
# chb06_14.edf    | Ictal      | 10720        | 10750
# chb06_14.edf    | Pre-Ictal  | 10750        | 13375
# chb06_14.edf    | Ictal      | 13375        | 13395
# chb06_14.edf    | Pre-Ictal  | 13395        | 14400
# chb06_15.edf    | Ictal      | 0            | 60
# chb06_15.edf    | Pre-Ictal  | 100          | 130
# chb06_15.edf    | Ictal      | 475          | 525
# chb06_15.edf    | Ictal      | 1010         | 1040
# chb06_15.edf    | Pre-Ictal  | 2505         | 2545
# chb06_15.edf    | Pre-Ictal  | 2975         | 3035
# chb06_15.edf    | Pre-Ictal  | 3445         | 3605
# chb06_15.edf    | Ictal      | 3605         | 3630
# chb06_15.edf    | Pre-Ictal  | 3630         | 4020
# chb06_15.edf    | Ictal      | 4075         | 4115
# chb06_15.edf    | Pre-Ictal  | 4140         | 4245
# chb06_15.edf    | Ictal      | 4245         | 4350
# chb06_15.edf    | Pre-Ictal  | 4590         | 4635
# chb06_15.edf    | Ictal      | 4720         | 4740
# chb06_15.edf    | Ictal      | 4805         | 4880
# chb06_15.edf    | Ictal      | 6795         | 6825
# chb06_15.edf    | Pre-Ictal  | 7950         | 8215
# chb06_15.edf    | Ictal      | 8215         | 8295
# chb06_15.edf    | Pre-Ictal  | 8295         | 8350
# chb06_15.edf    | Ictal      | 8350         | 8425
# chb06_15.edf    | Pre-Ictal  | 8425         | 8455
# chb06_15.edf    | Ictal      | 8455         | 8650
# chb06_15.edf    | Ictal      | 8675         | 8715
# chb06_15.edf    | Pre-Ictal  | 8715         | 8750
# chb06_15.edf    | Ictal      | 8750         | 8860
# chb06_15.edf    | Pre-Ictal  | 8880         | 8920
# chb06_15.edf    | Ictal      | 8920         | 9185
# chb06_15.edf    | Pre-Ictal  | 9185         | 9235
# chb06_15.edf    | Ictal      | 9235         | 9480
# chb06_15.edf    | Ictal      | 9520         | 9550
# chb06_15.edf    | Ictal      | 9715         | 9740
# chb06_15.edf    | Ictal      | 9765         | 9795
# chb06_15.edf    | Ictal      | 9915         | 9950
# chb06_15.edf    | Ictal      | 10185        | 10255
# chb06_15.edf    | Ictal      | 10300        | 10325
# chb06_15.edf    | Pre-Ictal  | 12405        | 12440
# chb06_15.edf    | Ictal      | 12635        | 12685
# chb06_15.edf    | Pre-Ictal  | 12700        | 12750
# chb06_15.edf    | Pre-Ictal  | 13205        | 13235
# chb06_15.edf    | Ictal      | 13460        | 13495
# chb06_15.edf    | Pre-Ictal  | 13510        | 13580
# chb06_15.edf    | Ictal      | 13580        | 13670
# chb06_15.edf    | Pre-Ictal  | 13670        | 13720
# chb06_15.edf    | Ictal      | 13720        | 13785
# chb06_15.edf    | Pre-Ictal  | 13785        | 13815
# chb06_15.edf    | Ictal      | 13815        | 13925
# chb06_15.edf    | Pre-Ictal  | 13925        | 13955
# chb06_15.edf    | Ictal      | 13955        | 14135
# chb06_15.edf    | Pre-Ictal  | 14165        | 14375
# chb06_15.edf    | Ictal      | 14375        | 14400
# chb06_16.edf    | Ictal      | 0            | 10
# chb06_16.edf    | Pre-Ictal  | 10           | 45
# chb06_16.edf    | Pre-Ictal  | 110          | 150
# chb06_16.edf    | Ictal      | 155          | 250
# chb06_16.edf    | Ictal      | 1345         | 1440
# chb06_16.edf    | Pre-Ictal  | 2040         | 2145
# chb06_16.edf    | Ictal      | 2145         | 2525
# chb06_16.edf    | Pre-Ictal  | 2525         | 2690
# chb06_16.edf    | Ictal      | 2690         | 2715
# chb06_16.edf    | Pre-Ictal  | 2715         | 2750
# chb06_16.edf    | Ictal      | 2750         | 2800
# chb06_16.edf    | Pre-Ictal  | 2800         | 2905
# chb06_16.edf    | Ictal      | 2930         | 2960
# chb06_16.edf    | Ictal      | 2985         | 3030
# chb06_17.edf    | Pre-Ictal  | 0            | 6335
# chb06_17.edf    | Ictal      | 6345         | 6370
# chb06_17.edf    | Ictal      | 6530         | 6565
# chb06_17.edf    | Ictal      | 6655         | 6790
# chb06_17.edf    | Ictal      | 6825         | 6905
# chb06_17.edf    | Ictal      | 6935         | 7105
# chb06_17.edf    | Ictal      | 7130         | 7245
# chb06_17.edf    | Ictal      | 7280         | 7295
# chb06_17.edf    | Ictal      | 7355         | 7430
# chb06_17.edf    | Ictal      | 7555         | 7610
# chb06_17.edf    | Ictal      | 7650         | 7665
# chb06_17.edf    | Ictal      | 7695         | 7785
# chb06_17.edf    | Ictal      | 7860         | 7935
# chb06_17.edf    | Ictal      | 7990         | 8055
# chb06_17.edf    | Ictal      | 8180         | 8250
# chb06_17.edf    | Ictal      | 8310         | 8335
# chb06_17.edf    | Ictal      | 8390         | 8590
# chb06_17.edf    | Ictal      | 8695         | 8725
# chb06_17.edf    | Ictal      | 8745         | 8785
# chb06_17.edf    | Ictal      | 8835         | 9035
# chb06_17.edf    | Ictal      | 9110         | 9140
# chb06_17.edf    | Ictal      | 9235         | 9270
# chb06_17.edf    | Ictal      | 9300         | 9355
# chb06_17.edf    | Ictal      | 9385         | 9405
# chb06_17.edf    | Ictal      | 9460         | 9490
# chb06_17.edf    | Ictal      | 9515         | 9605
# chb06_17.edf    | Ictal      | 9635         | 9665
# chb06_17.edf    | Ictal      | 9740         | 9875
# chb06_17.edf    | Ictal      | 9905         | 10025
# chb06_17.edf    | Ictal      | 10095        | 10340
# chb06_17.edf    | Ictal      | 10425        | 10680
# chb06_17.edf    | Ictal      | 10740        | 10840
# chb06_17.edf    | Ictal      | 10875        | 10910
# chb06_17.edf    | Ictal      | 10955        | 10975
# chb06_17.edf    | Ictal      | 11085        | 11180
# chb06_17.edf    | Ictal      | 11345        | 11400
# chb06_17.edf    | Ictal      | 11525        | 11575
# chb06_17.edf    | Ictal      | 11600        | 11615
# chb06_17.edf    | Ictal      | 11730        | 11745
# chb06_17.edf    | Ictal      | 11890        | 11930
# chb06_17.edf    | Ictal      | 11955        | 11980
# chb06_17.edf    | Ictal      | 12185        | 12260
# chb06_17.edf    | Ictal      | 12345        | 12485
# chb06_17.edf    | Ictal      | 12560        | 12615
# chb06_17.edf    | Ictal      | 12635        | 12750
# chb06_17.edf    | Ictal      | 12815        | 13020
# chb06_17.edf    | Ictal      | 13050        | 13130
# chb06_17.edf    | Ictal      | 13255        | 13390
# chb06_17.edf    | Ictal      | 13420        | 13620
# chb06_17.edf    | Ictal      | 13680        | 13695
# chb06_17.edf    | Ictal      | 13870        | 13945
# chb06_17.edf    | Ictal      | 14155        | 14190
# chb06_17.edf    | Ictal      | 14220        | 14245
# chb06_17.edf    | Ictal      | 14280        | 14300
# chb06_17.edf    | Ictal      | 14325        | 14370
# chb06_18.edf    | Ictal      | 0            | 35
# chb06_18.edf    | Pre-Ictal  | 35           | 85
# chb06_18.edf    | Ictal      | 115          | 165
# chb06_18.edf    | Ictal      | 180          | 210
# chb06_18.edf    | Ictal      | 250          | 275
# chb06_18.edf    | Ictal      | 290          | 320
# chb06_18.edf    | Pre-Ictal  | 430          | 460
# chb06_18.edf    | Pre-Ictal  | 495          | 530
# chb06_18.edf    | Ictal      | 530          | 555
# chb06_18.edf    | Ictal      | 595          | 620
# chb06_18.edf    | Pre-Ictal  | 635          | 710
# chb06_18.edf    | Ictal      | 710          | 725
# chb06_18.edf    | Ictal      | 740          | 770
# chb06_18.edf    | Ictal      | 805          | 835
# chb06_18.edf    | Ictal      | 910          | 925
# chb06_18.edf    | Ictal      | 960          | 980
# chb06_18.edf    | Pre-Ictal  | 1025         | 1165
# chb06_18.edf    | Ictal      | 1165         | 1190
# chb06_18.edf    | Pre-Ictal  | 1190         | 1455
# chb06_18.edf    | Pre-Ictal  | 1495         | 1620
# chb06_18.edf    | Pre-Ictal  | 1720         | 1795
# chb06_18.edf    | Ictal      | 1835         | 1885
# chb06_18.edf    | Pre-Ictal  | 1925         | 2005
# chb06_18.edf    | Ictal      | 2005         | 2030
# chb06_18.edf    | Ictal      | 2100         | 2150
# chb06_18.edf    | Pre-Ictal  | 2275         | 2355
# chb06_18.edf    | Ictal      | 2385         | 2410
# chb06_18.edf    | Pre-Ictal  | 2430         | 2470
# chb06_18.edf    | Pre-Ictal  | 2550         | 2585
# chb06_18.edf    | Pre-Ictal  | 2615         | 2685
# chb06_18.edf    | Ictal      | 2800         | 2835
# chb06_18.edf    | Pre-Ictal  | 2870         | 2945
# chb06_18.edf    | Pre-Ictal  | 2970         | 3005
# chb06_18.edf    | Ictal      | 3005         | 3040
# chb06_18.edf    | Ictal      | 3160         | 3175
# chb06_18.edf    | Pre-Ictal  | 3175         | 3210
# chb06_18.edf    | Ictal      | 3370         | 3390
# chb06_18.edf    | Ictal      | 3515         | 3550
# chb06_18.edf    | Ictal      | 4005         | 4030
# chb06_18.edf    | Pre-Ictal  | 4030         | 4155
# chb06_18.edf    | Ictal      | 4185         | 4230
# chb06_18.edf    | Ictal      | 4260         | 4305
# chb06_18.edf    | Ictal      | 4340         | 4365
# chb06_18.edf    | Pre-Ictal  | 4435         | 4540
# chb06_18.edf    | Pre-Ictal  | 4585         | 4675
# chb06_18.edf    | Pre-Ictal  | 4720         | 4760
# chb06_18.edf    | Pre-Ictal  | 4980         | 5050
# chb06_18.edf    | Pre-Ictal  | 5180         | 5275
# chb06_18.edf    | Ictal      | 5275         | 5320
# chb06_18.edf    | Pre-Ictal  | 5320         | 5350
# chb06_18.edf    | Pre-Ictal  | 5555         | 5600
# chb06_18.edf    | Pre-Ictal  | 5640         | 5680
# chb06_18.edf    | Pre-Ictal  | 5905         | 5925
# chb06_18.edf    | Ictal      | 6055         | 6075
# chb06_18.edf    | Pre-Ictal  | 6140         | 6205
# chb06_18.edf    | Pre-Ictal  | 6275         | 6320
# chb06_18.edf    | Pre-Ictal  | 6350         | 6425
# chb06_18.edf    | Ictal      | 6445         | 6475
# chb06_18.edf    | Pre-Ictal  | 6495         | 6525
# chb06_18.edf    | Ictal      | 6560         | 6605
# chb06_18.edf    | Ictal      | 6665         | 6685
# chb06_18.edf    | Ictal      | 6770         | 6805
# chb06_18.edf    | Ictal      | 7030         | 7055
# chb06_18.edf    | Ictal      | 7115         | 7145
# chb06_18.edf    | Ictal      | 7175         | 7195
# chb06_18.edf    | Ictal      | 7635         | 7700
# chb06_18.edf    | Ictal      | 7775         | 7800
# chb06_18.edf    | Pre-Ictal  | 7880         | 7925
# chb06_24.edf    | Pre-Ictal  | 0            | 1145
# chb06_24.edf    | Ictal      | 1145         | 1280
# chb06_24.edf    | Pre-Ictal  | 1310         | 6440
# chb06_24.edf    | Ictal      | 6440         | 6475
# chb06_24.edf    | Ictal      | 6510         | 9400
# chb06_24.edf    | Pre-Ictal  | 9480         | 9530
# chb06_24.edf    | Ictal      | 10635        | 10685
# chb06_24.edf    | Ictal      | 12105        | 12135
# chb06_24.edf    | Ictal      | 12190        | 12205
# chb06_24.edf    | Ictal      | 12490        | 12555
# chb06_24.edf    | Ictal      | 12620        | 12750
# chb06_24.edf    | Ictal      | 12790        | 12915
# chb06_24.edf    | Ictal      | 12950        | 12995
# chb06_24.edf    | Ictal      | 13265        | 13325
# chb06_24.edf    | Ictal      | 13395        | 13425
# chb06_24.edf    | Ictal      | 13490        | 13550
# chb06_24.edf    | Ictal      | 13630        | 13690
# chb06_24.edf    | Ictal      | 13730        | 13805
# chb06_24.edf    | Ictal      | 13925        | 13965
# chb06_24.edf    | Ictal      | 14155        | 14190
# chb06_24.edf    | Ictal      | 14255        | 14330

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb06_09.edf": [(12500, 12516)],
    "chb06_10.edf": [(10833, 10845)],
    "chb06_13.edf": [(506, 519)],
    "chb06_18.edf": [(7799, 7811)],
    "chb06_24.edf": [(9387, 9403)]
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()
