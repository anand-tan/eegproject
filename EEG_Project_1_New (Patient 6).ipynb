# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch, hilbert, butter, filtfilt
from antropy import perm_entropy

# --- Pre-define PAC Filters ---
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Filter coefficients for 256 Hz sampling rate
b_theta, a_theta = butter_bandpass(4.0, 8.0, 256)
b_gamma, a_gamma = butter_bandpass(30.0, 40.0, 256)

def get_regional_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    
    # Isolate Hemispheres based on standard bipolar pairs
    # Left: FP1-F7, F7-T7, T7-P7, P7-O1, FP1-F3, F3-C3, C3-P3, P3-O1
    LEFT_CH = [0, 1, 2, 3, 4, 5, 6, 7]
    # Right: FP2-F4, F4-C4, C4-P4, P4-O2, FP2-F8, F8-T8, T8-P8, P8-O2
    RIGHT_CH = [8, 9, 10, 11, 12, 13, 14, 15]

    for window in epoch_data:
        X_left = window[LEFT_CH, :]
        X_right = window[RIGHT_CH, :]

        # --- 1. Morphological (RMS & Line Length) ---
        rms_L = np.mean(np.sqrt(np.mean(X_left**2, axis=1)))
        rms_R = np.mean(np.sqrt(np.mean(X_right**2, axis=1)))

        ll_L = np.mean(np.sum(np.abs(np.diff(X_left, axis=1)), axis=1))
        ll_R = np.mean(np.sum(np.abs(np.diff(X_right, axis=1)), axis=1))

        # --- 2. Spectral Power (Theta/Alpha) ---
        freqs_L, psd_L = welch(X_left, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs_L >= 4) & (freqs_L < 8)
        al_mask = (freqs_L >= 8) & (freqs_L < 13)
        
        theta_L = np.trapezoid(psd_L[:, th_mask], freqs_L[th_mask], axis=1).mean()
        alpha_L = np.trapezoid(psd_L[:, al_mask], freqs_L[al_mask], axis=1).mean()
        ta_ratio_L = theta_L / (alpha_L + eps)

        freqs_R, psd_R = welch(X_right, sfreq, nperseg=sfreq * 2)
        theta_R = np.trapezoid(psd_R[:, th_mask], freqs_R[th_mask], axis=1).mean()
        alpha_R = np.trapezoid(psd_R[:, al_mask], freqs_R[al_mask], axis=1).mean()
        ta_ratio_R = theta_R / (alpha_R + eps)

        # --- 3. Phase-Amplitude Coupling (PAC) ---
        # Left PAC
        theta_sig_L = filtfilt(b_theta, a_theta, X_left, axis=1)
        gamma_sig_L = filtfilt(b_gamma, a_gamma, X_left, axis=1)
        theta_phase_L = np.angle(hilbert(theta_sig_L, axis=1))
        gamma_amp_L = np.abs(hilbert(gamma_sig_L, axis=1))
        pac_scores_L = [np.abs(np.corrcoef(np.cos(theta_phase_L[i]), gamma_amp_L[i])[0, 1]) for i in range(X_left.shape[0])]
        pac_L = np.mean(pac_scores_L)

        # Right PAC
        theta_sig_R = filtfilt(b_theta, a_theta, X_right, axis=1)
        gamma_sig_R = filtfilt(b_gamma, a_gamma, X_right, axis=1)
        theta_phase_R = np.angle(hilbert(theta_sig_R, axis=1))
        gamma_amp_R = np.abs(hilbert(gamma_sig_R, axis=1))
        pac_scores_R = [np.abs(np.corrcoef(np.cos(theta_phase_R[i]), gamma_amp_R[i])[0, 1]) for i in range(X_right.shape[0])]
        pac_R = np.mean(pac_scores_R)

        # --- 4. Spatial Sync (Cross-Hemisphere PLV) ---
        # Measure how locked the left hemisphere is to the right hemisphere
        phases_L = np.angle(hilbert(X_left, axis=1))
        phases_R = np.angle(hilbert(X_right, axis=1))
        
        sync_scores = []
        for i in range(len(LEFT_CH)):
            phase_diff = phases_L[i] - phases_R[i]
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))
            sync_scores.append(plv)
            
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        # --- Compile Regional Features ---
        features.append([
            rms_L, rms_R, 
            ll_L, ll_R, 
            ta_ratio_L, ta_ratio_R, 
            pac_L, pac_R, 
            avg_sync
        ])

    return np.array(features)

# %%
import numpy as np
from scipy.signal import welch, hilbert, butter, filtfilt
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

# --- Pre-define PAC Filters ---
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Filter coefficients for 256 Hz sampling rate
b_theta, a_theta = butter_bandpass(4.0, 8.0, 256)
b_gamma, a_gamma = butter_bandpass(30.0, 40.0, 256)


def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization (Phase-Locking Value)
    6. Phase-Amplitude Coupling (Theta-Gamma)
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        # --- 1. Spectral Power (Theta/Alpha) ---
        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        # --- 2. Complexity ---
        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        # --- 3. Spatial Sync (Phase-Locking Value) ---
        # Get instantaneous phase for all channels at once
        phases = np.angle(hilbert(X, axis=1))
        
        sync_scores = []
        for li, ri in PAIRS_LR:
            # Calculate phase difference
            phase_diff = phases[li] - phases[ri]
            # Calculate PLV for this pair (magnitude of the mean complex phase vector)
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))
            sync_scores.append(plv)
            
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        # --- 4. Morphological ---
        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        # --- 5. Phase-Amplitude Coupling (Theta-Gamma) ---
        # Fast vectorized filtering across all primary channels
        theta_sig = filtfilt(b_theta, a_theta, X, axis=1)
        gamma_sig = filtfilt(b_gamma, a_gamma, X, axis=1)
        
        # Hilbert transform to get phase and amplitude
        theta_phase = np.angle(hilbert(theta_sig, axis=1))
        gamma_amp = np.abs(hilbert(gamma_sig, axis=1))
        
        # Calculate coupling for each channel, then average
        pac_scores = [np.abs(np.corrcoef(np.cos(theta_phase[i]), gamma_amp[i])[0, 1]) for i in range(X.shape[0])]
        avg_pac = np.mean(pac_scores)

        # --- Compile Features ---
        features.append([ta_ratio, complexity, line_length, rms, avg_sync, avg_pac])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb02) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb06/chb06_24.edf"},
]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/18 files; last epochs=2880
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/18 files; last epochs=2880
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/18 files; last epochs=606
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_3138/1510394248.py:32: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 18/18 files; last epochs=2880
# Loading complete.

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.0130   0.9870   0.0000
# State 1   0.8399   0.1269   0.0332
# State 2   0.0000   0.0170   0.9830

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync", "Avg PAC"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : +0.210
#   PermEntropy : -0.700
#   LineLength  : -0.578
#   RMS         : -0.069
#   Avg Sync    : +0.372
#   Avg PAC     : +0.007
#
# State 1 means:
#   TA_ratio    : +0.206
#   PermEntropy : -0.674
#   LineLength  : -0.559
#   RMS         : -0.067
#   Avg Sync    : +0.358
#   Avg PAC     : +0.006
#
# State 2 means:
#   TA_ratio    : -0.197
#   PermEntropy : +0.652
#   LineLength  : +0.540
#   RMS         : +0.065
#   Avg Sync    : -0.347
#   Avg PAC     : -0.006

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy, [2] LineLength, 
# [3] RMS, [4] Avg Sync, [5] Avg PAC

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3
IDX_SYNC = 4
IDX_PAC = 5

# 1. Ictal: highest amplitude and spikiness
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# 2. Pre-ictal: highest Phase-Amplitude Coupling among non-ictal states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
preictal_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_PAC])]
)

# 3. Baseline: whatever state is left (the normal state)
baseline_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, preictal_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline (PAC-Optimized)")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb06_01.edf    | Pre-Ictal  | 5            | 10
# chb06_01.edf    | Pre-Ictal  | 15           | 20
# chb06_01.edf    | Pre-Ictal  | 25           | 30
# chb06_01.edf    | Ictal      | 35           | 65
# chb06_01.edf    | Pre-Ictal  | 70           | 75
# chb06_01.edf    | Pre-Ictal  | 80           | 85
# chb06_01.edf    | Ictal      | 90           | 135
# chb06_01.edf    | Pre-Ictal  | 140          | 145
# chb06_01.edf    | Pre-Ictal  | 150          | 155
# chb06_01.edf    | Ictal      | 160          | 180
# chb06_01.edf    | Pre-Ictal  | 185          | 190
# chb06_01.edf    | Pre-Ictal  | 195          | 200
# chb06_01.edf    | Pre-Ictal  | 205          | 210
# chb06_01.edf    | Pre-Ictal  | 215          | 220
# chb06_01.edf    | Ictal      | 225          | 260
# chb06_01.edf    | Pre-Ictal  | 265          | 270
# chb06_01.edf    | Pre-Ictal  | 275          | 280
# chb06_01.edf    | Pre-Ictal  | 285          | 290
# chb06_01.edf    | Ictal      | 295          | 335
# chb06_01.edf    | Pre-Ictal  | 340          | 345
# chb06_01.edf    | Pre-Ictal  | 350          | 355
# chb06_01.edf    | Pre-Ictal  | 360          | 365
# chb06_01.edf    | Ictal      | 370          | 400
# chb06_01.edf    | Pre-Ictal  | 405          | 410
# chb06_01.edf    | Pre-Ictal  | 415          | 420
# chb06_01.edf    | Ictal      | 425          | 455
# chb06_01.edf    | Pre-Ictal  | 460          | 465
# chb06_01.edf    | Pre-Ictal  | 470          | 475
# chb06_01.edf    | Ictal      | 480          | 590
# chb06_01.edf    | Pre-Ictal  | 595          | 600
# chb06_01.edf    | Pre-Ictal  | 605          | 610
# chb06_01.edf    | Pre-Ictal  | 615          | 620
# chb06_01.edf    | Pre-Ictal  | 625          | 630
# chb06_01.edf    | Pre-Ictal  | 635          | 640
# chb06_01.edf    | Pre-Ictal  | 645          | 650
# chb06_01.edf    | Ictal      | 655          | 740
# chb06_01.edf    | Pre-Ictal  | 745          | 750
# chb06_01.edf    | Pre-Ictal  | 755          | 760
# chb06_01.edf    | Pre-Ictal  | 765          | 770
# chb06_01.edf    | Pre-Ictal  | 775          | 780
# chb06_01.edf    | Pre-Ictal  | 785          | 790
# chb06_01.edf    | Pre-Ictal  | 795          | 800
# chb06_01.edf    | Ictal      | 805          | 875
# chb06_01.edf    | Pre-Ictal  | 880          | 885
# chb06_01.edf    | Pre-Ictal  | 890          | 895
# chb06_01.edf    | Pre-Ictal  | 900          | 905
# chb06_01.edf    | Ictal      | 910          | 955
# chb06_01.edf    | Pre-Ictal  | 960          | 965
# chb06_01.edf    | Pre-Ictal  | 970          | 975
# chb06_01.edf    | Pre-Ictal  | 980          | 985
# chb06_01.edf    | Pre-Ictal  | 990          | 995
# chb06_01.edf    | Pre-Ictal  | 1000         | 1005
# chb06_01.edf    | Pre-Ictal  | 1010         | 1015
# chb06_01.edf    | Pre-Ictal  | 1020         | 1025
# chb06_01.edf    | Ictal      | 1030         | 1125
# chb06_01.edf    | Pre-Ictal  | 1130         | 1135
# chb06_01.edf    | Pre-Ictal  | 1140         | 1145
# chb06_01.edf    | Pre-Ictal  | 1150         | 1155
# chb06_01.edf    | Pre-Ictal  | 1160         | 1165
# chb06_01.edf    | Ictal      | 1170         | 1210
# chb06_01.edf    | Pre-Ictal  | 1215         | 1220
# chb06_01.edf    | Pre-Ictal  | 1225         | 1230
# chb06_01.edf    | Pre-Ictal  | 1235         | 1240
# chb06_01.edf    | Pre-Ictal  | 1245         | 1250
# chb06_01.edf    | Pre-Ictal  | 1255         | 1260
# chb06_01.edf    | Ictal      | 1265         | 1295
# chb06_01.edf    | Pre-Ictal  | 1300         | 1305
# chb06_01.edf    | Pre-Ictal  | 1310         | 1315
# chb06_01.edf    | Pre-Ictal  | 1320         | 1325
# chb06_01.edf    | Pre-Ictal  | 1330         | 1335
# chb06_01.edf    | Pre-Ictal  | 1340         | 1345
# chb06_01.edf    | Pre-Ictal  | 1350         | 1355
# chb06_01.edf    | Pre-Ictal  | 1360         | 1365
# chb06_01.edf    | Pre-Ictal  | 1370         | 1375
# chb06_01.edf    | Pre-Ictal  | 1380         | 1385
# chb06_01.edf    | Ictal      | 1390         | 1525
# chb06_01.edf    | Pre-Ictal  | 1530         | 1535
# chb06_01.edf    | Pre-Ictal  | 1540         | 1545
# chb06_01.edf    | Pre-Ictal  | 1550         | 1555
# chb06_01.edf    | Pre-Ictal  | 1560         | 1565
# chb06_01.edf    | Pre-Ictal  | 1570         | 1575
# chb06_01.edf    | Pre-Ictal  | 1580         | 1585
# chb06_01.edf    | Pre-Ictal  | 1590         | 1595
# chb06_01.edf    | Pre-Ictal  | 1600         | 1605
# chb06_01.edf    | Pre-Ictal  | 1610         | 1615
# chb06_01.edf    | Pre-Ictal  | 1620         | 1625
# chb06_01.edf    | Pre-Ictal  | 1630         | 1635
# chb06_01.edf    | Ictal      | 1640         | 1655
# chb06_01.edf    | Pre-Ictal  | 1660         | 1665
# chb06_01.edf    | Pre-Ictal  | 1670         | 1675
# chb06_01.edf    | Pre-Ictal  | 1680         | 1685
# chb06_01.edf    | Pre-Ictal  | 1690         | 1695
# chb06_01.edf    | Ictal      | 1700         | 1755
# chb06_01.edf    | Pre-Ictal  | 1760         | 1765
# chb06_01.edf    | Pre-Ictal  | 1770         | 1775
# chb06_01.edf    | Pre-Ictal  | 1780         | 1785
# chb06_01.edf    | Pre-Ictal  | 1790         | 1795
# chb06_01.edf    | Pre-Ictal  | 1800         | 1805
# chb06_01.edf    | Pre-Ictal  | 1810         | 1815
# chb06_01.edf    | Pre-Ictal  | 1820         | 1825
# chb06_01.edf    | Pre-Ictal  | 1830         | 1835
# chb06_01.edf    | Pre-Ictal  | 1840         | 1845
# chb06_01.edf    | Pre-Ictal  | 1850         | 1855
# chb06_01.edf    | Pre-Ictal  | 1860         | 1865
# chb06_01.edf    | Pre-Ictal  | 1870         | 1875
# chb06_01.edf    | Pre-Ictal  | 1880         | 1885
# chb06_01.edf    | Pre-Ictal  | 1890         | 1895
# chb06_01.edf    | Pre-Ictal  | 1900         | 1905
# chb06_01.edf    | Pre-Ictal  | 1910         | 1915
# chb06_01.edf    | Pre-Ictal  | 1920         | 1925
# chb06_01.edf    | Pre-Ictal  | 1930         | 1935
# chb06_01.edf    | Pre-Ictal  | 1940         | 1945
# chb06_01.edf    | Pre-Ictal  | 1950         | 1955
# chb06_01.edf    | Pre-Ictal  | 1960         | 1965
# chb06_01.edf    | Pre-Ictal  | 1970         | 1975
# chb06_01.edf    | Pre-Ictal  | 1980         | 1985
# chb06_01.edf    | Pre-Ictal  | 1990         | 1995
# chb06_01.edf    | Pre-Ictal  | 2000         | 2005
# chb06_01.edf    | Pre-Ictal  | 2010         | 2015
# chb06_01.edf    | Pre-Ictal  | 2020         | 2025
# chb06_01.edf    | Pre-Ictal  | 2030         | 2035
# chb06_01.edf    | Pre-Ictal  | 2040         | 2045
# chb06_01.edf    | Pre-Ictal  | 2050         | 2055
# chb06_01.edf    | Pre-Ictal  | 2060         | 2065
# chb06_01.edf    | Pre-Ictal  | 2070         | 2075
# chb06_01.edf    | Pre-Ictal  | 2080         | 2085
# chb06_01.edf    | Pre-Ictal  | 2090         | 2095
# chb06_01.edf    | Pre-Ictal  | 2100         | 2105
# chb06_01.edf    | Pre-Ictal  | 2110         | 2115
# chb06_01.edf    | Pre-Ictal  | 2120         | 2125
# chb06_01.edf    | Pre-Ictal  | 2130         | 2135
# chb06_01.edf    | Pre-Ictal  | 2140         | 2145
# chb06_01.edf    | Pre-Ictal  | 2150         | 2155
# chb06_01.edf    | Pre-Ictal  | 2160         | 2165
# chb06_01.edf    | Pre-Ictal  | 2170         | 2175
# chb06_01.edf    | Pre-Ictal  | 2180         | 2185
# chb06_01.edf    | Pre-Ictal  | 2190         | 2195
# chb06_01.edf    | Pre-Ictal  | 2200         | 2205
# chb06_01.edf    | Pre-Ictal  | 2210         | 2215
# chb06_01.edf    | Pre-Ictal  | 2220         | 2225
# chb06_01.edf    | Pre-Ictal  | 2230         | 2235
# chb06_01.edf    | Pre-Ictal  | 2240         | 2245
# chb06_01.edf    | Pre-Ictal  | 2250         | 2255
# chb06_01.edf    | Pre-Ictal  | 2260         | 2265
# chb06_01.edf    | Pre-Ictal  | 2270         | 2275
# chb06_01.edf    | Pre-Ictal  | 2280         | 2285
# chb06_01.edf    | Pre-Ictal  | 2290         | 2295
# chb06_01.edf    | Pre-Ictal  | 2300         | 2305
# chb06_01.edf    | Pre-Ictal  | 2310         | 2315
# chb06_01.edf    | Pre-Ictal  | 2320         | 2325
# chb06_01.edf    | Pre-Ictal  | 2330         | 2335
# chb06_01.edf    | Pre-Ictal  | 2340         | 2345
# chb06_01.edf    | Pre-Ictal  | 2350         | 2355
# chb06_01.edf    | Pre-Ictal  | 2360         | 2365
# chb06_01.edf    | Pre-Ictal  | 2370         | 2375
# chb06_01.edf    | Pre-Ictal  | 2380         | 2385
# chb06_01.edf    | Pre-Ictal  | 2390         | 2395
# chb06_01.edf    | Pre-Ictal  | 2400         | 2405
# chb06_01.edf    | Pre-Ictal  | 2410         | 2415
# chb06_01.edf    | Pre-Ictal  | 2420         | 2425
# chb06_01.edf    | Pre-Ictal  | 2430         | 2435
# chb06_01.edf    | Pre-Ictal  | 2440         | 2445
# chb06_01.edf    | Pre-Ictal  | 2450         | 2455
# chb06_01.edf    | Pre-Ictal  | 2460         | 2465
# chb06_01.edf    | Pre-Ictal  | 2470         | 2475
# chb06_01.edf    | Pre-Ictal  | 2480         | 2485
# chb06_01.edf    | Pre-Ictal  | 2490         | 2495
# chb06_01.edf    | Pre-Ictal  | 2500         | 2505
# chb06_01.edf    | Pre-Ictal  | 2510         | 2515
# chb06_01.edf    | Pre-Ictal  | 2520         | 2525
# chb06_01.edf    | Pre-Ictal  | 2530         | 2535
# chb06_01.edf    | Pre-Ictal  | 2540         | 2545
# chb06_01.edf    | Pre-Ictal  | 2550         | 2555
# chb06_01.edf    | Pre-Ictal  | 2560         | 2565
# chb06_01.edf    | Pre-Ictal  | 2570         | 2575
# chb06_01.edf    | Pre-Ictal  | 2580         | 2585
# chb06_01.edf    | Pre-Ictal  | 2590         | 2595
# chb06_01.edf    | Pre-Ictal  | 2600         | 2605
# chb06_01.edf    | Pre-Ictal  | 2610         | 2615
# chb06_01.edf    | Pre-Ictal  | 2620         | 2625
# chb06_01.edf    | Pre-Ictal  | 2630         | 2635
# chb06_01.edf    | Pre-Ictal  | 2640         | 2645
# chb06_01.edf    | Pre-Ictal  | 2650         | 2655
# chb06_01.edf    | Pre-Ictal  | 2660         | 2665
# chb06_01.edf    | Pre-Ictal  | 2670         | 2675
# chb06_01.edf    | Pre-Ictal  | 2680         | 2685
# chb06_01.edf    | Pre-Ictal  | 2690         | 2695
# chb06_01.edf    | Pre-Ictal  | 2700         | 2705
# chb06_01.edf    | Pre-Ictal  | 2710         | 2715
# chb06_01.edf    | Pre-Ictal  | 2720         | 2725
# chb06_01.edf    | Pre-Ictal  | 2730         | 2735
# chb06_01.edf    | Pre-Ictal  | 2740         | 2745
# chb06_01.edf    | Pre-Ictal  | 2750         | 2755
# chb06_01.edf    | Pre-Ictal  | 2760         | 2765
# chb06_01.edf    | Pre-Ictal  | 2770         | 2775
# chb06_01.edf    | Pre-Ictal  | 2780         | 2785
# chb06_01.edf    | Pre-Ictal  | 2790         | 2795
# chb06_01.edf    | Pre-Ictal  | 2800         | 2805
# chb06_01.edf    | Pre-Ictal  | 2810         | 2815
# chb06_01.edf    | Pre-Ictal  | 2820         | 2825
# chb06_01.edf    | Pre-Ictal  | 2830         | 2835
# chb06_01.edf    | Pre-Ictal  | 2840         | 2845
# chb06_01.edf    | Pre-Ictal  | 2850         | 2855
# chb06_01.edf    | Pre-Ictal  | 2860         | 2865
# chb06_01.edf    | Pre-Ictal  | 2870         | 2875
# chb06_01.edf    | Pre-Ictal  | 2880         | 2885
# chb06_01.edf    | Pre-Ictal  | 2890         | 2895
# chb06_01.edf    | Pre-Ictal  | 2900         | 2905
# chb06_01.edf    | Pre-Ictal  | 2910         | 2915
# chb06_01.edf    | Pre-Ictal  | 2920         | 2925
# chb06_01.edf    | Pre-Ictal  | 2930         | 2935
# chb06_01.edf    | Pre-Ictal  | 2940         | 2945
# chb06_01.edf    | Pre-Ictal  | 2950         | 2955
# chb06_01.edf    | Pre-Ictal  | 2960         | 2965
# chb06_01.edf    | Pre-Ictal  | 2970         | 2975
# chb06_01.edf    | Pre-Ictal  | 2980         | 2985
# chb06_01.edf    | Pre-Ictal  | 2990         | 2995
# chb06_01.edf    | Pre-Ictal  | 3000         | 3005
# chb06_01.edf    | Pre-Ictal  | 3010         | 3015
# chb06_01.edf    | Pre-Ictal  | 3020         | 3025
# chb06_01.edf    | Pre-Ictal  | 3030         | 3035
# chb06_01.edf    | Ictal      | 3040         | 3400
# chb06_01.edf    | Pre-Ictal  | 3405         | 3410
# chb06_01.edf    | Pre-Ictal  | 3415         | 3420
# chb06_01.edf    | Pre-Ictal  | 3425         | 3430
# chb06_01.edf    | Pre-Ictal  | 3435         | 3440
# chb06_01.edf    | Pre-Ictal  | 3445         | 3450
# chb06_01.edf    | Pre-Ictal  | 3455         | 3460
# chb06_01.edf    | Pre-Ictal  | 3465         | 3470
# chb06_01.edf    | Pre-Ictal  | 3475         | 3480
# chb06_01.edf    | Pre-Ictal  | 3485         | 3490
# chb06_01.edf    | Pre-Ictal  | 3495         | 3500
# chb06_01.edf    | Pre-Ictal  | 3505         | 3510
# chb06_01.edf    | Pre-Ictal  | 3515         | 3520
# chb06_01.edf    | Pre-Ictal  | 3525         | 3530
# chb06_01.edf    | Pre-Ictal  | 3535         | 3540
# chb06_01.edf    | Pre-Ictal  | 3545         | 3550
# chb06_01.edf    | Pre-Ictal  | 3555         | 3560
# chb06_01.edf    | Pre-Ictal  | 3565         | 3570
# chb06_01.edf    | Pre-Ictal  | 3575         | 3580
# chb06_01.edf    | Pre-Ictal  | 3585         | 3590
# chb06_01.edf    | Pre-Ictal  | 3595         | 3600
# chb06_01.edf    | Pre-Ictal  | 3605         | 3610
# chb06_01.edf    | Pre-Ictal  | 3615         | 3620
# chb06_01.edf    | Pre-Ictal  | 3625         | 3630
# chb06_01.edf    | Pre-Ictal  | 3635         | 3640
# chb06_01.edf    | Pre-Ictal  | 3645         | 3650
# chb06_01.edf    | Pre-Ictal  | 3655         | 3660
# chb06_01.edf    | Pre-Ictal  | 3665         | 3670
# chb06_01.edf    | Pre-Ictal  | 3675         | 3680
# chb06_01.edf    | Pre-Ictal  | 3685         | 3690
# chb06_01.edf    | Pre-Ictal  | 3695         | 3700
# chb06_01.edf    | Pre-Ictal  | 3705         | 3710
# chb06_01.edf    | Pre-Ictal  | 3715         | 3720
# chb06_01.edf    | Pre-Ictal  | 3725         | 3730
# chb06_01.edf    | Pre-Ictal  | 3735         | 3740
# chb06_01.edf    | Pre-Ictal  | 3745         | 3750
# chb06_01.edf    | Pre-Ictal  | 3755         | 3760
# chb06_01.edf    | Pre-Ictal  | 3765         | 3770
# chb06_01.edf    | Pre-Ictal  | 3775         | 3780
# chb06_01.edf    | Pre-Ictal  | 3785         | 3790
# chb06_01.edf    | Pre-Ictal  | 3795         | 3800
# chb06_01.edf    | Pre-Ictal  | 3805         | 3810
# chb06_01.edf    | Pre-Ictal  | 3815         | 3820
# chb06_01.edf    | Pre-Ictal  | 3825         | 3830
# chb06_01.edf    | Pre-Ictal  | 3835         | 3840
# chb06_01.edf    | Ictal      | 3845         | 3995
# chb06_01.edf    | Pre-Ictal  | 4000         | 4005
# chb06_01.edf    | Pre-Ictal  | 4010         | 4015
# chb06_01.edf    | Pre-Ictal  | 4020         | 4025
# chb06_01.edf    | Pre-Ictal  | 4030         | 4035
# chb06_01.edf    | Pre-Ictal  | 4040         | 4045
# chb06_01.edf    | Pre-Ictal  | 4050         | 4055
# chb06_01.edf    | Pre-Ictal  | 4060         | 4065
# chb06_01.edf    | Pre-Ictal  | 4070         | 4075
# chb06_01.edf    | Pre-Ictal  | 4080         | 4085
# chb06_01.edf    | Ictal      | 4090         | 4225
# chb06_01.edf    | Pre-Ictal  | 4230         | 4235
# chb06_01.edf    | Pre-Ictal  | 4240         | 4245
# chb06_01.edf    | Pre-Ictal  | 4250         | 4255
# chb06_01.edf    | Pre-Ictal  | 4260         | 4265
# chb06_01.edf    | Pre-Ictal  | 4270         | 4275
# chb06_01.edf    | Pre-Ictal  | 4280         | 4285
# chb06_01.edf    | Pre-Ictal  | 4290         | 4295
# chb06_01.edf    | Pre-Ictal  | 4300         | 4305
# chb06_01.edf    | Pre-Ictal  | 4310         | 4315
# chb06_01.edf    | Pre-Ictal  | 4320         | 4325
# chb06_01.edf    | Pre-Ictal  | 4330         | 4335
# chb06_01.edf    | Pre-Ictal  | 4340         | 4345
# chb06_01.edf    | Pre-Ictal  | 4350         | 4355
# chb06_01.edf    | Pre-Ictal  | 4360         | 4365
# chb06_01.edf    | Pre-Ictal  | 4370         | 4375
# chb06_01.edf    | Pre-Ictal  | 4380         | 4385
# chb06_01.edf    | Pre-Ictal  | 4390         | 4395
# chb06_01.edf    | Pre-Ictal  | 4400         | 4405
# chb06_01.edf    | Pre-Ictal  | 4410         | 4415
# chb06_01.edf    | Pre-Ictal  | 4420         | 4425
# chb06_01.edf    | Pre-Ictal  | 4430         | 4435
# chb06_01.edf    | Pre-Ictal  | 4440         | 4445
# chb06_01.edf    | Ictal      | 4450         | 4500
# chb06_01.edf    | Pre-Ictal  | 4505         | 4510
# chb06_01.edf    | Pre-Ictal  | 4515         | 4520
# chb06_01.edf    | Pre-Ictal  | 4525         | 4530
# chb06_01.edf    | Pre-Ictal  | 4535         | 4540
# chb06_01.edf    | Pre-Ictal  | 4545         | 4550
# chb06_01.edf    | Pre-Ictal  | 4555         | 4560
# chb06_01.edf    | Pre-Ictal  | 4565         | 4570
# chb06_01.edf    | Ictal      | 4575         | 4680
# chb06_01.edf    | Pre-Ictal  | 4685         | 4690
# chb06_01.edf    | Pre-Ictal  | 4695         | 4700
# chb06_01.edf    | Ictal      | 4705         | 4770
# chb06_01.edf    | Pre-Ictal  | 4775         | 4780
# chb06_01.edf    | Pre-Ictal  | 4785         | 4790
# chb06_01.edf    | Pre-Ictal  | 4795         | 4800
# chb06_01.edf    | Pre-Ictal  | 4805         | 4810
# chb06_01.edf    | Pre-Ictal  | 4815         | 4820
# chb06_01.edf    | Pre-Ictal  | 4825         | 4830
# chb06_01.edf    | Pre-Ictal  | 4835         | 4840
# chb06_01.edf    | Pre-Ictal  | 4845         | 4850
# chb06_01.edf    | Pre-Ictal  | 4855         | 4860
# chb06_01.edf    | Pre-Ictal  | 4865         | 4870
# chb06_01.edf    | Pre-Ictal  | 4875         | 4880
# chb06_01.edf    | Pre-Ictal  | 4885         | 4890
# chb06_01.edf    | Pre-Ictal  | 4895         | 4900
# chb06_01.edf    | Pre-Ictal  | 4905         | 4910
# chb06_01.edf    | Pre-Ictal  | 4915         | 4920
# chb06_01.edf    | Pre-Ictal  | 4925         | 4930
# chb06_01.edf    | Pre-Ictal  | 4935         | 4940
# chb06_01.edf    | Pre-Ictal  | 4945         | 4950
# chb06_01.edf    | Pre-Ictal  | 4955         | 4960
# chb06_01.edf    | Pre-Ictal  | 4965         | 4970
# chb06_01.edf    | Pre-Ictal  | 4975         | 4980
# chb06_01.edf    | Pre-Ictal  | 4985         | 4990
# chb06_01.edf    | Pre-Ictal  | 4995         | 5000
# chb06_01.edf    | Pre-Ictal  | 5005         | 5010
# chb06_01.edf    | Pre-Ictal  | 5015         | 5020
# chb06_01.edf    | Pre-Ictal  | 5025         | 5030
# chb06_01.edf    | Pre-Ictal  | 5035         | 5040
# chb06_01.edf    | Ictal      | 5045         | 5155
# chb06_01.edf    | Pre-Ictal  | 5160         | 5165
# chb06_01.edf    | Pre-Ictal  | 5170         | 5175
# chb06_01.edf    | Pre-Ictal  | 5180         | 5185
# chb06_01.edf    | Ictal      | 5190         | 5285
# chb06_01.edf    | Pre-Ictal  | 5290         | 5295
# chb06_01.edf    | Pre-Ictal  | 5300         | 5305
# chb06_01.edf    | Ictal      | 5310         | 5480
# chb06_01.edf    | Pre-Ictal  | 5485         | 5490
# chb06_01.edf    | Pre-Ictal  | 5495         | 5500
# chb06_01.edf    | Pre-Ictal  | 5505         | 5510
# chb06_01.edf    | Pre-Ictal  | 5515         | 5520
# chb06_01.edf    | Pre-Ictal  | 5525         | 5530
# chb06_01.edf    | Pre-Ictal  | 5535         | 5540
# chb06_01.edf    | Ictal      | 5545         | 5735
# chb06_01.edf    | Pre-Ictal  | 5740         | 5745
# chb06_01.edf    | Pre-Ictal  | 5750         | 5755
# chb06_01.edf    | Pre-Ictal  | 5760         | 5765
# chb06_01.edf    | Pre-Ictal  | 5770         | 5775
# chb06_01.edf    | Pre-Ictal  | 5780         | 5785
# chb06_01.edf    | Pre-Ictal  | 5790         | 5795
# chb06_01.edf    | Pre-Ictal  | 5800         | 5805
# chb06_01.edf    | Pre-Ictal  | 5810         | 5815
# chb06_01.edf    | Pre-Ictal  | 5820         | 5825
# chb06_01.edf    | Pre-Ictal  | 5830         | 5835
# chb06_01.edf    | Pre-Ictal  | 5840         | 5845
# chb06_01.edf    | Pre-Ictal  | 5850         | 5855
# chb06_01.edf    | Pre-Ictal  | 5860         | 5865
# chb06_01.edf    | Pre-Ictal  | 5870         | 5875
# chb06_01.edf    | Pre-Ictal  | 5880         | 5885
# chb06_01.edf    | Pre-Ictal  | 5890         | 5895
# chb06_01.edf    | Pre-Ictal  | 5900         | 5905
# chb06_01.edf    | Ictal      | 5910         | 6030
# chb06_01.edf    | Pre-Ictal  | 6035         | 6040
# chb06_01.edf    | Pre-Ictal  | 6045         | 6050
# chb06_01.edf    | Pre-Ictal  | 6055         | 6060
# chb06_01.edf    | Pre-Ictal  | 6065         | 6070
# chb06_01.edf    | Pre-Ictal  | 6075         | 6080
# chb06_01.edf    | Pre-Ictal  | 6085         | 6090
# chb06_01.edf    | Pre-Ictal  | 6095         | 6100
# chb06_01.edf    | Pre-Ictal  | 6105         | 6110
# chb06_01.edf    | Pre-Ictal  | 6115         | 6120
# chb06_01.edf    | Pre-Ictal  | 6125         | 6130
# chb06_01.edf    | Pre-Ictal  | 6135         | 6140
# chb06_01.edf    | Ictal      | 6145         | 6195
# chb06_01.edf    | Pre-Ictal  | 6200         | 6205
# chb06_01.edf    | Pre-Ictal  | 6210         | 6215
# chb06_01.edf    | Pre-Ictal  | 6220         | 6225
# chb06_01.edf    | Pre-Ictal  | 6230         | 6235
# chb06_01.edf    | Pre-Ictal  | 6240         | 6245
# chb06_01.edf    | Pre-Ictal  | 6250         | 6255
# chb06_01.edf    | Pre-Ictal  | 6260         | 6265
# chb06_01.edf    | Pre-Ictal  | 6270         | 6275
# chb06_01.edf    | Pre-Ictal  | 6280         | 6285
# chb06_01.edf    | Pre-Ictal  | 6290         | 6295
# chb06_01.edf    | Pre-Ictal  | 6300         | 6305
# chb06_01.edf    | Pre-Ictal  | 6310         | 6315
# chb06_01.edf    | Pre-Ictal  | 6320         | 6325
# chb06_01.edf    | Pre-Ictal  | 6330         | 6335
# chb06_01.edf    | Pre-Ictal  | 6340         | 6345
# chb06_01.edf    | Pre-Ictal  | 6350         | 6355
# chb06_01.edf    | Pre-Ictal  | 6360         | 6365
# chb06_01.edf    | Pre-Ictal  | 6370         | 6375
# chb06_01.edf    | Pre-Ictal  | 6380         | 6385
# chb06_01.edf    | Pre-Ictal  | 6390         | 6395
# chb06_01.edf    | Pre-Ictal  | 6400         | 6405
# chb06_01.edf    | Pre-Ictal  | 6410         | 6415
# chb06_01.edf    | Ictal      | 6420         | 6465
# chb06_01.edf    | Pre-Ictal  | 6470         | 6475
# chb06_01.edf    | Pre-Ictal  | 6480         | 6485
# chb06_01.edf    | Pre-Ictal  | 6490         | 6495
# chb06_01.edf    | Pre-Ictal  | 6500         | 6505
# chb06_01.edf    | Pre-Ictal  | 6510         | 6515
# chb06_01.edf    | Pre-Ictal  | 6520         | 6525
# chb06_01.edf    | Pre-Ictal  | 6530         | 6535
# chb06_01.edf    | Pre-Ictal  | 6540         | 6545
# chb06_01.edf    | Pre-Ictal  | 6550         | 6555
# chb06_01.edf    | Pre-Ictal  | 6560         | 6565
# chb06_01.edf    | Pre-Ictal  | 6570         | 6575
# chb06_01.edf    | Pre-Ictal  | 6580         | 6585
# chb06_01.edf    | Pre-Ictal  | 6590         | 6595
# chb06_01.edf    | Pre-Ictal  | 6600         | 6605
# chb06_01.edf    | Pre-Ictal  | 6610         | 6615
# chb06_01.edf    | Pre-Ictal  | 6620         | 6625
# chb06_01.edf    | Pre-Ictal  | 6630         | 6635
# chb06_01.edf    | Pre-Ictal  | 6640         | 6645
# chb06_01.edf    | Pre-Ictal  | 6650         | 6655
# chb06_01.edf    | Ictal      | 6660         | 6905
# chb06_01.edf    | Pre-Ictal  | 6910         | 6915
# chb06_01.edf    | Pre-Ictal  | 6920         | 6925
# chb06_01.edf    | Pre-Ictal  | 6930         | 6935
# chb06_01.edf    | Pre-Ictal  | 6940         | 6945
# chb06_01.edf    | Pre-Ictal  | 6950         | 6955
# chb06_01.edf    | Pre-Ictal  | 6960         | 6965
# chb06_01.edf    | Pre-Ictal  | 6970         | 6975
# chb06_01.edf    | Pre-Ictal  | 6980         | 6985
# chb06_01.edf    | Ictal      | 6990         | 7485
# chb06_01.edf    | Pre-Ictal  | 7490         | 7495
# chb06_01.edf    | Pre-Ictal  | 7500         | 7505
# chb06_01.edf    | Pre-Ictal  | 7510         | 7515
# chb06_01.edf    | Pre-Ictal  | 7520         | 7525
# chb06_01.edf    | Pre-Ictal  | 7530         | 7535
# chb06_01.edf    | Pre-Ictal  | 7540         | 7545
# chb06_01.edf    | Pre-Ictal  | 7550         | 7555
# chb06_01.edf    | Pre-Ictal  | 7560         | 7565
# chb06_01.edf    | Pre-Ictal  | 7570         | 7575
# chb06_01.edf    | Pre-Ictal  | 7580         | 7585
# chb06_01.edf    | Pre-Ictal  | 7590         | 7595
# chb06_01.edf    | Pre-Ictal  | 7600         | 7605
# chb06_01.edf    | Pre-Ictal  | 7610         | 7615
# chb06_01.edf    | Pre-Ictal  | 7620         | 7625
# chb06_01.edf    | Pre-Ictal  | 7630         | 7635
# chb06_01.edf    | Pre-Ictal  | 7640         | 7645
# chb06_01.edf    | Pre-Ictal  | 7650         | 7655
# chb06_01.edf    | Pre-Ictal  | 7660         | 7665
# chb06_01.edf    | Pre-Ictal  | 7670         | 7675
# chb06_01.edf    | Pre-Ictal  | 7680         | 7685
# chb06_01.edf    | Pre-Ictal  | 7690         | 7695
# chb06_01.edf    | Pre-Ictal  | 7700         | 7705
# chb06_01.edf    | Pre-Ictal  | 7710         | 7715
# chb06_01.edf    | Pre-Ictal  | 7720         | 7725
# chb06_01.edf    | Pre-Ictal  | 7730         | 7735
# chb06_01.edf    | Pre-Ictal  | 7740         | 7745
# chb06_01.edf    | Pre-Ictal  | 7750         | 7755
# chb06_01.edf    | Pre-Ictal  | 7760         | 7765
# chb06_01.edf    | Pre-Ictal  | 7770         | 7775
# chb06_01.edf    | Pre-Ictal  | 7780         | 7785
# chb06_01.edf    | Pre-Ictal  | 7790         | 7795
# chb06_01.edf    | Pre-Ictal  | 7800         | 7805
# chb06_01.edf    | Pre-Ictal  | 7810         | 7815
# chb06_01.edf    | Pre-Ictal  | 7820         | 7825
# chb06_01.edf    | Pre-Ictal  | 7830         | 7835
# chb06_01.edf    | Pre-Ictal  | 7840         | 7845
# chb06_01.edf    | Pre-Ictal  | 7850         | 7855
# chb06_01.edf    | Pre-Ictal  | 7860         | 7865
# chb06_01.edf    | Pre-Ictal  | 7870         | 7875
# chb06_01.edf    | Pre-Ictal  | 7880         | 7885
# chb06_01.edf    | Pre-Ictal  | 7890         | 7895
# chb06_01.edf    | Pre-Ictal  | 7900         | 7905
# chb06_01.edf    | Pre-Ictal  | 7910         | 7915
# chb06_01.edf    | Pre-Ictal  | 7920         | 7925
# chb06_01.edf    | Pre-Ictal  | 7930         | 7935
# chb06_01.edf    | Pre-Ictal  | 7940         | 7945
# chb06_01.edf    | Pre-Ictal  | 7950         | 7955
# chb06_01.edf    | Pre-Ictal  | 7960         | 7965
# chb06_01.edf    | Pre-Ictal  | 7970         | 7975
# chb06_01.edf    | Pre-Ictal  | 7980         | 7985
# chb06_01.edf    | Pre-Ictal  | 7990         | 7995
# chb06_01.edf    | Pre-Ictal  | 8000         | 8005
# chb06_01.edf    | Pre-Ictal  | 8010         | 8015
# chb06_01.edf    | Pre-Ictal  | 8020         | 8025
# chb06_01.edf    | Pre-Ictal  | 8030         | 8035
# chb06_01.edf    | Pre-Ictal  | 8040         | 8045
# chb06_01.edf    | Pre-Ictal  | 8050         | 8055
# chb06_01.edf    | Pre-Ictal  | 8060         | 8065
# chb06_01.edf    | Pre-Ictal  | 8070         | 8075
# chb06_01.edf    | Pre-Ictal  | 8080         | 8085
# chb06_01.edf    | Pre-Ictal  | 8090         | 8095
# chb06_01.edf    | Pre-Ictal  | 8100         | 8105
# chb06_01.edf    | Pre-Ictal  | 8110         | 8115
# chb06_01.edf    | Pre-Ictal  | 8120         | 8125
# chb06_01.edf    | Pre-Ictal  | 8130         | 8135
# chb06_01.edf    | Pre-Ictal  | 8140         | 8145
# chb06_01.edf    | Pre-Ictal  | 8150         | 8155
# chb06_01.edf    | Pre-Ictal  | 8160         | 8165
# chb06_01.edf    | Pre-Ictal  | 8170         | 8175
# chb06_01.edf    | Pre-Ictal  | 8180         | 8185
# chb06_01.edf    | Pre-Ictal  | 8190         | 8195
# chb06_01.edf    | Pre-Ictal  | 8200         | 8205
# chb06_01.edf    | Pre-Ictal  | 8210         | 8215
# chb06_01.edf    | Pre-Ictal  | 8220         | 8225
# chb06_01.edf    | Pre-Ictal  | 8230         | 8235
# chb06_01.edf    | Pre-Ictal  | 8240         | 8245
# chb06_01.edf    | Pre-Ictal  | 8250         | 8255
# chb06_01.edf    | Pre-Ictal  | 8260         | 8265
# chb06_01.edf    | Pre-Ictal  | 8270         | 8275
# chb06_01.edf    | Pre-Ictal  | 8280         | 8285
# chb06_01.edf    | Pre-Ictal  | 8290         | 8295
# chb06_01.edf    | Pre-Ictal  | 8300         | 8305
# chb06_01.edf    | Pre-Ictal  | 8310         | 8315
# chb06_01.edf    | Pre-Ictal  | 8320         | 8325
# chb06_01.edf    | Pre-Ictal  | 8330         | 8335
# chb06_01.edf    | Pre-Ictal  | 8340         | 8345
# chb06_01.edf    | Pre-Ictal  | 8350         | 8355
# chb06_01.edf    | Pre-Ictal  | 8360         | 8365
# chb06_01.edf    | Pre-Ictal  | 8370         | 8375
# chb06_01.edf    | Pre-Ictal  | 8380         | 8385
# chb06_01.edf    | Ictal      | 8390         | 8475
# chb06_01.edf    | Pre-Ictal  | 8480         | 8485
# chb06_01.edf    | Pre-Ictal  | 8490         | 8495
# chb06_01.edf    | Pre-Ictal  | 8500         | 8505
# chb06_01.edf    | Pre-Ictal  | 8510         | 8515
# chb06_01.edf    | Pre-Ictal  | 8520         | 8525
# chb06_01.edf    | Pre-Ictal  | 8530         | 8535
# chb06_01.edf    | Pre-Ictal  | 8540         | 8545
# chb06_01.edf    | Pre-Ictal  | 8550         | 8555
# chb06_01.edf    | Pre-Ictal  | 8560         | 8565
# chb06_01.edf    | Pre-Ictal  | 8570         | 8575
# chb06_01.edf    | Pre-Ictal  | 8580         | 8585
# chb06_01.edf    | Pre-Ictal  | 8590         | 8595
# chb06_01.edf    | Pre-Ictal  | 8600         | 8605
# chb06_01.edf    | Pre-Ictal  | 8610         | 8615
# chb06_01.edf    | Pre-Ictal  | 8620         | 8625
# chb06_01.edf    | Pre-Ictal  | 8630         | 8635
# chb06_01.edf    | Pre-Ictal  | 8640         | 8645
# chb06_01.edf    | Pre-Ictal  | 8650         | 8655
# chb06_01.edf    | Ictal      | 8660         | 9140
# chb06_01.edf    | Pre-Ictal  | 9145         | 9150
# chb06_01.edf    | Pre-Ictal  | 9155         | 9160
# chb06_01.edf    | Pre-Ictal  | 9165         | 9170
# chb06_01.edf    | Pre-Ictal  | 9175         | 9180
# chb06_01.edf    | Pre-Ictal  | 9185         | 9190
# chb06_01.edf    | Pre-Ictal  | 9195         | 9200
# chb06_01.edf    | Ictal      | 9205         | 10190
# chb06_01.edf    | Pre-Ictal  | 10195        | 10200
# chb06_01.edf    | Pre-Ictal  | 10205        | 10210
# chb06_01.edf    | Pre-Ictal  | 10215        | 10220
# chb06_01.edf    | Ictal      | 10225        | 10415
# chb06_01.edf    | Pre-Ictal  | 10420        | 10425
# chb06_01.edf    | Pre-Ictal  | 10430        | 10435
# chb06_01.edf    | Pre-Ictal  | 10440        | 10445
# chb06_01.edf    | Pre-Ictal  | 10450        | 10455
# chb06_01.edf    | Ictal      | 10460        | 10505
# chb06_01.edf    | Pre-Ictal  | 10510        | 10515
# chb06_01.edf    | Pre-Ictal  | 10520        | 10525
# chb06_01.edf    | Pre-Ictal  | 10530        | 10535
# chb06_01.edf    | Pre-Ictal  | 10540        | 10545
# chb06_01.edf    | Pre-Ictal  | 10550        | 10555
# chb06_01.edf    | Pre-Ictal  | 10560        | 10565
# chb06_01.edf    | Pre-Ictal  | 10570        | 10575
# chb06_01.edf    | Ictal      | 10580        | 10620
# chb06_01.edf    | Pre-Ictal  | 10625        | 10630
# chb06_01.edf    | Pre-Ictal  | 10635        | 10640
# chb06_01.edf    | Pre-Ictal  | 10645        | 10650
# chb06_01.edf    | Pre-Ictal  | 10655        | 10660
# chb06_01.edf    | Pre-Ictal  | 10665        | 10670
# chb06_01.edf    | Pre-Ictal  | 10675        | 10680
# chb06_01.edf    | Pre-Ictal  | 10685        | 10690
# chb06_01.edf    | Pre-Ictal  | 10695        | 10700
# chb06_01.edf    | Ictal      | 10705        | 10765
# chb06_01.edf    | Pre-Ictal  | 10770        | 10775
# chb06_01.edf    | Pre-Ictal  | 10780        | 10785
# chb06_01.edf    | Pre-Ictal  | 10790        | 10795
# chb06_01.edf    | Pre-Ictal  | 10800        | 10805
# chb06_01.edf    | Ictal      | 10810        | 10850
# chb06_01.edf    | Pre-Ictal  | 10855        | 10860
# chb06_01.edf    | Pre-Ictal  | 10865        | 10870
# chb06_01.edf    | Pre-Ictal  | 10875        | 10880
# chb06_01.edf    | Pre-Ictal  | 10885        | 10890
# chb06_01.edf    | Pre-Ictal  | 10895        | 10900
# chb06_01.edf    | Ictal      | 10905        | 11025
# chb06_01.edf    | Pre-Ictal  | 11030        | 11035
# chb06_01.edf    | Pre-Ictal  | 11040        | 11045
# chb06_01.edf    | Pre-Ictal  | 11050        | 11055
# chb06_01.edf    | Pre-Ictal  | 11060        | 11065
# chb06_01.edf    | Pre-Ictal  | 11070        | 11075
# chb06_01.edf    | Pre-Ictal  | 11080        | 11085
# chb06_01.edf    | Pre-Ictal  | 11090        | 11095
# chb06_01.edf    | Ictal      | 11100        | 11155
# chb06_01.edf    | Pre-Ictal  | 11160        | 11165
# chb06_01.edf    | Pre-Ictal  | 11170        | 11175
# chb06_01.edf    | Pre-Ictal  | 11180        | 11185
# chb06_01.edf    | Ictal      | 11190        | 11700
# chb06_01.edf    | Pre-Ictal  | 11705        | 11710
# chb06_01.edf    | Pre-Ictal  | 11715        | 11720
# chb06_01.edf    | Ictal      | 11725        | 13505
# chb06_01.edf    | Pre-Ictal  | 13510        | 13515
# chb06_01.edf    | Pre-Ictal  | 13520        | 13525
# chb06_01.edf    | Ictal      | 13530        | 13555
# chb06_01.edf    | Pre-Ictal  | 13560        | 13565
# chb06_01.edf    | Pre-Ictal  | 13570        | 13575
# chb06_01.edf    | Pre-Ictal  | 13580        | 13585
# chb06_01.edf    | Pre-Ictal  | 13590        | 13595
# chb06_01.edf    | Pre-Ictal  | 13600        | 13605
# chb06_01.edf    | Pre-Ictal  | 13610        | 13615
# chb06_01.edf    | Pre-Ictal  | 13620        | 13625
# chb06_01.edf    | Pre-Ictal  | 13630        | 13635
# chb06_01.edf    | Pre-Ictal  | 13640        | 13645
# chb06_01.edf    | Pre-Ictal  | 13650        | 13655
# chb06_01.edf    | Pre-Ictal  | 13660        | 13665
# chb06_01.edf    | Pre-Ictal  | 13670        | 13675
# chb06_01.edf    | Pre-Ictal  | 13680        | 13685
# chb06_01.edf    | Pre-Ictal  | 13690        | 13695
# chb06_01.edf    | Ictal      | 13700        | 13795
# chb06_01.edf    | Pre-Ictal  | 13800        | 13805
# chb06_01.edf    | Pre-Ictal  | 13810        | 13815
# chb06_01.edf    | Ictal      | 13820        | 13870
# chb06_01.edf    | Pre-Ictal  | 13875        | 13880
# chb06_01.edf    | Pre-Ictal  | 13885        | 13890
# chb06_01.edf    | Pre-Ictal  | 13895        | 13900
# chb06_01.edf    | Pre-Ictal  | 13905        | 13910
# chb06_01.edf    | Pre-Ictal  | 13915        | 13920
# chb06_01.edf    | Pre-Ictal  | 13925        | 13930
# chb06_01.edf    | Pre-Ictal  | 13935        | 13940
# chb06_01.edf    | Pre-Ictal  | 13945        | 13950
# chb06_01.edf    | Pre-Ictal  | 13955        | 13960
# chb06_01.edf    | Pre-Ictal  | 13965        | 13970
# chb06_01.edf    | Ictal      | 13975        | 14150
# chb06_01.edf    | Pre-Ictal  | 14155        | 14160
# chb06_01.edf    | Pre-Ictal  | 14165        | 14170
# chb06_01.edf    | Pre-Ictal  | 14175        | 14180
# chb06_01.edf    | Pre-Ictal  | 14185        | 14190
# chb06_01.edf    | Pre-Ictal  | 14195        | 14200
# chb06_01.edf    | Pre-Ictal  | 14205        | 14210
# chb06_01.edf    | Pre-Ictal  | 14215        | 14220
# chb06_01.edf    | Pre-Ictal  | 14225        | 14230
# chb06_01.edf    | Pre-Ictal  | 14235        | 14240
# chb06_01.edf    | Pre-Ictal  | 14245        | 14250
# chb06_01.edf    | Pre-Ictal  | 14255        | 14260
# chb06_01.edf    | Pre-Ictal  | 14265        | 14270
# chb06_01.edf    | Pre-Ictal  | 14275        | 14280
# chb06_01.edf    | Pre-Ictal  | 14285        | 14290
# chb06_01.edf    | Pre-Ictal  | 14295        | 14300
# chb06_01.edf    | Pre-Ictal  | 14305        | 14310
# chb06_01.edf    | Pre-Ictal  | 14315        | 14320
# chb06_01.edf    | Pre-Ictal  | 14325        | 14330
# chb06_01.edf    | Pre-Ictal  | 14335        | 14340
# chb06_01.edf    | Pre-Ictal  | 14345        | 14350
# chb06_01.edf    | Pre-Ictal  | 14355        | 14360
# chb06_01.edf    | Pre-Ictal  | 14365        | 14370
# chb06_01.edf    | Pre-Ictal  | 14375        | 14380
# chb06_01.edf    | Ictal      | 14385        | 14425
# chb06_02.edf    | Ictal      | 0            | 1505
# chb06_02.edf    | Pre-Ictal  | 1510         | 1515
# chb06_02.edf    | Pre-Ictal  | 1520         | 1525
# chb06_02.edf    | Ictal      | 1530         | 4320
# chb06_02.edf    | Pre-Ictal  | 4325         | 4330
# chb06_02.edf    | Pre-Ictal  | 4335         | 4340
# chb06_02.edf    | Pre-Ictal  | 4345         | 4350
# chb06_02.edf    | Ictal      | 4355         | 5660
# chb06_02.edf    | Pre-Ictal  | 5665         | 5670
# chb06_02.edf    | Pre-Ictal  | 5675         | 5680
# chb06_02.edf    | Pre-Ictal  | 5685         | 5690
# chb06_02.edf    | Pre-Ictal  | 5695         | 5700
# chb06_02.edf    | Pre-Ictal  | 5705         | 5710
# chb06_02.edf    | Pre-Ictal  | 5715         | 5720
# chb06_02.edf    | Ictal      | 5725         | 6535
# chb06_02.edf    | Pre-Ictal  | 6540         | 6545
# chb06_02.edf    | Pre-Ictal  | 6550         | 6555
# chb06_02.edf    | Pre-Ictal  | 6560         | 6565
# chb06_02.edf    | Pre-Ictal  | 6570         | 6575
# chb06_02.edf    | Pre-Ictal  | 6580         | 6585
# chb06_02.edf    | Pre-Ictal  | 6590         | 6595
# chb06_02.edf    | Pre-Ictal  | 6600         | 6605
# chb06_02.edf    | Pre-Ictal  | 6610         | 6615
# chb06_02.edf    | Pre-Ictal  | 6620         | 6625
# chb06_02.edf    | Pre-Ictal  | 6630         | 6635
# chb06_02.edf    | Pre-Ictal  | 6640         | 6645
# chb06_02.edf    | Pre-Ictal  | 6650         | 6655
# chb06_02.edf    | Pre-Ictal  | 6660         | 6665
# chb06_02.edf    | Pre-Ictal  | 6670         | 6675
# chb06_02.edf    | Pre-Ictal  | 6680         | 6685
# chb06_02.edf    | Pre-Ictal  | 6690         | 6695
# chb06_02.edf    | Ictal      | 6700         | 7035
# chb06_02.edf    | Pre-Ictal  | 7040         | 7045
# chb06_02.edf    | Pre-Ictal  | 7050         | 7055
# chb06_02.edf    | Pre-Ictal  | 7060         | 7065
# chb06_02.edf    | Pre-Ictal  | 7070         | 7075
# chb06_02.edf    | Pre-Ictal  | 7080         | 7085
# chb06_02.edf    | Pre-Ictal  | 7090         | 7095
# chb06_02.edf    | Pre-Ictal  | 7100         | 7105
# chb06_02.edf    | Pre-Ictal  | 7110         | 7115
# chb06_02.edf    | Pre-Ictal  | 7120         | 7125
# chb06_02.edf    | Pre-Ictal  | 7130         | 7135
# chb06_02.edf    | Ictal      | 7140         | 7840
# chb06_02.edf    | Pre-Ictal  | 7845         | 7850
# chb06_02.edf    | Pre-Ictal  | 7855         | 7860
# chb06_02.edf    | Pre-Ictal  | 7865         | 7870
# chb06_02.edf    | Pre-Ictal  | 7875         | 7880
# chb06_02.edf    | Ictal      | 7885         | 8475
# chb06_02.edf    | Pre-Ictal  | 8480         | 8485
# chb06_02.edf    | Pre-Ictal  | 8490         | 8495
# chb06_02.edf    | Ictal      | 8500         | 8520
# chb06_02.edf    | Pre-Ictal  | 8525         | 8530
# chb06_02.edf    | Pre-Ictal  | 8535         | 8540
# chb06_02.edf    | Pre-Ictal  | 8545         | 8550
# chb06_02.edf    | Pre-Ictal  | 8555         | 8560
# chb06_02.edf    | Pre-Ictal  | 8565         | 8570
# chb06_02.edf    | Pre-Ictal  | 8575         | 8580
# chb06_02.edf    | Pre-Ictal  | 8585         | 8590
# chb06_02.edf    | Pre-Ictal  | 8595         | 8600
# chb06_02.edf    | Ictal      | 8605         | 8660
# chb06_02.edf    | Pre-Ictal  | 8665         | 8670
# chb06_02.edf    | Pre-Ictal  | 8675         | 8680
# chb06_02.edf    | Pre-Ictal  | 8685         | 8690
# chb06_02.edf    | Ictal      | 8695         | 8805
# chb06_02.edf    | Pre-Ictal  | 8810         | 8815
# chb06_02.edf    | Pre-Ictal  | 8820         | 8825
# chb06_02.edf    | Pre-Ictal  | 8830         | 8835
# chb06_02.edf    | Pre-Ictal  | 8840         | 8845
# chb06_02.edf    | Pre-Ictal  | 8850         | 8855
# chb06_02.edf    | Pre-Ictal  | 8860         | 8865
# chb06_02.edf    | Pre-Ictal  | 8870         | 8875
# chb06_02.edf    | Pre-Ictal  | 8880         | 8885
# chb06_02.edf    | Pre-Ictal  | 8890         | 8895
# chb06_02.edf    | Pre-Ictal  | 8900         | 8905
# chb06_02.edf    | Pre-Ictal  | 8910         | 8915
# chb06_02.edf    | Pre-Ictal  | 8920         | 8925
# chb06_02.edf    | Pre-Ictal  | 8930         | 8935
# chb06_02.edf    | Pre-Ictal  | 8940         | 8945
# chb06_02.edf    | Pre-Ictal  | 8950         | 8955
# chb06_02.edf    | Pre-Ictal  | 8960         | 8965
# chb06_02.edf    | Pre-Ictal  | 8970         | 8975
# chb06_02.edf    | Pre-Ictal  | 8980         | 8985
# chb06_02.edf    | Pre-Ictal  | 8990         | 8995
# chb06_02.edf    | Pre-Ictal  | 9000         | 9005
# chb06_02.edf    | Pre-Ictal  | 9010         | 9015
# chb06_02.edf    | Pre-Ictal  | 9020         | 9025
# chb06_02.edf    | Pre-Ictal  | 9030         | 9035
# chb06_02.edf    | Pre-Ictal  | 9040         | 9045
# chb06_02.edf    | Pre-Ictal  | 9050         | 9055
# chb06_02.edf    | Pre-Ictal  | 9060         | 9065
# chb06_02.edf    | Pre-Ictal  | 9070         | 9075
# chb06_02.edf    | Pre-Ictal  | 9080         | 9085
# chb06_02.edf    | Pre-Ictal  | 9090         | 9095
# chb06_02.edf    | Pre-Ictal  | 9100         | 9105
# chb06_02.edf    | Pre-Ictal  | 9110         | 9115
# chb06_02.edf    | Pre-Ictal  | 9120         | 9125
# chb06_02.edf    | Pre-Ictal  | 9130         | 9135
# chb06_02.edf    | Pre-Ictal  | 9140         | 9145
# chb06_02.edf    | Pre-Ictal  | 9150         | 9155
# chb06_02.edf    | Pre-Ictal  | 9160         | 9165
# chb06_02.edf    | Pre-Ictal  | 9170         | 9175
# chb06_02.edf    | Pre-Ictal  | 9180         | 9185
# chb06_02.edf    | Pre-Ictal  | 9190         | 9195
# chb06_02.edf    | Pre-Ictal  | 9200         | 9205
# chb06_02.edf    | Pre-Ictal  | 9210         | 9215
# chb06_02.edf    | Pre-Ictal  | 9220         | 9225
# chb06_02.edf    | Pre-Ictal  | 9230         | 9235
# chb06_02.edf    | Pre-Ictal  | 9240         | 9245
# chb06_02.edf    | Pre-Ictal  | 9250         | 9255
# chb06_02.edf    | Pre-Ictal  | 9260         | 9265
# chb06_02.edf    | Pre-Ictal  | 9270         | 9275
# chb06_02.edf    | Pre-Ictal  | 9280         | 9285
# chb06_02.edf    | Pre-Ictal  | 9290         | 9295
# chb06_02.edf    | Pre-Ictal  | 9300         | 9305
# chb06_02.edf    | Pre-Ictal  | 9310         | 9315
# chb06_02.edf    | Pre-Ictal  | 9320         | 9325
# chb06_02.edf    | Pre-Ictal  | 9330         | 9335
# chb06_02.edf    | Pre-Ictal  | 9340         | 9345
# chb06_02.edf    | Pre-Ictal  | 9350         | 9355
# chb06_02.edf    | Pre-Ictal  | 9360         | 9365
# chb06_02.edf    | Pre-Ictal  | 9370         | 9375
# chb06_02.edf    | Pre-Ictal  | 9380         | 9385
# chb06_02.edf    | Pre-Ictal  | 9390         | 9395
# chb06_02.edf    | Pre-Ictal  | 9400         | 9405
# chb06_02.edf    | Pre-Ictal  | 9410         | 9415
# chb06_02.edf    | Pre-Ictal  | 9420         | 9425
# chb06_02.edf    | Pre-Ictal  | 9430         | 9435
# chb06_02.edf    | Pre-Ictal  | 9440         | 9445
# chb06_02.edf    | Pre-Ictal  | 9450         | 9455
# chb06_02.edf    | Pre-Ictal  | 9460         | 9465
# chb06_02.edf    | Pre-Ictal  | 9470         | 9475
# chb06_02.edf    | Pre-Ictal  | 9480         | 9485
# chb06_02.edf    | Pre-Ictal  | 9490         | 9495
# chb06_02.edf    | Pre-Ictal  | 9500         | 9505
# chb06_02.edf    | Pre-Ictal  | 9510         | 9515
# chb06_02.edf    | Pre-Ictal  | 9520         | 9525
# chb06_02.edf    | Pre-Ictal  | 9530         | 9535
# chb06_02.edf    | Pre-Ictal  | 9540         | 9545
# chb06_02.edf    | Pre-Ictal  | 9550         | 9555
# chb06_02.edf    | Pre-Ictal  | 9560         | 9565
# chb06_02.edf    | Pre-Ictal  | 9570         | 9575
# chb06_02.edf    | Pre-Ictal  | 9580         | 9585
# chb06_02.edf    | Pre-Ictal  | 9590         | 9595
# chb06_02.edf    | Pre-Ictal  | 9600         | 9605
# chb06_02.edf    | Pre-Ictal  | 9610         | 9615
# chb06_02.edf    | Pre-Ictal  | 9620         | 9625
# chb06_02.edf    | Pre-Ictal  | 9630         | 9635
# chb06_02.edf    | Pre-Ictal  | 9640         | 9645
# chb06_02.edf    | Pre-Ictal  | 9650         | 9655
# chb06_02.edf    | Pre-Ictal  | 9660         | 9665
# chb06_02.edf    | Pre-Ictal  | 9670         | 9675
# ...
# chb06_24.edf    | Pre-Ictal  | 4240         | 4245
# chb06_24.edf    | Pre-Ictal  | 4250         | 4255
# chb06_24.edf    | Pre-Ictal  | 4260         | 4265
# chb06_24.edf    | Pre-Ictal  | 4270         | 4275
# chb06_24.edf    | Pre-Ictal  | 4280         | 4285
# chb06_24.edf    | Pre-Ictal  | 4290         | 4295
# chb06_24.edf    | Pre-Ictal  | 4300         | 4305
# chb06_24.edf    | Pre-Ictal  | 4310         | 4315
# chb06_24.edf    | Pre-Ictal  | 4320         | 4325
# chb06_24.edf    | Pre-Ictal  | 4330         | 4335
# chb06_24.edf    | Pre-Ictal  | 4340         | 4345
# chb06_24.edf    | Pre-Ictal  | 4350         | 4355
# chb06_24.edf    | Pre-Ictal  | 4360         | 4365
# chb06_24.edf    | Pre-Ictal  | 4370         | 4375
# chb06_24.edf    | Pre-Ictal  | 4380         | 4385
# chb06_24.edf    | Pre-Ictal  | 4390         | 4395
# chb06_24.edf    | Pre-Ictal  | 4400         | 4405
# chb06_24.edf    | Pre-Ictal  | 4410         | 4415
# chb06_24.edf    | Pre-Ictal  | 4420         | 4425
# chb06_24.edf    | Pre-Ictal  | 4430         | 4435
# chb06_24.edf    | Pre-Ictal  | 4440         | 4445
# chb06_24.edf    | Pre-Ictal  | 4450         | 4455
# chb06_24.edf    | Pre-Ictal  | 4460         | 4465
# chb06_24.edf    | Pre-Ictal  | 4470         | 4475
# chb06_24.edf    | Pre-Ictal  | 4480         | 4485
# chb06_24.edf    | Pre-Ictal  | 4490         | 4495
# chb06_24.edf    | Pre-Ictal  | 4500         | 4505
# chb06_24.edf    | Pre-Ictal  | 4510         | 4515
# chb06_24.edf    | Pre-Ictal  | 4520         | 4525
# chb06_24.edf    | Pre-Ictal  | 4530         | 4535
# chb06_24.edf    | Pre-Ictal  | 4540         | 4545
# chb06_24.edf    | Pre-Ictal  | 4550         | 4555
# chb06_24.edf    | Pre-Ictal  | 4560         | 4565
# chb06_24.edf    | Pre-Ictal  | 4570         | 4575
# chb06_24.edf    | Pre-Ictal  | 4580         | 4585
# chb06_24.edf    | Pre-Ictal  | 4590         | 4595
# chb06_24.edf    | Pre-Ictal  | 4600         | 4605
# chb06_24.edf    | Pre-Ictal  | 4610         | 4615
# chb06_24.edf    | Pre-Ictal  | 4620         | 4625
# chb06_24.edf    | Pre-Ictal  | 4630         | 4635
# chb06_24.edf    | Pre-Ictal  | 4640         | 4645
# chb06_24.edf    | Pre-Ictal  | 4650         | 4655
# chb06_24.edf    | Pre-Ictal  | 4660         | 4665
# chb06_24.edf    | Pre-Ictal  | 4670         | 4675
# chb06_24.edf    | Pre-Ictal  | 4680         | 4685
# chb06_24.edf    | Pre-Ictal  | 4690         | 4695
# chb06_24.edf    | Pre-Ictal  | 4700         | 4705
# chb06_24.edf    | Pre-Ictal  | 4710         | 4715
# chb06_24.edf    | Pre-Ictal  | 4720         | 4725
# chb06_24.edf    | Pre-Ictal  | 4730         | 4735
# chb06_24.edf    | Pre-Ictal  | 4740         | 4745
# chb06_24.edf    | Pre-Ictal  | 4750         | 4755
# chb06_24.edf    | Pre-Ictal  | 4760         | 4765
# chb06_24.edf    | Pre-Ictal  | 4770         | 4775
# chb06_24.edf    | Pre-Ictal  | 4780         | 4785
# chb06_24.edf    | Pre-Ictal  | 4790         | 4795
# chb06_24.edf    | Pre-Ictal  | 4800         | 4805
# chb06_24.edf    | Pre-Ictal  | 4810         | 4815
# chb06_24.edf    | Pre-Ictal  | 4820         | 4825
# chb06_24.edf    | Pre-Ictal  | 4830         | 4835
# chb06_24.edf    | Pre-Ictal  | 4840         | 4845
# chb06_24.edf    | Pre-Ictal  | 4850         | 4855
# chb06_24.edf    | Pre-Ictal  | 4860         | 4865
# chb06_24.edf    | Pre-Ictal  | 4870         | 4875
# chb06_24.edf    | Pre-Ictal  | 4880         | 4885
# chb06_24.edf    | Pre-Ictal  | 4890         | 4895
# chb06_24.edf    | Pre-Ictal  | 4900         | 4905
# chb06_24.edf    | Pre-Ictal  | 4910         | 4915
# chb06_24.edf    | Pre-Ictal  | 4920         | 4925
# chb06_24.edf    | Pre-Ictal  | 4930         | 4935
# chb06_24.edf    | Pre-Ictal  | 4940         | 4945
# chb06_24.edf    | Pre-Ictal  | 4950         | 4955
# chb06_24.edf    | Pre-Ictal  | 4960         | 4965
# chb06_24.edf    | Pre-Ictal  | 4970         | 4975
# chb06_24.edf    | Pre-Ictal  | 4980         | 4985
# chb06_24.edf    | Pre-Ictal  | 4990         | 4995
# chb06_24.edf    | Pre-Ictal  | 5000         | 5005
# chb06_24.edf    | Pre-Ictal  | 5010         | 5015
# chb06_24.edf    | Pre-Ictal  | 5020         | 5025
# chb06_24.edf    | Pre-Ictal  | 5030         | 5035
# chb06_24.edf    | Pre-Ictal  | 5040         | 5045
# chb06_24.edf    | Pre-Ictal  | 5050         | 5055
# chb06_24.edf    | Pre-Ictal  | 5060         | 5065
# chb06_24.edf    | Pre-Ictal  | 5070         | 5075
# chb06_24.edf    | Pre-Ictal  | 5080         | 5085
# chb06_24.edf    | Pre-Ictal  | 5090         | 5095
# chb06_24.edf    | Pre-Ictal  | 5100         | 5105
# chb06_24.edf    | Pre-Ictal  | 5110         | 5115
# chb06_24.edf    | Pre-Ictal  | 5120         | 5125
# chb06_24.edf    | Pre-Ictal  | 5130         | 5135
# chb06_24.edf    | Pre-Ictal  | 5140         | 5145
# chb06_24.edf    | Pre-Ictal  | 5150         | 5155
# chb06_24.edf    | Pre-Ictal  | 5160         | 5165
# chb06_24.edf    | Pre-Ictal  | 5170         | 5175
# chb06_24.edf    | Pre-Ictal  | 5180         | 5185
# chb06_24.edf    | Pre-Ictal  | 5190         | 5195
# chb06_24.edf    | Pre-Ictal  | 5200         | 5205
# chb06_24.edf    | Pre-Ictal  | 5210         | 5215
# chb06_24.edf    | Pre-Ictal  | 5220         | 5225
# chb06_24.edf    | Pre-Ictal  | 5230         | 5235
# chb06_24.edf    | Pre-Ictal  | 5240         | 5245
# chb06_24.edf    | Pre-Ictal  | 5250         | 5255
# chb06_24.edf    | Pre-Ictal  | 5260         | 5265
# chb06_24.edf    | Pre-Ictal  | 5270         | 5275
# chb06_24.edf    | Pre-Ictal  | 5280         | 5285
# chb06_24.edf    | Pre-Ictal  | 5290         | 5295
# chb06_24.edf    | Pre-Ictal  | 5300         | 5305
# chb06_24.edf    | Pre-Ictal  | 5310         | 5315
# chb06_24.edf    | Pre-Ictal  | 5320         | 5325
# chb06_24.edf    | Pre-Ictal  | 5330         | 5335
# chb06_24.edf    | Pre-Ictal  | 5340         | 5345
# chb06_24.edf    | Pre-Ictal  | 5350         | 5355
# chb06_24.edf    | Pre-Ictal  | 5360         | 5365
# chb06_24.edf    | Pre-Ictal  | 5370         | 5375
# chb06_24.edf    | Pre-Ictal  | 5380         | 5385
# chb06_24.edf    | Pre-Ictal  | 5390         | 5395
# chb06_24.edf    | Pre-Ictal  | 5400         | 5405
# chb06_24.edf    | Pre-Ictal  | 5410         | 5415
# chb06_24.edf    | Pre-Ictal  | 5420         | 5425
# chb06_24.edf    | Pre-Ictal  | 5430         | 5435
# chb06_24.edf    | Pre-Ictal  | 5440         | 5445
# chb06_24.edf    | Pre-Ictal  | 5450         | 5455
# chb06_24.edf    | Pre-Ictal  | 5460         | 5465
# chb06_24.edf    | Pre-Ictal  | 5470         | 5475
# chb06_24.edf    | Pre-Ictal  | 5480         | 5485
# chb06_24.edf    | Pre-Ictal  | 5490         | 5495
# chb06_24.edf    | Pre-Ictal  | 5500         | 5505
# chb06_24.edf    | Pre-Ictal  | 5510         | 5515
# chb06_24.edf    | Pre-Ictal  | 5520         | 5525
# chb06_24.edf    | Pre-Ictal  | 5530         | 5535
# chb06_24.edf    | Pre-Ictal  | 5540         | 5545
# chb06_24.edf    | Pre-Ictal  | 5550         | 5555
# chb06_24.edf    | Pre-Ictal  | 5560         | 5565
# chb06_24.edf    | Pre-Ictal  | 5570         | 5575
# chb06_24.edf    | Pre-Ictal  | 5580         | 5585
# chb06_24.edf    | Pre-Ictal  | 5590         | 5595
# chb06_24.edf    | Pre-Ictal  | 5600         | 5605
# chb06_24.edf    | Pre-Ictal  | 5610         | 5615
# chb06_24.edf    | Pre-Ictal  | 5620         | 5625
# chb06_24.edf    | Pre-Ictal  | 5630         | 5635
# chb06_24.edf    | Pre-Ictal  | 5640         | 5645
# chb06_24.edf    | Pre-Ictal  | 5650         | 5655
# chb06_24.edf    | Pre-Ictal  | 5660         | 5665
# chb06_24.edf    | Pre-Ictal  | 5670         | 5675
# chb06_24.edf    | Pre-Ictal  | 5680         | 5685
# chb06_24.edf    | Pre-Ictal  | 5690         | 5695
# chb06_24.edf    | Pre-Ictal  | 5700         | 5705
# chb06_24.edf    | Pre-Ictal  | 5710         | 5715
# chb06_24.edf    | Pre-Ictal  | 5720         | 5725
# chb06_24.edf    | Pre-Ictal  | 5730         | 5735
# chb06_24.edf    | Pre-Ictal  | 5740         | 5745
# chb06_24.edf    | Pre-Ictal  | 5750         | 5755
# chb06_24.edf    | Pre-Ictal  | 5760         | 5765
# chb06_24.edf    | Pre-Ictal  | 5770         | 5775
# chb06_24.edf    | Pre-Ictal  | 5780         | 5785
# chb06_24.edf    | Pre-Ictal  | 5790         | 5795
# chb06_24.edf    | Pre-Ictal  | 5800         | 5805
# chb06_24.edf    | Pre-Ictal  | 5810         | 5815
# chb06_24.edf    | Pre-Ictal  | 5820         | 5825
# chb06_24.edf    | Pre-Ictal  | 5830         | 5835
# chb06_24.edf    | Pre-Ictal  | 5840         | 5845
# chb06_24.edf    | Pre-Ictal  | 5850         | 5855
# chb06_24.edf    | Pre-Ictal  | 5860         | 5865
# chb06_24.edf    | Pre-Ictal  | 5870         | 5875
# chb06_24.edf    | Pre-Ictal  | 5880         | 5885
# chb06_24.edf    | Pre-Ictal  | 5890         | 5895
# chb06_24.edf    | Pre-Ictal  | 5900         | 5905
# chb06_24.edf    | Pre-Ictal  | 5910         | 5915
# chb06_24.edf    | Pre-Ictal  | 5920         | 5925
# chb06_24.edf    | Pre-Ictal  | 5930         | 5935
# chb06_24.edf    | Pre-Ictal  | 5940         | 5945
# chb06_24.edf    | Pre-Ictal  | 5950         | 5955
# chb06_24.edf    | Pre-Ictal  | 5960         | 5965
# chb06_24.edf    | Pre-Ictal  | 5970         | 5975
# chb06_24.edf    | Pre-Ictal  | 5980         | 5985
# chb06_24.edf    | Pre-Ictal  | 5990         | 5995
# chb06_24.edf    | Pre-Ictal  | 6000         | 6005
# chb06_24.edf    | Pre-Ictal  | 6010         | 6015
# chb06_24.edf    | Pre-Ictal  | 6020         | 6025
# chb06_24.edf    | Pre-Ictal  | 6030         | 6035
# chb06_24.edf    | Pre-Ictal  | 6040         | 6045
# chb06_24.edf    | Pre-Ictal  | 6050         | 6055
# chb06_24.edf    | Pre-Ictal  | 6060         | 6065
# chb06_24.edf    | Pre-Ictal  | 6070         | 6075
# chb06_24.edf    | Pre-Ictal  | 6080         | 6085
# chb06_24.edf    | Pre-Ictal  | 6090         | 6095
# chb06_24.edf    | Pre-Ictal  | 6100         | 6105
# chb06_24.edf    | Pre-Ictal  | 6110         | 6115
# chb06_24.edf    | Pre-Ictal  | 6120         | 6125
# chb06_24.edf    | Pre-Ictal  | 6130         | 6135
# chb06_24.edf    | Pre-Ictal  | 6140         | 6145
# chb06_24.edf    | Pre-Ictal  | 6150         | 6155
# chb06_24.edf    | Pre-Ictal  | 6160         | 6165
# chb06_24.edf    | Pre-Ictal  | 6170         | 6175
# chb06_24.edf    | Pre-Ictal  | 6180         | 6185
# chb06_24.edf    | Pre-Ictal  | 6190         | 6195
# chb06_24.edf    | Pre-Ictal  | 6200         | 6205
# chb06_24.edf    | Pre-Ictal  | 6210         | 6215
# chb06_24.edf    | Pre-Ictal  | 6220         | 6225
# chb06_24.edf    | Pre-Ictal  | 6230         | 6235
# chb06_24.edf    | Pre-Ictal  | 6240         | 6245
# chb06_24.edf    | Pre-Ictal  | 6250         | 6255
# chb06_24.edf    | Pre-Ictal  | 6260         | 6265
# chb06_24.edf    | Pre-Ictal  | 6270         | 6275
# chb06_24.edf    | Pre-Ictal  | 6280         | 6285
# chb06_24.edf    | Pre-Ictal  | 6290         | 6295
# chb06_24.edf    | Pre-Ictal  | 6300         | 6305
# chb06_24.edf    | Pre-Ictal  | 6310         | 6315
# chb06_24.edf    | Pre-Ictal  | 6320         | 6325
# chb06_24.edf    | Pre-Ictal  | 6330         | 6335
# chb06_24.edf    | Pre-Ictal  | 6340         | 6345
# chb06_24.edf    | Pre-Ictal  | 6350         | 6355
# chb06_24.edf    | Pre-Ictal  | 6360         | 6365
# chb06_24.edf    | Pre-Ictal  | 6370         | 6375
# chb06_24.edf    | Pre-Ictal  | 6380         | 6385
# chb06_24.edf    | Pre-Ictal  | 6390         | 6395
# chb06_24.edf    | Pre-Ictal  | 6400         | 6405
# chb06_24.edf    | Pre-Ictal  | 6410         | 6415
# chb06_24.edf    | Pre-Ictal  | 6420         | 6425
# chb06_24.edf    | Pre-Ictal  | 6430         | 6435
# chb06_24.edf    | Pre-Ictal  | 6440         | 6445
# chb06_24.edf    | Pre-Ictal  | 6450         | 6455
# chb06_24.edf    | Ictal      | 6460         | 9415
# chb06_24.edf    | Pre-Ictal  | 9420         | 9425
# chb06_24.edf    | Pre-Ictal  | 9430         | 9435
# chb06_24.edf    | Ictal      | 9440         | 9470
# chb06_24.edf    | Pre-Ictal  | 9475         | 9480
# chb06_24.edf    | Pre-Ictal  | 9485         | 9490
# chb06_24.edf    | Pre-Ictal  | 9495         | 9500
# chb06_24.edf    | Pre-Ictal  | 9505         | 9510
# chb06_24.edf    | Pre-Ictal  | 9515         | 9520
# chb06_24.edf    | Pre-Ictal  | 9525         | 9530
# chb06_24.edf    | Ictal      | 9535         | 10200
# chb06_24.edf    | Pre-Ictal  | 10205        | 10210
# chb06_24.edf    | Pre-Ictal  | 10215        | 10220
# chb06_24.edf    | Pre-Ictal  | 10225        | 10230
# chb06_24.edf    | Pre-Ictal  | 10235        | 10240
# chb06_24.edf    | Ictal      | 10245        | 10880
# chb06_24.edf    | Pre-Ictal  | 10885        | 10890
# chb06_24.edf    | Pre-Ictal  | 10895        | 10900
# chb06_24.edf    | Pre-Ictal  | 10905        | 10910
# chb06_24.edf    | Pre-Ictal  | 10915        | 10920
# chb06_24.edf    | Pre-Ictal  | 10925        | 10930
# chb06_24.edf    | Ictal      | 10935        | 11405
# chb06_24.edf    | Pre-Ictal  | 11410        | 11415
# chb06_24.edf    | Pre-Ictal  | 11420        | 11425
# chb06_24.edf    | Pre-Ictal  | 11430        | 11435
# chb06_24.edf    | Pre-Ictal  | 11440        | 11445
# chb06_24.edf    | Pre-Ictal  | 11450        | 11455
# chb06_24.edf    | Ictal      | 11460        | 13830
# chb06_24.edf    | Pre-Ictal  | 13835        | 13840
# chb06_24.edf    | Pre-Ictal  | 13845        | 13850
# chb06_24.edf    | Pre-Ictal  | 13855        | 13860
# chb06_24.edf    | Pre-Ictal  | 13865        | 13870
# chb06_24.edf    | Ictal      | 13875        | 13895
# chb06_24.edf    | Pre-Ictal  | 13900        | 13905
# chb06_24.edf    | Pre-Ictal  | 13910        | 13915
# chb06_24.edf    | Ictal      | 13920        | 14000
# chb06_24.edf    | Pre-Ictal  | 14005        | 14010
# chb06_24.edf    | Pre-Ictal  | 14015        | 14020
# chb06_24.edf    | Ictal      | 14025        | 14050
# chb06_24.edf    | Pre-Ictal  | 14055        | 14060
# chb06_24.edf    | Pre-Ictal  | 14065        | 14070
# chb06_24.edf    | Ictal      | 14075        | 14115
# chb06_24.edf    | Pre-Ictal  | 14120        | 14125
# chb06_24.edf    | Pre-Ictal  | 14130        | 14135
# chb06_24.edf    | Pre-Ictal  | 14140        | 14145
# chb06_24.edf    | Ictal      | 14150        | 14260
# chb06_24.edf    | Pre-Ictal  | 14265        | 14270
# chb06_24.edf    | Pre-Ictal  | 14275        | 14280
# chb06_24.edf    | Ictal      | 14285        | 14400

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb06_01.edf": [(1724, 1738), (7461, 7476), (13525, 13540)],
    "chb06_04.edf": [(327, 347), (6211, 6231)],
    "chb06_09.edf": [(12500, 12516)],
    "chb06_10.edf": [(10833, 10845)],
    "chb06_13.edf": [(506, 519)],
    "chb06_18.edf": [(7799, 7811)],
    "chb06_24.edf": [(9387, 9403)],
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

# --- 1. Define the Prediction Target (Respecting File Boundaries) ---
PREDICTION_WINDOW_MIN = 90.0
y_true = np.zeros(len(t_min))
current_idx = 0

for i, length in enumerate(lengths):
    fname = os.path.basename(train_files[i]["path"])
    # Create a time axis for JUST this file
    file_t_min = (np.arange(length) * WINDOW_SEC) / 60.0
    file_y = np.zeros(length)
    
    if fname in clinical:
        for (s0, s1) in clinical[fname]:
            # Mark windows where a seizure starts within the next 90 mins IN THIS FILE
            start_min = s0 / 60.0
            mask = (file_t_min <= start_min) & (file_t_min >= start_min - PREDICTION_WINDOW_MIN)
            file_y[mask] = 1
    
    # Place this file's ground truth into the global array
    y_true[current_idx : current_idx + length] = file_y
    current_idx += length

# --- 2. Calculate Probabilities for different Thresholds (m) ---
thresholds = np.linspace(0, 0.9, 19) 
observed_probs = []

for m in thresholds:
    alarm_mask = pre_density > m
    if np.any(alarm_mask):
        # Accuracy: How often was our alarm followed by a seizure?
        prob = np.mean(y_true[alarm_mask])
        observed_probs.append(prob)
    else:
        observed_probs.append(0.0)

# --- 3. Statistical Significance (Monte Carlo / Surrogate Test) ---
# We shuffle WITHIN the constraints of the data to see if we beat chance
n_permutations = 1000
surrogate_max_probs = []

print(f"Running {n_permutations} permutations for statistical significance...")
for _ in tqdm(range(n_permutations)):
    # Randomly shuffle the TRUE labels to create a "fake" patient history
    y_surrogate = np.random.permutation(y_true)

    # Calculate the max probability achieved by chance for ANY threshold
    chance_probs = [np.mean(y_surrogate[pre_density > m]) if np.any(pre_density > m) else 0 for m in thresholds]
    surrogate_max_probs.append(np.max(chance_probs))

# Calculate p-value for each threshold
p_values = []
for i, m in enumerate(thresholds):
    better_than_us = np.sum(np.array(surrogate_max_probs) >= observed_probs[i])
    p_values.append(better_than_us / n_permutations)

# --- 4. Results Table & Plotting ---
results_df = pd.DataFrame({
    "Threshold (m)": thresholds,
    "Seizure Probability (x%)": np.array(observed_probs) * 100,
    "P-Value": p_values,
    "Significant (p<0.05)": np.array(p_values) < 0.05
})

print("\nThreshold Analysis Results (File-Aware):")
print(results_df.to_string(index=False))

# Visualization
plt.figure(figsize=(10, 5))
plt.plot(thresholds, np.array(observed_probs)*100, marker='o', label="Observed Probability")
plt.axhline(y=np.mean(surrogate_max_probs)*100, color='r', linestyle='--', label="Chance Level (Mean)")
plt.fill_between(thresholds, 0, 100, where=results_df["Significant (p<0.05)"], 
                 color='green', alpha=0.1, label="Statistically Significant Zone")

plt.xlabel("Density Threshold (m)")
plt.ylabel("Probability of Seizure in next 90m (%)")
plt.title("Optimal Threshold for Seizure Prediction (Corrected)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Running 1000 permutations for statistical significance...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1095.68it/s]
# Threshold Analysis Results (File-Aware):
#  Threshold (m)  Seizure Probability (x%)  P-Value  Significant (p<0.05)
#           0.00                 18.915711      0.0                  True
#           0.05                 20.662803      0.0                  True
#           0.10                 21.322157      0.0                  True
#           0.15                 21.655097      0.0                  True
#           0.20                 21.772759      0.0                  True
#           0.25                 21.050902      0.0                  True
#           0.30                 20.662252      0.0                  True
#           0.35                 20.228191      0.0                  True
#           0.40                 20.555018      0.0                  True
#           0.45                 20.186159      0.0                  True
#           0.50                  0.000000      1.0                 False
#           0.55                  0.000000      1.0                 False
#           0.60                  0.000000      1.0                 False
#           0.65                  0.000000      1.0                 False
#           0.70                  0.000000      1.0                 False
#           0.75                  0.000000      1.0                 False
#           0.80                  0.000000      1.0                 False
#           0.85                  0.000000      1.0                 False
#           0.90                  0.000000      1.0                 False

# %%
import numpy as np
import os

# --- Clinical Evaluation Parameters ---
SPH_SEC = 5 * 60          # 5 minutes minimum warning
SOP_SEC = 85 * 60         # 85 minutes occurrence period 
REFRACTORY_SEC = 90 * 60  # 90 minutes silence after an alarm is triggered

# 1. Build a list of exact clinical seizure start times in the global timeline
global_seizure_onsets = []
file_start_sec = np.cumsum([0] + lengths[:-1]) * WINDOW_SEC

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname in clinical:
        base_sec = file_start_sec[i]
        for (s0, s1) in clinical[fname]:
            global_seizure_onsets.append(base_sec + s0)

# 2. Setup Evaluation Loop
total_hours = len(hidden_states) * WINDOW_SEC / 3600.0
total_days = total_hours / 24.0

print(f"Total Recording Time: {total_hours:.2f} hours ({total_days:.2f} days)")
print(f"Total Clinical Seizures: {len(global_seizure_onsets)}")
print(f"Parameters -> SPH: {SPH_SEC/60:.0f}m | SOP: {SOP_SEC/60:.0f}m | Refractory: {REFRACTORY_SEC/60:.0f}m")
print("-" * 75)
print(f"{'Threshold (m)':<15} | {'Sensitivity':<15} | {'False Alarms / 24h':<20}")
print("-" * 75)

# 3. Chronological Alarm Evaluation
for m in [0.55, 0.65, 0.75, 0.85, 0.90]:
    false_positives = 0
    seizures_caught = set() # Track by ID so we don't double-count catching the same seizure
    
    next_allowed_alarm_sec = 0.0
    
    # Find all windows where density exceeds threshold
    alarm_indices = np.where(pre_density > m)[0]
    
    for idx in alarm_indices:
        current_sec = idx * WINDOW_SEC
        
        # Check if the device is allowed to ring (outside refractory period)
        if current_sec >= next_allowed_alarm_sec:
            next_allowed_alarm_sec = current_sec + REFRACTORY_SEC
            
            # Define the valid prediction window for this specific alarm
            pred_window_start = current_sec + SPH_SEC
            pred_window_end = current_sec + SPH_SEC + SOP_SEC
            
            # Did any seizure onset fall inside this window?
            caught_any = False
            for sz_idx, sz_sec in enumerate(global_seizure_onsets):
                if pred_window_start <= sz_sec <= pred_window_end:
                    caught_any = True
                    seizures_caught.add(sz_idx)
                    
            if not caught_any:
                # Alarm rang, but no seizure occurred in the SOP
                false_positives += 1
                
    # Calculate final clinical metrics
    far_per_24h = false_positives / total_days if total_days > 0 else 0
    sensitivity = (len(seizures_caught) / len(global_seizure_onsets)) * 100 if len(global_seizure_onsets) > 0 else 0
    
    print(f"{m:<15.2f} | {sensitivity:<13.1f}% | {far_per_24h:<20.2f}")
# Out:
# Total Recording Time: 66.73 hours (2.78 days)
# Total Clinical Seizures: 10
# Parameters -> SPH: 5m | SOP: 85m | Refractory: 90m
# ---------------------------------------------------------------------------
# Threshold (m)   | Sensitivity     | False Alarms / 24h
# ---------------------------------------------------------------------------
# 0.55            | 0.0          % | 0.00
# 0.65            | 0.0          % | 0.00
# 0.75            | 0.0          % | 0.00
# 0.85            | 0.0          % | 0.00
# 0.90            | 0.0          % | 0.00

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# --- 1. Choose the threshold we want to visualize ---
target_m = 0.90

# --- 2. Re-run the strict device logic for just this threshold ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC-Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

# Track legend entries to avoid duplicates
seen_labels = set()

# Plot Clinical Seizures
for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

# Plot Alarms, SOPs, and Refractory Periods
for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    # 1. The Alarm Trigger
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    # 2. Refractory Period (Red hatched background)
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = "Refractory Period (Snooze)" if "Refractory Period (Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add("Refractory Period (Snooze)")
    
    # 3. SOP (Green expected seizure window)
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    # Plot as a line block slightly above the graph to keep it clean
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"Clinical Device Simulation (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

# Put legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. The Final PLV Goldilocks Parameters ---
target_m = 0.75
REFRACTORY_SEC = 60 * 60  # 60 minute snooze

# --- 2. Re-run the strict device logic ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC+PLV Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

seen_labels = set()

for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
    
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"FINAL Clinical Device Simulation: PLV Edition (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. The PLV-Optimized Goldilocks Parameters ---
target_m = 0.80
REFRACTORY_SEC = 60 * 60  # Shortened to 60 minutes to prevent shadowing

# --- 2. Re-run the strict device logic for just this threshold ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC+PLV Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

# Track legend entries to avoid duplicates
seen_labels = set()

# Plot Clinical Seizures
for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

# Plot Alarms, SOPs, and Refractory Periods
for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    # 1. The Alarm Trigger
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    # 2. Refractory Period (Red hatched background)
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
    
    # 3. SOP (Green expected seizure window)
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"Clinical Device Simulation: PLV Edition (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

# Put legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()
