# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization
    6. Spectral Edge Frequency 95%
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        sync_scores = []
        for li, ri in PAIRS_LR:
            c = np.corrcoef(X[li], X[ri])[0, 1]
            sync_scores.append(c)
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        df = np.diff(freqs)
        df = np.r_[df, df[-1]]
        power_bins = psd * df
        cumulative_power = np.cumsum(power_bins, axis=1)
        total_power = cumulative_power[:, -1]
        sef_indices = np.argmax(cumulative_power >= 0.95 * total_power[:, None], axis=1)
        avg_sef95 = freqs[sef_indices].mean()

        features.append([ta_ratio, complexity, line_length, rms, avg_sync])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb02) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_11.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_19.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_20.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_21.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_22.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_23.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_24.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb02/chb02_25.edf"}
]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 20/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_41053/2039753222.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 25/25 files; last epochs=720
# Loading complete.

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.9348   0.0652   0.0000
# State 1   0.0581   0.8894   0.0525
# State 2   0.0010   0.0684   0.9306

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : -0.519
#   PermEntropy : -0.409
#   LineLength  : -0.557
#   RMS         : -0.660
#   Avg Sync    : +0.109
#
# State 1 means:
#   TA_ratio    : -0.005
#   PermEntropy : -0.024
#   LineLength  : -0.110
#   RMS         : -0.110
#   Avg Sync    : +0.025
#
# State 2 means:
#   TA_ratio    : +0.633
#   PermEntropy : +0.525
#   LineLength  : +0.817
#   RMS         : +0.942
#   Avg Sync    : -0.165

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy,
# [2] LineLength, [3] RMS

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3

# Ictal: high line length + high RMS
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# Baseline: highest entropy among remaining states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
baseline_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_ENT])]
)

# Pre-ictal: whatever state is left (for 3-state HMM)
preictal_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, baseline_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb02_01.edf    | Ictal      | 0            | 15
# chb02_01.edf    | Pre-Ictal  | 15           | 100
# chb02_01.edf    | Ictal      | 130          | 155
# chb02_01.edf    | Pre-Ictal  | 185          | 220
# chb02_01.edf    | Ictal      | 270          | 320
# chb02_01.edf    | Pre-Ictal  | 345          | 365
# chb02_01.edf    | Pre-Ictal  | 395          | 780
# chb02_01.edf    | Ictal      | 790          | 880
# chb02_01.edf    | Ictal      | 920          | 1005
# chb02_01.edf    | Ictal      | 1095         | 1130
# chb02_01.edf    | Pre-Ictal  | 1160         | 1695
# chb02_01.edf    | Ictal      | 1710         | 1765
# chb02_01.edf    | Pre-Ictal  | 1805         | 1830
# chb02_01.edf    | Pre-Ictal  | 1860         | 1915
# chb02_01.edf    | Ictal      | 1925         | 2000
# chb02_01.edf    | Pre-Ictal  | 2010         | 2170
# chb02_01.edf    | Pre-Ictal  | 2235         | 2305
# chb02_01.edf    | Pre-Ictal  | 2350         | 2385
# chb02_01.edf    | Ictal      | 2475         | 2690
# chb02_01.edf    | Ictal      | 2700         | 2840
# chb02_01.edf    | Pre-Ictal  | 2955         | 3015
# chb02_01.edf    | Pre-Ictal  | 3145         | 3190
# chb02_02.edf    | Ictal      | 20           | 85
# chb02_02.edf    | Pre-Ictal  | 95           | 120
# chb02_02.edf    | Pre-Ictal  | 160          | 180
# chb02_02.edf    | Ictal      | 190          | 215
# chb02_02.edf    | Pre-Ictal  | 235          | 280
# chb02_02.edf    | Ictal      | 345          | 370
# chb02_02.edf    | Pre-Ictal  | 410          | 425
# chb02_02.edf    | Pre-Ictal  | 460          | 530
# chb02_02.edf    | Pre-Ictal  | 620          | 655
# chb02_02.edf    | Pre-Ictal  | 700          | 755
# chb02_02.edf    | Pre-Ictal  | 805          | 835
# chb02_02.edf    | Ictal      | 840          | 880
# chb02_02.edf    | Ictal      | 950          | 1060
# chb02_02.edf    | Ictal      | 1165         | 1255
# chb02_02.edf    | Pre-Ictal  | 1295         | 1395
# chb02_02.edf    | Ictal      | 1415         | 1465
# chb02_02.edf    | Pre-Ictal  | 1535         | 1560
# chb02_02.edf    | Ictal      | 1570         | 1650
# chb02_02.edf    | Ictal      | 1670         | 1695
# chb02_02.edf    | Pre-Ictal  | 1700         | 1740
# chb02_02.edf    | Ictal      | 1800         | 1875
# chb02_02.edf    | Pre-Ictal  | 1880         | 1895
# chb02_02.edf    | Ictal      | 2095         | 2145
# chb02_02.edf    | Ictal      | 2180         | 2250
# chb02_02.edf    | Pre-Ictal  | 2320         | 2350
# chb02_02.edf    | Pre-Ictal  | 2605         | 2645
# chb02_02.edf    | Pre-Ictal  | 2730         | 2770
# chb02_02.edf    | Ictal      | 2785         | 2805
# chb02_02.edf    | Ictal      | 2915         | 3030
# chb02_02.edf    | Ictal      | 3085         | 3125
# chb02_02.edf    | Pre-Ictal  | 3175         | 3265
# chb02_02.edf    | Pre-Ictal  | 3320         | 3350
# chb02_02.edf    | Ictal      | 3360         | 3380
# chb02_02.edf    | Pre-Ictal  | 3390         | 3455
# chb02_02.edf    | Pre-Ictal  | 3510         | 3540
# chb02_02.edf    | Ictal      | 3565         | 3600
# chb02_03.edf    | Pre-Ictal  | 0            | 30
# chb02_03.edf    | Pre-Ictal  | 80           | 250
# chb02_03.edf    | Ictal      | 260          | 540
# chb02_03.edf    | Pre-Ictal  | 555          | 615
# chb02_03.edf    | Pre-Ictal  | 675          | 905
# chb02_03.edf    | Pre-Ictal  | 915          | 1095
# chb02_03.edf    | Pre-Ictal  | 1130         | 1605
# chb02_03.edf    | Ictal      | 1625         | 1745
# chb02_03.edf    | Pre-Ictal  | 1760         | 1805
# chb02_03.edf    | Ictal      | 1820         | 1925
# chb02_03.edf    | Ictal      | 1970         | 2010
# chb02_03.edf    | Pre-Ictal  | 2035         | 2080
# chb02_03.edf    | Ictal      | 2085         | 2125
# chb02_03.edf    | Ictal      | 2160         | 2200
# chb02_03.edf    | Ictal      | 2235         | 2485
# chb02_03.edf    | Ictal      | 2520         | 2545
# chb02_03.edf    | Pre-Ictal  | 2555         | 2585
# chb02_03.edf    | Pre-Ictal  | 2635         | 2720
# chb02_03.edf    | Pre-Ictal  | 2750         | 2805
# chb02_03.edf    | Ictal      | 2810         | 2885
# chb02_03.edf    | Pre-Ictal  | 2895         | 2950
# chb02_03.edf    | Ictal      | 2955         | 3055
# chb02_03.edf    | Pre-Ictal  | 3070         | 3085
# chb02_03.edf    | Ictal      | 3110         | 3165
# chb02_03.edf    | Pre-Ictal  | 3175         | 3195
# chb02_03.edf    | Ictal      | 3200         | 3265
# chb02_03.edf    | Pre-Ictal  | 3335         | 3380
# chb02_03.edf    | Ictal      | 3385         | 3405
# chb02_03.edf    | Ictal      | 3465         | 3495
# chb02_03.edf    | Ictal      | 3540         | 3600
# chb02_04.edf    | Ictal      | 0            | 130
# chb02_04.edf    | Ictal      | 180          | 260
# chb02_04.edf    | Pre-Ictal  | 320          | 335
# chb02_04.edf    | Ictal      | 355          | 395
# chb02_04.edf    | Ictal      | 465          | 490
# chb02_04.edf    | Ictal      | 550          | 630
# chb02_04.edf    | Ictal      | 685          | 730
# chb02_04.edf    | Pre-Ictal  | 740          | 755
# chb02_04.edf    | Ictal      | 770          | 850
# chb02_04.edf    | Ictal      | 940          | 970
# chb02_04.edf    | Ictal      | 1025         | 1045
# chb02_04.edf    | Ictal      | 1105         | 1135
# chb02_04.edf    | Pre-Ictal  | 1305         | 1335
# chb02_04.edf    | Ictal      | 1555         | 1575
# chb02_04.edf    | Ictal      | 1755         | 1810
# chb02_04.edf    | Pre-Ictal  | 1895         | 1990
# chb02_04.edf    | Pre-Ictal  | 2035         | 2060
# chb02_04.edf    | Pre-Ictal  | 2085         | 2255
# chb02_04.edf    | Pre-Ictal  | 2335         | 2430
# chb02_04.edf    | Ictal      | 2455         | 2475
# chb02_04.edf    | Pre-Ictal  | 2490         | 2800
# chb02_04.edf    | Ictal      | 2875         | 2895
# chb02_04.edf    | Pre-Ictal  | 2910         | 2955
# chb02_04.edf    | Pre-Ictal  | 3000         | 3075
# chb02_04.edf    | Pre-Ictal  | 3125         | 3145
# chb02_04.edf    | Pre-Ictal  | 3175         | 3190
# chb02_04.edf    | Pre-Ictal  | 3220         | 3235
# chb02_04.edf    | Ictal      | 3250         | 3295
# chb02_04.edf    | Pre-Ictal  | 3310         | 3440
# chb02_04.edf    | Pre-Ictal  | 3505         | 3540
# chb02_05.edf    | Ictal      | 0            | 15
# chb02_05.edf    | Pre-Ictal  | 30           | 50
# chb02_05.edf    | Ictal      | 55           | 155
# chb02_05.edf    | Ictal      | 255          | 345
# chb02_05.edf    | Pre-Ictal  | 350          | 375
# chb02_05.edf    | Ictal      | 385          | 440
# chb02_05.edf    | Pre-Ictal  | 450          | 545
# chb02_05.edf    | Ictal      | 550          | 575
# chb02_05.edf    | Pre-Ictal  | 580          | 660
# chb02_05.edf    | Ictal      | 670          | 690
# chb02_05.edf    | Pre-Ictal  | 725          | 805
# chb02_05.edf    | Ictal      | 845          | 855
# chb02_05.edf    | Pre-Ictal  | 870          | 1120
# chb02_05.edf    | Pre-Ictal  | 1155         | 1195
# chb02_05.edf    | Pre-Ictal  | 1235         | 1310
# chb02_05.edf    | Pre-Ictal  | 1350         | 1405
# chb02_05.edf    | Pre-Ictal  | 1435         | 1455
# chb02_05.edf    | Pre-Ictal  | 1540         | 1590
# chb02_05.edf    | Ictal      | 1600         | 1625
# chb02_05.edf    | Ictal      | 1665         | 1685
# chb02_05.edf    | Pre-Ictal  | 1695         | 1720
# chb02_05.edf    | Ictal      | 1730         | 1815
# chb02_05.edf    | Pre-Ictal  | 1855         | 1915
# chb02_05.edf    | Pre-Ictal  | 1940         | 2025
# chb02_05.edf    | Pre-Ictal  | 2055         | 2170
# chb02_05.edf    | Ictal      | 2175         | 2245
# chb02_05.edf    | Pre-Ictal  | 2300         | 2395
# chb02_05.edf    | Ictal      | 2405         | 2430
# chb02_05.edf    | Ictal      | 2460         | 2495
# chb02_05.edf    | Pre-Ictal  | 2510         | 2530
# chb02_05.edf    | Ictal      | 2575         | 2680
# chb02_05.edf    | Ictal      | 2695         | 2770
# chb02_05.edf    | Ictal      | 2800         | 2820
# chb02_05.edf    | Pre-Ictal  | 2830         | 2860
# chb02_05.edf    | Ictal      | 2875         | 3285
# chb02_05.edf    | Pre-Ictal  | 3320         | 3345
# chb02_05.edf    | Pre-Ictal  | 3390         | 3425
# chb02_05.edf    | Ictal      | 3435         | 3480
# chb02_05.edf    | Ictal      | 3530         | 3555
# chb02_05.edf    | Ictal      | 3580         | 3600
# chb02_06.edf    | Ictal      | 0            | 45
# chb02_06.edf    | Pre-Ictal  | 50           | 70
# chb02_06.edf    | Pre-Ictal  | 95           | 115
# chb02_06.edf    | Ictal      | 120          | 215
# chb02_06.edf    | Pre-Ictal  | 230          | 295
# chb02_06.edf    | Ictal      | 335          | 380
# chb02_06.edf    | Ictal      | 410          | 420
# chb02_06.edf    | Ictal      | 550          | 655
# chb02_06.edf    | Ictal      | 695          | 705
# chb02_06.edf    | Ictal      | 780          | 840
# chb02_06.edf    | Pre-Ictal  | 845          | 910
# chb02_06.edf    | Pre-Ictal  | 1115         | 1135
# chb02_06.edf    | Pre-Ictal  | 1160         | 1285
# chb02_06.edf    | Ictal      | 1290         | 1340
# chb02_06.edf    | Pre-Ictal  | 1345         | 1365
# chb02_06.edf    | Ictal      | 1420         | 1440
# chb02_06.edf    | Pre-Ictal  | 1450         | 1485
# chb02_06.edf    | Ictal      | 1535         | 1655
# chb02_06.edf    | Pre-Ictal  | 1670         | 1735
# chb02_06.edf    | Ictal      | 1750         | 1765
# chb02_06.edf    | Ictal      | 1825         | 1850
# chb02_06.edf    | Pre-Ictal  | 1910         | 1950
# chb02_06.edf    | Pre-Ictal  | 1980         | 2015
# chb02_06.edf    | Ictal      | 2070         | 2115
# chb02_06.edf    | Pre-Ictal  | 2160         | 2190
# chb02_06.edf    | Ictal      | 2200         | 2280
# chb02_06.edf    | Pre-Ictal  | 2410         | 2500
# chb02_06.edf    | Pre-Ictal  | 2530         | 2580
# chb02_06.edf    | Ictal      | 2595         | 2620
# chb02_06.edf    | Pre-Ictal  | 2900         | 2950
# chb02_06.edf    | Ictal      | 3055         | 3075
# chb02_06.edf    | Pre-Ictal  | 3085         | 3105
# chb02_06.edf    | Pre-Ictal  | 3185         | 3395
# chb02_06.edf    | Pre-Ictal  | 3470         | 3530
# chb02_06.edf    | Pre-Ictal  | 3555         | 3570
# chb02_06.edf    | Pre-Ictal  | 3590         | 3600
# chb02_07.edf    | Pre-Ictal  | 5            | 15
# chb02_07.edf    | Ictal      | 35           | 115
# chb02_07.edf    | Ictal      | 150          | 170
# chb02_07.edf    | Ictal      | 190          | 215
# chb02_07.edf    | Ictal      | 245          | 320
# chb02_07.edf    | Ictal      | 355          | 380
# chb02_07.edf    | Pre-Ictal  | 390          | 405
# chb02_07.edf    | Ictal      | 425          | 470
# chb02_07.edf    | Ictal      | 560          | 585
# chb02_07.edf    | Pre-Ictal  | 590          | 655
# chb02_07.edf    | Pre-Ictal  | 680          | 755
# chb02_07.edf    | Pre-Ictal  | 770          | 860
# chb02_07.edf    | Pre-Ictal  | 895          | 920
# chb02_07.edf    | Pre-Ictal  | 940          | 965
# chb02_07.edf    | Ictal      | 1165         | 1185
# chb02_07.edf    | Ictal      | 1225         | 1335
# chb02_07.edf    | Ictal      | 1370         | 1515
# chb02_07.edf    | Ictal      | 1545         | 1675
# chb02_07.edf    | Ictal      | 1865         | 1910
# chb02_07.edf    | Ictal      | 1940         | 1965
# chb02_07.edf    | Pre-Ictal  | 1980         | 2005
# chb02_07.edf    | Pre-Ictal  | 2140         | 2485
# chb02_07.edf    | Ictal      | 2490         | 2505
# chb02_07.edf    | Pre-Ictal  | 2510         | 2585
# chb02_07.edf    | Ictal      | 2610         | 2680
# chb02_07.edf    | Ictal      | 2730         | 2765
# chb02_07.edf    | Pre-Ictal  | 2805         | 2820
# chb02_07.edf    | Ictal      | 2895         | 2920
# chb02_07.edf    | Pre-Ictal  | 2940         | 2960
# chb02_07.edf    | Ictal      | 2990         | 3065
# chb02_07.edf    | Ictal      | 3150         | 3170
# chb02_07.edf    | Ictal      | 3200         | 3305
# chb02_07.edf    | Pre-Ictal  | 3325         | 3505
# chb02_07.edf    | Ictal      | 3550         | 3600
# chb02_08.edf    | Pre-Ictal  | 45           | 90
# chb02_08.edf    | Pre-Ictal  | 125          | 285
# chb02_08.edf    | Pre-Ictal  | 350          | 400
# chb02_08.edf    | Pre-Ictal  | 435          | 505
# chb02_08.edf    | Ictal      | 565          | 700
# chb02_08.edf    | Ictal      | 725          | 805
# chb02_08.edf    | Pre-Ictal  | 810          | 880
# chb02_08.edf    | Ictal      | 925          | 950
# chb02_08.edf    | Pre-Ictal  | 955          | 980
# chb02_08.edf    | Ictal      | 985          | 1030
# chb02_08.edf    | Pre-Ictal  | 1060         | 1145
# chb02_08.edf    | Pre-Ictal  | 1270         | 1585
# chb02_08.edf    | Ictal      | 1605         | 1820
# chb02_08.edf    | Ictal      | 1840         | 1955
# chb02_08.edf    | Ictal      | 1975         | 2000
# chb02_08.edf    | Ictal      | 2020         | 2045
# chb02_08.edf    | Pre-Ictal  | 2085         | 2115
# chb02_08.edf    | Pre-Ictal  | 2175         | 2215
# chb02_08.edf    | Pre-Ictal  | 2245         | 2290
# chb02_08.edf    | Pre-Ictal  | 2310         | 2365
# chb02_08.edf    | Ictal      | 2380         | 2515
# chb02_08.edf    | Pre-Ictal  | 2570         | 2645
# chb02_08.edf    | Ictal      | 2720         | 2740
# chb02_08.edf    | Pre-Ictal  | 2750         | 2790
# chb02_08.edf    | Pre-Ictal  | 2880         | 3000
# chb02_08.edf    | Pre-Ictal  | 3025         | 3115
# chb02_08.edf    | Ictal      | 3175         | 3220
# chb02_08.edf    | Ictal      | 3250         | 3305
# chb02_08.edf    | Pre-Ictal  | 3360         | 3375
# chb02_08.edf    | Pre-Ictal  | 3415         | 3445
# chb02_08.edf    | Ictal      | 3470         | 3600
# chb02_09.edf    | Ictal      | 0            | 5
# chb02_09.edf    | Ictal      | 40           | 75
# chb02_09.edf    | Ictal      | 95           | 185
# chb02_09.edf    | Ictal      | 225          | 445
# chb02_09.edf    | Ictal      | 480          | 515
# chb02_09.edf    | Ictal      | 535          | 595
# chb02_09.edf    | Ictal      | 700          | 875
# chb02_09.edf    | Pre-Ictal  | 885          | 915
# chb02_09.edf    | Ictal      | 945          | 1210
# chb02_09.edf    | Pre-Ictal  | 1210         | 1580
# chb02_09.edf    | Pre-Ictal  | 1615         | 1675
# chb02_09.edf    | Ictal      | 1845         | 1875
# chb02_09.edf    | Pre-Ictal  | 1900         | 2150
# chb02_09.edf    | Ictal      | 2450         | 2475
# chb02_09.edf    | Ictal      | 2510         | 3600
# chb02_10.edf    | Ictal      | 0            | 935
# chb02_10.edf    | Pre-Ictal  | 940          | 1215
# chb02_10.edf    | Pre-Ictal  | 1235         | 1495
# chb02_10.edf    | Pre-Ictal  | 1520         | 1710
# chb02_10.edf    | Pre-Ictal  | 1740         | 1890
# chb02_10.edf    | Pre-Ictal  | 1925         | 1950
# chb02_10.edf    | Pre-Ictal  | 2090         | 2190
# chb02_10.edf    | Ictal      | 2390         | 2470
# chb02_10.edf    | Pre-Ictal  | 2475         | 2640
# chb02_10.edf    | Pre-Ictal  | 2685         | 2995
# chb02_10.edf    | Pre-Ictal  | 3065         | 3085
# chb02_10.edf    | Ictal      | 3360         | 3395
# chb02_10.edf    | Pre-Ictal  | 3415         | 3470
# chb02_10.edf    | Pre-Ictal  | 3500         | 3530
# chb02_10.edf    | Ictal      | 3550         | 3600
# chb02_11.edf    | Pre-Ictal  | 175          | 215
# chb02_11.edf    | Pre-Ictal  | 400          | 440
# chb02_11.edf    | Ictal      | 650          | 695
# chb02_11.edf    | Pre-Ictal  | 815          | 835
# chb02_11.edf    | Ictal      | 945          | 995
# chb02_11.edf    | Ictal      | 1505         | 2275
# chb02_11.edf    | Ictal      | 2365         | 2415
# chb02_11.edf    | Pre-Ictal  | 2420         | 3600
# chb02_12.edf    | Pre-Ictal  | 0            | 55
# chb02_12.edf    | Ictal      | 95           | 135
# chb02_12.edf    | Pre-Ictal  | 645          | 675
# chb02_12.edf    | Pre-Ictal  | 815          | 900
# chb02_12.edf    | Pre-Ictal  | 1065         | 1120
# chb02_12.edf    | Ictal      | 1300         | 1340
# chb02_12.edf    | Pre-Ictal  | 1360         | 1390
# chb02_12.edf    | Pre-Ictal  | 1440         | 1475
# chb02_12.edf    | Pre-Ictal  | 1670         | 1720
# chb02_12.edf    | Ictal      | 1725         | 1755
# chb02_12.edf    | Pre-Ictal  | 1760         | 1840
# chb02_12.edf    | Pre-Ictal  | 1930         | 2010
# chb02_12.edf    | Ictal      | 2465         | 2490
# chb02_12.edf    | Ictal      | 2905         | 2930
# chb02_12.edf    | Ictal      | 2955         | 2970
# chb02_12.edf    | Ictal      | 3060         | 3255
# chb02_12.edf    | Ictal      | 3360         | 3385
# chb02_12.edf    | Ictal      | 3545         | 3600
# chb02_13.edf    | Pre-Ictal  | 0            | 75
# chb02_13.edf    | Pre-Ictal  | 110          | 155
# chb02_13.edf    | Ictal      | 515          | 530
# chb02_13.edf    | Ictal      | 560          | 585
# chb02_13.edf    | Ictal      | 645          | 700
# chb02_13.edf    | Ictal      | 725          | 1625
# chb02_13.edf    | Ictal      | 1655         | 1690
# chb02_13.edf    | Ictal      | 1780         | 1840
# chb02_13.edf    | Pre-Ictal  | 1845         | 1895
# chb02_13.edf    | Pre-Ictal  | 1935         | 1970
# chb02_13.edf    | Pre-Ictal  | 2025         | 2645
# chb02_13.edf    | Ictal      | 2650         | 2675
# chb02_13.edf    | Pre-Ictal  | 2680         | 2960
# chb02_13.edf    | Pre-Ictal  | 2990         | 3040
# chb02_13.edf    | Ictal      | 3045         | 3075
# chb02_13.edf    | Pre-Ictal  | 3080         | 3245
# chb02_13.edf    | Ictal      | 3265         | 3360
# chb02_13.edf    | Pre-Ictal  | 3360         | 3485
# chb02_13.edf    | Ictal      | 3490         | 3525
# chb02_13.edf    | Ictal      | 3540         | 3600
# chb02_14.edf    | Pre-Ictal  | 0            | 45
# chb02_14.edf    | Pre-Ictal  | 185          | 225
# chb02_14.edf    | Pre-Ictal  | 280          | 390
# chb02_14.edf    | Pre-Ictal  | 420          | 500
# chb02_14.edf    | Pre-Ictal  | 535          | 575
# chb02_14.edf    | Pre-Ictal  | 640          | 670
# chb02_14.edf    | Ictal      | 705          | 755
# chb02_14.edf    | Pre-Ictal  | 855          | 870
# chb02_14.edf    | Ictal      | 880          | 1040
# chb02_14.edf    | Ictal      | 1095         | 1330
# chb02_14.edf    | Pre-Ictal  | 1385         | 1415
# chb02_14.edf    | Ictal      | 1435         | 1505
# chb02_14.edf    | Ictal      | 1525         | 1560
# chb02_14.edf    | Pre-Ictal  | 1590         | 1625
# chb02_14.edf    | Pre-Ictal  | 1660         | 1730
# chb02_14.edf    | Pre-Ictal  | 1775         | 1825
# chb02_14.edf    | Pre-Ictal  | 1890         | 1980
# chb02_14.edf    | Pre-Ictal  | 2065         | 2100
# chb02_14.edf    | Pre-Ictal  | 2130         | 2190
# chb02_14.edf    | Pre-Ictal  | 2575         | 2640
# chb02_14.edf    | Pre-Ictal  | 2910         | 2965
# chb02_14.edf    | Pre-Ictal  | 3030         | 3065
# chb02_14.edf    | Ictal      | 3070         | 3110
# chb02_14.edf    | Pre-Ictal  | 3115         | 3375
# chb02_14.edf    | Pre-Ictal  | 3450         | 3490
# chb02_15.edf    | Pre-Ictal  | 10           | 190
# chb02_15.edf    | Pre-Ictal  | 240          | 425
# chb02_15.edf    | Ictal      | 460          | 495
# chb02_15.edf    | Pre-Ictal  | 565          | 600
# chb02_15.edf    | Ictal      | 620          | 665
# chb02_15.edf    | Pre-Ictal  | 680          | 865
# chb02_15.edf    | Pre-Ictal  | 895          | 960
# chb02_15.edf    | Pre-Ictal  | 975          | 1075
# chb02_15.edf    | Pre-Ictal  | 1105         | 1190
# chb02_15.edf    | Ictal      | 1200         | 1275
# chb02_15.edf    | Pre-Ictal  | 1280         | 1300
# chb02_15.edf    | Ictal      | 1350         | 1390
# chb02_15.edf    | Pre-Ictal  | 1460         | 1510
# chb02_15.edf    | Ictal      | 1555         | 1715
# chb02_15.edf    | Pre-Ictal  | 1725         | 1740
# chb02_15.edf    | Ictal      | 1750         | 1815
# chb02_15.edf    | Pre-Ictal  | 1855         | 1910
# chb02_15.edf    | Pre-Ictal  | 1950         | 2095
# chb02_15.edf    | Pre-Ictal  | 2135         | 2155
# chb02_15.edf    | Ictal      | 2170         | 2220
# chb02_15.edf    | Pre-Ictal  | 2255         | 2280
# chb02_15.edf    | Pre-Ictal  | 2380         | 2390
# chb02_15.edf    | Ictal      | 2440         | 2460
# chb02_15.edf    | Ictal      | 2480         | 2545
# chb02_15.edf    | Pre-Ictal  | 2555         | 2600
# chb02_15.edf    | Ictal      | 2610         | 2770
# chb02_15.edf    | Ictal      | 2780         | 2815
# chb02_15.edf    | Ictal      | 2850         | 2880
# chb02_15.edf    | Pre-Ictal  | 2885         | 2915
# chb02_15.edf    | Ictal      | 2940         | 2970
# chb02_15.edf    | Pre-Ictal  | 2985         | 3005
# chb02_15.edf    | Pre-Ictal  | 3050         | 3100
# chb02_15.edf    | Pre-Ictal  | 3275         | 3295
# chb02_15.edf    | Ictal      | 3300         | 3375
# chb02_15.edf    | Ictal      | 3410         | 3445
# chb02_15.edf    | Pre-Ictal  | 3525         | 3585
# chb02_15.edf    | Ictal      | 3590         | 3600
# chb02_16.edf    | Pre-Ictal  | 30           | 50
# chb02_16.edf    | Pre-Ictal  | 80           | 110
# chb02_16.edf    | Ictal      | 145          | 235
# chb02_16.edf    | Pre-Ictal  | 360          | 405
# chb02_16.edf    | Ictal      | 410          | 435
# chb02_16.edf    | Pre-Ictal  | 445          | 485
# chb02_16.edf    | Ictal      | 495          | 655
# chb02_16.edf    | Pre-Ictal  | 675          | 795
# chb02_16.edf    | Ictal      | 805          | 825
# chb02_16.edf    | Pre-Ictal  | 835          | 870
# chb02_16.edf    | Ictal      | 890          | 915
# chb02_16.edf    | Pre-Ictal  | 930          | 955
# chb02_17.edf    | Pre-Ictal  | 0            | 180
# chb02_17.edf    | Ictal      | 190          | 215
# chb02_17.edf    | Pre-Ictal  | 280          | 310
# chb02_17.edf    | Ictal      | 410          | 475
# chb02_17.edf    | Ictal      | 505          | 595
# chb02_17.edf    | Ictal      | 660          | 695
# chb02_17.edf    | Ictal      | 775          | 980
# chb02_17.edf    | Ictal      | 1010         | 1035
# chb02_17.edf    | Ictal      | 1055         | 1105
# chb02_17.edf    | Ictal      | 1150         | 1205
# chb02_17.edf    | Pre-Ictal  | 1250         | 1315
# chb02_17.edf    | Ictal      | 1330         | 1400
# chb02_17.edf    | Pre-Ictal  | 1405         | 1420
# chb02_17.edf    | Ictal      | 1425         | 1450
# chb02_17.edf    | Pre-Ictal  | 1455         | 1495
# chb02_17.edf    | Ictal      | 1500         | 1530
# chb02_17.edf    | Ictal      | 1560         | 1590
# chb02_17.edf    | Pre-Ictal  | 1610         | 1645
# chb02_17.edf    | Ictal      | 1655         | 1695
# chb02_17.edf    | Pre-Ictal  | 1705         | 1815
# chb02_17.edf    | Pre-Ictal  | 1895         | 1935
# chb02_17.edf    | Ictal      | 1950         | 2085
# chb02_17.edf    | Ictal      | 2265         | 2345
# chb02_17.edf    | Pre-Ictal  | 2440         | 2510
# chb02_17.edf    | Pre-Ictal  | 2560         | 2690
# chb02_17.edf    | Pre-Ictal  | 2730         | 2845
# chb02_17.edf    | Ictal      | 2860         | 2890
# chb02_17.edf    | Ictal      | 2905         | 2930
# chb02_17.edf    | Pre-Ictal  | 2940         | 2965
# chb02_17.edf    | Ictal      | 2970         | 3010
# chb02_17.edf    | Ictal      | 3040         | 3140
# chb02_17.edf    | Pre-Ictal  | 3150         | 3255
# chb02_17.edf    | Ictal      | 3260         | 3280
# chb02_17.edf    | Pre-Ictal  | 3290         | 3325
# chb02_17.edf    | Ictal      | 3335         | 3355
# chb02_17.edf    | Pre-Ictal  | 3385         | 3600
# chb02_18.edf    | Pre-Ictal  | 30           | 165
# chb02_18.edf    | Ictal      | 175          | 215
# chb02_18.edf    | Pre-Ictal  | 220          | 265
# chb02_18.edf    | Ictal      | 300          | 360
# chb02_18.edf    | Pre-Ictal  | 395          | 565
# chb02_18.edf    | Pre-Ictal  | 620          | 645
# chb02_18.edf    | Ictal      | 685          | 755
# chb02_18.edf    | Ictal      | 790          | 825
# chb02_18.edf    | Ictal      | 855          | 885
# chb02_18.edf    | Ictal      | 910          | 945
# chb02_18.edf    | Pre-Ictal  | 955          | 965
# chb02_18.edf    | Ictal      | 1000         | 1040
# chb02_18.edf    | Ictal      | 1110         | 1135
# chb02_18.edf    | Pre-Ictal  | 1235         | 1355
# chb02_18.edf    | Ictal      | 1370         | 1385
# chb02_18.edf    | Pre-Ictal  | 1430         | 1490
# chb02_18.edf    | Ictal      | 1535         | 1590
# chb02_18.edf    | Pre-Ictal  | 1625         | 1680
# chb02_18.edf    | Ictal      | 1705         | 1770
# chb02_18.edf    | Pre-Ictal  | 1790         | 1820
# chb02_18.edf    | Ictal      | 1910         | 1935
# chb02_18.edf    | Pre-Ictal  | 2130         | 2180
# chb02_18.edf    | Pre-Ictal  | 2390         | 2425
# chb02_18.edf    | Ictal      | 2505         | 2565
# chb02_18.edf    | Pre-Ictal  | 2595         | 2630
# chb02_18.edf    | Ictal      | 2645         | 2675
# chb02_18.edf    | Ictal      | 2700         | 2725
# chb02_18.edf    | Pre-Ictal  | 2740         | 2755
# chb02_18.edf    | Ictal      | 2775         | 2800
# chb02_18.edf    | Pre-Ictal  | 2810         | 2825
# chb02_18.edf    | Pre-Ictal  | 2860         | 2895
# chb02_18.edf    | Pre-Ictal  | 2980         | 3065
# chb02_18.edf    | Ictal      | 3115         | 3165
# chb02_18.edf    | Pre-Ictal  | 3175         | 3195
# chb02_18.edf    | Ictal      | 3205         | 3230
# chb02_18.edf    | Ictal      | 3260         | 3310
# chb02_18.edf    | Ictal      | 3380         | 3415
# chb02_18.edf    | Ictal      | 3500         | 3550
# chb02_18.edf    | Ictal      | 3575         | 3600
# chb02_19.edf    | Ictal      | 0            | 35
# chb02_19.edf    | Pre-Ictal  | 40           | 125
# chb02_19.edf    | Ictal      | 135          | 170
# chb02_19.edf    | Pre-Ictal  | 235          | 340
# chb02_19.edf    | Pre-Ictal  | 505          | 535
# chb02_19.edf    | Ictal      | 555          | 570
# chb02_19.edf    | Pre-Ictal  | 580          | 605
# chb02_19.edf    | Pre-Ictal  | 675          | 765
# chb02_19.edf    | Pre-Ictal  | 795          | 1475
# chb02_19.edf    | Pre-Ictal  | 1555         | 1575
# chb02_19.edf    | Pre-Ictal  | 1605         | 1640
# chb02_19.edf    | Pre-Ictal  | 1660         | 1695
# chb02_19.edf    | Pre-Ictal  | 1745         | 1930
# chb02_19.edf    | Ictal      | 1975         | 1995
# chb02_19.edf    | Ictal      | 2020         | 2060
# chb02_19.edf    | Pre-Ictal  | 2065         | 2135
# chb02_19.edf    | Pre-Ictal  | 2170         | 2230
# chb02_19.edf    | Ictal      | 2250         | 2265
# chb02_19.edf    | Ictal      | 2325         | 2350
# chb02_19.edf    | Ictal      | 2480         | 2690
# chb02_19.edf    | Pre-Ictal  | 2750         | 2815
# chb02_19.edf    | Ictal      | 2850         | 2880
# chb02_19.edf    | Pre-Ictal  | 2930         | 2960
# chb02_19.edf    | Pre-Ictal  | 2985         | 3010
# chb02_19.edf    | Ictal      | 3020         | 3065
# chb02_19.edf    | Pre-Ictal  | 3115         | 3160
# chb02_19.edf    | Ictal      | 3175         | 3205
# chb02_19.edf    | Ictal      | 3215         | 3560
# chb02_20.edf    | Pre-Ictal  | 40           | 65
# chb02_20.edf    | Ictal      | 75           | 105
# chb02_20.edf    | Ictal      | 130          | 165
# chb02_20.edf    | Ictal      | 215          | 245
# chb02_20.edf    | Pre-Ictal  | 290          | 325
# chb02_20.edf    | Ictal      | 345          | 390
# chb02_20.edf    | Ictal      | 420          | 450
# chb02_20.edf    | Ictal      | 490          | 545
# chb02_20.edf    | Ictal      | 570          | 585
# chb02_20.edf    | Pre-Ictal  | 595          | 620
# chb02_20.edf    | Ictal      | 630          | 690
# chb02_20.edf    | Pre-Ictal  | 705          | 765
# chb02_20.edf    | Ictal      | 780          | 800
# chb02_20.edf    | Pre-Ictal  | 810          | 865
# chb02_20.edf    | Ictal      | 875          | 930
# chb02_20.edf    | Pre-Ictal  | 950          | 975
# chb02_20.edf    | Pre-Ictal  | 1005         | 1125
# chb02_20.edf    | Pre-Ictal  | 1165         | 1280
# chb02_20.edf    | Pre-Ictal  | 1310         | 1380
# chb02_20.edf    | Ictal      | 1390         | 1445
# chb02_20.edf    | Ictal      | 1470         | 1500
# chb02_20.edf    | Ictal      | 1525         | 1705
# chb02_20.edf    | Ictal      | 1735         | 1755
# chb02_20.edf    | Pre-Ictal  | 1765         | 1940
# chb02_20.edf    | Pre-Ictal  | 1975         | 2080
# chb02_20.edf    | Pre-Ictal  | 2120         | 2235
# chb02_20.edf    | Ictal      | 2255         | 2295
# chb02_20.edf    | Pre-Ictal  | 2310         | 2370
# chb02_20.edf    | Ictal      | 2380         | 2420
# chb02_20.edf    | Pre-Ictal  | 2430         | 2450
# chb02_20.edf    | Ictal      | 2465         | 2535
# chb02_20.edf    | Ictal      | 2560         | 2600
# chb02_20.edf    | Ictal      | 2615         | 2685
# chb02_20.edf    | Pre-Ictal  | 2695         | 2710
# chb02_20.edf    | Pre-Ictal  | 2740         | 2770
# chb02_20.edf    | Pre-Ictal  | 2860         | 2975
# chb02_20.edf    | Ictal      | 2985         | 3015
# chb02_20.edf    | Pre-Ictal  | 3020         | 3265
# chb02_20.edf    | Ictal      | 3270         | 3295
# chb02_20.edf    | Pre-Ictal  | 3330         | 3355
# chb02_20.edf    | Ictal      | 3410         | 3500
# chb02_20.edf    | Ictal      | 3525         | 3600
# chb02_21.edf    | Ictal      | 0            | 295
# chb02_21.edf    | Pre-Ictal  | 305          | 325
# chb02_21.edf    | Ictal      | 390          | 420
# chb02_21.edf    | Pre-Ictal  | 445          | 555
# chb02_21.edf    | Pre-Ictal  | 595          | 640
# chb02_21.edf    | Pre-Ictal  | 655          | 770
# chb02_21.edf    | Ictal      | 805          | 830
# chb02_21.edf    | Pre-Ictal  | 840          | 930
# chb02_21.edf    | Pre-Ictal  | 1040         | 1110
# chb02_21.edf    | Pre-Ictal  | 1140         | 1305
# chb02_21.edf    | Pre-Ictal  | 1410         | 1455
# chb02_21.edf    | Ictal      | 1460         | 1490
# chb02_21.edf    | Pre-Ictal  | 1510         | 1545
# chb02_21.edf    | Pre-Ictal  | 1575         | 1605
# chb02_21.edf    | Pre-Ictal  | 1730         | 1890
# chb02_21.edf    | Pre-Ictal  | 1955         | 2030
# chb02_21.edf    | Pre-Ictal  | 2090         | 2105
# chb02_21.edf    | Pre-Ictal  | 2175         | 2390
# chb02_21.edf    | Pre-Ictal  | 2410         | 2460
# chb02_21.edf    | Pre-Ictal  | 2490         | 2545
# chb02_21.edf    | Pre-Ictal  | 2570         | 2600
# chb02_21.edf    | Ictal      | 2665         | 2710
# chb02_21.edf    | Ictal      | 2745         | 2775
# chb02_21.edf    | Pre-Ictal  | 2780         | 2800
# chb02_21.edf    | Ictal      | 2810         | 2830
# chb02_21.edf    | Pre-Ictal  | 2840         | 2860
# chb02_21.edf    | Ictal      | 2970         | 3185
# chb02_21.edf    | Ictal      | 3220         | 3265
# chb02_21.edf    | Ictal      | 3315         | 3560
# chb02_22.edf    | Pre-Ictal  | 0            | 90
# chb02_22.edf    | Pre-Ictal  | 105          | 180
# chb02_22.edf    | Pre-Ictal  | 245          | 305
# chb02_22.edf    | Pre-Ictal  | 335          | 375
# chb02_22.edf    | Pre-Ictal  | 410          | 445
# chb02_22.edf    | Ictal      | 465          | 485
# chb02_22.edf    | Pre-Ictal  | 500          | 570
# chb02_22.edf    | Pre-Ictal  | 610          | 670
# chb02_22.edf    | Pre-Ictal  | 695          | 775
# chb02_22.edf    | Pre-Ictal  | 795          | 815
# chb02_22.edf    | Ictal      | 825          | 840
# chb02_22.edf    | Pre-Ictal  | 855          | 1060
# chb02_22.edf    | Ictal      | 1105         | 1130
# chb02_22.edf    | Ictal      | 1220         | 1330
# chb02_22.edf    | Ictal      | 1365         | 1400
# chb02_22.edf    | Pre-Ictal  | 1410         | 1440
# chb02_22.edf    | Ictal      | 1495         | 1735
# chb02_22.edf    | Pre-Ictal  | 1810         | 1860
# chb02_22.edf    | Ictal      | 1900         | 1930
# chb02_22.edf    | Pre-Ictal  | 1935         | 1965
# chb02_22.edf    | Pre-Ictal  | 1995         | 2010
# chb02_22.edf    | Pre-Ictal  | 2035         | 2130
# chb02_22.edf    | Ictal      | 2135         | 2160
# chb02_22.edf    | Pre-Ictal  | 2170         | 2265
# chb02_22.edf    | Ictal      | 2275         | 2295
# chb02_22.edf    | Ictal      | 2310         | 2370
# chb02_22.edf    | Pre-Ictal  | 2380         | 2460
# chb02_22.edf    | Pre-Ictal  | 2530         | 2590
# chb02_22.edf    | Ictal      | 2610         | 2655
# chb02_22.edf    | Ictal      | 2740         | 2765
# chb02_22.edf    | Pre-Ictal  | 2785         | 2800
# chb02_22.edf    | Ictal      | 2845         | 2875
# chb02_22.edf    | Ictal      | 2965         | 3005
# chb02_22.edf    | Pre-Ictal  | 3025         | 3035
# chb02_22.edf    | Pre-Ictal  | 3060         | 3075
# chb02_22.edf    | Ictal      | 3115         | 3240
# chb02_22.edf    | Pre-Ictal  | 3285         | 3320
# chb02_22.edf    | Ictal      | 3325         | 3400
# chb02_23.edf    | Pre-Ictal  | 10           | 105
# chb02_23.edf    | Pre-Ictal  | 135          | 245
# chb02_23.edf    | Pre-Ictal  | 280          | 405
# chb02_23.edf    | Pre-Ictal  | 425          | 745
# chb02_23.edf    | Ictal      | 810          | 840
# chb02_23.edf    | Ictal      | 900          | 925
# chb02_23.edf    | Pre-Ictal  | 930          | 955
# chb02_23.edf    | Pre-Ictal  | 1040         | 1125
# chb02_23.edf    | Ictal      | 1130         | 1155
# chb02_23.edf    | Pre-Ictal  | 1160         | 1175
# chb02_23.edf    | Pre-Ictal  | 1195         | 1305
# chb02_23.edf    | Pre-Ictal  | 1380         | 1440
# chb02_23.edf    | Ictal      | 1565         | 1620
# chb02_23.edf    | Pre-Ictal  | 1630         | 1650
# chb02_23.edf    | Ictal      | 1660         | 1695
# chb02_23.edf    | Ictal      | 1740         | 1770
# chb02_23.edf    | Pre-Ictal  | 1990         | 2020
# chb02_23.edf    | Ictal      | 2070         | 2090
# chb02_23.edf    | Pre-Ictal  | 2135         | 2170
# chb02_23.edf    | Ictal      | 2175         | 2240
# chb02_23.edf    | Ictal      | 2280         | 2330
# chb02_23.edf    | Ictal      | 2380         | 2460
# chb02_23.edf    | Pre-Ictal  | 2470         | 2485
# chb02_23.edf    | Ictal      | 2530         | 2555
# chb02_23.edf    | Pre-Ictal  | 2565         | 2575
# chb02_23.edf    | Ictal      | 2585         | 2625
# chb02_23.edf    | Pre-Ictal  | 2685         | 2705
# chb02_23.edf    | Ictal      | 2730         | 2755
# chb02_23.edf    | Ictal      | 2785         | 2815
# chb02_23.edf    | Pre-Ictal  | 2880         | 2900
# chb02_23.edf    | Ictal      | 2910         | 2955
# chb02_23.edf    | Ictal      | 2980         | 3015
# chb02_23.edf    | Ictal      | 3030         | 3215
# chb02_23.edf    | Pre-Ictal  | 3255         | 3295
# chb02_23.edf    | Ictal      | 3310         | 3415
# chb02_23.edf    | Pre-Ictal  | 3420         | 3440
# chb02_23.edf    | Ictal      | 3445         | 3600
# chb02_24.edf    | Pre-Ictal  | 0            | 10
# chb02_24.edf    | Ictal      | 40           | 95
# chb02_24.edf    | Ictal      | 160          | 525
# chb02_24.edf    | Pre-Ictal  | 550          | 590
# chb02_24.edf    | Ictal      | 615          | 700
# chb02_24.edf    | Ictal      | 720          | 745
# chb02_24.edf    | Ictal      | 765          | 845
# chb02_24.edf    | Pre-Ictal  | 865          | 970
# chb02_24.edf    | Pre-Ictal  | 1000         | 1030
# chb02_24.edf    | Ictal      | 1040         | 1105
# chb02_24.edf    | Ictal      | 1120         | 1170
# chb02_24.edf    | Pre-Ictal  | 1390         | 1595
# chb02_24.edf    | Pre-Ictal  | 1635         | 1925
# chb02_24.edf    | Pre-Ictal  | 1995         | 2075
# chb02_24.edf    | Ictal      | 2080         | 2115
# chb02_24.edf    | Ictal      | 2145         | 2355
# chb02_24.edf    | Pre-Ictal  | 2385         | 2835
# chb02_24.edf    | Pre-Ictal  | 2865         | 2920
# chb02_24.edf    | Pre-Ictal  | 2940         | 2980
# chb02_24.edf    | Ictal      | 3010         | 3045
# chb02_24.edf    | Pre-Ictal  | 3120         | 3375
# chb02_24.edf    | Ictal      | 3380         | 3405
# chb02_24.edf    | Pre-Ictal  | 3410         | 3470
# chb02_24.edf    | Ictal      | 3480         | 3510
# chb02_24.edf    | Pre-Ictal  | 3520         | 3570
# chb02_25.edf    | Ictal      | 0            | 260
# chb02_25.edf    | Ictal      | 285          | 395
# chb02_25.edf    | Ictal      | 430          | 660
# chb02_25.edf    | Ictal      | 690          | 715
# chb02_25.edf    | Pre-Ictal  | 840          | 1030
# chb02_25.edf    | Pre-Ictal  | 1530         | 1605
# chb02_25.edf    | Ictal      | 1620         | 1635
# chb02_25.edf    | Pre-Ictal  | 1660         | 1715
# chb02_25.edf    | Ictal      | 1750         | 1775
# chb02_25.edf    | Pre-Ictal  | 1790         | 1805
# chb02_25.edf    | Pre-Ictal  | 2020         | 2065
# chb02_25.edf    | Ictal      | 2370         | 2410
# chb02_25.edf    | Pre-Ictal  | 2520         | 2595
# chb02_25.edf    | Pre-Ictal  | 2625         | 2670
# chb02_25.edf    | Ictal      | 2685         | 2710
# chb02_25.edf    | Pre-Ictal  | 2730         | 2935
# chb02_25.edf    | Pre-Ictal  | 2970         | 3405
# chb02_25.edf    | Pre-Ictal  | 3460         | 3530
# chb02_25.edf    | Ictal      | 3540         | 3565
# chb02_25.edf    | Pre-Ictal  | 3575         | 3600

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb02_16.edf": [(130, 212)],
    "chb02_19.edf": [(3369, 3378)]
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()
