# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization
    6. Spectral Edge Frequency 95%
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        sync_scores = []
        for li, ri in PAIRS_LR:
            c = np.corrcoef(X[li], X[ri])[0, 1]
            sync_scores.append(c)
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        df = np.diff(freqs)
        df = np.r_[df, df[-1]]
        power_bins = psd * df
        cumulative_power = np.cumsum(power_bins, axis=1)
        total_power = cumulative_power[:, -1]
        sef_indices = np.argmax(cumulative_power >= 0.95 * total_power[:, None], axis=1)
        avg_sef95 = freqs[sef_indices].mean()

        features.append([ta_ratio, complexity, line_length, rms, avg_sync])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb05) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_11.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_19.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_20.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_21.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_22.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_23.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_24.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_25.edf"}
]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 20/25 files; last epochs=720
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/v5/fl3p2mv95pn6b5w09z_mbpf40000gn/T/ipykernel_40956/1521378678.py:39: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 25/25 files; last epochs=720
# Loading complete.

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.9260   0.0403   0.0337
# State 1   0.0225   0.9279   0.0496
# State 2   0.0129   0.0218   0.9652

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : +0.553
#   PermEntropy : -0.222
#   LineLength  : +0.522
#   RMS         : +0.692
#   Avg Sync    : +0.238
#
# State 1 means:
#   TA_ratio    : -0.067
#   PermEntropy : +0.622
#   LineLength  : +0.413
#   RMS         : +0.229
#   Avg Sync    : -0.147
#
# State 2 means:
#   TA_ratio    : -0.145
#   PermEntropy : -0.228
#   LineLength  : -0.367
#   RMS         : -0.332
#   Avg Sync    : -0.006

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy,
# [2] LineLength, [3] RMS

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3

# Ictal: high line length + high RMS
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# Baseline: highest entropy among remaining states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
baseline_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_ENT])]
)

# Pre-ictal: whatever state is left (for 3-state HMM)
preictal_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, baseline_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb05_01.edf    | Ictal      | 0            | 80
# chb05_01.edf    | Pre-Ictal  | 80           | 250
# chb05_01.edf    | Ictal      | 250          | 285
# chb05_01.edf    | Pre-Ictal  | 355          | 440
# chb05_01.edf    | Pre-Ictal  | 480          | 615
# chb05_01.edf    | Ictal      | 615          | 675
# chb05_01.edf    | Ictal      | 695          | 730
# chb05_01.edf    | Pre-Ictal  | 790          | 805
# chb05_01.edf    | Ictal      | 850          | 870
# chb05_01.edf    | Pre-Ictal  | 885          | 905
# chb05_01.edf    | Pre-Ictal  | 1035         | 1225
# chb05_01.edf    | Ictal      | 1225         | 1245
# chb05_01.edf    | Pre-Ictal  | 1265         | 1285
# chb05_01.edf    | Ictal      | 1285         | 1340
# chb05_01.edf    | Pre-Ictal  | 1455         | 1495
# chb05_01.edf    | Ictal      | 1510         | 1645
# chb05_01.edf    | Pre-Ictal  | 1690         | 1720
# chb05_01.edf    | Ictal      | 1720         | 1745
# chb05_01.edf    | Pre-Ictal  | 1745         | 1810
# chb05_01.edf    | Pre-Ictal  | 1870         | 1975
# chb05_01.edf    | Pre-Ictal  | 2010         | 2065
# chb05_01.edf    | Ictal      | 2065         | 2095
# chb05_01.edf    | Pre-Ictal  | 2115         | 2155
# chb05_01.edf    | Pre-Ictal  | 2180         | 2255
# chb05_01.edf    | Pre-Ictal  | 2280         | 2310
# chb05_01.edf    | Pre-Ictal  | 2350         | 2380
# chb05_01.edf    | Ictal      | 2400         | 2420
# chb05_01.edf    | Pre-Ictal  | 2420         | 2475
# chb05_01.edf    | Pre-Ictal  | 2505         | 2885
# chb05_01.edf    | Pre-Ictal  | 2935         | 2975
# chb05_01.edf    | Ictal      | 2975         | 3020
# chb05_01.edf    | Pre-Ictal  | 3020         | 3060
# chb05_01.edf    | Ictal      | 3060         | 3100
# chb05_01.edf    | Pre-Ictal  | 3100         | 3250
# chb05_01.edf    | Ictal      | 3250         | 3290
# chb05_01.edf    | Pre-Ictal  | 3290         | 3305
# chb05_01.edf    | Ictal      | 3335         | 3365
# chb05_02.edf    | Pre-Ictal  | 40           | 100
# chb05_02.edf    | Pre-Ictal  | 130          | 195
# chb05_02.edf    | Pre-Ictal  | 320          | 345
# chb05_02.edf    | Pre-Ictal  | 380          | 445
# chb05_02.edf    | Ictal      | 445          | 475
# chb05_02.edf    | Pre-Ictal  | 475          | 520
# chb05_02.edf    | Pre-Ictal  | 615          | 920
# chb05_02.edf    | Pre-Ictal  | 955          | 1725
# chb05_02.edf    | Pre-Ictal  | 1980         | 2030
# chb05_02.edf    | Ictal      | 2030         | 2185
# chb05_02.edf    | Pre-Ictal  | 2185         | 2250
# chb05_02.edf    | Pre-Ictal  | 2280         | 2370
# chb05_02.edf    | Pre-Ictal  | 2410         | 2460
# chb05_02.edf    | Pre-Ictal  | 2515         | 2575
# chb05_02.edf    | Ictal      | 2575         | 2610
# chb05_02.edf    | Ictal      | 2650         | 2690
# chb05_02.edf    | Pre-Ictal  | 2690         | 2730
# chb05_02.edf    | Pre-Ictal  | 2765         | 2910
# chb05_02.edf    | Pre-Ictal  | 2960         | 2975
# chb05_02.edf    | Pre-Ictal  | 3045         | 3080
# chb05_02.edf    | Ictal      | 3130         | 3175
# chb05_02.edf    | Pre-Ictal  | 3195         | 3215
# chb05_02.edf    | Ictal      | 3215         | 3440
# chb05_03.edf    | Pre-Ictal  | 0            | 75
# chb05_03.edf    | Ictal      | 75           | 160
# chb05_03.edf    | Pre-Ictal  | 225          | 255
# chb05_03.edf    | Ictal      | 255          | 285
# chb05_03.edf    | Pre-Ictal  | 285          | 395
# chb05_03.edf    | Pre-Ictal  | 470          | 520
# chb05_03.edf    | Pre-Ictal  | 595          | 620
# chb05_03.edf    | Ictal      | 635          | 705
# chb05_03.edf    | Pre-Ictal  | 825          | 885
# chb05_03.edf    | Ictal      | 885          | 1045
# chb05_03.edf    | Pre-Ictal  | 1045         | 1165
# chb05_03.edf    | Ictal      | 1165         | 1265
# chb05_03.edf    | Pre-Ictal  | 1265         | 1300
# chb05_03.edf    | Ictal      | 1300         | 1340
# chb05_03.edf    | Pre-Ictal  | 1340         | 1505
# chb05_03.edf    | Ictal      | 1505         | 1540
# chb05_03.edf    | Pre-Ictal  | 1540         | 1835
# chb05_03.edf    | Pre-Ictal  | 1850         | 1865
# chb05_03.edf    | Pre-Ictal  | 1890         | 2030
# chb05_03.edf    | Pre-Ictal  | 2095         | 2200
# chb05_03.edf    | Pre-Ictal  | 2225         | 2265
# chb05_03.edf    | Ictal      | 2285         | 2340
# chb05_03.edf    | Pre-Ictal  | 2365         | 2510
# chb05_03.edf    | Pre-Ictal  | 2560         | 2580
# chb05_03.edf    | Pre-Ictal  | 2710         | 2750
# chb05_03.edf    | Ictal      | 2765         | 2785
# chb05_03.edf    | Ictal      | 2855         | 2935
# chb05_03.edf    | Ictal      | 2985         | 3090
# chb05_03.edf    | Ictal      | 3295         | 3330
# chb05_03.edf    | Pre-Ictal  | 3330         | 3365
# chb05_03.edf    | Ictal      | 3375         | 3400
# chb05_03.edf    | Pre-Ictal  | 3565         | 3600
# chb05_04.edf    | Pre-Ictal  | 70           | 95
# chb05_04.edf    | Pre-Ictal  | 125          | 185
# chb05_04.edf    | Pre-Ictal  | 305          | 625
# chb05_04.edf    | Ictal      | 680          | 725
# chb05_04.edf    | Pre-Ictal  | 725          | 1075
# chb05_04.edf    | Ictal      | 1075         | 1165
# chb05_04.edf    | Ictal      | 1205         | 1240
# chb05_04.edf    | Pre-Ictal  | 1275         | 1310
# chb05_04.edf    | Ictal      | 1420         | 1450
# chb05_04.edf    | Pre-Ictal  | 1610         | 1715
# chb05_04.edf    | Pre-Ictal  | 1750         | 1785
# chb05_04.edf    | Pre-Ictal  | 1840         | 2035
# chb05_04.edf    | Ictal      | 2035         | 2130
# chb05_04.edf    | Pre-Ictal  | 2145         | 2180
# chb05_04.edf    | Pre-Ictal  | 2320         | 2330
# chb05_04.edf    | Ictal      | 2330         | 2395
# chb05_04.edf    | Pre-Ictal  | 2395         | 2695
# chb05_04.edf    | Ictal      | 2805         | 2850
# chb05_04.edf    | Ictal      | 2885         | 2930
# chb05_04.edf    | Pre-Ictal  | 3005         | 3025
# chb05_04.edf    | Ictal      | 3060         | 3285
# chb05_04.edf    | Pre-Ictal  | 3375         | 3430
# chb05_05.edf    | Pre-Ictal  | 0            | 65
# chb05_05.edf    | Ictal      | 105          | 140
# chb05_05.edf    | Pre-Ictal  | 235          | 260
# chb05_05.edf    | Ictal      | 270          | 295
# chb05_05.edf    | Ictal      | 325          | 355
# chb05_05.edf    | Pre-Ictal  | 390          | 440
# chb05_05.edf    | Ictal      | 440          | 455
# chb05_05.edf    | Pre-Ictal  | 565          | 625
# chb05_05.edf    | Ictal      | 730          | 745
# chb05_05.edf    | Pre-Ictal  | 745          | 765
# chb05_05.edf    | Pre-Ictal  | 790          | 805
# chb05_05.edf    | Ictal      | 805          | 840
# chb05_05.edf    | Pre-Ictal  | 840          | 880
# chb05_05.edf    | Ictal      | 880          | 905
# chb05_05.edf    | Pre-Ictal  | 905          | 915
# chb05_05.edf    | Pre-Ictal  | 945          | 960
# chb05_05.edf    | Ictal      | 960          | 1020
# chb05_05.edf    | Pre-Ictal  | 1020         | 1030
# chb05_05.edf    | Pre-Ictal  | 1050         | 1115
# chb05_05.edf    | Ictal      | 1175         | 1225
# chb05_05.edf    | Pre-Ictal  | 1325         | 1380
# chb05_05.edf    | Pre-Ictal  | 1430         | 1460
# chb05_05.edf    | Ictal      | 1585         | 1625
# chb05_05.edf    | Ictal      | 1745         | 1775
# chb05_05.edf    | Pre-Ictal  | 1800         | 1820
# chb05_05.edf    | Ictal      | 1820         | 1980
# chb05_05.edf    | Pre-Ictal  | 2010         | 2035
# chb05_05.edf    | Pre-Ictal  | 2090         | 2155
# chb05_05.edf    | Pre-Ictal  | 2240         | 2255
# chb05_05.edf    | Ictal      | 2255         | 2360
# chb05_05.edf    | Pre-Ictal  | 2360         | 2440
# chb05_05.edf    | Pre-Ictal  | 2465         | 2520
# chb05_05.edf    | Pre-Ictal  | 2655         | 2675
# chb05_05.edf    | Ictal      | 2675         | 2710
# chb05_05.edf    | Pre-Ictal  | 2710         | 2740
# chb05_05.edf    | Pre-Ictal  | 2760         | 2890
# chb05_05.edf    | Pre-Ictal  | 3020         | 3040
# chb05_05.edf    | Ictal      | 3040         | 3080
# chb05_05.edf    | Pre-Ictal  | 3080         | 3145
# chb05_05.edf    | Ictal      | 3145         | 3180
# chb05_05.edf    | Pre-Ictal  | 3180         | 3395
# chb05_05.edf    | Pre-Ictal  | 3425         | 3460
# chb05_05.edf    | Pre-Ictal  | 3495         | 3550
# chb05_05.edf    | Ictal      | 3550         | 3600
# chb05_06.edf    | Ictal      | 0            | 55
# chb05_06.edf    | Ictal      | 270          | 565
# chb05_06.edf    | Ictal      | 610          | 940
# chb05_06.edf    | Pre-Ictal  | 960          | 1325
# chb05_06.edf    | Pre-Ictal  | 1355         | 2345
# chb05_06.edf    | Ictal      | 2360         | 2380
# chb05_06.edf    | Pre-Ictal  | 2635         | 2865
# chb05_06.edf    | Pre-Ictal  | 2990         | 3600
# chb05_07.edf    | Ictal      | 0            | 5
# chb05_07.edf    | Pre-Ictal  | 5            | 970
# chb05_07.edf    | Pre-Ictal  | 1000         | 1170
# chb05_07.edf    | Ictal      | 1205         | 1285
# chb05_07.edf    | Ictal      | 1330         | 1520
# chb05_07.edf    | Pre-Ictal  | 1520         | 1605
# chb05_07.edf    | Ictal      | 1605         | 1645
# chb05_07.edf    | Pre-Ictal  | 1645         | 2350
# chb05_07.edf    | Pre-Ictal  | 2455         | 3030
# chb05_07.edf    | Ictal      | 3030         | 3165
# chb05_07.edf    | Ictal      | 3210         | 3255
# chb05_07.edf    | Pre-Ictal  | 3320         | 3600
# chb05_08.edf    | Pre-Ictal  | 0            | 405
# chb05_08.edf    | Ictal      | 405          | 465
# chb05_08.edf    | Pre-Ictal  | 585          | 680
# chb05_08.edf    | Pre-Ictal  | 710          | 860
# chb05_08.edf    | Ictal      | 860          | 915
# chb05_08.edf    | Pre-Ictal  | 1005         | 1090
# chb05_08.edf    | Ictal      | 1090         | 1150
# chb05_08.edf    | Pre-Ictal  | 1175         | 1275
# chb05_08.edf    | Ictal      | 1275         | 1325
# chb05_08.edf    | Pre-Ictal  | 1340         | 1470
# chb05_08.edf    | Pre-Ictal  | 1510         | 1560
# chb05_08.edf    | Ictal      | 1560         | 1605
# chb05_08.edf    | Pre-Ictal  | 1605         | 2280
# chb05_08.edf    | Ictal      | 2280         | 2310
# chb05_08.edf    | Pre-Ictal  | 2535         | 3080
# chb05_09.edf    | Ictal      | 30           | 100
# chb05_09.edf    | Ictal      | 195          | 255
# chb05_09.edf    | Pre-Ictal  | 255          | 680
# chb05_09.edf    | Ictal      | 695          | 735
# chb05_09.edf    | Ictal      | 800          | 905
# chb05_09.edf    | Ictal      | 930          | 960
# chb05_09.edf    | Pre-Ictal  | 960          | 1035
# chb05_09.edf    | Pre-Ictal  | 1080         | 1220
# chb05_09.edf    | Pre-Ictal  | 1250         | 2185
# chb05_09.edf    | Ictal      | 2185         | 2230
# chb05_09.edf    | Ictal      | 2420         | 2465
# chb05_09.edf    | Pre-Ictal  | 2480         | 2560
# chb05_09.edf    | Ictal      | 2560         | 2595
# chb05_09.edf    | Pre-Ictal  | 2620         | 2925
# chb05_09.edf    | Ictal      | 2925         | 2950
# chb05_09.edf    | Pre-Ictal  | 2950         | 3115
# chb05_09.edf    | Ictal      | 3140         | 3160
# chb05_09.edf    | Pre-Ictal  | 3375         | 3405
# chb05_09.edf    | Ictal      | 3405         | 3435
# chb05_09.edf    | Pre-Ictal  | 3435         | 3525
# chb05_09.edf    | Pre-Ictal  | 3555         | 3600
# chb05_10.edf    | Ictal      | 85           | 155
# chb05_10.edf    | Ictal      | 250          | 290
# chb05_10.edf    | Ictal      | 365          | 400
# chb05_10.edf    | Pre-Ictal  | 400          | 730
# chb05_10.edf    | Ictal      | 730          | 750
# chb05_10.edf    | Pre-Ictal  | 995          | 1025
# chb05_10.edf    | Pre-Ictal  | 1075         | 1115
# chb05_10.edf    | Ictal      | 1280         | 1305
# chb05_10.edf    | Pre-Ictal  | 1335         | 1390
# chb05_10.edf    | Ictal      | 1390         | 1455
# chb05_10.edf    | Pre-Ictal  | 1455         | 1585
# chb05_10.edf    | Pre-Ictal  | 1620         | 2680
# chb05_10.edf    | Pre-Ictal  | 2710         | 2860
# chb05_10.edf    | Pre-Ictal  | 2905         | 2945
# chb05_10.edf    | Ictal      | 2945         | 2975
# chb05_10.edf    | Pre-Ictal  | 2975         | 3020
# chb05_10.edf    | Ictal      | 3020         | 3050
# chb05_10.edf    | Pre-Ictal  | 3050         | 3120
# chb05_10.edf    | Ictal      | 3120         | 3165
# chb05_10.edf    | Pre-Ictal  | 3165         | 3355
# chb05_10.edf    | Pre-Ictal  | 3395         | 3600
# chb05_11.edf    | Pre-Ictal  | 0            | 1335
# chb05_11.edf    | Ictal      | 1335         | 1385
# chb05_11.edf    | Pre-Ictal  | 1485         | 1900
# chb05_11.edf    | Ictal      | 1900         | 1925
# chb05_11.edf    | Pre-Ictal  | 1925         | 2050
# chb05_11.edf    | Ictal      | 2085         | 2115
# chb05_11.edf    | Pre-Ictal  | 2115         | 2355
# chb05_11.edf    | Ictal      | 2355         | 2395
# chb05_11.edf    | Pre-Ictal  | 2395         | 2710
# chb05_11.edf    | Ictal      | 2710         | 2810
# chb05_11.edf    | Pre-Ictal  | 2935         | 3020
# chb05_11.edf    | Pre-Ictal  | 3055         | 3225
# chb05_11.edf    | Ictal      | 3355         | 3450
# chb05_11.edf    | Pre-Ictal  | 3475         | 3600
# chb05_12.edf    | Pre-Ictal  | 0            | 335
# chb05_12.edf    | Ictal      | 345          | 370
# chb05_12.edf    | Ictal      | 400          | 575
# chb05_12.edf    | Pre-Ictal  | 575          | 605
# chb05_12.edf    | Ictal      | 605          | 650
# chb05_12.edf    | Ictal      | 725          | 785
# chb05_12.edf    | Ictal      | 840          | 870
# chb05_12.edf    | Pre-Ictal  | 870          | 1375
# chb05_12.edf    | Pre-Ictal  | 1405         | 1430
# chb05_12.edf    | Ictal      | 1430         | 1785
# chb05_12.edf    | Pre-Ictal  | 1785         | 1900
# chb05_12.edf    | Ictal      | 1900         | 1930
# chb05_12.edf    | Pre-Ictal  | 1930         | 2260
# chb05_12.edf    | Pre-Ictal  | 2300         | 2500
# chb05_12.edf    | Ictal      | 2515         | 2550
# chb05_12.edf    | Pre-Ictal  | 2550         | 2575
# chb05_12.edf    | Pre-Ictal  | 2630         | 2935
# chb05_12.edf    | Pre-Ictal  | 3035         | 3540
# chb05_13.edf    | Pre-Ictal  | 60           | 495
# chb05_13.edf    | Pre-Ictal  | 550          | 790
# chb05_13.edf    | Pre-Ictal  | 835          | 1085
# chb05_13.edf    | Ictal      | 1095         | 1250
# chb05_13.edf    | Ictal      | 1295         | 1850
# chb05_13.edf    | Pre-Ictal  | 1885         | 1930
# chb05_13.edf    | Pre-Ictal  | 1965         | 2125
# chb05_13.edf    | Pre-Ictal  | 2195         | 2350
# chb05_13.edf    | Pre-Ictal  | 2415         | 3450
# chb05_14.edf    | Pre-Ictal  | 95           | 115
# chb05_14.edf    | Ictal      | 135          | 190
# chb05_14.edf    | Pre-Ictal  | 360          | 445
# chb05_14.edf    | Ictal      | 475          | 510
# chb05_14.edf    | Pre-Ictal  | 620          | 645
# chb05_14.edf    | Pre-Ictal  | 725          | 875
# chb05_14.edf    | Ictal      | 970          | 990
# chb05_14.edf    | Pre-Ictal  | 1075         | 1090
# chb05_14.edf    | Ictal      | 1090         | 1425
# chb05_14.edf    | Pre-Ictal  | 1425         | 1495
# chb05_14.edf    | Pre-Ictal  | 2060         | 2090
# chb05_14.edf    | Pre-Ictal  | 2215         | 2245
# chb05_14.edf    | Pre-Ictal  | 2285         | 2310
# chb05_14.edf    | Ictal      | 2310         | 2380
# chb05_14.edf    | Pre-Ictal  | 2380         | 2425
# chb05_14.edf    | Pre-Ictal  | 2520         | 2575
# chb05_14.edf    | Pre-Ictal  | 2690         | 2790
# chb05_14.edf    | Pre-Ictal  | 2830         | 2895
# chb05_14.edf    | Pre-Ictal  | 2925         | 2945
# chb05_14.edf    | Ictal      | 2945         | 3080
# chb05_14.edf    | Pre-Ictal  | 3080         | 3245
# chb05_14.edf    | Ictal      | 3290         | 3385
# chb05_14.edf    | Pre-Ictal  | 3385         | 3410
# chb05_14.edf    | Ictal      | 3410         | 3465
# chb05_14.edf    | Pre-Ictal  | 3465         | 3495
# chb05_14.edf    | Ictal      | 3495         | 3505
# chb05_14.edf    | Ictal      | 3560         | 3600
# chb05_15.edf    | Ictal      | 0            | 35
# chb05_15.edf    | Pre-Ictal  | 45           | 110
# chb05_15.edf    | Ictal      | 130          | 295
# chb05_15.edf    | Pre-Ictal  | 365          | 395
# chb05_15.edf    | Pre-Ictal  | 430          | 765
# chb05_15.edf    | Ictal      | 765          | 780
# chb05_15.edf    | Pre-Ictal  | 780          | 2165
# chb05_15.edf    | Ictal      | 2290         | 2325
# chb05_15.edf    | Ictal      | 2350         | 2380
# chb05_15.edf    | Pre-Ictal  | 2380         | 2450
# chb05_15.edf    | Ictal      | 2450         | 2480
# chb05_15.edf    | Pre-Ictal  | 2480         | 2590
# chb05_15.edf    | Ictal      | 2590         | 2645
# chb05_15.edf    | Pre-Ictal  | 2645         | 2665
# chb05_15.edf    | Ictal      | 2665         | 2825
# chb05_15.edf    | Pre-Ictal  | 2825         | 2900
# chb05_15.edf    | Ictal      | 2900         | 3010
# chb05_15.edf    | Ictal      | 3030         | 3105
# chb05_15.edf    | Pre-Ictal  | 3105         | 3155
# chb05_15.edf    | Ictal      | 3155         | 3185
# chb05_15.edf    | Pre-Ictal  | 3185         | 3600
# chb05_16.edf    | Pre-Ictal  | 0            | 85
# chb05_16.edf    | Pre-Ictal  | 115          | 700
# chb05_16.edf    | Pre-Ictal  | 740          | 1035
# chb05_16.edf    | Pre-Ictal  | 1070         | 1350
# chb05_16.edf    | Pre-Ictal  | 1385         | 1975
# chb05_16.edf    | Ictal      | 2335         | 2690
# chb05_16.edf    | Pre-Ictal  | 2770         | 2810
# chb05_16.edf    | Ictal      | 2810         | 2850
# chb05_16.edf    | Pre-Ictal  | 2850         | 2925
# chb05_16.edf    | Ictal      | 2925         | 2995
# chb05_16.edf    | Pre-Ictal  | 2995         | 3030
# chb05_16.edf    | Pre-Ictal  | 3115         | 3410
# chb05_16.edf    | Ictal      | 3410         | 3485
# chb05_16.edf    | Pre-Ictal  | 3485         | 3520
# chb05_16.edf    | Ictal      | 3520         | 3575
# chb05_16.edf    | Pre-Ictal  | 3575         | 3600
# chb05_17.edf    | Pre-Ictal  | 0            | 35
# chb05_17.edf    | Pre-Ictal  | 155          | 235
# chb05_17.edf    | Pre-Ictal  | 280          | 345
# chb05_17.edf    | Pre-Ictal  | 380          | 490
# chb05_17.edf    | Pre-Ictal  | 530          | 545
# chb05_17.edf    | Pre-Ictal  | 700          | 1430
# chb05_17.edf    | Pre-Ictal  | 1450         | 1855
# chb05_17.edf    | Ictal      | 2030         | 2105
# chb05_17.edf    | Ictal      | 2190         | 2235
# chb05_17.edf    | Ictal      | 2450         | 2765
# chb05_17.edf    | Pre-Ictal  | 2765         | 2890
# chb05_17.edf    | Pre-Ictal  | 2910         | 3195
# chb05_17.edf    | Pre-Ictal  | 3220         | 3520
# chb05_17.edf    | Pre-Ictal  | 3550         | 3600
# chb05_18.edf    | Pre-Ictal  | 0            | 280
# chb05_18.edf    | Ictal      | 290          | 310
# chb05_18.edf    | Ictal      | 540          | 555
# chb05_18.edf    | Pre-Ictal  | 635          | 685
# chb05_18.edf    | Ictal      | 685          | 815
# chb05_18.edf    | Ictal      | 840          | 1005
# chb05_18.edf    | Pre-Ictal  | 1005         | 1035
# chb05_18.edf    | Ictal      | 1035         | 1070
# chb05_18.edf    | Ictal      | 1100         | 1170
# chb05_18.edf    | Pre-Ictal  | 1170         | 1180
# chb05_18.edf    | Ictal      | 1205         | 1230
# chb05_18.edf    | Pre-Ictal  | 1280         | 1395
# chb05_18.edf    | Pre-Ictal  | 1520         | 1585
# chb05_18.edf    | Pre-Ictal  | 1625         | 1650
# chb05_18.edf    | Pre-Ictal  | 1685         | 1815
# chb05_18.edf    | Pre-Ictal  | 1930         | 1970
# chb05_18.edf    | Ictal      | 2050         | 2065
# chb05_18.edf    | Pre-Ictal  | 2065         | 2180
# chb05_18.edf    | Pre-Ictal  | 2210         | 2275
# chb05_18.edf    | Pre-Ictal  | 2315         | 2340
# chb05_18.edf    | Pre-Ictal  | 2370         | 2470
# chb05_18.edf    | Pre-Ictal  | 2510         | 2535
# chb05_18.edf    | Pre-Ictal  | 2745         | 2780
# chb05_18.edf    | Pre-Ictal  | 2805         | 2995
# chb05_18.edf    | Ictal      | 3165         | 3225
# chb05_18.edf    | Pre-Ictal  | 3225         | 3275
# chb05_18.edf    | Ictal      | 3295         | 3330
# chb05_18.edf    | Ictal      | 3465         | 3500
# chb05_18.edf    | Ictal      | 3550         | 3600
# chb05_19.edf    | Ictal      | 0            | 60
# chb05_19.edf    | Pre-Ictal  | 60           | 220
# chb05_19.edf    | Ictal      | 220          | 250
# chb05_19.edf    | Pre-Ictal  | 250          | 405
# chb05_19.edf    | Ictal      | 535          | 555
# chb05_19.edf    | Ictal      | 585          | 640
# chb05_19.edf    | Pre-Ictal  | 675          | 730
# chb05_19.edf    | Ictal      | 745          | 760
# chb05_19.edf    | Pre-Ictal  | 850          | 1145
# chb05_19.edf    | Pre-Ictal  | 1185         | 1270
# chb05_19.edf    | Pre-Ictal  | 1315         | 1345
# chb05_19.edf    | Ictal      | 1480         | 1515
# chb05_19.edf    | Pre-Ictal  | 1655         | 1830
# chb05_19.edf    | Pre-Ictal  | 1975         | 2060
# chb05_19.edf    | Pre-Ictal  | 2140         | 2165
# chb05_19.edf    | Ictal      | 2165         | 2190
# chb05_19.edf    | Pre-Ictal  | 2220         | 2300
# chb05_19.edf    | Ictal      | 2300         | 2360
# chb05_19.edf    | Pre-Ictal  | 2425         | 2480
# chb05_19.edf    | Pre-Ictal  | 2510         | 2645
# chb05_19.edf    | Pre-Ictal  | 2675         | 2705
# chb05_19.edf    | Ictal      | 2705         | 2775
# chb05_19.edf    | Pre-Ictal  | 2775         | 2915
# chb05_19.edf    | Pre-Ictal  | 2970         | 3000
# chb05_19.edf    | Ictal      | 3000         | 3030
# chb05_19.edf    | Pre-Ictal  | 3030         | 3120
# chb05_19.edf    | Ictal      | 3120         | 3175
# chb05_19.edf    | Pre-Ictal  | 3175         | 3305
# chb05_19.edf    | Pre-Ictal  | 3395         | 3450
# chb05_19.edf    | Ictal      | 3450         | 3515
# chb05_19.edf    | Ictal      | 3555         | 3600
# chb05_20.edf    | Ictal      | 0            | 50
# chb05_20.edf    | Pre-Ictal  | 50           | 95
# chb05_20.edf    | Ictal      | 95           | 115
# chb05_20.edf    | Pre-Ictal  | 115          | 300
# chb05_20.edf    | Pre-Ictal  | 370          | 385
# chb05_20.edf    | Pre-Ictal  | 455          | 575
# chb05_20.edf    | Pre-Ictal  | 590          | 640
# chb05_20.edf    | Pre-Ictal  | 670          | 760
# chb05_20.edf    | Pre-Ictal  | 785          | 820
# chb05_20.edf    | Ictal      | 820          | 860
# chb05_20.edf    | Pre-Ictal  | 860          | 885
# chb05_20.edf    | Ictal      | 900          | 960
# chb05_20.edf    | Ictal      | 1060         | 1100
# chb05_20.edf    | Pre-Ictal  | 1100         | 1305
# chb05_20.edf    | Ictal      | 1305         | 1415
# chb05_20.edf    | Pre-Ictal  | 1415         | 1445
# chb05_20.edf    | Pre-Ictal  | 1480         | 1505
# chb05_20.edf    | Ictal      | 1505         | 1545
# chb05_20.edf    | Pre-Ictal  | 1545         | 1600
# chb05_20.edf    | Ictal      | 1600         | 1625
# chb05_20.edf    | Pre-Ictal  | 1625         | 1650
# chb05_20.edf    | Ictal      | 1665         | 1685
# chb05_20.edf    | Pre-Ictal  | 2105         | 2120
# chb05_20.edf    | Pre-Ictal  | 2185         | 2230
# chb05_20.edf    | Pre-Ictal  | 2270         | 2630
# chb05_20.edf    | Ictal      | 2630         | 2680
# chb05_20.edf    | Pre-Ictal  | 2680         | 2750
# chb05_20.edf    | Pre-Ictal  | 2785         | 2805
# chb05_20.edf    | Ictal      | 2805         | 2840
# chb05_20.edf    | Pre-Ictal  | 2840         | 2870
# chb05_20.edf    | Ictal      | 2870         | 2900
# chb05_20.edf    | Pre-Ictal  | 2910         | 3000
# chb05_20.edf    | Ictal      | 3145         | 3190
# chb05_20.edf    | Pre-Ictal  | 3360         | 3380
# chb05_20.edf    | Pre-Ictal  | 3440         | 3470
# chb05_20.edf    | Ictal      | 3550         | 3600
# chb05_21.edf    | Pre-Ictal  | 155          | 185
# chb05_21.edf    | Pre-Ictal  | 230          | 300
# chb05_21.edf    | Ictal      | 300          | 350
# chb05_21.edf    | Pre-Ictal  | 350          | 400
# chb05_21.edf    | Pre-Ictal  | 505          | 530
# chb05_21.edf    | Pre-Ictal  | 565          | 590
# chb05_21.edf    | Pre-Ictal  | 645          | 730
# chb05_21.edf    | Ictal      | 730          | 775
# chb05_21.edf    | Pre-Ictal  | 775          | 790
# chb05_21.edf    | Pre-Ictal  | 820          | 875
# chb05_21.edf    | Pre-Ictal  | 910          | 935
# chb05_21.edf    | Ictal      | 935          | 1020
# chb05_21.edf    | Pre-Ictal  | 1020         | 1095
# chb05_21.edf    | Ictal      | 1105         | 1145
# chb05_21.edf    | Pre-Ictal  | 1225         | 1260
# chb05_21.edf    | Ictal      | 1285         | 1310
# chb05_21.edf    | Ictal      | 1400         | 1435
# chb05_21.edf    | Pre-Ictal  | 1435         | 1455
# chb05_21.edf    | Pre-Ictal  | 1515         | 1565
# chb05_21.edf    | Pre-Ictal  | 1630         | 1700
# chb05_21.edf    | Ictal      | 1700         | 1750
# chb05_21.edf    | Pre-Ictal  | 1750         | 1780
# chb05_21.edf    | Ictal      | 1780         | 1845
# chb05_21.edf    | Pre-Ictal  | 1860         | 1875
# chb05_21.edf    | Ictal      | 1875         | 1895
# chb05_21.edf    | Pre-Ictal  | 2035         | 2055
# chb05_21.edf    | Ictal      | 2055         | 2165
# chb05_21.edf    | Pre-Ictal  | 2165         | 2200
# chb05_21.edf    | Ictal      | 2200         | 2235
# chb05_21.edf    | Pre-Ictal  | 2260         | 2485
# chb05_21.edf    | Ictal      | 2485         | 2495
# chb05_21.edf    | Pre-Ictal  | 2495         | 2505
# chb05_21.edf    | Pre-Ictal  | 2540         | 2570
# chb05_21.edf    | Pre-Ictal  | 2650         | 2680
# chb05_21.edf    | Pre-Ictal  | 2705         | 2735
# chb05_21.edf    | Pre-Ictal  | 2760         | 2815
# chb05_21.edf    | Pre-Ictal  | 2880         | 2960
# chb05_21.edf    | Ictal      | 2960         | 2975
# chb05_21.edf    | Pre-Ictal  | 3080         | 3110
# chb05_21.edf    | Ictal      | 3110         | 3130
# chb05_21.edf    | Ictal      | 3215         | 3245
# chb05_21.edf    | Pre-Ictal  | 3270         | 3290
# chb05_21.edf    | Pre-Ictal  | 3400         | 3485
# chb05_21.edf    | Ictal      | 3485         | 3600
# chb05_22.edf    | Pre-Ictal  | 0            | 235
# chb05_22.edf    | Ictal      | 910          | 985
# chb05_22.edf    | Pre-Ictal  | 1050         | 1070
# chb05_22.edf    | Ictal      | 1070         | 1100
# chb05_22.edf    | Pre-Ictal  | 1685         | 1735
# chb05_22.edf    | Pre-Ictal  | 1815         | 1870
# chb05_22.edf    | Ictal      | 2370         | 2495
# chb05_22.edf    | Ictal      | 2585         | 2675
# chb05_22.edf    | Pre-Ictal  | 2675         | 2740
# chb05_22.edf    | Ictal      | 2740         | 2980
# chb05_22.edf    | Pre-Ictal  | 2980         | 3045
# chb05_22.edf    | Ictal      | 3045         | 3600
# chb05_23.edf    | Pre-Ictal  | 0            | 590
# chb05_23.edf    | Ictal      | 590          | 690
# chb05_23.edf    | Ictal      | 775          | 805
# chb05_23.edf    | Pre-Ictal  | 820          | 1500
# chb05_23.edf    | Pre-Ictal  | 1530         | 2095
# chb05_23.edf    | Ictal      | 2130         | 2220
# chb05_23.edf    | Pre-Ictal  | 2285         | 2470
# chb05_23.edf    | Ictal      | 2470         | 2490
# chb05_23.edf    | Pre-Ictal  | 2490         | 2580
# chb05_23.edf    | Ictal      | 2580         | 2605
# chb05_23.edf    | Pre-Ictal  | 2605         | 2785
# chb05_23.edf    | Ictal      | 2785         | 2815
# chb05_23.edf    | Pre-Ictal  | 2815         | 2850
# chb05_23.edf    | Ictal      | 2850         | 2880
# chb05_23.edf    | Pre-Ictal  | 2880         | 2925
# chb05_23.edf    | Ictal      | 2925         | 2945
# chb05_23.edf    | Pre-Ictal  | 2945         | 3050
# chb05_23.edf    | Ictal      | 3050         | 3065
# chb05_23.edf    | Pre-Ictal  | 3065         | 3090
# chb05_23.edf    | Ictal      | 3090         | 3130
# chb05_23.edf    | Pre-Ictal  | 3130         | 3160
# chb05_23.edf    | Pre-Ictal  | 3190         | 3600
# chb05_24.edf    | Pre-Ictal  | 0            | 70
# chb05_24.edf    | Pre-Ictal  | 125          | 795
# chb05_24.edf    | Ictal      | 805          | 845
# chb05_24.edf    | Pre-Ictal  | 875          | 985
# chb05_24.edf    | Pre-Ictal  | 1125         | 2720
# chb05_24.edf    | Ictal      | 2720         | 2805
# chb05_24.edf    | Ictal      | 2850         | 3030
# chb05_24.edf    | Ictal      | 3075         | 3530
# chb05_24.edf    | Pre-Ictal  | 3530         | 3580
# chb05_25.edf    | Ictal      | 0            | 10
# chb05_25.edf    | Pre-Ictal  | 10           | 75
# chb05_25.edf    | Ictal      | 75           | 95
# chb05_25.edf    | Pre-Ictal  | 115          | 175
# chb05_25.edf    | Pre-Ictal  | 200          | 345
# chb05_25.edf    | Ictal      | 345          | 360
# chb05_25.edf    | Pre-Ictal  | 360          | 450
# chb05_25.edf    | Ictal      | 450          | 475
# chb05_25.edf    | Pre-Ictal  | 540          | 630
# chb05_25.edf    | Ictal      | 630          | 665
# chb05_25.edf    | Pre-Ictal  | 675          | 815
# chb05_25.edf    | Ictal      | 815          | 835
# chb05_25.edf    | Pre-Ictal  | 865          | 1815
# chb05_25.edf    | Pre-Ictal  | 1845         | 2195
# chb05_25.edf    | Ictal      | 2195         | 2335
# chb05_25.edf    | Pre-Ictal  | 2375         | 2440
# chb05_25.edf    | Pre-Ictal  | 2475         | 2685
# chb05_25.edf    | Pre-Ictal  | 2730         | 2950
# chb05_25.edf    | Ictal      | 2960         | 3060
# chb05_25.edf    | Pre-Ictal  | 3135         | 3335
# chb05_25.edf    | Ictal      | 3335         | 3425
# chb05_25.edf    | Pre-Ictal  | 3425         | 3450
# chb05_25.edf    | Pre-Ictal  | 3510         | 3545
# chb05_25.edf    | Ictal      | 3545         | 3600

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb05_06.edf": [(417, 532)],
    "chb05_13.edf": [(1086, 1196)],
    "chb05_16.edf": [(2317, 2413)],
    "chb05_22.edf": [(2348, 2465)]
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()
