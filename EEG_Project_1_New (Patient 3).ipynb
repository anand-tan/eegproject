# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch, hilbert, butter, filtfilt
from antropy import perm_entropy

# --- Pre-define PAC Filters ---
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Filter coefficients for 256 Hz sampling rate
b_theta, a_theta = butter_bandpass(4.0, 8.0, 256)
b_gamma, a_gamma = butter_bandpass(30.0, 40.0, 256)

def get_regional_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    
    # Isolate Hemispheres based on standard bipolar pairs
    # Left: FP1-F7, F7-T7, T7-P7, P7-O1, FP1-F3, F3-C3, C3-P3, P3-O1
    LEFT_CH = [0, 1, 2, 3, 4, 5, 6, 7]
    # Right: FP2-F4, F4-C4, C4-P4, P4-O2, FP2-F8, F8-T8, T8-P8, P8-O2
    RIGHT_CH = [8, 9, 10, 11, 12, 13, 14, 15]

    for window in epoch_data:
        X_left = window[LEFT_CH, :]
        X_right = window[RIGHT_CH, :]

        # --- 1. Morphological (RMS & Line Length) ---
        rms_L = np.mean(np.sqrt(np.mean(X_left**2, axis=1)))
        rms_R = np.mean(np.sqrt(np.mean(X_right**2, axis=1)))

        ll_L = np.mean(np.sum(np.abs(np.diff(X_left, axis=1)), axis=1))
        ll_R = np.mean(np.sum(np.abs(np.diff(X_right, axis=1)), axis=1))

        # --- 2. Spectral Power (Theta/Alpha) ---
        freqs_L, psd_L = welch(X_left, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs_L >= 4) & (freqs_L < 8)
        al_mask = (freqs_L >= 8) & (freqs_L < 13)
        
        theta_L = np.trapezoid(psd_L[:, th_mask], freqs_L[th_mask], axis=1).mean()
        alpha_L = np.trapezoid(psd_L[:, al_mask], freqs_L[al_mask], axis=1).mean()
        ta_ratio_L = theta_L / (alpha_L + eps)

        freqs_R, psd_R = welch(X_right, sfreq, nperseg=sfreq * 2)
        theta_R = np.trapezoid(psd_R[:, th_mask], freqs_R[th_mask], axis=1).mean()
        alpha_R = np.trapezoid(psd_R[:, al_mask], freqs_R[al_mask], axis=1).mean()
        ta_ratio_R = theta_R / (alpha_R + eps)

        # --- 3. Phase-Amplitude Coupling (PAC) ---
        # Left PAC
        theta_sig_L = filtfilt(b_theta, a_theta, X_left, axis=1)
        gamma_sig_L = filtfilt(b_gamma, a_gamma, X_left, axis=1)
        theta_phase_L = np.angle(hilbert(theta_sig_L, axis=1))
        gamma_amp_L = np.abs(hilbert(gamma_sig_L, axis=1))
        pac_scores_L = [np.abs(np.corrcoef(np.cos(theta_phase_L[i]), gamma_amp_L[i])[0, 1]) for i in range(X_left.shape[0])]
        pac_L = np.mean(pac_scores_L)

        # Right PAC
        theta_sig_R = filtfilt(b_theta, a_theta, X_right, axis=1)
        gamma_sig_R = filtfilt(b_gamma, a_gamma, X_right, axis=1)
        theta_phase_R = np.angle(hilbert(theta_sig_R, axis=1))
        gamma_amp_R = np.abs(hilbert(gamma_sig_R, axis=1))
        pac_scores_R = [np.abs(np.corrcoef(np.cos(theta_phase_R[i]), gamma_amp_R[i])[0, 1]) for i in range(X_right.shape[0])]
        pac_R = np.mean(pac_scores_R)

        # --- 4. Spatial Sync (Cross-Hemisphere PLV) ---
        # Measure how locked the left hemisphere is to the right hemisphere
        phases_L = np.angle(hilbert(X_left, axis=1))
        phases_R = np.angle(hilbert(X_right, axis=1))
        
        sync_scores = []
        for i in range(len(LEFT_CH)):
            phase_diff = phases_L[i] - phases_R[i]
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))
            sync_scores.append(plv)
            
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        # --- Compile Regional Features ---
        features.append([
            rms_L, rms_R, 
            ll_L, ll_R, 
            ta_ratio_L, ta_ratio_R, 
            pac_L, pac_R, 
            avg_sync
        ])

    return np.array(features)

# %%
import numpy as np
from scipy.signal import welch, hilbert, butter, filtfilt
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

# --- Pre-define PAC Filters ---
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Filter coefficients for 256 Hz sampling rate
b_theta, a_theta = butter_bandpass(4.0, 8.0, 256)
b_gamma, a_gamma = butter_bandpass(30.0, 40.0, 256)


def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization (Phase-Locking Value)
    6. Phase-Amplitude Coupling (Theta-Gamma)
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        # --- 1. Spectral Power (Theta/Alpha) ---
        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        # --- 2. Complexity ---
        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        # --- 3. Spatial Sync (Phase-Locking Value) ---
        # Get instantaneous phase for all channels at once
        phases = np.angle(hilbert(X, axis=1))
        
        sync_scores = []
        for li, ri in PAIRS_LR:
            # Calculate phase difference
            phase_diff = phases[li] - phases[ri]
            # Calculate PLV for this pair (magnitude of the mean complex phase vector)
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))
            sync_scores.append(plv)
            
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        # --- 4. Morphological ---
        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        # --- 5. Phase-Amplitude Coupling (Theta-Gamma) ---
        # Fast vectorized filtering across all primary channels
        theta_sig = filtfilt(b_theta, a_theta, X, axis=1)
        gamma_sig = filtfilt(b_gamma, a_gamma, X, axis=1)
        
        # Hilbert transform to get phase and amplitude
        theta_phase = np.angle(hilbert(theta_sig, axis=1))
        gamma_amp = np.abs(hilbert(gamma_sig, axis=1))
        
        # Calculate coupling for each channel, then average
        pac_scores = [np.abs(np.corrcoef(np.cos(theta_phase[i]), gamma_amp[i])[0, 1]) for i in range(X.shape[0])]
        avg_pac = np.mean(pac_scores)

        # --- Compile Features ---
        features.append([ta_ratio, complexity, line_length, rms, avg_sync, avg_pac])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb03) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_11.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_19.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_20.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_21.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_22.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_23.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_24.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_25.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_26.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_27.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_28.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_29.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_30.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_31.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_32.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_33.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_34.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_35.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_36.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_37.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb03/chb03_38.edf"},
]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/38 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/38 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/38 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 20/38 files; last epochs=721
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 25/38 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 30/38 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 35/38 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_4161/4044087417.py:52: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 38/38 files; last epochs=720
# Loading complete.

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.9619   0.0381   0.0000
# State 1   0.0329   0.9370   0.0301
# State 2   0.0010   0.0665   0.9325

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync", "Avg PAC"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : -0.516
#   PermEntropy : -0.410
#   LineLength  : -0.572
#   RMS         : -0.612
#   Avg Sync    : +0.104
#   Avg PAC     : +0.195
#
# State 1 means:
#   TA_ratio    : +0.076
#   PermEntropy : +0.112
#   LineLength  : -0.011
#   RMS         : +0.040
#   Avg Sync    : -0.030
#   Avg PAC     : -0.027
#
# State 2 means:
#   TA_ratio    : +0.830
#   PermEntropy : +0.551
#   LineLength  : +1.134
#   RMS         : +1.102
#   Avg Sync    : -0.137
#   Avg PAC     : -0.316

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy, [2] LineLength, 
# [3] RMS, [4] Avg Sync, [5] Avg PAC

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3
IDX_SYNC = 4
IDX_PAC = 5

# 1. Ictal: highest amplitude and spikiness
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# 2. Pre-ictal: highest Phase-Amplitude Coupling among non-ictal states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
preictal_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_PAC])]
)

# 3. Baseline: whatever state is left (the normal state)
baseline_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, preictal_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline (PAC-Optimized)")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb03_01.edf    | Pre-Ictal  | 0            | 365
# chb03_01.edf    | Ictal      | 375          | 555
# chb03_01.edf    | Ictal      | 705          | 840
# chb03_01.edf    | Pre-Ictal  | 1070         | 1205
# chb03_01.edf    | Ictal      | 1330         | 1370
# chb03_01.edf    | Pre-Ictal  | 1395         | 1450
# chb03_01.edf    | Ictal      | 1555         | 1780
# chb03_01.edf    | Ictal      | 2040         | 2170
# chb03_01.edf    | Pre-Ictal  | 2280         | 3020
# chb03_01.edf    | Pre-Ictal  | 3260         | 3600
# chb03_02.edf    | Pre-Ictal  | 0            | 675
# chb03_02.edf    | Ictal      | 745          | 840
# chb03_02.edf    | Pre-Ictal  | 1195         | 1300
# chb03_02.edf    | Pre-Ictal  | 1325         | 2225
# chb03_02.edf    | Ictal      | 2595         | 2635
# chb03_02.edf    | Ictal      | 2675         | 2820
# chb03_02.edf    | Ictal      | 2900         | 3205
# chb03_02.edf    | Ictal      | 3225         | 3445
# chb03_02.edf    | Ictal      | 3490         | 3520
# chb03_03.edf    | Pre-Ictal  | 0            | 10
# chb03_03.edf    | Pre-Ictal  | 155          | 225
# chb03_03.edf    | Pre-Ictal  | 260          | 365
# chb03_03.edf    | Ictal      | 440          | 575
# chb03_03.edf    | Pre-Ictal  | 810          | 985
# chb03_03.edf    | Pre-Ictal  | 1045         | 1125
# chb03_03.edf    | Pre-Ictal  | 1175         | 1320
# chb03_03.edf    | Pre-Ictal  | 1345         | 1395
# chb03_03.edf    | Ictal      | 1405         | 2035
# chb03_03.edf    | Pre-Ictal  | 2050         | 2430
# chb03_03.edf    | Pre-Ictal  | 2465         | 2980
# chb03_03.edf    | Pre-Ictal  | 3190         | 3340
# chb03_03.edf    | Pre-Ictal  | 3405         | 3600
# chb03_04.edf    | Ictal      | 550          | 600
# chb03_04.edf    | Pre-Ictal  | 1295         | 1350
# chb03_04.edf    | Pre-Ictal  | 1405         | 1450
# chb03_04.edf    | Pre-Ictal  | 1570         | 1600
# chb03_04.edf    | Pre-Ictal  | 1785         | 1870
# chb03_04.edf    | Ictal      | 1930         | 2010
# chb03_04.edf    | Ictal      | 2035         | 2310
# chb03_04.edf    | Pre-Ictal  | 2480         | 2495
# chb03_04.edf    | Ictal      | 2510         | 2525
# chb03_04.edf    | Ictal      | 2625         | 2665
# chb03_04.edf    | Ictal      | 2690         | 2720
# chb03_04.edf    | Ictal      | 2825         | 2850
# chb03_04.edf    | Pre-Ictal  | 2885         | 3600
# chb03_05.edf    | Pre-Ictal  | 0            | 65
# chb03_05.edf    | Pre-Ictal  | 100          | 310
# chb03_05.edf    | Ictal      | 330          | 365
# chb03_05.edf    | Pre-Ictal  | 375          | 620
# chb03_05.edf    | Pre-Ictal  | 640          | 740
# chb03_05.edf    | Ictal      | 1140         | 1190
# chb03_05.edf    | Ictal      | 1255         | 1310
# chb03_05.edf    | Ictal      | 1350         | 1580
# chb03_05.edf    | Pre-Ictal  | 1630         | 1675
# chb03_05.edf    | Ictal      | 1755         | 1815
# chb03_05.edf    | Pre-Ictal  | 1825         | 1920
# chb03_05.edf    | Pre-Ictal  | 1945         | 1985
# chb03_05.edf    | Pre-Ictal  | 2035         | 2120
# chb03_05.edf    | Ictal      | 2160         | 2190
# chb03_05.edf    | Pre-Ictal  | 2225         | 2265
# chb03_05.edf    | Ictal      | 2280         | 2330
# chb03_05.edf    | Ictal      | 2355         | 2390
# chb03_05.edf    | Pre-Ictal  | 2410         | 2435
# chb03_05.edf    | Ictal      | 2445         | 2595
# chb03_05.edf    | Ictal      | 2615         | 2685
# chb03_05.edf    | Pre-Ictal  | 2700         | 2725
# chb03_05.edf    | Ictal      | 2785         | 2920
# chb03_05.edf    | Pre-Ictal  | 2925         | 3060
# chb03_05.edf    | Pre-Ictal  | 3100         | 3130
# chb03_05.edf    | Ictal      | 3140         | 3175
# chb03_05.edf    | Pre-Ictal  | 3275         | 3600
# chb03_06.edf    | Ictal      | 0            | 300
# chb03_06.edf    | Pre-Ictal  | 300          | 415
# chb03_06.edf    | Pre-Ictal  | 435          | 465
# chb03_06.edf    | Ictal      | 470          | 530
# chb03_06.edf    | Pre-Ictal  | 535          | 555
# chb03_06.edf    | Pre-Ictal  | 580          | 910
# chb03_06.edf    | Pre-Ictal  | 930          | 950
# chb03_06.edf    | Ictal      | 1170         | 1190
# chb03_06.edf    | Ictal      | 1220         | 1245
# chb03_06.edf    | Ictal      | 1300         | 1315
# chb03_06.edf    | Ictal      | 1365         | 1395
# chb03_06.edf    | Ictal      | 1455         | 1485
# chb03_06.edf    | Ictal      | 1550         | 1575
# chb03_06.edf    | Ictal      | 1625         | 1675
# chb03_06.edf    | Ictal      | 1825         | 1855
# chb03_06.edf    | Ictal      | 1960         | 2030
# chb03_06.edf    | Ictal      | 2065         | 2140
# chb03_06.edf    | Ictal      | 2280         | 2300
# chb03_06.edf    | Ictal      | 2435         | 2465
# chb03_07.edf    | Ictal      | 0            | 385
# chb03_07.edf    | Pre-Ictal  | 470          | 510
# chb03_07.edf    | Pre-Ictal  | 595          | 685
# chb03_07.edf    | Pre-Ictal  | 715          | 740
# chb03_07.edf    | Pre-Ictal  | 835          | 890
# chb03_07.edf    | Ictal      | 1045         | 1090
# chb03_07.edf    | Pre-Ictal  | 1200         | 1260
# chb03_07.edf    | Pre-Ictal  | 1360         | 1565
# chb03_07.edf    | Pre-Ictal  | 1615         | 1770
# chb03_07.edf    | Pre-Ictal  | 1810         | 1850
# chb03_07.edf    | Pre-Ictal  | 1920         | 1950
# chb03_07.edf    | Pre-Ictal  | 2010         | 2055
# chb03_07.edf    | Pre-Ictal  | 2090         | 2390
# chb03_07.edf    | Pre-Ictal  | 2425         | 2595
# chb03_07.edf    | Ictal      | 2620         | 2690
# chb03_07.edf    | Ictal      | 2755         | 2765
# chb03_07.edf    | Pre-Ictal  | 2905         | 2920
# chb03_07.edf    | Pre-Ictal  | 2955         | 3155
# chb03_07.edf    | Pre-Ictal  | 3185         | 3205
# chb03_07.edf    | Pre-Ictal  | 3545         | 3600
# chb03_08.edf    | Pre-Ictal  | 20           | 85
# chb03_08.edf    | Pre-Ictal  | 115          | 135
# chb03_08.edf    | Pre-Ictal  | 235          | 315
# chb03_08.edf    | Ictal      | 1255         | 1290
# chb03_08.edf    | Ictal      | 1435         | 1465
# chb03_08.edf    | Ictal      | 1535         | 1690
# chb03_08.edf    | Ictal      | 1755         | 1925
# chb03_08.edf    | Pre-Ictal  | 1930         | 2365
# chb03_08.edf    | Pre-Ictal  | 2395         | 2445
# chb03_08.edf    | Ictal      | 2450         | 2485
# chb03_08.edf    | Pre-Ictal  | 2510         | 2595
# chb03_08.edf    | Pre-Ictal  | 2625         | 2645
# chb03_08.edf    | Pre-Ictal  | 2785         | 2820
# chb03_08.edf    | Ictal      | 3205         | 3235
# chb03_08.edf    | Pre-Ictal  | 3315         | 3535
# chb03_08.edf    | Pre-Ictal  | 3565         | 3585
# chb03_09.edf    | Ictal      | 65           | 215
# chb03_09.edf    | Pre-Ictal  | 375          | 420
# chb03_09.edf    | Pre-Ictal  | 760          | 805
# chb03_09.edf    | Pre-Ictal  | 910          | 945
# chb03_09.edf    | Pre-Ictal  | 1015         | 1030
# chb03_09.edf    | Pre-Ictal  | 1280         | 1295
# chb03_09.edf    | Pre-Ictal  | 1530         | 1555
# chb03_09.edf    | Ictal      | 1740         | 1815
# chb03_09.edf    | Ictal      | 1865         | 1915
# chb03_09.edf    | Pre-Ictal  | 2040         | 2050
# chb03_09.edf    | Pre-Ictal  | 2110         | 2200
# chb03_09.edf    | Pre-Ictal  | 2265         | 2290
# chb03_09.edf    | Ictal      | 2955         | 2965
# chb03_09.edf    | Ictal      | 3150         | 3165
# chb03_09.edf    | Ictal      | 3195         | 3220
# chb03_09.edf    | Ictal      | 3240         | 3270
# chb03_09.edf    | Ictal      | 3295         | 3345
# chb03_09.edf    | Ictal      | 3375         | 3470
# chb03_09.edf    | Ictal      | 3505         | 3545
# chb03_09.edf    | Ictal      | 3575         | 3600
# chb03_10.edf    | Pre-Ictal  | 0            | 420
# chb03_10.edf    | Pre-Ictal  | 440          | 630
# chb03_10.edf    | Pre-Ictal  | 660          | 845
# chb03_10.edf    | Pre-Ictal  | 895          | 1190
# chb03_10.edf    | Pre-Ictal  | 1210         | 1260
# chb03_10.edf    | Pre-Ictal  | 1290         | 1325
# chb03_10.edf    | Pre-Ictal  | 1360         | 1400
# chb03_10.edf    | Ictal      | 1410         | 1420
# chb03_10.edf    | Pre-Ictal  | 1435         | 1535
# chb03_10.edf    | Ictal      | 1595         | 1790
# chb03_10.edf    | Ictal      | 1850         | 1890
# chb03_10.edf    | Ictal      | 1945         | 2085
# chb03_10.edf    | Ictal      | 2110         | 2260
# chb03_10.edf    | Ictal      | 2285         | 2320
# chb03_10.edf    | Ictal      | 2345         | 2390
# chb03_10.edf    | Ictal      | 2420         | 2470
# chb03_10.edf    | Ictal      | 2705         | 2820
# chb03_10.edf    | Ictal      | 2860         | 3015
# chb03_10.edf    | Pre-Ictal  | 3055         | 3130
# chb03_10.edf    | Pre-Ictal  | 3165         | 3600
# chb03_11.edf    | Ictal      | 0            | 65
# chb03_11.edf    | Pre-Ictal  | 65           | 95
# chb03_11.edf    | Pre-Ictal  | 180          | 230
# chb03_11.edf    | Pre-Ictal  | 310          | 390
# chb03_11.edf    | Pre-Ictal  | 410          | 730
# chb03_11.edf    | Ictal      | 735          | 765
# chb03_11.edf    | Pre-Ictal  | 765          | 1410
# chb03_11.edf    | Ictal      | 2020         | 2045
# chb03_11.edf    | Ictal      | 2120         | 2140
# chb03_11.edf    | Ictal      | 2245         | 2275
# chb03_11.edf    | Ictal      | 2335         | 2410
# chb03_11.edf    | Ictal      | 2465         | 2500
# chb03_11.edf    | Ictal      | 2565         | 2635
# chb03_11.edf    | Ictal      | 2670         | 2695
# chb03_11.edf    | Ictal      | 2760         | 2795
# chb03_11.edf    | Ictal      | 2840         | 2930
# chb03_11.edf    | Ictal      | 2950         | 2980
# chb03_11.edf    | Ictal      | 2995         | 3025
# chb03_11.edf    | Ictal      | 3070         | 3140
# chb03_11.edf    | Pre-Ictal  | 3250         | 3285
# chb03_12.edf    | Ictal      | 20           | 100
# chb03_12.edf    | Pre-Ictal  | 150          | 190
# chb03_12.edf    | Pre-Ictal  | 350          | 385
# chb03_12.edf    | Pre-Ictal  | 705          | 735
# chb03_12.edf    | Pre-Ictal  | 965          | 985
# chb03_12.edf    | Pre-Ictal  | 1035         | 1075
# chb03_12.edf    | Pre-Ictal  | 1105         | 1140
# chb03_12.edf    | Ictal      | 1315         | 1340
# chb03_12.edf    | Ictal      | 1410         | 1455
# chb03_12.edf    | Ictal      | 1485         | 1540
# chb03_12.edf    | Pre-Ictal  | 1860         | 1895
# chb03_12.edf    | Ictal      | 2650         | 2675
# chb03_12.edf    | Ictal      | 2765         | 2780
# chb03_12.edf    | Ictal      | 2990         | 3045
# chb03_12.edf    | Ictal      | 3085         | 3125
# chb03_12.edf    | Ictal      | 3150         | 3165
# chb03_12.edf    | Ictal      | 3410         | 3440
# chb03_12.edf    | Ictal      | 3570         | 3600
# chb03_13.edf    | Pre-Ictal  | 0            | 85
# chb03_13.edf    | Ictal      | 1160         | 1190
# chb03_13.edf    | Pre-Ictal  | 1295         | 1330
# chb03_13.edf    | Ictal      | 1730         | 1740
# chb03_13.edf    | Ictal      | 2300         | 2320
# chb03_13.edf    | Ictal      | 2350         | 2390
# chb03_13.edf    | Pre-Ictal  | 2390         | 2425
# chb03_13.edf    | Pre-Ictal  | 2490         | 2615
# chb03_13.edf    | Ictal      | 2910         | 2915
# chb03_13.edf    | Pre-Ictal  | 3080         | 3225
# chb03_13.edf    | Ictal      | 3245         | 3295
# chb03_13.edf    | Pre-Ictal  | 3295         | 3345
# chb03_13.edf    | Pre-Ictal  | 3430         | 3455
# chb03_13.edf    | Ictal      | 3475         | 3580
# chb03_14.edf    | Pre-Ictal  | 80           | 115
# chb03_14.edf    | Pre-Ictal  | 240          | 290
# chb03_14.edf    | Pre-Ictal  | 340          | 380
# chb03_14.edf    | Pre-Ictal  | 460          | 480
# chb03_14.edf    | Ictal      | 695          | 735
# chb03_14.edf    | Pre-Ictal  | 780          | 880
# chb03_14.edf    | Pre-Ictal  | 935          | 960
# chb03_14.edf    | Pre-Ictal  | 1335         | 1365
# chb03_14.edf    | Pre-Ictal  | 1585         | 1635
# chb03_14.edf    | Pre-Ictal  | 1675         | 1700
# chb03_14.edf    | Pre-Ictal  | 2115         | 2150
# chb03_14.edf    | Ictal      | 2190         | 2220
# chb03_14.edf    | Ictal      | 2455         | 2485
# chb03_14.edf    | Ictal      | 2585         | 2610
# chb03_14.edf    | Ictal      | 3220         | 3250
# chb03_14.edf    | Ictal      | 3305         | 3315
# chb03_14.edf    | Ictal      | 3370         | 3400
# chb03_14.edf    | Ictal      | 3435         | 3450
# chb03_14.edf    | Ictal      | 3470         | 3555
# chb03_15.edf    | Ictal      | 0            | 5
# chb03_15.edf    | Ictal      | 405          | 425
# chb03_15.edf    | Ictal      | 490          | 520
# chb03_15.edf    | Ictal      | 560          | 585
# chb03_15.edf    | Ictal      | 620          | 720
# chb03_15.edf    | Pre-Ictal  | 775          | 1125
# chb03_15.edf    | Ictal      | 1130         | 1160
# chb03_15.edf    | Pre-Ictal  | 1160         | 1510
# chb03_15.edf    | Ictal      | 2340         | 2385
# chb03_15.edf    | Pre-Ictal  | 2535         | 2585
# chb03_15.edf    | Ictal      | 2895         | 2915
# chb03_15.edf    | Pre-Ictal  | 3390         | 3425
# chb03_16.edf    | Pre-Ictal  | 0            | 2075
# chb03_16.edf    | Ictal      | 2085         | 2365
# chb03_16.edf    | Ictal      | 2410         | 2730
# chb03_16.edf    | Pre-Ictal  | 2745         | 2760
# chb03_16.edf    | Ictal      | 2805         | 2855
# chb03_16.edf    | Ictal      | 2930         | 3270
# chb03_16.edf    | Ictal      | 3345         | 3445
# chb03_16.edf    | Ictal      | 3495         | 3590
# chb03_17.edf    | Pre-Ictal  | 0            | 190
# chb03_17.edf    | Pre-Ictal  | 225          | 270
# chb03_17.edf    | Pre-Ictal  | 315          | 350
# chb03_17.edf    | Ictal      | 365          | 400
# chb03_17.edf    | Ictal      | 440          | 470
# chb03_17.edf    | Pre-Ictal  | 510          | 525
# chb03_17.edf    | Pre-Ictal  | 800          | 815
# chb03_17.edf    | Ictal      | 855          | 915
# chb03_17.edf    | Pre-Ictal  | 925          | 985
# chb03_17.edf    | Ictal      | 995          | 1015
# chb03_17.edf    | Ictal      | 1060         | 1120
# chb03_17.edf    | Ictal      | 1255         | 1280
# chb03_17.edf    | Pre-Ictal  | 1290         | 1355
# chb03_17.edf    | Pre-Ictal  | 1415         | 1540
# chb03_17.edf    | Ictal      | 1675         | 1980
# chb03_17.edf    | Ictal      | 2120         | 2185
# chb03_17.edf    | Pre-Ictal  | 2190         | 2215
# chb03_17.edf    | Ictal      | 2230         | 2245
# chb03_17.edf    | Pre-Ictal  | 2355         | 2380
# chb03_17.edf    | Pre-Ictal  | 2410         | 2430
# chb03_17.edf    | Pre-Ictal  | 2450         | 2490
# chb03_17.edf    | Pre-Ictal  | 2555         | 2630
# chb03_17.edf    | Pre-Ictal  | 2700         | 2830
# chb03_17.edf    | Pre-Ictal  | 2860         | 2875
# chb03_17.edf    | Pre-Ictal  | 2900         | 2940
# chb03_17.edf    | Pre-Ictal  | 2985         | 3025
# chb03_17.edf    | Pre-Ictal  | 3165         | 3230
# chb03_17.edf    | Pre-Ictal  | 3255         | 3365
# chb03_17.edf    | Pre-Ictal  | 3415         | 3470
# chb03_17.edf    | Pre-Ictal  | 3510         | 3580
# chb03_17.edf    | Ictal      | 3585         | 3600
# chb03_18.edf    | Ictal      | 0            | 495
# chb03_18.edf    | Ictal      | 615          | 640
# chb03_18.edf    | Pre-Ictal  | 680          | 720
# chb03_18.edf    | Ictal      | 740          | 805
# chb03_18.edf    | Pre-Ictal  | 850          | 940
# chb03_18.edf    | Ictal      | 960          | 1150
# chb03_18.edf    | Ictal      | 1215         | 1240
# chb03_18.edf    | Pre-Ictal  | 1255         | 1790
# chb03_18.edf    | Pre-Ictal  | 1815         | 2410
# chb03_18.edf    | Ictal      | 2420         | 2445
# chb03_18.edf    | Pre-Ictal  | 2455         | 3125
# chb03_18.edf    | Ictal      | 3130         | 3230
# chb03_18.edf    | Ictal      | 3260         | 3305
# chb03_18.edf    | Pre-Ictal  | 3370         | 3600
# chb03_19.edf    | Pre-Ictal  | 0            | 655
# chb03_19.edf    | Ictal      | 665          | 685
# chb03_19.edf    | Ictal      | 740          | 795
# chb03_19.edf    | Pre-Ictal  | 800          | 940
# chb03_19.edf    | Ictal      | 955          | 980
# chb03_19.edf    | Ictal      | 1070         | 1095
# chb03_19.edf    | Ictal      | 1175         | 1205
# chb03_19.edf    | Ictal      | 1295         | 1335
# chb03_19.edf    | Ictal      | 1375         | 1450
# chb03_19.edf    | Ictal      | 1520         | 1575
# chb03_19.edf    | Pre-Ictal  | 1655         | 1695
# chb03_19.edf    | Pre-Ictal  | 1875         | 1935
# chb03_19.edf    | Pre-Ictal  | 1965         | 1990
# chb03_19.edf    | Pre-Ictal  | 2010         | 2045
# chb03_19.edf    | Pre-Ictal  | 2115         | 2155
# chb03_19.edf    | Ictal      | 2235         | 2320
# chb03_19.edf    | Pre-Ictal  | 2370         | 2420
# chb03_19.edf    | Ictal      | 2435         | 2460
# chb03_19.edf    | Ictal      | 2485         | 2515
# chb03_19.edf    | Pre-Ictal  | 2695         | 2715
# chb03_19.edf    | Ictal      | 2725         | 2745
# chb03_19.edf    | Ictal      | 2820         | 2850
# chb03_19.edf    | Pre-Ictal  | 2900         | 2925
# chb03_19.edf    | Ictal      | 2980         | 3075
# chb03_19.edf    | Ictal      | 3180         | 3250
# chb03_19.edf    | Ictal      | 3275         | 3355
# chb03_19.edf    | Ictal      | 3525         | 3565
# chb03_20.edf    | Pre-Ictal  | 0            | 25
# chb03_20.edf    | Pre-Ictal  | 95           | 140
# chb03_20.edf    | Ictal      | 160          | 200
# chb03_20.edf    | Pre-Ictal  | 210          | 225
# chb03_20.edf    | Pre-Ictal  | 250          | 330
# chb03_20.edf    | Pre-Ictal  | 405          | 480
# chb03_20.edf    | Ictal      | 515          | 560
# chb03_20.edf    | Pre-Ictal  | 585          | 925
# chb03_20.edf    | Pre-Ictal  | 985          | 1070
# chb03_20.edf    | Pre-Ictal  | 1110         | 1135
# chb03_20.edf    | Pre-Ictal  | 1200         | 1230
# chb03_20.edf    | Ictal      | 1360         | 1410
# chb03_20.edf    | Pre-Ictal  | 1420         | 1490
# chb03_20.edf    | Ictal      | 1565         | 1600
# chb03_20.edf    | Pre-Ictal  | 1640         | 1665
# chb03_20.edf    | Pre-Ictal  | 1770         | 2110
# chb03_20.edf    | Ictal      | 2185         | 2260
# chb03_20.edf    | Ictal      | 2320         | 2345
# chb03_20.edf    | Ictal      | 2375         | 2405
# chb03_20.edf    | Pre-Ictal  | 2515         | 2545
# chb03_20.edf    | Ictal      | 2635         | 2665
# chb03_20.edf    | Pre-Ictal  | 2760         | 2790
# chb03_20.edf    | Ictal      | 2850         | 2955
# chb03_20.edf    | Ictal      | 2980         | 3145
# chb03_20.edf    | Ictal      | 3305         | 3335
# chb03_20.edf    | Ictal      | 3470         | 3535
# chb03_21.edf    | Ictal      | 0            | 15
# chb03_21.edf    | Ictal      | 60           | 90
# chb03_21.edf    | Ictal      | 525          | 685
# chb03_21.edf    | Ictal      | 1285         | 1310
# chb03_21.edf    | Ictal      | 1495         | 1565
# chb03_21.edf    | Ictal      | 1590         | 1615
# chb03_21.edf    | Pre-Ictal  | 1635         | 1680
# chb03_21.edf    | Ictal      | 1800         | 1830
# chb03_21.edf    | Pre-Ictal  | 1865         | 1995
# chb03_21.edf    | Pre-Ictal  | 2025         | 2240
# chb03_21.edf    | Ictal      | 2285         | 2380
# chb03_21.edf    | Ictal      | 2405         | 2475
# chb03_21.edf    | Ictal      | 2505         | 2545
# chb03_21.edf    | Ictal      | 2595         | 2670
# chb03_21.edf    | Pre-Ictal  | 2690         | 2730
# chb03_21.edf    | Ictal      | 2735         | 2760
# chb03_21.edf    | Ictal      | 2775         | 2820
# chb03_21.edf    | Pre-Ictal  | 2825         | 2850
# chb03_21.edf    | Ictal      | 2860         | 2970
# chb03_21.edf    | Pre-Ictal  | 3085         | 3600
# chb03_22.edf    | Pre-Ictal  | 0            | 610
# chb03_22.edf    | Ictal      | 790          | 840
# chb03_22.edf    | Ictal      | 880          | 1105
# chb03_22.edf    | Ictal      | 1135         | 1235
# chb03_22.edf    | Ictal      | 1330         | 1480
# chb03_22.edf    | Ictal      | 1625         | 1720
# chb03_22.edf    | Ictal      | 1760         | 1855
# chb03_22.edf    | Pre-Ictal  | 1915         | 1945
# chb03_22.edf    | Pre-Ictal  | 1970         | 2105
# chb03_22.edf    | Pre-Ictal  | 2165         | 2230
# chb03_22.edf    | Pre-Ictal  | 2250         | 2300
# chb03_22.edf    | Pre-Ictal  | 2345         | 2440
# chb03_22.edf    | Pre-Ictal  | 2480         | 2570
# chb03_22.edf    | Pre-Ictal  | 2595         | 2625
# chb03_22.edf    | Pre-Ictal  | 2645         | 2705
# chb03_22.edf    | Pre-Ictal  | 2735         | 2815
# chb03_22.edf    | Ictal      | 2910         | 2950
# chb03_22.edf    | Pre-Ictal  | 3020         | 3135
# chb03_22.edf    | Ictal      | 3150         | 3175
# chb03_22.edf    | Pre-Ictal  | 3195         | 3265
# chb03_22.edf    | Ictal      | 3430         | 3495
# chb03_22.edf    | Pre-Ictal  | 3515         | 3555
# chb03_23.edf    | Pre-Ictal  | 0            | 65
# chb03_23.edf    | Pre-Ictal  | 150          | 190
# chb03_23.edf    | Pre-Ictal  | 250          | 365
# chb03_23.edf    | Ictal      | 450          | 490
# chb03_23.edf    | Ictal      | 530          | 680
# chb03_23.edf    | Pre-Ictal  | 885          | 975
# chb03_23.edf    | Pre-Ictal  | 1005         | 1145
# chb03_23.edf    | Pre-Ictal  | 1220         | 1420
# chb03_23.edf    | Pre-Ictal  | 1525         | 1775
# chb03_23.edf    | Pre-Ictal  | 1820         | 2085
# chb03_23.edf    | Pre-Ictal  | 2125         | 2275
# chb03_23.edf    | Pre-Ictal  | 2295         | 2585
# chb03_23.edf    | Pre-Ictal  | 2610         | 2720
# chb03_23.edf    | Ictal      | 2745         | 2960
# chb03_23.edf    | Ictal      | 3040         | 3110
# chb03_23.edf    | Ictal      | 3270         | 3295
# chb03_23.edf    | Pre-Ictal  | 3425         | 3460
# chb03_24.edf    | Pre-Ictal  | 65           | 115
# chb03_24.edf    | Pre-Ictal  | 410          | 430
# chb03_24.edf    | Pre-Ictal  | 460          | 520
# chb03_24.edf    | Pre-Ictal  | 630          | 660
# chb03_24.edf    | Pre-Ictal  | 965          | 995
# chb03_24.edf    | Pre-Ictal  | 1050         | 1095
# chb03_24.edf    | Pre-Ictal  | 1185         | 1215
# chb03_24.edf    | Ictal      | 1250         | 1305
# chb03_24.edf    | Ictal      | 1320         | 1385
# chb03_24.edf    | Ictal      | 1455         | 1475
# chb03_24.edf    | Pre-Ictal  | 1490         | 1535
# chb03_24.edf    | Pre-Ictal  | 1695         | 1710
# chb03_24.edf    | Pre-Ictal  | 1810         | 1905
# chb03_24.edf    | Pre-Ictal  | 2115         | 2130
# chb03_24.edf    | Ictal      | 2155         | 2385
# chb03_24.edf    | Ictal      | 2415         | 2490
# chb03_24.edf    | Ictal      | 2510         | 2520
# chb03_24.edf    | Pre-Ictal  | 2540         | 2565
# chb03_24.edf    | Pre-Ictal  | 2600         | 2615
# chb03_24.edf    | Pre-Ictal  | 2715         | 2795
# chb03_24.edf    | Pre-Ictal  | 2840         | 2865
# chb03_24.edf    | Ictal      | 2915         | 2935
# chb03_24.edf    | Pre-Ictal  | 3130         | 3165
# chb03_24.edf    | Pre-Ictal  | 3210         | 3265
# chb03_24.edf    | Pre-Ictal  | 3375         | 3430
# chb03_24.edf    | Pre-Ictal  | 3495         | 3560
# chb03_24.edf    | Ictal      | 3570         | 3600
# chb03_25.edf    | Ictal      | 0            | 55
# chb03_25.edf    | Pre-Ictal  | 160          | 215
# chb03_25.edf    | Pre-Ictal  | 235          | 345
# chb03_25.edf    | Pre-Ictal  | 385          | 440
# chb03_25.edf    | Pre-Ictal  | 455          | 705
# chb03_25.edf    | Pre-Ictal  | 745          | 1420
# chb03_25.edf    | Pre-Ictal  | 1550         | 1620
# chb03_25.edf    | Ictal      | 1650         | 1680
# chb03_25.edf    | Pre-Ictal  | 1690         | 1720
# chb03_25.edf    | Ictal      | 1735         | 1755
# chb03_25.edf    | Pre-Ictal  | 1765         | 1800
# chb03_25.edf    | Pre-Ictal  | 1820         | 2185
# chb03_25.edf    | Ictal      | 2200         | 2400
# chb03_25.edf    | Ictal      | 2440         | 2515
# chb03_25.edf    | Ictal      | 2605         | 2935
# chb03_25.edf    | Ictal      | 2980         | 3205
# chb03_25.edf    | Pre-Ictal  | 3275         | 3320
# chb03_26.edf    | Ictal      | 0            | 20
# chb03_26.edf    | Ictal      | 45           | 245
# chb03_26.edf    | Pre-Ictal  | 320          | 340
# chb03_26.edf    | Ictal      | 375          | 540
# chb03_26.edf    | Ictal      | 670          | 695
# chb03_26.edf    | Ictal      | 940          | 965
# chb03_26.edf    | Pre-Ictal  | 1150         | 1180
# chb03_26.edf    | Pre-Ictal  | 1270         | 1290
# chb03_26.edf    | Pre-Ictal  | 1395         | 1420
# chb03_26.edf    | Pre-Ictal  | 1445         | 1480
# chb03_26.edf    | Pre-Ictal  | 1875         | 1910
# chb03_26.edf    | Pre-Ictal  | 2035         | 2065
# chb03_26.edf    | Ictal      | 2090         | 2120
# chb03_26.edf    | Ictal      | 2185         | 2230
# chb03_26.edf    | Pre-Ictal  | 2280         | 2430
# chb03_26.edf    | Pre-Ictal  | 2450         | 3060
# chb03_26.edf    | Pre-Ictal  | 3085         | 3180
# chb03_26.edf    | Ictal      | 3190         | 3215
# chb03_26.edf    | Ictal      | 3230         | 3300
# chb03_26.edf    | Ictal      | 3465         | 3600
# chb03_27.edf    | Ictal      | 0            | 35
# chb03_27.edf    | Ictal      | 70           | 110
# chb03_27.edf    | Ictal      | 195          | 230
# chb03_27.edf    | Ictal      | 250          | 375
# chb03_27.edf    | Ictal      | 395          | 440
# chb03_27.edf    | Ictal      | 460          | 525
# chb03_27.edf    | Ictal      | 550          | 685
# chb03_27.edf    | Ictal      | 730          | 885
# chb03_27.edf    | Ictal      | 910          | 1005
# chb03_27.edf    | Pre-Ictal  | 1015         | 1040
# chb03_27.edf    | Ictal      | 1055         | 1115
# chb03_27.edf    | Ictal      | 1195         | 1260
# chb03_27.edf    | Pre-Ictal  | 1325         | 1395
# chb03_27.edf    | Pre-Ictal  | 1465         | 1610
# chb03_27.edf    | Pre-Ictal  | 1630         | 1770
# chb03_27.edf    | Pre-Ictal  | 1835         | 1990
# chb03_27.edf    | Pre-Ictal  | 2010         | 2135
# chb03_27.edf    | Pre-Ictal  | 2235         | 2255
# chb03_27.edf    | Pre-Ictal  | 2300         | 2410
# chb03_27.edf    | Pre-Ictal  | 2460         | 2490
# chb03_27.edf    | Pre-Ictal  | 2550         | 2565
# chb03_27.edf    | Pre-Ictal  | 2630         | 2890
# chb03_27.edf    | Pre-Ictal  | 3020         | 3250
# chb03_27.edf    | Pre-Ictal  | 3290         | 3385
# chb03_27.edf    | Pre-Ictal  | 3415         | 3600
# chb03_28.edf    | Pre-Ictal  | 0            | 15
# chb03_28.edf    | Pre-Ictal  | 180          | 245
# chb03_28.edf    | Ictal      | 685          | 870
# chb03_28.edf    | Ictal      | 915          | 1055
# chb03_28.edf    | Ictal      | 1080         | 1135
# chb03_28.edf    | Ictal      | 1165         | 1250
# chb03_28.edf    | Ictal      | 1275         | 1830
# chb03_28.edf    | Pre-Ictal  | 1840         | 1945
# chb03_28.edf    | Pre-Ictal  | 1980         | 2455
# chb03_28.edf    | Pre-Ictal  | 2550         | 3110
# chb03_28.edf    | Pre-Ictal  | 3130         | 3395
# chb03_28.edf    | Pre-Ictal  | 3505         | 3555
# chb03_29.edf    | Ictal      | 0            | 85
# chb03_29.edf    | Pre-Ictal  | 175          | 410
# chb03_29.edf    | Pre-Ictal  | 440          | 505
# chb03_29.edf    | Ictal      | 520          | 555
# chb03_29.edf    | Ictal      | 580          | 620
# chb03_29.edf    | Pre-Ictal  | 695          | 765
# chb03_29.edf    | Pre-Ictal  | 825          | 895
# chb03_29.edf    | Pre-Ictal  | 940          | 1010
# chb03_29.edf    | Ictal      | 1035         | 1075
# chb03_29.edf    | Pre-Ictal  | 1120         | 1155
# chb03_29.edf    | Ictal      | 1235         | 1280
# chb03_29.edf    | Ictal      | 1420         | 1565
# chb03_29.edf    | Ictal      | 1610         | 1755
# chb03_29.edf    | Pre-Ictal  | 1775         | 1900
# chb03_29.edf    | Pre-Ictal  | 2000         | 2265
# chb03_29.edf    | Pre-Ictal  | 2300         | 2380
# chb03_29.edf    | Pre-Ictal  | 2405         | 2460
# chb03_29.edf    | Pre-Ictal  | 2515         | 2535
# chb03_29.edf    | Pre-Ictal  | 2565         | 2585
# chb03_29.edf    | Ictal      | 2625         | 2655
# chb03_29.edf    | Pre-Ictal  | 2670         | 2780
# chb03_29.edf    | Pre-Ictal  | 2820         | 2915
# chb03_29.edf    | Pre-Ictal  | 2950         | 2990
# chb03_29.edf    | Pre-Ictal  | 3075         | 3135
# chb03_29.edf    | Pre-Ictal  | 3165         | 3195
# chb03_29.edf    | Pre-Ictal  | 3300         | 3375
# chb03_29.edf    | Ictal      | 3525         | 3600
# chb03_30.edf    | Ictal      | 0            | 130
# chb03_30.edf    | Pre-Ictal  | 200          | 230
# chb03_30.edf    | Ictal      | 255          | 390
# chb03_30.edf    | Pre-Ictal  | 445          | 650
# chb03_30.edf    | Pre-Ictal  | 680          | 740
# chb03_30.edf    | Ictal      | 1050         | 1150
# chb03_30.edf    | Ictal      | 1385         | 1525
# chb03_30.edf    | Pre-Ictal  | 1580         | 1605
# chb03_30.edf    | Ictal      | 1645         | 1660
# chb03_30.edf    | Pre-Ictal  | 1840         | 1875
# chb03_30.edf    | Pre-Ictal  | 1950         | 1965
# chb03_30.edf    | Ictal      | 2030         | 2085
# chb03_30.edf    | Pre-Ictal  | 2220         | 2300
# chb03_30.edf    | Pre-Ictal  | 2325         | 2445
# chb03_30.edf    | Ictal      | 2465         | 2565
# chb03_30.edf    | Pre-Ictal  | 2620         | 2710
# chb03_30.edf    | Pre-Ictal  | 2755         | 3600
# chb03_31.edf    | Ictal      | 15           | 45
# chb03_31.edf    | Pre-Ictal  | 95           | 135
# chb03_31.edf    | Ictal      | 175          | 325
# chb03_31.edf    | Ictal      | 390          | 505
# chb03_31.edf    | Pre-Ictal  | 575          | 610
# chb03_31.edf    | Ictal      | 630          | 665
# chb03_31.edf    | Pre-Ictal  | 690          | 740
# chb03_31.edf    | Ictal      | 810          | 845
# chb03_31.edf    | Ictal      | 910          | 930
# chb03_31.edf    | Pre-Ictal  | 940          | 1545
# chb03_31.edf    | Pre-Ictal  | 1575         | 1935
# chb03_31.edf    | Ictal      | 1985         | 2020
# chb03_31.edf    | Ictal      | 2035         | 2075
# chb03_31.edf    | Pre-Ictal  | 2085         | 2235
# chb03_31.edf    | Pre-Ictal  | 2310         | 2330
# chb03_31.edf    | Pre-Ictal  | 2375         | 2590
# chb03_31.edf    | Ictal      | 2615         | 2680
# chb03_31.edf    | Ictal      | 2695         | 2855
# chb03_31.edf    | Pre-Ictal  | 2965         | 3145
# chb03_31.edf    | Ictal      | 3165         | 3195
# chb03_31.edf    | Pre-Ictal  | 3230         | 3600
# chb03_32.edf    | Pre-Ictal  | 0            | 345
# chb03_32.edf    | Pre-Ictal  | 375          | 920
# chb03_32.edf    | Ictal      | 935          | 965
# chb03_32.edf    | Pre-Ictal  | 980          | 1020
# chb03_32.edf    | Ictal      | 1035         | 1060
# chb03_32.edf    | Ictal      | 1180         | 1200
# chb03_32.edf    | Pre-Ictal  | 1255         | 1620
# chb03_32.edf    | Ictal      | 1635         | 1650
# chb03_32.edf    | Pre-Ictal  | 1710         | 1925
# chb03_32.edf    | Pre-Ictal  | 1965         | 2120
# chb03_32.edf    | Ictal      | 2130         | 2515
# chb03_32.edf    | Ictal      | 2535         | 2575
# chb03_32.edf    | Ictal      | 2705         | 2750
# chb03_32.edf    | Ictal      | 2795         | 2865
# chb03_32.edf    | Ictal      | 2885         | 2950
# chb03_32.edf    | Pre-Ictal  | 3030         | 3115
# chb03_32.edf    | Ictal      | 3125         | 3220
# chb03_32.edf    | Ictal      | 3325         | 3375
# chb03_32.edf    | Ictal      | 3465         | 3545
# chb03_32.edf    | Pre-Ictal  | 3560         | 3600
# chb03_33.edf    | Pre-Ictal  | 0            | 70
# chb03_33.edf    | Ictal      | 110          | 135
# chb03_33.edf    | Pre-Ictal  | 145          | 435
# chb03_33.edf    | Ictal      | 465          | 595
# chb03_33.edf    | Pre-Ictal  | 680          | 740
# chb03_33.edf    | Ictal      | 755          | 770
# chb03_33.edf    | Pre-Ictal  | 790          | 1310
# chb03_33.edf    | Ictal      | 1355         | 1455
# chb03_33.edf    | Ictal      | 1500         | 1565
# chb03_33.edf    | Pre-Ictal  | 1765         | 2050
# chb03_33.edf    | Ictal      | 2065         | 2085
# chb03_33.edf    | Pre-Ictal  | 2105         | 2145
# chb03_33.edf    | Pre-Ictal  | 2185         | 2220
# chb03_33.edf    | Ictal      | 2235         | 2260
# chb03_33.edf    | Pre-Ictal  | 2270         | 2500
# chb03_33.edf    | Ictal      | 2520         | 2545
# chb03_33.edf    | Pre-Ictal  | 2565         | 2945
# chb03_33.edf    | Ictal      | 2995         | 3020
# chb03_33.edf    | Pre-Ictal  | 3025         | 3045
# chb03_33.edf    | Ictal      | 3105         | 3135
# chb03_33.edf    | Pre-Ictal  | 3230         | 3285
# chb03_33.edf    | Ictal      | 3360         | 3550
# chb03_34.edf    | Ictal      | 10           | 85
# chb03_34.edf    | Pre-Ictal  | 105          | 495
# chb03_34.edf    | Ictal      | 505          | 525
# chb03_34.edf    | Pre-Ictal  | 570          | 640
# chb03_34.edf    | Pre-Ictal  | 665          | 700
# chb03_34.edf    | Pre-Ictal  | 730          | 855
# chb03_34.edf    | Ictal      | 895          | 985
# chb03_34.edf    | Pre-Ictal  | 1000         | 1265
# chb03_34.edf    | Pre-Ictal  | 1300         | 1675
# chb03_34.edf    | Pre-Ictal  | 1710         | 1815
# chb03_34.edf    | Ictal      | 1950         | 2180
# chb03_34.edf    | Ictal      | 2245         | 2440
# chb03_34.edf    | Ictal      | 2505         | 2545
# chb03_34.edf    | Pre-Ictal  | 2580         | 3305
# chb03_34.edf    | Pre-Ictal  | 3360         | 3600
# chb03_35.edf    | Pre-Ictal  | 0            | 130
# chb03_35.edf    | Pre-Ictal  | 165          | 195
# chb03_35.edf    | Pre-Ictal  | 225          | 570
# chb03_35.edf    | Ictal      | 580          | 605
# chb03_35.edf    | Pre-Ictal  | 615          | 1130
# chb03_35.edf    | Ictal      | 2130         | 2265
# chb03_35.edf    | Pre-Ictal  | 2440         | 2470
# chb03_35.edf    | Ictal      | 2490         | 2575
# chb03_35.edf    | Ictal      | 2600         | 2790
# chb03_35.edf    | Ictal      | 2835         | 2910
# chb03_35.edf    | Pre-Ictal  | 3000         | 3600
# chb03_36.edf    | Ictal      | 0            | 5
# chb03_36.edf    | Pre-Ictal  | 40           | 95
# chb03_36.edf    | Pre-Ictal  | 190          | 245
# chb03_36.edf    | Ictal      | 325          | 375
# chb03_36.edf    | Pre-Ictal  | 390          | 495
# chb03_36.edf    | Ictal      | 535          | 590
# chb03_36.edf    | Pre-Ictal  | 600          | 750
# chb03_36.edf    | Pre-Ictal  | 780          | 865
# chb03_36.edf    | Pre-Ictal  | 895          | 975
# chb03_36.edf    | Pre-Ictal  | 1045         | 1085
# chb03_36.edf    | Pre-Ictal  | 1135         | 1150
# chb03_36.edf    | Pre-Ictal  | 1200         | 1215
# chb03_36.edf    | Ictal      | 1230         | 1245
# chb03_36.edf    | Pre-Ictal  | 1260         | 1280
# chb03_36.edf    | Ictal      | 1290         | 1310
# chb03_36.edf    | Pre-Ictal  | 1325         | 1580
# chb03_36.edf    | Ictal      | 1590         | 1625
# chb03_36.edf    | Pre-Ictal  | 1660         | 1725
# chb03_36.edf    | Ictal      | 1735         | 1875
# chb03_36.edf    | Pre-Ictal  | 1985         | 2015
# chb03_36.edf    | Ictal      | 2035         | 2065
# chb03_36.edf    | Pre-Ictal  | 2405         | 2515
# chb03_36.edf    | Ictal      | 2635         | 2660
# chb03_36.edf    | Pre-Ictal  | 2715         | 2770
# chb03_36.edf    | Ictal      | 2785         | 2830
# chb03_36.edf    | Pre-Ictal  | 2905         | 3120
# chb03_36.edf    | Pre-Ictal  | 3150         | 3345
# chb03_36.edf    | Pre-Ictal  | 3500         | 3600
# chb03_37.edf    | Ictal      | 0            | 15
# chb03_37.edf    | Pre-Ictal  | 40           | 105
# chb03_37.edf    | Pre-Ictal  | 190          | 230
# chb03_37.edf    | Pre-Ictal  | 315          | 365
# chb03_37.edf    | Pre-Ictal  | 395          | 450
# chb03_37.edf    | Ictal      | 500          | 520
# chb03_37.edf    | Pre-Ictal  | 535          | 590
# chb03_37.edf    | Pre-Ictal  | 665          | 705
# chb03_37.edf    | Ictal      | 715          | 740
# chb03_37.edf    | Pre-Ictal  | 760          | 850
# chb03_37.edf    | Ictal      | 865          | 905
# chb03_37.edf    | Ictal      | 925          | 1090
# chb03_37.edf    | Pre-Ictal  | 1380         | 1435
# chb03_37.edf    | Ictal      | 1545         | 1620
# chb03_37.edf    | Pre-Ictal  | 1630         | 1955
# chb03_37.edf    | Pre-Ictal  | 1985         | 2025
# chb03_37.edf    | Ictal      | 2210         | 2485
# chb03_37.edf    | Pre-Ictal  | 2515         | 2570
# chb03_37.edf    | Pre-Ictal  | 2595         | 2625
# chb03_37.edf    | Ictal      | 2650         | 2680
# chb03_37.edf    | Ictal      | 2700         | 2785
# chb03_37.edf    | Pre-Ictal  | 2810         | 2890
# chb03_37.edf    | Ictal      | 2905         | 2940
# chb03_37.edf    | Pre-Ictal  | 2950         | 3105
# chb03_37.edf    | Ictal      | 3175         | 3205
# chb03_37.edf    | Ictal      | 3420         | 3450
# chb03_37.edf    | Pre-Ictal  | 3465         | 3600
# chb03_38.edf    | Pre-Ictal  | 0            | 890
# chb03_38.edf    | Pre-Ictal  | 920          | 1010
# chb03_38.edf    | Ictal      | 1015         | 1385
# chb03_38.edf    | Ictal      | 1550         | 1625
# chb03_38.edf    | Ictal      | 1650         | 1715
# chb03_38.edf    | Pre-Ictal  | 1725         | 1810
# chb03_38.edf    | Ictal      | 1825         | 1855
# chb03_38.edf    | Ictal      | 1925         | 1945
# chb03_38.edf    | Ictal      | 1965         | 1990
# chb03_38.edf    | Pre-Ictal  | 1995         | 2050
# chb03_38.edf    | Pre-Ictal  | 2080         | 2110
# chb03_38.edf    | Ictal      | 2135         | 2185
# chb03_38.edf    | Pre-Ictal  | 2195         | 2210
# chb03_38.edf    | Ictal      | 2270         | 2290
# chb03_38.edf    | Ictal      | 2335         | 2370
# chb03_38.edf    | Ictal      | 2400         | 2475
# chb03_38.edf    | Ictal      | 2500         | 2585
# chb03_38.edf    | Ictal      | 3460         | 3570

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb03_01.edf": [(362, 414)],
    "chb03_02.edf": [(731, 796)],
    "chb03_03.edf": [(432, 501)],
    "chb03_04.edf": [(2162, 2214)],
    "chb03_34.edf": [(1982, 2029)],
    "chb03_35.edf": [(2592, 2656)],
    "chb03_36.edf": [(1725, 1778)],
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

# --- 1. Define the Prediction Target (Respecting File Boundaries) ---
PREDICTION_WINDOW_MIN = 90.0
y_true = np.zeros(len(t_min))
current_idx = 0

for i, length in enumerate(lengths):
    fname = os.path.basename(train_files[i]["path"])
    # Create a time axis for JUST this file
    file_t_min = (np.arange(length) * WINDOW_SEC) / 60.0
    file_y = np.zeros(length)
    
    if fname in clinical:
        for (s0, s1) in clinical[fname]:
            # Mark windows where a seizure starts within the next 90 mins IN THIS FILE
            start_min = s0 / 60.0
            mask = (file_t_min <= start_min) & (file_t_min >= start_min - PREDICTION_WINDOW_MIN)
            file_y[mask] = 1
    
    # Place this file's ground truth into the global array
    y_true[current_idx : current_idx + length] = file_y
    current_idx += length

# --- 2. Calculate Probabilities for different Thresholds (m) ---
thresholds = np.linspace(0, 0.9, 19) 
observed_probs = []

for m in thresholds:
    alarm_mask = pre_density > m
    if np.any(alarm_mask):
        # Accuracy: How often was our alarm followed by a seizure?
        prob = np.mean(y_true[alarm_mask])
        observed_probs.append(prob)
    else:
        observed_probs.append(0.0)

# --- 3. Statistical Significance (Monte Carlo / Surrogate Test) ---
# We shuffle WITHIN the constraints of the data to see if we beat chance
n_permutations = 1000
surrogate_max_probs = []

print(f"Running {n_permutations} permutations for statistical significance...")
for _ in tqdm(range(n_permutations)):
    # Randomly shuffle the TRUE labels to create a "fake" patient history
    y_surrogate = np.random.permutation(y_true)

    # Calculate the max probability achieved by chance for ANY threshold
    chance_probs = [np.mean(y_surrogate[pre_density > m]) if np.any(pre_density > m) else 0 for m in thresholds]
    surrogate_max_probs.append(np.max(chance_probs))

# Calculate p-value for each threshold
p_values = []
for i, m in enumerate(thresholds):
    better_than_us = np.sum(np.array(surrogate_max_probs) >= observed_probs[i])
    p_values.append(better_than_us / n_permutations)

# --- 4. Results Table & Plotting ---
results_df = pd.DataFrame({
    "Threshold (m)": thresholds,
    "Seizure Probability (x%)": np.array(observed_probs) * 100,
    "P-Value": p_values,
    "Significant (p<0.05)": np.array(p_values) < 0.05
})

print("\nThreshold Analysis Results (File-Aware):")
print(results_df.to_string(index=False))

# Visualization
plt.figure(figsize=(10, 5))
plt.plot(thresholds, np.array(observed_probs)*100, marker='o', label="Observed Probability")
plt.axhline(y=np.mean(surrogate_max_probs)*100, color='r', linestyle='--', label="Chance Level (Mean)")
plt.fill_between(thresholds, 0, 100, where=results_df["Significant (p<0.05)"], 
                 color='green', alpha=0.1, label="Statistically Significant Zone")

plt.xlabel("Density Threshold (m)")
plt.ylabel("Probability of Seizure in next 90m (%)")
plt.title("Optimal Threshold for Seizure Prediction (Corrected)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Running 1000 permutations for statistical significance...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1340.21it/s]
# Threshold Analysis Results (File-Aware):
#  Threshold (m)  Seizure Probability (x%)  P-Value  Significant (p<0.05)
#           0.00                  7.579803    0.622                 False
#           0.05                  7.639927    0.563                 False
#           0.10                  7.843749    0.411                 False
#           0.15                  8.091146    0.266                 False
#           0.20                  8.336009    0.177                 False
#           0.25                  9.196643    0.031                  True
#           0.30                  9.664253    0.008                  True
#           0.35                 10.693128    0.001                  True
#           0.40                 11.752820    0.000                  True
#           0.45                 11.848835    0.000                  True
#           0.50                 13.002443    0.000                  True
#           0.55                 13.377135    0.000                  True
#           0.60                 14.029287    0.000                  True
#           0.65                 15.444466    0.000                  True
#           0.70                 15.926893    0.000                  True
#           0.75                 16.137230    0.000                  True
#           0.80                 17.298106    0.000                  True
#           0.85                 22.977099    0.000                  True
#           0.90                 16.773367    0.000                  True

# %%
import numpy as np
import os

# --- Clinical Evaluation Parameters ---
SPH_SEC = 5 * 60          # 5 minutes minimum warning
SOP_SEC = 85 * 60         # 85 minutes occurrence period 
REFRACTORY_SEC = 90 * 60  # 90 minutes silence after an alarm is triggered

# 1. Build a list of exact clinical seizure start times in the global timeline
global_seizure_onsets = []
file_start_sec = np.cumsum([0] + lengths[:-1]) * WINDOW_SEC

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname in clinical:
        base_sec = file_start_sec[i]
        for (s0, s1) in clinical[fname]:
            global_seizure_onsets.append(base_sec + s0)

# 2. Setup Evaluation Loop
total_hours = len(hidden_states) * WINDOW_SEC / 3600.0
total_days = total_hours / 24.0

print(f"Total Recording Time: {total_hours:.2f} hours ({total_days:.2f} days)")
print(f"Total Clinical Seizures: {len(global_seizure_onsets)}")
print(f"Parameters -> SPH: {SPH_SEC/60:.0f}m | SOP: {SOP_SEC/60:.0f}m | Refractory: {REFRACTORY_SEC/60:.0f}m")
print("-" * 75)
print(f"{'Threshold (m)':<15} | {'Sensitivity':<15} | {'False Alarms / 24h':<20}")
print("-" * 75)

# 3. Chronological Alarm Evaluation
for m in [0.55, 0.65, 0.75, 0.85, 0.90]:
    false_positives = 0
    seizures_caught = set() # Track by ID so we don't double-count catching the same seizure
    
    next_allowed_alarm_sec = 0.0
    
    # Find all windows where density exceeds threshold
    alarm_indices = np.where(pre_density > m)[0]
    
    for idx in alarm_indices:
        current_sec = idx * WINDOW_SEC
        
        # Check if the device is allowed to ring (outside refractory period)
        if current_sec >= next_allowed_alarm_sec:
            next_allowed_alarm_sec = current_sec + REFRACTORY_SEC
            
            # Define the valid prediction window for this specific alarm
            pred_window_start = current_sec + SPH_SEC
            pred_window_end = current_sec + SPH_SEC + SOP_SEC
            
            # Did any seizure onset fall inside this window?
            caught_any = False
            for sz_idx, sz_sec in enumerate(global_seizure_onsets):
                if pred_window_start <= sz_sec <= pred_window_end:
                    caught_any = True
                    seizures_caught.add(sz_idx)
                    
            if not caught_any:
                # Alarm rang, but no seizure occurred in the SOP
                false_positives += 1
                
    # Calculate final clinical metrics
    far_per_24h = false_positives / total_days if total_days > 0 else 0
    sensitivity = (len(seizures_caught) / len(global_seizure_onsets)) * 100 if len(global_seizure_onsets) > 0 else 0
    
    print(f"{m:<15.2f} | {sensitivity:<13.1f}% | {far_per_24h:<20.2f}")
# Out:
# Total Recording Time: 38.00 hours (1.58 days)
# Total Clinical Seizures: 7
# Parameters -> SPH: 5m | SOP: 85m | Refractory: 90m
# ---------------------------------------------------------------------------
# Threshold (m)   | Sensitivity     | False Alarms / 24h
# ---------------------------------------------------------------------------
# 0.55            | 100.0        % | 8.84
# 0.65            | 85.7         % | 8.21
# 0.75            | 57.1         % | 7.58
# 0.85            | 57.1         % | 6.32
# 0.90            | 57.1         % | 5.68

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# --- 1. Choose the threshold we want to visualize ---
target_m = 0.90

# --- 2. Re-run the strict device logic for just this threshold ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC-Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

# Track legend entries to avoid duplicates
seen_labels = set()

# Plot Clinical Seizures
for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

# Plot Alarms, SOPs, and Refractory Periods
for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    # 1. The Alarm Trigger
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    # 2. Refractory Period (Red hatched background)
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = "Refractory Period (Snooze)" if "Refractory Period (Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add("Refractory Period (Snooze)")
    
    # 3. SOP (Green expected seizure window)
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    # Plot as a line block slightly above the graph to keep it clean
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"Clinical Device Simulation (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

# Put legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. The Final PLV Goldilocks Parameters ---
target_m = 0.75
REFRACTORY_SEC = 60 * 60  # 60 minute snooze

# --- 2. Re-run the strict device logic ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC+PLV Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

seen_labels = set()

for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
    
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"FINAL Clinical Device Simulation: PLV Edition (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. The PLV-Optimized Goldilocks Parameters ---
target_m = 0.80
REFRACTORY_SEC = 60 * 60  # Shortened to 60 minutes to prevent shadowing

# --- 2. Re-run the strict device logic for just this threshold ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC+PLV Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

# Track legend entries to avoid duplicates
seen_labels = set()

# Plot Clinical Seizures
for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

# Plot Alarms, SOPs, and Refractory Periods
for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    # 1. The Alarm Trigger
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    # 2. Refractory Period (Red hatched background)
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
    
    # 3. SOP (Green expected seizure window)
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"Clinical Device Simulation: PLV Edition (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

# Put legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()
