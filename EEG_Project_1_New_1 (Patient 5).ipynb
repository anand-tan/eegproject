# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch, hilbert, butter, filtfilt
from antropy import perm_entropy

# --- Pre-define PAC Filters ---
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Filter coefficients for 256 Hz sampling rate
b_theta, a_theta = butter_bandpass(4.0, 8.0, 256)
b_gamma, a_gamma = butter_bandpass(30.0, 40.0, 256)

def get_regional_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    
    # Isolate Hemispheres based on standard bipolar pairs
    # Left: FP1-F7, F7-T7, T7-P7, P7-O1, FP1-F3, F3-C3, C3-P3, P3-O1
    LEFT_CH = [0, 1, 2, 3, 4, 5, 6, 7]
    # Right: FP2-F4, F4-C4, C4-P4, P4-O2, FP2-F8, F8-T8, T8-P8, P8-O2
    RIGHT_CH = [8, 9, 10, 11, 12, 13, 14, 15]

    for window in epoch_data:
        X_left = window[LEFT_CH, :]
        X_right = window[RIGHT_CH, :]

        # --- 1. Morphological (RMS & Line Length) ---
        rms_L = np.mean(np.sqrt(np.mean(X_left**2, axis=1)))
        rms_R = np.mean(np.sqrt(np.mean(X_right**2, axis=1)))

        ll_L = np.mean(np.sum(np.abs(np.diff(X_left, axis=1)), axis=1))
        ll_R = np.mean(np.sum(np.abs(np.diff(X_right, axis=1)), axis=1))

        # --- 2. Spectral Power (Theta/Alpha) ---
        freqs_L, psd_L = welch(X_left, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs_L >= 4) & (freqs_L < 8)
        al_mask = (freqs_L >= 8) & (freqs_L < 13)
        
        theta_L = np.trapezoid(psd_L[:, th_mask], freqs_L[th_mask], axis=1).mean()
        alpha_L = np.trapezoid(psd_L[:, al_mask], freqs_L[al_mask], axis=1).mean()
        ta_ratio_L = theta_L / (alpha_L + eps)

        freqs_R, psd_R = welch(X_right, sfreq, nperseg=sfreq * 2)
        theta_R = np.trapezoid(psd_R[:, th_mask], freqs_R[th_mask], axis=1).mean()
        alpha_R = np.trapezoid(psd_R[:, al_mask], freqs_R[al_mask], axis=1).mean()
        ta_ratio_R = theta_R / (alpha_R + eps)

        # --- 3. Phase-Amplitude Coupling (PAC) ---
        # Left PAC
        theta_sig_L = filtfilt(b_theta, a_theta, X_left, axis=1)
        gamma_sig_L = filtfilt(b_gamma, a_gamma, X_left, axis=1)
        theta_phase_L = np.angle(hilbert(theta_sig_L, axis=1))
        gamma_amp_L = np.abs(hilbert(gamma_sig_L, axis=1))
        pac_scores_L = [np.abs(np.corrcoef(np.cos(theta_phase_L[i]), gamma_amp_L[i])[0, 1]) for i in range(X_left.shape[0])]
        pac_L = np.mean(pac_scores_L)

        # Right PAC
        theta_sig_R = filtfilt(b_theta, a_theta, X_right, axis=1)
        gamma_sig_R = filtfilt(b_gamma, a_gamma, X_right, axis=1)
        theta_phase_R = np.angle(hilbert(theta_sig_R, axis=1))
        gamma_amp_R = np.abs(hilbert(gamma_sig_R, axis=1))
        pac_scores_R = [np.abs(np.corrcoef(np.cos(theta_phase_R[i]), gamma_amp_R[i])[0, 1]) for i in range(X_right.shape[0])]
        pac_R = np.mean(pac_scores_R)

        # --- 4. Spatial Sync (Cross-Hemisphere PLV) ---
        # Measure how locked the left hemisphere is to the right hemisphere
        phases_L = np.angle(hilbert(X_left, axis=1))
        phases_R = np.angle(hilbert(X_right, axis=1))
        
        sync_scores = []
        for i in range(len(LEFT_CH)):
            phase_diff = phases_L[i] - phases_R[i]
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))
            sync_scores.append(plv)
            
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        # --- Compile Regional Features ---
        features.append([
            rms_L, rms_R, 
            ll_L, ll_R, 
            ta_ratio_L, ta_ratio_R, 
            pac_L, pac_R, 
            avg_sync
        ])

    return np.array(features)

# %%
import numpy as np
from scipy.signal import welch, hilbert, butter, filtfilt
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

# --- Pre-define PAC Filters ---
def butter_bandpass(lowcut, highcut, fs, order=3):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = butter(order, [low, high], btype='band')
    return b, a

# Filter coefficients for 256 Hz sampling rate
b_theta, a_theta = butter_bandpass(4.0, 8.0, 256)
b_gamma, a_gamma = butter_bandpass(30.0, 40.0, 256)


def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization (Phase-Locking Value)
    6. Phase-Amplitude Coupling (Theta-Gamma)
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        # --- 1. Spectral Power (Theta/Alpha) ---
        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        # --- 2. Complexity ---
        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        # --- 3. Spatial Sync (Phase-Locking Value) ---
        # Get instantaneous phase for all channels at once
        phases = np.angle(hilbert(X, axis=1))
        
        sync_scores = []
        for li, ri in PAIRS_LR:
            # Calculate phase difference
            phase_diff = phases[li] - phases[ri]
            # Calculate PLV for this pair (magnitude of the mean complex phase vector)
            plv = np.abs(np.mean(np.exp(1j * phase_diff)))
            sync_scores.append(plv)
            
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        # --- 4. Morphological ---
        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        # --- 5. Phase-Amplitude Coupling (Theta-Gamma) ---
        # Fast vectorized filtering across all primary channels
        theta_sig = filtfilt(b_theta, a_theta, X, axis=1)
        gamma_sig = filtfilt(b_gamma, a_gamma, X, axis=1)
        
        # Hilbert transform to get phase and amplitude
        theta_phase = np.angle(hilbert(theta_sig, axis=1))
        gamma_amp = np.abs(hilbert(gamma_sig, axis=1))
        
        # Calculate coupling for each channel, then average
        pac_scores = [np.abs(np.corrcoef(np.cos(theta_phase[i]), gamma_amp[i])[0, 1]) for i in range(X.shape[0])]
        avg_pac = np.mean(pac_scores)

        # --- Compile Features ---
        features.append([ta_ratio, complexity, line_length, rms, avg_sync, avg_pac])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb02) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_11.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_19.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_20.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_21.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_22.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_23.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_24.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_25.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_26.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_27.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_28.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_29.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_30.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_31.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_32.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_33.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_34.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_35.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_36.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_37.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_38.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb05/chb05_39.edf"},
]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /opt/anaconda3/envs/eeg_proj/lib/python3.13/site-packages/mne/datasets/eegbci/eegbci.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 20/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 25/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 30/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 35/39 files; last epochs=720
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_59128/3233601900.py:53: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 39/39 files; last epochs=720
# Loading complete.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import LeaveOneGroupOut

# =============================================================================
# 1. FEATURE PREPARATION & SMOOTHING
# =============================================================================
processed_all_features = []
for f_features in all_features:
    # Scale each file individually to its own baseline
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    # Smooth (30-second moving average)
    df = pd.DataFrame(feat_local_scaled)
    feat_local_smoothed = df.rolling(window=6, min_periods=1, center=False).mean().values
    processed_all_features.append(feat_local_smoothed)

X_full = np.vstack(processed_all_features)

# =============================================================================
# 2. SUPERVISED TARGET CREATION & GROUPING
# =============================================================================
# We explicitly teach the model that the 60 minutes before a seizure is "Pre-Ictal" (Class 1)
TRAIN_PRE_ICTAL_MIN = 60.0 
WINDOW_SEC = 5.0

y_class = np.zeros(len(X_full))
groups = np.zeros(len(X_full)) # File ID for Cross-Validation

clinical = {
    "chb05_06.edf": [(417, 532)],
    "chb05_13.edf": [(1086, 1196)],
    "chb05_16.edf": [(2317, 2413)],
    "chb05_17.edf": [(2451, 2571)],
    "chb05_22.edf": [(2348, 2465)],
}

current_idx = 0
file_start_sec = []

for i, length in enumerate(lengths):
    fname = os.path.basename(train_files[i]["path"])
    file_t_sec = np.arange(length) * WINDOW_SEC
    file_start_sec.append(current_idx * WINDOW_SEC)
    
    # Assign group ID for Leave-One-File-Out
    groups[current_idx : current_idx + length] = i
    
    if fname in clinical:
        for (s0, s1) in clinical[fname]:
            # Label the 60 minutes prior to seizure onset as Class 1
            target_start = s0 - (TRAIN_PRE_ICTAL_MIN * 60)
            mask = (file_t_sec >= target_start) & (file_t_sec <= s0)
            y_class[current_idx : current_idx + length][mask] = 1
            
    current_idx += length

# =============================================================================
# 3. LEAVE-ONE-FILE-OUT (LOFO) CROSS-VALIDATION
# =============================================================================
# This trains 39 separate models, ensuring predicting data is strictly unseen
logo = LeaveOneGroupOut()
# Max depth kept low (5) to prevent overfitting to patient noise
rf = RandomForestClassifier(n_estimators=100, max_depth=5, class_weight='balanced', random_state=42)

continuous_pred_proba = np.zeros(len(X_full))

print("Training 39 Random Forest models (Leave-One-File-Out CV)...")
for train_idx, test_idx in tqdm(logo.split(X_full, y_class, groups), total=len(lengths)):
    X_train, y_train = X_full[train_idx], y_class[train_idx]
    X_test = X_full[test_idx]
    
    rf.fit(X_train, y_train)
    # Store probability of Class 1 (Pre-Ictal)
    continuous_pred_proba[test_idx] = rf.predict_proba(X_test)[:, 1]

# Smooth the raw RF probabilities over a 10-minute window to create Pre-Ictal Density
DENSITY_MIN = 10.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(continuous_pred_proba, kernel, mode="full")[:len(continuous_pred_proba)] / W
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# =============================================================================
# 4. MODEL INTERPRETABILITY ("MEANS" EQUIVALENT)
# =============================================================================
# Train one final model on all data simply to extract global feature metrics
rf_full = RandomForestClassifier(n_estimators=100, max_depth=5, class_weight='balanced', random_state=42)
rf_full.fit(X_full, y_class)

# Change this line from the 9-feature list to your 6-feature list:
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync", "Avg PAC"]

print("\n=== Random Forest Feature Importances ===")
for name, imp in zip(feature_names, rf_full.feature_importances_):
    print(f"  {name:<12}: {imp:.4f}")
    
print("\n=== Standardized Feature Means (Baseline vs Pre-Ictal) ===")
for i, name in enumerate(feature_names):
    mean_0 = np.mean(X_full[y_class == 0, i])
    mean_1 = np.mean(X_full[y_class == 1, i])
    print(f"  {name:<12} -> Baseline: {mean_0:+.3f} | Pre-Ictal (60m): {mean_1:+.3f}")
# =============================================================================
# 5. MONTE CARLO STATISTICAL EVALUATION
# =============================================================================
PREDICTION_WINDOW_MIN = 90.0
y_eval = np.zeros(len(X_full))
t_min = (np.arange(len(X_full)) * WINDOW_SEC) / 60.0

current_idx = 0
for i, length in enumerate(lengths):
    fname = os.path.basename(train_files[i]["path"])
    file_t_min = (np.arange(length) * WINDOW_SEC) / 60.0
    file_y = np.zeros(length)
    if fname in clinical:
        for (s0, s1) in clinical[fname]:
            start_min = s0 / 60.0
            mask = (file_t_min <= start_min) & (file_t_min >= start_min - PREDICTION_WINDOW_MIN)
            file_y[mask] = 1
    y_eval[current_idx : current_idx + length] = file_y
    current_idx += length

thresholds = np.linspace(0, 0.9, 19) 
observed_probs = []

for m in thresholds:
    alarm_mask = pre_density > m
    if np.any(alarm_mask):
        prob = np.mean(y_eval[alarm_mask])
        observed_probs.append(prob)
    else:
        observed_probs.append(0.0)

n_permutations = 1000
surrogate_max_probs = []

print(f"\nRunning {n_permutations} permutations for statistical significance...")
for _ in tqdm(range(n_permutations)):
    y_surrogate = np.random.permutation(y_eval)
    chance_probs = [np.mean(y_surrogate[pre_density > m]) if np.any(pre_density > m) else 0 for m in thresholds]
    surrogate_max_probs.append(np.max(chance_probs))

p_values = []
for i, m in enumerate(thresholds):
    better_than_us = np.sum(np.array(surrogate_max_probs) >= observed_probs[i])
    p_values.append(better_than_us / n_permutations)

results_df = pd.DataFrame({
    "Threshold (m)": thresholds,
    "Seizure Probability (x%)": np.array(observed_probs) * 100,
    "P-Value": p_values,
    "Significant (p<0.05)": np.array(p_values) < 0.05
})

print("\nThreshold Analysis Results (Out-of-Fold Predictions):")
print(results_df.to_string(index=False))

plt.figure(figsize=(10, 5))
plt.plot(thresholds, np.array(observed_probs)*100, marker='o', label="Observed Probability")
plt.axhline(y=np.mean(surrogate_max_probs)*100, color='r', linestyle='--', label="Chance Level (Mean)")
plt.fill_between(thresholds, 0, 100, where=results_df["Significant (p<0.05)"], color='green', alpha=0.1, label="Significant Zone")
plt.xlabel("Density Threshold (m)")
plt.ylabel("Probability of Seizure in next 90m (%)")
plt.title("Optimal Threshold for Seizure Prediction (Supervised Random Forest)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# =============================================================================
# 6. CLINICAL ALARM EVALUATION & PLOTTING TIMELINES
# =============================================================================
global_seizure_onsets = []
for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname in clinical:
        base_sec = file_start_sec[i]
        for (s0, s1) in clinical[fname]:
            global_seizure_onsets.append(base_sec + s0)

SPH_SEC = 5 * 60         
SOP_SEC = 85 * 60         
REFRACTORY_SEC = 60 * 60  

def plot_clinical_device(target_m):
    alarm_times_sec = []
    next_allowed_alarm_sec = 0.0
    alarm_indices = np.where(pre_density > target_m)[0]

    for idx in alarm_indices:
        current_sec = idx * WINDOW_SEC
        if current_sec >= next_allowed_alarm_sec:
            alarm_times_sec.append(current_sec)
            next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

    plt.figure(figsize=(18, 7))
    plt.plot(t_min, pre_density, label="Pre-Ictal RF Probability Density", color="#1f77b4", linewidth=2)
    plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

    seen_labels = set()
    for sz_sec in global_seizure_onsets:
        sz_min = sz_sec / 60.0
        label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
        plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
        seen_labels.add("Clinical Seizure Onset")

    for alarm_sec in alarm_times_sec:
        alarm_min = alarm_sec / 60.0
        
        label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
        plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
        seen_labels.add("Alarm Triggered")
        
        ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
        label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
        plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
        seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
        
        sop_start_min = alarm_min + (SPH_SEC / 60.0)
        sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
        label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
        plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
        seen_labels.add("SOP (Valid Prediction Window)")

    plt.ylim(0, 1.05)
    plt.xlabel("Total Time (Minutes)", fontsize=12)
    plt.ylabel("Pre-Ictal Probability Density", fontsize=12)
    plt.title(f"Supervised Clinical Simulation (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)
    plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
    plt.tight_layout()
    plt.show()

# Output the requested thresholds
for m_val in [0.90, 0.80, 0.75]:
    plot_clinical_device(m_val)
# Out:
# Training 39 Random Forest models (Leave-One-File-Out CV)...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:48<00:00,  1.23s/it]
# === Random Forest Feature Importances ===
#   TA_ratio    : 0.0512
#   PermEntropy : 0.1312
#   LineLength  : 0.3412
#   RMS         : 0.3500
#   Avg Sync    : 0.1002
#   Avg PAC     : 0.0263
#
# === Standardized Feature Means (Baseline vs Pre-Ictal) ===
#   TA_ratio     -> Baseline: -0.004 | Pre-Ictal (60m): +0.053
#   PermEntropy  -> Baseline: -0.022 | Pre-Ictal (60m): +0.343
#   LineLength   -> Baseline: +0.000 | Pre-Ictal (60m): -0.005
#   RMS          -> Baseline: +0.012 | Pre-Ictal (60m): -0.190
#   Avg Sync     -> Baseline: +0.012 | Pre-Ictal (60m): -0.191
#   Avg PAC      -> Baseline: +0.009 | Pre-Ictal (60m): -0.111
#
# Running 1000 permutations for statistical significance...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1565.96it/s]
# Threshold Analysis Results (Out-of-Fold Predictions):
#  Threshold (m)  Seizure Probability (x%)  P-Value  Significant (p<0.05)
#           0.00                  6.149847    1.000                 False
#           0.05                  6.173590    0.941                 False
#           0.10                  6.281142    0.833                 False
#           0.15                  6.460180    0.701                 False
#           0.20                  6.960903    0.523                 False
#           0.25                  7.711694    0.422                 False
#           0.30                  8.757423    0.171                 False
#           0.35                 10.713763    0.161                 False
#           0.40                 13.157895    0.055                 False
#           0.45                 17.546254    0.009                  True
#           0.50                 28.272101    0.000                  True
#           0.55                 33.735632    0.000                  True
#           0.60                 14.618644    0.027                  True
#           0.65                  0.000000    1.000                 False
#           0.70                  0.000000    1.000                 False
#           0.75                  0.000000    1.000                 False
#           0.80                  0.000000    1.000                 False
#           0.85                  0.000000    1.000                 False
#           0.90                  0.000000    1.000                 False

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.9518   0.0327   0.0155
# State 1   0.0403   0.9362   0.0235
# State 2   0.0279   0.0299   0.9422

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync", "Avg PAC"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : -0.441
#   PermEntropy : -0.011
#   LineLength  : -0.395
#   RMS         : -0.536
#   Avg Sync    : -0.158
#   Avg PAC     : +0.103
#
# State 1 means:
#   TA_ratio    : +0.496
#   PermEntropy : -0.595
#   LineLength  : -0.248
#   RMS         : +0.142
#   Avg Sync    : +0.229
#   Avg PAC     : +0.069
#
# State 2 means:
#   TA_ratio    : +0.081
#   PermEntropy : +0.815
#   LineLength  : +0.998
#   RMS         : +0.714
#   Avg Sync    : -0.042
#   Avg PAC     : -0.261

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy, [2] LineLength, 
# [3] RMS, [4] Avg Sync, [5] Avg PAC

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3
IDX_SYNC = 4
IDX_PAC = 5

# 1. Ictal: highest amplitude and spikiness
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# 2. Pre-ictal: highest Phase-Amplitude Coupling among non-ictal states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
preictal_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_PAC])]
)

# 3. Baseline: whatever state is left (the normal state)
baseline_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, preictal_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline (PAC-Optimized)")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb05_01.edf    | Pre-Ictal  | 100          | 125
# chb05_01.edf    | Pre-Ictal  | 150          | 230
# chb05_01.edf    | Ictal      | 295          | 345
# chb05_01.edf    | Pre-Ictal  | 355          | 435
# chb05_01.edf    | Ictal      | 445          | 475
# chb05_01.edf    | Pre-Ictal  | 515          | 610
# chb05_01.edf    | Ictal      | 675          | 745
# chb05_01.edf    | Ictal      | 805          | 880
# chb05_01.edf    | Ictal      | 945          | 995
# chb05_01.edf    | Pre-Ictal  | 995          | 1060
# chb05_01.edf    | Pre-Ictal  | 1100         | 1160
# chb05_01.edf    | Ictal      | 1350         | 1450
# chb05_01.edf    | Pre-Ictal  | 1450         | 1485
# chb05_01.edf    | Ictal      | 1505         | 1655
# chb05_01.edf    | Pre-Ictal  | 1700         | 1710
# chb05_01.edf    | Pre-Ictal  | 1770         | 1830
# chb05_01.edf    | Ictal      | 1830         | 1865
# chb05_01.edf    | Pre-Ictal  | 1865         | 1890
# chb05_01.edf    | Pre-Ictal  | 1930         | 1970
# chb05_01.edf    | Ictal      | 1970         | 2010
# chb05_01.edf    | Pre-Ictal  | 2010         | 2050
# chb05_01.edf    | Pre-Ictal  | 2105         | 2165
# chb05_01.edf    | Pre-Ictal  | 2195         | 2255
# chb05_01.edf    | Pre-Ictal  | 2285         | 2320
# chb05_01.edf    | Ictal      | 2320         | 2340
# chb05_01.edf    | Pre-Ictal  | 2340         | 2380
# chb05_01.edf    | Pre-Ictal  | 2660         | 2765
# chb05_01.edf    | Pre-Ictal  | 2855         | 2890
# chb05_01.edf    | Ictal      | 2890         | 2920
# chb05_01.edf    | Pre-Ictal  | 2950         | 3040
# chb05_01.edf    | Pre-Ictal  | 3120         | 3315
# chb05_01.edf    | Ictal      | 3315         | 3440
# chb05_01.edf    | Pre-Ictal  | 3440         | 3460
# chb05_01.edf    | Ictal      | 3460         | 3520
# chb05_01.edf    | Pre-Ictal  | 3520         | 3540
# chb05_01.edf    | Ictal      | 3540         | 3610
# chb05_02.edf    | Ictal      | 0            | 20
# chb05_02.edf    | Pre-Ictal  | 20           | 70
# chb05_02.edf    | Pre-Ictal  | 170          | 195
# chb05_02.edf    | Ictal      | 195          | 310
# chb05_02.edf    | Pre-Ictal  | 310          | 355
# chb05_02.edf    | Pre-Ictal  | 395          | 430
# chb05_02.edf    | Pre-Ictal  | 485          | 580
# chb05_02.edf    | Ictal      | 580          | 610
# chb05_02.edf    | Pre-Ictal  | 675          | 750
# chb05_02.edf    | Pre-Ictal  | 795          | 925
# chb05_02.edf    | Ictal      | 925          | 955
# chb05_02.edf    | Pre-Ictal  | 955          | 1350
# chb05_02.edf    | Pre-Ictal  | 1465         | 1580
# chb05_02.edf    | Pre-Ictal  | 1710         | 1735
# chb05_02.edf    | Ictal      | 1735         | 1790
# chb05_02.edf    | Pre-Ictal  | 1825         | 1855
# chb05_02.edf    | Ictal      | 1855         | 1890
# chb05_02.edf    | Ictal      | 1915         | 1980
# chb05_02.edf    | Pre-Ictal  | 1980         | 2010
# chb05_02.edf    | Ictal      | 2145         | 2175
# chb05_02.edf    | Pre-Ictal  | 2275         | 2350
# chb05_02.edf    | Ictal      | 2460         | 2505
# chb05_02.edf    | Pre-Ictal  | 2505         | 2565
# chb05_02.edf    | Ictal      | 2630         | 2660
# chb05_02.edf    | Pre-Ictal  | 2700         | 2740
# chb05_02.edf    | Ictal      | 2740         | 2760
# chb05_02.edf    | Pre-Ictal  | 2800         | 2950
# chb05_02.edf    | Ictal      | 2980         | 3040
# chb05_02.edf    | Pre-Ictal  | 3040         | 3090
# chb05_02.edf    | Ictal      | 3090         | 3185
# chb05_02.edf    | Ictal      | 3235         | 3600
# chb05_03.edf    | Pre-Ictal  | 80           | 105
# chb05_03.edf    | Ictal      | 145          | 220
# chb05_03.edf    | Pre-Ictal  | 220          | 240
# chb05_03.edf    | Pre-Ictal  | 290          | 300
# chb05_03.edf    | Pre-Ictal  | 335          | 625
# chb05_03.edf    | Ictal      | 625          | 730
# chb05_03.edf    | Pre-Ictal  | 825          | 865
# chb05_03.edf    | Pre-Ictal  | 1130         | 1155
# chb05_03.edf    | Pre-Ictal  | 1345         | 1495
# chb05_03.edf    | Pre-Ictal  | 1610         | 1665
# chb05_03.edf    | Pre-Ictal  | 1715         | 1820
# chb05_03.edf    | Pre-Ictal  | 1885         | 2025
# chb05_03.edf    | Ictal      | 2055         | 2095
# chb05_03.edf    | Pre-Ictal  | 2125         | 2165
# chb05_03.edf    | Pre-Ictal  | 2195         | 2275
# chb05_03.edf    | Ictal      | 2275         | 2360
# chb05_03.edf    | Pre-Ictal  | 2360         | 2510
# chb05_03.edf    | Ictal      | 2510         | 2545
# chb05_03.edf    | Pre-Ictal  | 2545         | 2565
# chb05_03.edf    | Ictal      | 2595         | 2660
# chb05_03.edf    | Pre-Ictal  | 2725         | 2755
# chb05_03.edf    | Ictal      | 2755         | 2940
# chb05_03.edf    | Ictal      | 2960         | 3255
# chb05_03.edf    | Ictal      | 3270         | 3330
# chb05_03.edf    | Pre-Ictal  | 3330         | 3365
# chb05_03.edf    | Ictal      | 3365         | 3420
# chb05_03.edf    | Ictal      | 3460         | 3490
# chb05_03.edf    | Pre-Ictal  | 3505         | 3600
# chb05_04.edf    | Pre-Ictal  | 0            | 55
# chb05_04.edf    | Pre-Ictal  | 70           | 95
# chb05_04.edf    | Pre-Ictal  | 130          | 155
# chb05_04.edf    | Ictal      | 190          | 295
# chb05_04.edf    | Pre-Ictal  | 295          | 465
# chb05_04.edf    | Pre-Ictal  | 510          | 635
# chb05_04.edf    | Ictal      | 635          | 675
# chb05_04.edf    | Pre-Ictal  | 830          | 865
# chb05_04.edf    | Pre-Ictal  | 930          | 955
# chb05_04.edf    | Ictal      | 1170         | 1200
# chb05_04.edf    | Pre-Ictal  | 1245         | 1315
# chb05_04.edf    | Ictal      | 1315         | 1345
# chb05_04.edf    | Pre-Ictal  | 1345         | 1365
# chb05_04.edf    | Ictal      | 1365         | 1415
# chb05_04.edf    | Ictal      | 1455         | 1595
# chb05_04.edf    | Pre-Ictal  | 1615         | 1655
# chb05_04.edf    | Ictal      | 1720         | 1745
# chb05_04.edf    | Pre-Ictal  | 1745         | 1790
# chb05_04.edf    | Ictal      | 1790         | 1840
# chb05_04.edf    | Pre-Ictal  | 1840         | 1880
# chb05_04.edf    | Pre-Ictal  | 1920         | 1975
# chb05_04.edf    | Pre-Ictal  | 2030         | 2050
# chb05_04.edf    | Ictal      | 2105         | 2135
# chb05_04.edf    | Pre-Ictal  | 2145         | 2170
# chb05_04.edf    | Ictal      | 2200         | 2220
# chb05_04.edf    | Ictal      | 2245         | 2320
# chb05_04.edf    | Pre-Ictal  | 2405         | 2420
# chb05_04.edf    | Pre-Ictal  | 2470         | 2585
# chb05_04.edf    | Pre-Ictal  | 2660         | 2695
# chb05_04.edf    | Ictal      | 2695         | 2745
# chb05_04.edf    | Pre-Ictal  | 2745         | 2785
# chb05_04.edf    | Ictal      | 2785         | 3000
# chb05_04.edf    | Pre-Ictal  | 3000         | 3020
# chb05_04.edf    | Ictal      | 3030         | 3070
# chb05_04.edf    | Ictal      | 3130         | 3375
# chb05_04.edf    | Pre-Ictal  | 3390         | 3435
# chb05_04.edf    | Ictal      | 3435         | 3445
# chb05_04.edf    | Pre-Ictal  | 3445         | 3475
# chb05_04.edf    | Ictal      | 3475         | 3540
# chb05_04.edf    | Pre-Ictal  | 3540         | 3575
# chb05_04.edf    | Ictal      | 3575         | 3600
# chb05_05.edf    | Ictal      | 85           | 215
# chb05_05.edf    | Ictal      | 265          | 305
# chb05_05.edf    | Pre-Ictal  | 400          | 420
# chb05_05.edf    | Ictal      | 445          | 485
# chb05_05.edf    | Pre-Ictal  | 485          | 530
# chb05_05.edf    | Ictal      | 530          | 565
# chb05_05.edf    | Ictal      | 660          | 725
# chb05_05.edf    | Ictal      | 920          | 945
# chb05_05.edf    | Pre-Ictal  | 980          | 1010
# chb05_05.edf    | Pre-Ictal  | 1050         | 1120
# chb05_05.edf    | Ictal      | 1120         | 1315
# chb05_05.edf    | Pre-Ictal  | 1315         | 1460
# chb05_05.edf    | Ictal      | 1460         | 1695
# chb05_05.edf    | Pre-Ictal  | 1695         | 1725
# chb05_05.edf    | Ictal      | 1725         | 1795
# chb05_05.edf    | Ictal      | 1975         | 2010
# chb05_05.edf    | Ictal      | 2040         | 2080
# chb05_05.edf    | Pre-Ictal  | 2080         | 2130
# chb05_05.edf    | Ictal      | 2170         | 2220
# chb05_05.edf    | Pre-Ictal  | 2410         | 2520
# chb05_05.edf    | Ictal      | 2520         | 2565
# chb05_05.edf    | Ictal      | 2595         | 2650
# chb05_05.edf    | Pre-Ictal  | 2650         | 2815
# chb05_05.edf    | Pre-Ictal  | 2840         | 2910
# chb05_05.edf    | Ictal      | 2910         | 3005
# chb05_05.edf    | Pre-Ictal  | 3005         | 3035
# chb05_05.edf    | Pre-Ictal  | 3190         | 3415
# chb05_05.edf    | Pre-Ictal  | 3490         | 3540
# chb05_06.edf    | Ictal      | 0            | 615
# chb05_06.edf    | Ictal      | 645          | 750
# chb05_06.edf    | Ictal      | 920          | 955
# chb05_06.edf    | Pre-Ictal  | 1080         | 1325
# chb05_06.edf    | Pre-Ictal  | 1355         | 2345
# chb05_06.edf    | Ictal      | 2345         | 2640
# chb05_06.edf    | Pre-Ictal  | 2760         | 2840
# chb05_06.edf    | Ictal      | 2865         | 2940
# chb05_06.edf    | Pre-Ictal  | 2940         | 3600
# chb05_07.edf    | Pre-Ictal  | 15           | 55
# chb05_07.edf    | Pre-Ictal  | 100          | 130
# chb05_07.edf    | Pre-Ictal  | 260          | 325
# chb05_07.edf    | Pre-Ictal  | 420          | 445
# chb05_07.edf    | Pre-Ictal  | 945          | 970
# chb05_07.edf    | Pre-Ictal  | 1155         | 1195
# chb05_07.edf    | Ictal      | 1195         | 1315
# chb05_07.edf    | Ictal      | 1435         | 1460
# chb05_07.edf    | Pre-Ictal  | 1660         | 1680
# chb05_07.edf    | Pre-Ictal  | 1745         | 1925
# chb05_07.edf    | Pre-Ictal  | 1955         | 2095
# chb05_07.edf    | Pre-Ictal  | 2120         | 2350
# chb05_07.edf    | Ictal      | 2365         | 2380
# chb05_07.edf    | Pre-Ictal  | 2380         | 2405
# chb05_07.edf    | Pre-Ictal  | 2435         | 2840
# chb05_07.edf    | Pre-Ictal  | 2865         | 2920
# chb05_07.edf    | Pre-Ictal  | 2945         | 2970
# chb05_07.edf    | Pre-Ictal  | 2995         | 3015
# chb05_07.edf    | Ictal      | 3030         | 3275
# chb05_07.edf    | Pre-Ictal  | 3275         | 3420
# chb05_07.edf    | Pre-Ictal  | 3450         | 3600
# chb05_08.edf    | Pre-Ictal  | 0            | 65
# chb05_08.edf    | Pre-Ictal  | 165          | 215
# chb05_08.edf    | Pre-Ictal  | 240          | 275
# chb05_08.edf    | Pre-Ictal  | 335          | 400
# chb05_08.edf    | Ictal      | 415          | 525
# chb05_08.edf    | Pre-Ictal  | 525          | 675
# chb05_08.edf    | Pre-Ictal  | 710          | 850
# chb05_08.edf    | Ictal      | 860          | 1000
# chb05_08.edf    | Pre-Ictal  | 1000         | 1050
# chb05_08.edf    | Ictal      | 1095         | 1155
# chb05_08.edf    | Ictal      | 1290         | 1335
# chb05_08.edf    | Pre-Ictal  | 1335         | 1365
# chb05_08.edf    | Ictal      | 1475         | 1505
# chb05_08.edf    | Pre-Ictal  | 1505         | 1535
# chb05_08.edf    | Pre-Ictal  | 1655         | 1850
# chb05_08.edf    | Pre-Ictal  | 1970         | 1990
# chb05_08.edf    | Pre-Ictal  | 2075         | 2125
# chb05_08.edf    | Pre-Ictal  | 2155         | 2175
# chb05_08.edf    | Pre-Ictal  | 2225         | 2260
# chb05_08.edf    | Ictal      | 2280         | 2395
# chb05_08.edf    | Pre-Ictal  | 2395         | 2465
# chb05_08.edf    | Pre-Ictal  | 2495         | 2920
# chb05_08.edf    | Pre-Ictal  | 3025         | 3055
# chb05_08.edf    | Pre-Ictal  | 3110         | 3215
# chb05_08.edf    | Ictal      | 3215         | 3240
# chb05_08.edf    | Pre-Ictal  | 3240         | 3265
# chb05_08.edf    | Pre-Ictal  | 3295         | 3485
# chb05_08.edf    | Pre-Ictal  | 3575         | 3600
# chb05_09.edf    | Ictal      | 30           | 130
# chb05_09.edf    | Pre-Ictal  | 430          | 455
# chb05_09.edf    | Pre-Ictal  | 555          | 595
# chb05_09.edf    | Ictal      | 685          | 790
# chb05_09.edf    | Ictal      | 825          | 875
# chb05_09.edf    | Ictal      | 915          | 945
# chb05_09.edf    | Ictal      | 1035         | 1065
# chb05_09.edf    | Pre-Ictal  | 1065         | 1760
# chb05_09.edf    | Pre-Ictal  | 1810         | 1885
# chb05_09.edf    | Pre-Ictal  | 1940         | 1980
# chb05_09.edf    | Pre-Ictal  | 2000         | 2030
# chb05_09.edf    | Pre-Ictal  | 2065         | 2185
# chb05_09.edf    | Ictal      | 2195         | 2385
# chb05_09.edf    | Pre-Ictal  | 2385         | 2410
# chb05_09.edf    | Ictal      | 2410         | 2480
# chb05_09.edf    | Pre-Ictal  | 2480         | 2515
# chb05_09.edf    | Ictal      | 2565         | 2610
# chb05_09.edf    | Pre-Ictal  | 2610         | 2650
# chb05_09.edf    | Pre-Ictal  | 2685         | 2760
# chb05_09.edf    | Pre-Ictal  | 2795         | 2835
# chb05_09.edf    | Pre-Ictal  | 2870         | 2900
# chb05_09.edf    | Pre-Ictal  | 2965         | 3095
# chb05_09.edf    | Ictal      | 3130         | 3320
# chb05_09.edf    | Pre-Ictal  | 3320         | 3350
# chb05_09.edf    | Pre-Ictal  | 3365         | 3395
# chb05_09.edf    | Pre-Ictal  | 3450         | 3525
# chb05_09.edf    | Pre-Ictal  | 3560         | 3600
# chb05_10.edf    | Ictal      | 0            | 355
# chb05_10.edf    | Pre-Ictal  | 410          | 560
# chb05_10.edf    | Pre-Ictal  | 595          | 615
# chb05_10.edf    | Pre-Ictal  | 665          | 730
# chb05_10.edf    | Ictal      | 730          | 760
# chb05_10.edf    | Pre-Ictal  | 760          | 770
# chb05_10.edf    | Pre-Ictal  | 860          | 910
# chb05_10.edf    | Ictal      | 930          | 960
# chb05_10.edf    | Pre-Ictal  | 995          | 1025
# chb05_10.edf    | Pre-Ictal  | 1055         | 1105
# chb05_10.edf    | Ictal      | 1125         | 1235
# chb05_10.edf    | Pre-Ictal  | 1235         | 1265
# chb05_10.edf    | Ictal      | 1265         | 1305
# chb05_10.edf    | Pre-Ictal  | 1335         | 1370
# chb05_10.edf    | Pre-Ictal  | 1500         | 1555
# chb05_10.edf    | Ictal      | 1585         | 1620
# chb05_10.edf    | Pre-Ictal  | 1620         | 1680
# chb05_10.edf    | Pre-Ictal  | 1750         | 1930
# chb05_10.edf    | Pre-Ictal  | 1970         | 2060
# chb05_10.edf    | Pre-Ictal  | 2090         | 2200
# chb05_10.edf    | Pre-Ictal  | 2365         | 2410
# chb05_10.edf    | Pre-Ictal  | 2435         | 2520
# chb05_10.edf    | Pre-Ictal  | 2575         | 2600
# chb05_10.edf    | Pre-Ictal  | 2630         | 2660
# chb05_10.edf    | Pre-Ictal  | 2725         | 2865
# chb05_10.edf    | Ictal      | 2865         | 2895
# chb05_10.edf    | Ictal      | 3130         | 3165
# chb05_10.edf    | Pre-Ictal  | 3195         | 3325
# chb05_10.edf    | Ictal      | 3365         | 3395
# chb05_10.edf    | Pre-Ictal  | 3395         | 3600
# chb05_11.edf    | Pre-Ictal  | 0            | 405
# chb05_11.edf    | Pre-Ictal  | 430          | 550
# chb05_11.edf    | Pre-Ictal  | 580          | 630
# chb05_11.edf    | Pre-Ictal  | 660          | 815
# chb05_11.edf    | Pre-Ictal  | 865          | 900
# chb05_11.edf    | Pre-Ictal  | 975          | 1005
# chb05_11.edf    | Pre-Ictal  | 1075         | 1095
# chb05_11.edf    | Pre-Ictal  | 1195         | 1210
# chb05_11.edf    | Pre-Ictal  | 1240         | 1270
# chb05_11.edf    | Ictal      | 1335         | 1460
# chb05_11.edf    | Pre-Ictal  | 1460         | 1530
# chb05_11.edf    | Pre-Ictal  | 1625         | 1660
# chb05_11.edf    | Pre-Ictal  | 1685         | 1765
# chb05_11.edf    | Pre-Ictal  | 1930         | 2015
# chb05_11.edf    | Pre-Ictal  | 2135         | 2155
# chb05_11.edf    | Pre-Ictal  | 2210         | 2305
# chb05_11.edf    | Pre-Ictal  | 2505         | 2530
# chb05_11.edf    | Pre-Ictal  | 2560         | 2595
# chb05_11.edf    | Ictal      | 2715         | 2880
# chb05_11.edf    | Pre-Ictal  | 3140         | 3225
# chb05_11.edf    | Ictal      | 3225         | 3475
# chb05_11.edf    | Pre-Ictal  | 3475         | 3600
# chb05_12.edf    | Pre-Ictal  | 0            | 335
# chb05_12.edf    | Ictal      | 335          | 385
# chb05_12.edf    | Ictal      | 445          | 470
# chb05_12.edf    | Ictal      | 705          | 775
# chb05_12.edf    | Pre-Ictal  | 930          | 1000
# chb05_12.edf    | Pre-Ictal  | 1035         | 1235
# chb05_12.edf    | Pre-Ictal  | 1265         | 1375
# chb05_12.edf    | Ictal      | 1435         | 1520
# chb05_12.edf    | Ictal      | 1605         | 1700
# chb05_12.edf    | Ictal      | 1725         | 1760
# chb05_12.edf    | Pre-Ictal  | 1840         | 1885
# chb05_12.edf    | Pre-Ictal  | 1940         | 1990
# chb05_12.edf    | Pre-Ictal  | 2040         | 2260
# chb05_12.edf    | Ictal      | 2260         | 2300
# chb05_12.edf    | Pre-Ictal  | 2300         | 2410
# chb05_12.edf    | Pre-Ictal  | 2440         | 2500
# chb05_12.edf    | Ictal      | 2510         | 2550
# chb05_12.edf    | Pre-Ictal  | 2550         | 2610
# chb05_12.edf    | Pre-Ictal  | 2640         | 2940
# chb05_12.edf    | Ictal      | 2940         | 2975
# chb05_12.edf    | Pre-Ictal  | 2975         | 3550
# chb05_12.edf    | Pre-Ictal  | 3570         | 3600
# chb05_13.edf    | Ictal      | 0            | 45
# chb05_13.edf    | Pre-Ictal  | 45           | 500
# chb05_13.edf    | Ictal      | 500          | 545
# chb05_13.edf    | Pre-Ictal  | 545          | 795
# chb05_13.edf    | Ictal      | 795          | 825
# chb05_13.edf    | Pre-Ictal  | 825          | 1085
# chb05_13.edf    | Ictal      | 1085         | 1360
# chb05_13.edf    | Ictal      | 2135         | 2185
# chb05_13.edf    | Pre-Ictal  | 2185         | 2245
# chb05_13.edf    | Ictal      | 2365         | 2400
# chb05_13.edf    | Pre-Ictal  | 2400         | 2595
# chb05_13.edf    | Pre-Ictal  | 2715         | 2835
# chb05_13.edf    | Pre-Ictal  | 2955         | 3450
# chb05_13.edf    | Ictal      | 3450         | 3600
# chb05_14.edf    | Ictal      | 0            | 90
# chb05_14.edf    | Ictal      | 115          | 195
# chb05_14.edf    | Ictal      | 225          | 320
# chb05_14.edf    | Pre-Ictal  | 390          | 450
# chb05_14.edf    | Ictal      | 450          | 470
# chb05_14.edf    | Ictal      | 520          | 620
# chb05_14.edf    | Ictal      | 655          | 710
# chb05_14.edf    | Pre-Ictal  | 760          | 825
# chb05_14.edf    | Pre-Ictal  | 860          | 880
# chb05_14.edf    | Ictal      | 880          | 1075
# chb05_14.edf    | Pre-Ictal  | 1075         | 1365
# chb05_14.edf    | Pre-Ictal  | 1380         | 1470
# chb05_14.edf    | Ictal      | 1505         | 1825
# chb05_14.edf    | Ictal      | 1850         | 2055
# chb05_14.edf    | Pre-Ictal  | 2055         | 2100
# chb05_14.edf    | Ictal      | 2100         | 2210
# chb05_14.edf    | Ictal      | 2245         | 2275
# chb05_14.edf    | Pre-Ictal  | 2305         | 2430
# chb05_14.edf    | Ictal      | 2430         | 2515
# chb05_14.edf    | Ictal      | 2615         | 2675
# chb05_14.edf    | Pre-Ictal  | 2975         | 3250
# chb05_14.edf    | Ictal      | 3250         | 3280
# chb05_14.edf    | Pre-Ictal  | 3440         | 3480
# chb05_14.edf    | Ictal      | 3510         | 3560
# chb05_15.edf    | Ictal      | 0            | 45
# chb05_15.edf    | Pre-Ictal  | 45           | 115
# chb05_15.edf    | Ictal      | 115          | 365
# chb05_15.edf    | Ictal      | 400          | 425
# chb05_15.edf    | Pre-Ictal  | 425          | 745
# chb05_15.edf    | Pre-Ictal  | 785          | 820
# chb05_15.edf    | Pre-Ictal  | 870          | 1020
# chb05_15.edf    | Pre-Ictal  | 1035         | 1915
# chb05_15.edf    | Pre-Ictal  | 1935         | 2280
# chb05_15.edf    | Ictal      | 2285         | 2340
# chb05_15.edf    | Pre-Ictal  | 2485         | 2505
# chb05_15.edf    | Ictal      | 3015         | 3080
# chb05_15.edf    | Pre-Ictal  | 3460         | 3485
# chb05_15.edf    | Pre-Ictal  | 3545         | 3575
# chb05_16.edf    | Pre-Ictal  | 0            | 55
# chb05_16.edf    | Ictal      | 85           | 105
# chb05_16.edf    | Pre-Ictal  | 135          | 700
# chb05_16.edf    | Ictal      | 700          | 730
# chb05_16.edf    | Pre-Ictal  | 730          | 1040
# chb05_16.edf    | Ictal      | 1040         | 1060
# chb05_16.edf    | Pre-Ictal  | 1060         | 1355
# chb05_16.edf    | Ictal      | 1355         | 1375
# chb05_16.edf    | Pre-Ictal  | 1375         | 1975
# chb05_16.edf    | Ictal      | 1975         | 2175
# chb05_16.edf    | Pre-Ictal  | 2175         | 2215
# chb05_16.edf    | Ictal      | 2215         | 2605
# chb05_16.edf    | Ictal      | 2645         | 2755
# chb05_17.edf    | Ictal      | 40           | 65
# chb05_17.edf    | Pre-Ictal  | 65           | 240
# chb05_17.edf    | Ictal      | 240          | 275
# chb05_17.edf    | Pre-Ictal  | 275          | 350
# chb05_17.edf    | Ictal      | 350          | 375
# chb05_17.edf    | Pre-Ictal  | 375          | 490
# chb05_17.edf    | Ictal      | 490          | 525
# chb05_17.edf    | Pre-Ictal  | 525          | 550
# chb05_17.edf    | Ictal      | 550          | 615
# chb05_17.edf    | Pre-Ictal  | 735          | 870
# chb05_17.edf    | Pre-Ictal  | 920          | 1775
# chb05_17.edf    | Pre-Ictal  | 1800         | 1855
# chb05_17.edf    | Ictal      | 1860         | 2445
# chb05_17.edf    | Ictal      | 2465         | 2745
# chb05_17.edf    | Pre-Ictal  | 2845         | 2885
# chb05_17.edf    | Pre-Ictal  | 2915         | 3525
# chb05_17.edf    | Ictal      | 3525         | 3550
# chb05_17.edf    | Pre-Ictal  | 3550         | 3600
# chb05_18.edf    | Pre-Ictal  | 0            | 280
# chb05_18.edf    | Ictal      | 280          | 385
# chb05_18.edf    | Ictal      | 450          | 625
# chb05_18.edf    | Pre-Ictal  | 675          | 1180
# chb05_18.edf    | Ictal      | 1180         | 1275
# chb05_18.edf    | Pre-Ictal  | 1275         | 1335
# chb05_18.edf    | Pre-Ictal  | 1370         | 1415
# chb05_18.edf    | Ictal      | 1415         | 1515
# chb05_18.edf    | Ictal      | 1655         | 1680
# chb05_18.edf    | Ictal      | 1820         | 1925
# chb05_18.edf    | Pre-Ictal  | 1945         | 1970
# chb05_18.edf    | Ictal      | 1970         | 2050
# chb05_18.edf    | Pre-Ictal  | 2160         | 2180
# chb05_18.edf    | Ictal      | 2180         | 2205
# chb05_18.edf    | Ictal      | 2280         | 2310
# chb05_18.edf    | Pre-Ictal  | 2325         | 2460
# chb05_18.edf    | Ictal      | 2485         | 2510
# chb05_18.edf    | Pre-Ictal  | 2510         | 2535
# chb05_18.edf    | Ictal      | 2535         | 2705
# chb05_18.edf    | Pre-Ictal  | 2840         | 2880
# chb05_18.edf    | Pre-Ictal  | 2920         | 2955
# chb05_18.edf    | Ictal      | 3000         | 3070
# chb05_18.edf    | Ictal      | 3100         | 3155
# chb05_18.edf    | Ictal      | 3195         | 3220
# chb05_18.edf    | Ictal      | 3320         | 3600
# chb05_19.edf    | Ictal      | 0            | 50
# chb05_19.edf    | Pre-Ictal  | 305          | 410
# chb05_19.edf    | Ictal      | 410          | 570
# chb05_19.edf    | Pre-Ictal  | 570          | 595
# chb05_19.edf    | Ictal      | 595          | 670
# chb05_19.edf    | Pre-Ictal  | 670          | 730
# chb05_19.edf    | Ictal      | 730          | 775
# chb05_19.edf    | Pre-Ictal  | 775          | 910
# chb05_19.edf    | Pre-Ictal  | 935          | 990
# chb05_19.edf    | Pre-Ictal  | 1020         | 1150
# chb05_19.edf    | Ictal      | 1150         | 1180
# chb05_19.edf    | Pre-Ictal  | 1180         | 1280
# chb05_19.edf    | Ictal      | 1280         | 1310
# chb05_19.edf    | Pre-Ictal  | 1325         | 1345
# chb05_19.edf    | Ictal      | 1345         | 1460
# chb05_19.edf    | Ictal      | 1485         | 1555
# chb05_19.edf    | Pre-Ictal  | 1555         | 1570
# chb05_19.edf    | Ictal      | 1570         | 1600
# chb05_19.edf    | Pre-Ictal  | 1655         | 1720
# chb05_19.edf    | Pre-Ictal  | 1760         | 1810
# chb05_19.edf    | Pre-Ictal  | 1840         | 1885
# chb05_19.edf    | Ictal      | 1885         | 1970
# chb05_19.edf    | Pre-Ictal  | 1970         | 1985
# chb05_19.edf    | Pre-Ictal  | 2040         | 2160
# chb05_19.edf    | Pre-Ictal  | 2270         | 2295
# chb05_19.edf    | Ictal      | 2305         | 2335
# chb05_19.edf    | Ictal      | 2390         | 2420
# chb05_19.edf    | Pre-Ictal  | 2420         | 2470
# chb05_19.edf    | Pre-Ictal  | 2545         | 2645
# chb05_19.edf    | Ictal      | 2645         | 2675
# chb05_19.edf    | Ictal      | 2715         | 2745
# chb05_19.edf    | Pre-Ictal  | 2835         | 2865
# chb05_19.edf    | Ictal      | 2935         | 2960
# chb05_19.edf    | Pre-Ictal  | 3055         | 3110
# chb05_19.edf    | Pre-Ictal  | 3225         | 3305
# chb05_19.edf    | Ictal      | 3305         | 3395
# chb05_19.edf    | Pre-Ictal  | 3395         | 3425
# chb05_19.edf    | Ictal      | 3455         | 3525
# chb05_19.edf    | Pre-Ictal  | 3525         | 3545
# chb05_19.edf    | Ictal      | 3575         | 3600
# chb05_20.edf    | Pre-Ictal  | 55           | 80
# chb05_20.edf    | Pre-Ictal  | 175          | 270
# chb05_20.edf    | Ictal      | 340          | 355
# chb05_20.edf    | Ictal      | 410          | 455
# chb05_20.edf    | Pre-Ictal  | 455          | 495
# chb05_20.edf    | Pre-Ictal  | 525          | 595
# chb05_20.edf    | Ictal      | 640          | 670
# chb05_20.edf    | Ictal      | 885          | 1060
# chb05_20.edf    | Pre-Ictal  | 1135         | 1220
# chb05_20.edf    | Pre-Ictal  | 1370         | 1450
# chb05_20.edf    | Ictal      | 1450         | 1475
# chb05_20.edf    | Pre-Ictal  | 1475         | 1500
# chb05_20.edf    | Pre-Ictal  | 1550         | 1585
# chb05_20.edf    | Ictal      | 1655         | 1790
# chb05_20.edf    | Pre-Ictal  | 1790         | 1840
# chb05_20.edf    | Ictal      | 1840         | 2090
# chb05_20.edf    | Ictal      | 2130         | 2155
# chb05_20.edf    | Ictal      | 2235         | 2260
# chb05_20.edf    | Pre-Ictal  | 2390         | 2465
# chb05_20.edf    | Pre-Ictal  | 2495         | 2515
# chb05_20.edf    | Pre-Ictal  | 2585         | 2755
# chb05_20.edf    | Ictal      | 2755         | 2780
# chb05_20.edf    | Ictal      | 2880         | 2905
# chb05_20.edf    | Pre-Ictal  | 2950         | 3015
# chb05_20.edf    | Ictal      | 3050         | 3320
# chb05_20.edf    | Ictal      | 3390         | 3435
# chb05_20.edf    | Pre-Ictal  | 3435         | 3490
# chb05_20.edf    | Ictal      | 3490         | 3600
# chb05_21.edf    | Ictal      | 0            | 150
# chb05_21.edf    | Pre-Ictal  | 150          | 165
# chb05_21.edf    | Ictal      | 190          | 225
# chb05_21.edf    | Pre-Ictal  | 225          | 260
# chb05_21.edf    | Pre-Ictal  | 285          | 320
# chb05_21.edf    | Pre-Ictal  | 365          | 405
# chb05_21.edf    | Ictal      | 405          | 430
# chb05_21.edf    | Pre-Ictal  | 430          | 530
# chb05_21.edf    | Ictal      | 530          | 565
# chb05_21.edf    | Pre-Ictal  | 565          | 600
# chb05_21.edf    | Pre-Ictal  | 685          | 795
# chb05_21.edf    | Ictal      | 795          | 815
# chb05_21.edf    | Pre-Ictal  | 815          | 920
# chb05_21.edf    | Ictal      | 1095         | 1220
# chb05_21.edf    | Pre-Ictal  | 1220         | 1265
# chb05_21.edf    | Ictal      | 1265         | 1335
# chb05_21.edf    | Ictal      | 1355         | 1390
# chb05_21.edf    | Pre-Ictal  | 1495         | 1535
# chb05_21.edf    | Ictal      | 1585         | 1615
# chb05_21.edf    | Ictal      | 1905         | 1990
# chb05_21.edf    | Ictal      | 2060         | 2085
# chb05_21.edf    | Ictal      | 2215         | 2280
# chb05_21.edf    | Pre-Ictal  | 2350         | 2475
# chb05_21.edf    | Ictal      | 2505         | 2535
# chb05_21.edf    | Ictal      | 2570         | 2605
# chb05_21.edf    | Pre-Ictal  | 2605         | 2655
# chb05_21.edf    | Pre-Ictal  | 2695         | 2720
# chb05_21.edf    | Pre-Ictal  | 2775         | 2820
# chb05_21.edf    | Ictal      | 2820         | 2875
# chb05_21.edf    | Pre-Ictal  | 2875         | 2905
# chb05_21.edf    | Ictal      | 2975         | 3055
# chb05_21.edf    | Ictal      | 3120         | 3145
# chb05_21.edf    | Ictal      | 3165         | 3260
# chb05_21.edf    | Pre-Ictal  | 3260         | 3290
# chb05_21.edf    | Ictal      | 3290         | 3345
# chb05_21.edf    | Pre-Ictal  | 3345         | 3375
# chb05_21.edf    | Ictal      | 3375         | 3390
# chb05_21.edf    | Pre-Ictal  | 3410         | 3445
# chb05_22.edf    | Ictal      | 260          | 350
# chb05_22.edf    | Ictal      | 390          | 1035
# chb05_22.edf    | Ictal      | 1100         | 1125
# chb05_22.edf    | Pre-Ictal  | 1185         | 1260
# chb05_22.edf    | Ictal      | 1260         | 1355
# chb05_22.edf    | Ictal      | 1475         | 1665
# chb05_22.edf    | Pre-Ictal  | 1700         | 1750
# chb05_22.edf    | Ictal      | 1750         | 1800
# chb05_22.edf    | Ictal      | 1875         | 1920
# chb05_22.edf    | Pre-Ictal  | 2065         | 2115
# chb05_22.edf    | Ictal      | 2115         | 2145
# chb05_22.edf    | Ictal      | 2180         | 2220
# chb05_22.edf    | Ictal      | 2330         | 2590
# chb05_22.edf    | Pre-Ictal  | 2705         | 2775
# chb05_22.edf    | Pre-Ictal  | 2815         | 2900
# chb05_22.edf    | Pre-Ictal  | 2935         | 3600
# chb05_23.edf    | Pre-Ictal  | 0            | 95
# chb05_23.edf    | Pre-Ictal  | 150          | 255
# chb05_23.edf    | Pre-Ictal  | 415          | 485
# chb05_23.edf    | Pre-Ictal  | 530          | 575
# chb05_23.edf    | Ictal      | 595          | 715
# chb05_23.edf    | Pre-Ictal  | 715          | 765
# chb05_23.edf    | Pre-Ictal  | 925          | 985
# chb05_23.edf    | Pre-Ictal  | 1035         | 1060
# chb05_23.edf    | Pre-Ictal  | 1090         | 1165
# chb05_23.edf    | Pre-Ictal  | 1280         | 1310
# chb05_23.edf    | Pre-Ictal  | 1360         | 1395
# chb05_23.edf    | Pre-Ictal  | 1810         | 2000
# chb05_23.edf    | Ictal      | 2125         | 2250
# chb05_23.edf    | Pre-Ictal  | 2320         | 2360
# chb05_23.edf    | Pre-Ictal  | 2395         | 2460
# chb05_23.edf    | Pre-Ictal  | 2500         | 2570
# chb05_23.edf    | Pre-Ictal  | 2610         | 2625
# chb05_23.edf    | Pre-Ictal  | 2650         | 2675
# chb05_23.edf    | Pre-Ictal  | 2715         | 2740
# chb05_23.edf    | Pre-Ictal  | 2815         | 2850
# chb05_23.edf    | Pre-Ictal  | 2880         | 2920
# chb05_23.edf    | Pre-Ictal  | 2955         | 2975
# chb05_23.edf    | Ictal      | 3095         | 3120
# chb05_23.edf    | Pre-Ictal  | 3140         | 3165
# chb05_23.edf    | Pre-Ictal  | 3190         | 3600
# chb05_24.edf    | Pre-Ictal  | 0            | 70
# chb05_24.edf    | Ictal      | 70           | 115
# chb05_24.edf    | Pre-Ictal  | 115          | 795
# chb05_24.edf    | Ictal      | 795          | 865
# chb05_24.edf    | Pre-Ictal  | 865          | 990
# chb05_24.edf    | Ictal      | 990          | 1115
# chb05_24.edf    | Pre-Ictal  | 1115         | 1200
# chb05_24.edf    | Pre-Ictal  | 1255         | 1305
# chb05_24.edf    | Pre-Ictal  | 1375         | 1500
# chb05_24.edf    | Pre-Ictal  | 1655         | 1870
# chb05_24.edf    | Pre-Ictal  | 1935         | 2145
# chb05_24.edf    | Pre-Ictal  | 2170         | 2720
# chb05_24.edf    | Ictal      | 2740         | 3440
# chb05_24.edf    | Ictal      | 3455         | 3480
# chb05_25.edf    | Pre-Ictal  | 180          | 245
# chb05_25.edf    | Ictal      | 480          | 525
# chb05_25.edf    | Pre-Ictal  | 525          | 610
# chb05_25.edf    | Ictal      | 640          | 675
# chb05_25.edf    | Pre-Ictal  | 675          | 700
# chb05_25.edf    | Pre-Ictal  | 775          | 805
# chb05_25.edf    | Ictal      | 820          | 855
# chb05_25.edf    | Pre-Ictal  | 855          | 1005
# chb05_25.edf    | Pre-Ictal  | 1025         | 1280
# chb05_25.edf    | Pre-Ictal  | 1315         | 1815
# chb05_25.edf    | Ictal      | 1815         | 1845
# chb05_25.edf    | Pre-Ictal  | 1895         | 1975
# chb05_25.edf    | Pre-Ictal  | 2005         | 2120
# chb05_25.edf    | Pre-Ictal  | 2150         | 2190
# chb05_25.edf    | Ictal      | 2195         | 2360
# chb05_25.edf    | Pre-Ictal  | 2360         | 2445
# chb05_25.edf    | Ictal      | 2445         | 2470
# chb05_25.edf    | Pre-Ictal  | 2480         | 2685
# chb05_25.edf    | Ictal      | 2685         | 2720
# chb05_25.edf    | Pre-Ictal  | 2720         | 2820
# chb05_25.edf    | Pre-Ictal  | 2845         | 2955
# chb05_25.edf    | Ictal      | 2955         | 3100
# chb05_25.edf    | Ictal      | 3455         | 3510
# chb05_25.edf    | Pre-Ictal  | 3510         | 3530
# chb05_26.edf    | Pre-Ictal  | 0            | 50
# chb05_26.edf    | Ictal      | 185          | 200
# chb05_26.edf    | Pre-Ictal  | 200          | 280
# chb05_26.edf    | Pre-Ictal  | 310          | 360
# chb05_26.edf    | Ictal      | 360          | 385
# chb05_26.edf    | Pre-Ictal  | 385          | 1590
# chb05_26.edf    | Ictal      | 1590         | 1615
# chb05_26.edf    | Pre-Ictal  | 1615         | 1855
# chb05_26.edf    | Ictal      | 1855         | 2890
# chb05_26.edf    | Ictal      | 2935         | 2965
# chb05_27.edf    | Pre-Ictal  | 40           | 460
# chb05_27.edf    | Ictal      | 1120         | 1195
# chb05_27.edf    | Ictal      | 1280         | 1350
# chb05_27.edf    | Ictal      | 1370         | 1410
# chb05_27.edf    | Ictal      | 1455         | 1530
# chb05_27.edf    | Pre-Ictal  | 1640         | 1840
# chb05_27.edf    | Ictal      | 1840         | 1880
# chb05_27.edf    | Pre-Ictal  | 1880         | 1935
# chb05_27.edf    | Ictal      | 1935         | 1960
# chb05_27.edf    | Pre-Ictal  | 1960         | 2040
# chb05_27.edf    | Pre-Ictal  | 2065         | 2095
# chb05_27.edf    | Ictal      | 2095         | 2135
# chb05_27.edf    | Pre-Ictal  | 2135         | 2160
# chb05_27.edf    | Ictal      | 2160         | 2210
# chb05_27.edf    | Pre-Ictal  | 2210         | 2440
# chb05_27.edf    | Ictal      | 2440         | 2700
# chb05_27.edf    | Ictal      | 2740         | 2835
# chb05_27.edf    | Pre-Ictal  | 2875         | 3080
# chb05_27.edf    | Ictal      | 3080         | 3110
# chb05_27.edf    | Pre-Ictal  | 3110         | 3230
# chb05_27.edf    | Ictal      | 3230         | 3295
# chb05_27.edf    | Pre-Ictal  | 3350         | 3405
# chb05_27.edf    | Ictal      | 3405         | 3495
# chb05_27.edf    | Pre-Ictal  | 3495         | 3600
# chb05_28.edf    | Ictal      | 0            | 45
# chb05_28.edf    | Pre-Ictal  | 240          | 270
# chb05_28.edf    | Ictal      | 270          | 470
# chb05_28.edf    | Pre-Ictal  | 525          | 535
# chb05_28.edf    | Ictal      | 535          | 595
# chb05_28.edf    | Pre-Ictal  | 595          | 620
# chb05_28.edf    | Ictal      | 620          | 700
# chb05_28.edf    | Pre-Ictal  | 700          | 890
# chb05_28.edf    | Ictal      | 890          | 925
# chb05_28.edf    | Pre-Ictal  | 1060         | 1145
# chb05_28.edf    | Ictal      | 1165         | 1310
# chb05_28.edf    | Ictal      | 1340         | 1360
# chb05_28.edf    | Pre-Ictal  | 1380         | 1395
# chb05_28.edf    | Ictal      | 1395         | 1435
# chb05_28.edf    | Pre-Ictal  | 1435         | 1460
# chb05_28.edf    | Ictal      | 1475         | 1500
# chb05_28.edf    | Pre-Ictal  | 1500         | 1580
# chb05_28.edf    | Pre-Ictal  | 1605         | 1620
# chb05_28.edf    | Ictal      | 1620         | 1760
# chb05_28.edf    | Pre-Ictal  | 1830         | 1860
# chb05_28.edf    | Ictal      | 2020         | 2045
# chb05_28.edf    | Pre-Ictal  | 2090         | 2120
# chb05_28.edf    | Ictal      | 2120         | 2245
# chb05_28.edf    | Pre-Ictal  | 2275         | 2450
# chb05_28.edf    | Ictal      | 2450         | 2495
# chb05_28.edf    | Pre-Ictal  | 2495         | 2515
# chb05_28.edf    | Ictal      | 2515         | 2660
# chb05_28.edf    | Ictal      | 2715         | 2740
# chb05_28.edf    | Pre-Ictal  | 2740         | 2775
# chb05_28.edf    | Ictal      | 2775         | 2800
# chb05_28.edf    | Pre-Ictal  | 2800         | 2835
# chb05_28.edf    | Ictal      | 2855         | 2885
# chb05_28.edf    | Pre-Ictal  | 2885         | 2950
# chb05_28.edf    | Ictal      | 2975         | 2990
# chb05_28.edf    | Pre-Ictal  | 2990         | 3045
# chb05_28.edf    | Ictal      | 3120         | 3225
# chb05_28.edf    | Ictal      | 3275         | 3330
# chb05_28.edf    | Ictal      | 3435         | 3465
# chb05_28.edf    | Pre-Ictal  | 3550         | 3575
# chb05_28.edf    | Ictal      | 3575         | 3600
# chb05_29.edf    | Pre-Ictal  | 0            | 120
# chb05_29.edf    | Ictal      | 120          | 180
# chb05_29.edf    | Pre-Ictal  | 180          | 220
# chb05_29.edf    | Ictal      | 220          | 315
# chb05_29.edf    | Pre-Ictal  | 315          | 345
# chb05_29.edf    | Ictal      | 345          | 385
# chb05_29.edf    | Pre-Ictal  | 385          | 465
# chb05_29.edf    | Ictal      | 465          | 490
# chb05_29.edf    | Pre-Ictal  | 490          | 630
# chb05_29.edf    | Ictal      | 630          | 690
# chb05_29.edf    | Pre-Ictal  | 690          | 775
# chb05_29.edf    | Ictal      | 775          | 830
# chb05_29.edf    | Ictal      | 875          | 980
# chb05_29.edf    | Pre-Ictal  | 980          | 1025
# chb05_29.edf    | Ictal      | 1025         | 1085
# chb05_29.edf    | Pre-Ictal  | 1200         | 1230
# chb05_29.edf    | Ictal      | 1715         | 1735
# chb05_29.edf    | Pre-Ictal  | 1785         | 1870
# chb05_29.edf    | Ictal      | 1870         | 1920
# chb05_29.edf    | Pre-Ictal  | 1920         | 1975
# chb05_29.edf    | Pre-Ictal  | 2005         | 2015
# chb05_29.edf    | Ictal      | 2015         | 2090
# chb05_29.edf    | Pre-Ictal  | 2110         | 2210
# chb05_29.edf    | Ictal      | 2210         | 2245
# chb05_29.edf    | Ictal      | 2615         | 2670
# chb05_29.edf    | Pre-Ictal  | 2670         | 2720
# chb05_29.edf    | Pre-Ictal  | 2750         | 2785
# chb05_29.edf    | Pre-Ictal  | 2805         | 2830
# chb05_29.edf    | Ictal      | 2855         | 3005
# chb05_29.edf    | Ictal      | 3170         | 3270
# chb05_29.edf    | Ictal      | 3300         | 3425
# chb05_29.edf    | Ictal      | 3445         | 3495
# chb05_29.edf    | Pre-Ictal  | 3495         | 3520
# chb05_29.edf    | Ictal      | 3520         | 3600
# chb05_30.edf    | Ictal      | 0            | 260
# chb05_30.edf    | Ictal      | 290          | 650
# chb05_30.edf    | Ictal      | 780          | 810
# chb05_30.edf    | Ictal      | 875          | 930
# chb05_30.edf    | Ictal      | 1005         | 1110
# chb05_30.edf    | Ictal      | 1170         | 1265
# chb05_30.edf    | Ictal      | 1480         | 1515
# chb05_30.edf    | Pre-Ictal  | 1515         | 1525
# chb05_30.edf    | Pre-Ictal  | 1580         | 1600
# chb05_30.edf    | Pre-Ictal  | 1645         | 1675
# chb05_30.edf    | Pre-Ictal  | 1705         | 2000
# chb05_30.edf    | Pre-Ictal  | 2020         | 2295
# chb05_30.edf    | Ictal      | 2295         | 2435
# chb05_30.edf    | Pre-Ictal  | 2435         | 2545
# chb05_30.edf    | Ictal      | 2545         | 2590
# chb05_30.edf    | Pre-Ictal  | 2590         | 3535
# chb05_30.edf    | Ictal      | 3535         | 3600
# chb05_31.edf    | Ictal      | 0            | 280
# chb05_31.edf    | Pre-Ictal  | 1185         | 1215
# chb05_31.edf    | Pre-Ictal  | 1330         | 2660
# chb05_31.edf    | Pre-Ictal  | 2735         | 2765
# chb05_31.edf    | Pre-Ictal  | 2795         | 2985
# chb05_31.edf    | Pre-Ictal  | 3015         | 3365
# chb05_31.edf    | Ictal      | 3365         | 3600
# chb05_32.edf    | Ictal      | 0            | 25
# chb05_32.edf    | Pre-Ictal  | 240          | 260
# chb05_32.edf    | Pre-Ictal  | 1220         | 1865
# chb05_32.edf    | Ictal      | 1865         | 1930
# chb05_32.edf    | Pre-Ictal  | 1930         | 2260
# chb05_32.edf    | Ictal      | 2260         | 2380
# chb05_32.edf    | Pre-Ictal  | 2380         | 2405
# chb05_32.edf    | Ictal      | 2405         | 2445
# chb05_32.edf    | Pre-Ictal  | 2445         | 2635
# chb05_32.edf    | Ictal      | 2635         | 2725
# chb05_32.edf    | Pre-Ictal  | 2725         | 2750
# chb05_32.edf    | Pre-Ictal  | 2785         | 2900
# chb05_32.edf    | Ictal      | 2900         | 2950
# chb05_32.edf    | Pre-Ictal  | 2950         | 3105
# chb05_32.edf    | Pre-Ictal  | 3150         | 3330
# chb05_32.edf    | Ictal      | 3330         | 3510
# chb05_32.edf    | Pre-Ictal  | 3510         | 3600
# chb05_33.edf    | Pre-Ictal  | 0            | 155
# chb05_33.edf    | Ictal      | 155          | 250
# chb05_33.edf    | Pre-Ictal  | 250          | 370
# chb05_33.edf    | Ictal      | 370          | 570
# chb05_33.edf    | Pre-Ictal  | 675          | 835
# chb05_33.edf    | Pre-Ictal  | 845          | 930
# chb05_33.edf    | Pre-Ictal  | 995          | 1005
# chb05_33.edf    | Ictal      | 1005         | 1295
# chb05_33.edf    | Pre-Ictal  | 1355         | 1625
# chb05_33.edf    | Pre-Ictal  | 1660         | 1845
# chb05_33.edf    | Pre-Ictal  | 1880         | 1915
# chb05_33.edf    | Ictal      | 2975         | 2995
# chb05_33.edf    | Pre-Ictal  | 2995         | 3600
# chb05_34.edf    | Pre-Ictal  | 0            | 1540
# chb05_34.edf    | Ictal      | 1540         | 1685
# chb05_34.edf    | Pre-Ictal  | 1760         | 1795
# chb05_34.edf    | Ictal      | 1795         | 1825
# chb05_34.edf    | Pre-Ictal  | 1825         | 1925
# chb05_34.edf    | Ictal      | 1925         | 2000
# chb05_34.edf    | Pre-Ictal  | 2000         | 2185
# chb05_34.edf    | Pre-Ictal  | 2210         | 2330
# chb05_34.edf    | Ictal      | 2330         | 2645
# chb05_34.edf    | Pre-Ictal  | 3350         | 3370
# chb05_34.edf    | Ictal      | 3595         | 3600
# chb05_35.edf    | Ictal      | 0            | 150
# chb05_35.edf    | Pre-Ictal  | 150          | 185
# chb05_35.edf    | Ictal      | 185          | 245
# chb05_35.edf    | Pre-Ictal  | 245          | 270
# chb05_35.edf    | Ictal      | 270          | 310
# chb05_35.edf    | Pre-Ictal  | 310          | 355
# chb05_35.edf    | Ictal      | 365          | 400
# chb05_35.edf    | Pre-Ictal  | 400          | 660
# chb05_35.edf    | Pre-Ictal  | 690          | 720
# chb05_35.edf    | Pre-Ictal  | 750          | 785
# chb05_35.edf    | Pre-Ictal  | 810          | 830
# chb05_35.edf    | Ictal      | 830          | 920
# chb05_35.edf    | Pre-Ictal  | 920          | 1030
# chb05_35.edf    | Ictal      | 1030         | 1110
# chb05_35.edf    | Pre-Ictal  | 1110         | 1180
# chb05_35.edf    | Ictal      | 1180         | 1210
# chb05_35.edf    | Pre-Ictal  | 1210         | 1310
# chb05_35.edf    | Ictal      | 1310         | 1350
# chb05_35.edf    | Pre-Ictal  | 1350         | 1450
# chb05_35.edf    | Pre-Ictal  | 1475         | 1485
# chb05_35.edf    | Ictal      | 1485         | 1520
# chb05_35.edf    | Pre-Ictal  | 1520         | 1540
# chb05_35.edf    | Pre-Ictal  | 1560         | 1720
# chb05_35.edf    | Ictal      | 1720         | 1775
# chb05_35.edf    | Pre-Ictal  | 1775         | 2005
# chb05_35.edf    | Pre-Ictal  | 2020         | 2110
# chb05_35.edf    | Ictal      | 2110         | 2265
# chb05_35.edf    | Pre-Ictal  | 2265         | 2350
# chb05_35.edf    | Pre-Ictal  | 2370         | 2475
# chb05_35.edf    | Pre-Ictal  | 3470         | 3500
# chb05_35.edf    | Pre-Ictal  | 3590         | 3600
# chb05_36.edf    | Pre-Ictal  | 90           | 175
# chb05_36.edf    | Pre-Ictal  | 200          | 235
# chb05_36.edf    | Ictal      | 240          | 275
# chb05_36.edf    | Pre-Ictal  | 275          | 530
# chb05_36.edf    | Ictal      | 530          | 630
# chb05_36.edf    | Pre-Ictal  | 630          | 740
# chb05_36.edf    | Pre-Ictal  | 760          | 785
# chb05_36.edf    | Ictal      | 785          | 820
# chb05_36.edf    | Pre-Ictal  | 820          | 965
# chb05_36.edf    | Ictal      | 965          | 1055
# chb05_36.edf    | Pre-Ictal  | 1125         | 1200
# chb05_36.edf    | Pre-Ictal  | 1225         | 1255
# chb05_36.edf    | Ictal      | 1270         | 1295
# chb05_36.edf    | Pre-Ictal  | 1295         | 1535
# chb05_36.edf    | Pre-Ictal  | 1570         | 1730
# chb05_36.edf    | Ictal      | 1740         | 1775
# chb05_36.edf    | Pre-Ictal  | 1775         | 1820
# chb05_36.edf    | Ictal      | 1820         | 1850
# chb05_36.edf    | Pre-Ictal  | 1850         | 1890
# chb05_36.edf    | Ictal      | 1890         | 1935
# chb05_36.edf    | Pre-Ictal  | 1950         | 1985
# chb05_36.edf    | Ictal      | 1985         | 2020
# chb05_36.edf    | Pre-Ictal  | 2020         | 2135
# chb05_36.edf    | Ictal      | 2135         | 2205
# chb05_36.edf    | Pre-Ictal  | 2205         | 2330
# chb05_36.edf    | Pre-Ictal  | 2360         | 2385
# chb05_36.edf    | Pre-Ictal  | 2405         | 2505
# chb05_36.edf    | Ictal      | 2505         | 2585
# chb05_36.edf    | Pre-Ictal  | 2585         | 2685
# chb05_36.edf    | Pre-Ictal  | 2705         | 2815
# chb05_36.edf    | Ictal      | 2820         | 3110
# chb05_36.edf    | Ictal      | 3135         | 3350
# chb05_37.edf    | Ictal      | 15           | 50
# chb05_37.edf    | Pre-Ictal  | 50           | 85
# chb05_37.edf    | Pre-Ictal  | 135          | 230
# chb05_37.edf    | Pre-Ictal  | 750          | 780
# chb05_37.edf    | Ictal      | 1270         | 1300
# chb05_37.edf    | Ictal      | 1475         | 1510
# chb05_37.edf    | Pre-Ictal  | 2075         | 2105
# chb05_37.edf    | Pre-Ictal  | 2140         | 3080
# chb05_37.edf    | Ictal      | 3080         | 3350
# chb05_37.edf    | Pre-Ictal  | 3350         | 3385
# chb05_37.edf    | Ictal      | 3385         | 3490
# chb05_37.edf    | Pre-Ictal  | 3490         | 3550
# chb05_37.edf    | Ictal      | 3550         | 3585
# chb05_37.edf    | Pre-Ictal  | 3585         | 3600
# chb05_38.edf    | Ictal      | 0            | 5
# chb05_38.edf    | Pre-Ictal  | 5            | 65
# chb05_38.edf    | Pre-Ictal  | 90           | 350
# chb05_38.edf    | Ictal      | 350          | 425
# chb05_38.edf    | Pre-Ictal  | 425          | 470
# chb05_38.edf    | Pre-Ictal  | 480          | 525
# chb05_38.edf    | Ictal      | 525          | 710
# chb05_38.edf    | Pre-Ictal  | 730          | 760
# chb05_38.edf    | Pre-Ictal  | 785          | 820
# chb05_38.edf    | Pre-Ictal  | 840          | 1095
# chb05_38.edf    | Ictal      | 1105         | 1345
# chb05_38.edf    | Pre-Ictal  | 1345         | 1485
# chb05_38.edf    | Pre-Ictal  | 1505         | 1520
# chb05_38.edf    | Pre-Ictal  | 1535         | 1590
# chb05_38.edf    | Pre-Ictal  | 1615         | 1840
# chb05_38.edf    | Pre-Ictal  | 1870         | 1905
# chb05_38.edf    | Pre-Ictal  | 1935         | 2030
# chb05_38.edf    | Ictal      | 2030         | 2135
# chb05_38.edf    | Pre-Ictal  | 2135         | 2170
# chb05_38.edf    | Pre-Ictal  | 2200         | 2245
# chb05_38.edf    | Pre-Ictal  | 2325         | 2390
# chb05_38.edf    | Ictal      | 2390         | 2420
# chb05_38.edf    | Pre-Ictal  | 2420         | 2445
# chb05_38.edf    | Ictal      | 3045         | 3070
# chb05_38.edf    | Ictal      | 3200         | 3230
# chb05_38.edf    | Pre-Ictal  | 3360         | 3380
# chb05_38.edf    | Pre-Ictal  | 3490         | 3530
# chb05_39.edf    | Pre-Ictal  | 0            | 95
# chb05_39.edf    | Ictal      | 95           | 120
# chb05_39.edf    | Pre-Ictal  | 120          | 470
# chb05_39.edf    | Ictal      | 470          | 540
# chb05_39.edf    | Pre-Ictal  | 540          | 555
# chb05_39.edf    | Ictal      | 585          | 1000
# chb05_39.edf    | Pre-Ictal  | 1000         | 1090
# chb05_39.edf    | Ictal      | 1090         | 1240
# chb05_39.edf    | Pre-Ictal  | 1240         | 1265
# chb05_39.edf    | Ictal      | 1265         | 1500
# chb05_39.edf    | Ictal      | 2190         | 2325
# chb05_39.edf    | Ictal      | 2360         | 2405
# chb05_39.edf    | Pre-Ictal  | 2655         | 2675
# chb05_39.edf    | Ictal      | 2915         | 2940
# chb05_39.edf    | Pre-Ictal  | 2940         | 2950
# chb05_39.edf    | Pre-Ictal  | 2995         | 3010
# chb05_39.edf    | Pre-Ictal  | 3035         | 3065
# chb05_39.edf    | Pre-Ictal  | 3100         | 3160
# chb05_39.edf    | Pre-Ictal  | 3210         | 3240
# chb05_39.edf    | Ictal      | 3255         | 3285
# chb05_39.edf    | Pre-Ictal  | 3285         | 3320
# chb05_39.edf    | Pre-Ictal  | 3400         | 3455
# chb05_39.edf    | Ictal      | 3470         | 3490
# chb05_39.edf    | Pre-Ictal  | 3490         | 3510
# chb05_39.edf    | Ictal      | 3520         | 3545
# chb05_39.edf    | Pre-Ictal  | 3545         | 3580

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb05_06.edf": [(417, 532)],
    "chb05_13.edf": [(1086, 1196)],
    "chb05_16.edf": [(2317, 2413)],
    "chb05_17.edf": [(2451, 2571)],
    "chb05_22.edf": [(2348, 2465)],
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
from tqdm import tqdm

# --- 1. Define the Prediction Target (Respecting File Boundaries) ---
PREDICTION_WINDOW_MIN = 90.0
y_true = np.zeros(len(t_min))
current_idx = 0

for i, length in enumerate(lengths):
    fname = os.path.basename(train_files[i]["path"])
    # Create a time axis for JUST this file
    file_t_min = (np.arange(length) * WINDOW_SEC) / 60.0
    file_y = np.zeros(length)
    
    if fname in clinical:
        for (s0, s1) in clinical[fname]:
            # Mark windows where a seizure starts within the next 90 mins IN THIS FILE
            start_min = s0 / 60.0
            mask = (file_t_min <= start_min) & (file_t_min >= start_min - PREDICTION_WINDOW_MIN)
            file_y[mask] = 1
    
    # Place this file's ground truth into the global array
    y_true[current_idx : current_idx + length] = file_y
    current_idx += length

# --- 2. Calculate Probabilities for different Thresholds (m) ---
thresholds = np.linspace(0, 0.9, 19) 
observed_probs = []

for m in thresholds:
    alarm_mask = pre_density > m
    if np.any(alarm_mask):
        # Accuracy: How often was our alarm followed by a seizure?
        prob = np.mean(y_true[alarm_mask])
        observed_probs.append(prob)
    else:
        observed_probs.append(0.0)

# --- 3. Statistical Significance (Monte Carlo / Surrogate Test) ---
# We shuffle WITHIN the constraints of the data to see if we beat chance
n_permutations = 1000
surrogate_max_probs = []

print(f"Running {n_permutations} permutations for statistical significance...")
for _ in tqdm(range(n_permutations)):
    # Randomly shuffle the TRUE labels to create a "fake" patient history
    y_surrogate = np.random.permutation(y_true)

    # Calculate the max probability achieved by chance for ANY threshold
    chance_probs = [np.mean(y_surrogate[pre_density > m]) if np.any(pre_density > m) else 0 for m in thresholds]
    surrogate_max_probs.append(np.max(chance_probs))

# Calculate p-value for each threshold
p_values = []
for i, m in enumerate(thresholds):
    better_than_us = np.sum(np.array(surrogate_max_probs) >= observed_probs[i])
    p_values.append(better_than_us / n_permutations)

# --- 4. Results Table & Plotting ---
results_df = pd.DataFrame({
    "Threshold (m)": thresholds,
    "Seizure Probability (x%)": np.array(observed_probs) * 100,
    "P-Value": p_values,
    "Significant (p<0.05)": np.array(p_values) < 0.05
})

print("\nThreshold Analysis Results (File-Aware):")
print(results_df.to_string(index=False))

# Visualization
plt.figure(figsize=(10, 5))
plt.plot(thresholds, np.array(observed_probs)*100, marker='o', label="Observed Probability")
plt.axhline(y=np.mean(surrogate_max_probs)*100, color='r', linestyle='--', label="Chance Level (Mean)")
plt.fill_between(thresholds, 0, 100, where=results_df["Significant (p<0.05)"], 
                 color='green', alpha=0.1, label="Statistically Significant Zone")

plt.xlabel("Density Threshold (m)")
plt.ylabel("Probability of Seizure in next 90m (%)")
plt.title("Optimal Threshold for Seizure Prediction (Corrected)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Running 1000 permutations for statistical significance...
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:00<00:00, 1332.13it/s]
# Threshold Analysis Results (File-Aware):
#  Threshold (m)  Seizure Probability (x%)  P-Value  Significant (p<0.05)
#           0.00                  6.079960    1.000                 False
#           0.05                  6.114773    1.000                 False
#           0.10                  5.489862    1.000                 False
#           0.15                  5.030073    1.000                 False
#           0.20                  5.108064    1.000                 False
#           0.25                  5.349655    1.000                 False
#           0.30                  5.839219    1.000                 False
#           0.35                  6.479928    0.494                 False
#           0.40                  7.200238    0.103                 False
#           0.45                  8.024360    0.012                  True
#           0.50                  8.923720    0.000                  True
#           0.55                 10.044810    0.000                  True
#           0.60                 11.283186    0.000                  True
#           0.65                 13.608363    0.000                  True
#           0.70                 17.737394    0.000                  True
#           0.75                 19.794344    0.000                  True
#           0.80                 21.626224    0.000                  True
#           0.85                 28.657315    0.000                  True
#           0.90                 26.300000    0.000                  True

# %%
import numpy as np
import os

# --- Clinical Evaluation Parameters ---
SPH_SEC = 5 * 60          # 5 minutes minimum warning
SOP_SEC = 85 * 60         # 85 minutes occurrence period 
REFRACTORY_SEC = 90 * 60  # 90 minutes silence after an alarm is triggered

# 1. Build a list of exact clinical seizure start times in the global timeline
global_seizure_onsets = []
file_start_sec = np.cumsum([0] + lengths[:-1]) * WINDOW_SEC

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname in clinical:
        base_sec = file_start_sec[i]
        for (s0, s1) in clinical[fname]:
            global_seizure_onsets.append(base_sec + s0)

# 2. Setup Evaluation Loop
total_hours = len(hidden_states) * WINDOW_SEC / 3600.0
total_days = total_hours / 24.0

print(f"Total Recording Time: {total_hours:.2f} hours ({total_days:.2f} days)")
print(f"Total Clinical Seizures: {len(global_seizure_onsets)}")
print(f"Parameters -> SPH: {SPH_SEC/60:.0f}m | SOP: {SOP_SEC/60:.0f}m | Refractory: {REFRACTORY_SEC/60:.0f}m")
print("-" * 75)
print(f"{'Threshold (m)':<15} | {'Sensitivity':<15} | {'False Alarms / 24h':<20}")
print("-" * 75)

# 3. Chronological Alarm Evaluation
for m in [0.55, 0.65, 0.75, 0.85, 0.90]:
    false_positives = 0
    seizures_caught = set() # Track by ID so we don't double-count catching the same seizure
    
    next_allowed_alarm_sec = 0.0
    
    # Find all windows where density exceeds threshold
    alarm_indices = np.where(pre_density > m)[0]
    
    for idx in alarm_indices:
        current_sec = idx * WINDOW_SEC
        
        # Check if the device is allowed to ring (outside refractory period)
        if current_sec >= next_allowed_alarm_sec:
            next_allowed_alarm_sec = current_sec + REFRACTORY_SEC
            
            # Define the valid prediction window for this specific alarm
            pred_window_start = current_sec + SPH_SEC
            pred_window_end = current_sec + SPH_SEC + SOP_SEC
            
            # Did any seizure onset fall inside this window?
            caught_any = False
            for sz_idx, sz_sec in enumerate(global_seizure_onsets):
                if pred_window_start <= sz_sec <= pred_window_end:
                    caught_any = True
                    seizures_caught.add(sz_idx)
                    
            if not caught_any:
                # Alarm rang, but no seizure occurred in the SOP
                false_positives += 1
                
    # Calculate final clinical metrics
    far_per_24h = false_positives / total_days if total_days > 0 else 0
    sensitivity = (len(seizures_caught) / len(global_seizure_onsets)) * 100 if len(global_seizure_onsets) > 0 else 0
    
    print(f"{m:<15.2f} | {sensitivity:<13.1f}% | {far_per_24h:<20.2f}")
# Out:
# Total Recording Time: 39.00 hours (1.63 days)
# Total Clinical Seizures: 5
# Parameters -> SPH: 5m | SOP: 85m | Refractory: 90m
# ---------------------------------------------------------------------------
# Threshold (m)   | Sensitivity     | False Alarms / 24h
# ---------------------------------------------------------------------------
# 0.55            | 60.0         % | 8.00
# 0.65            | 60.0         % | 8.00
# 0.75            | 60.0         % | 6.15
# 0.85            | 60.0         % | 3.69
# 0.90            | 40.0         % | 3.08

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# --- 1. Choose the threshold we want to visualize ---
target_m = 0.90

# --- 2. Re-run the strict device logic for just this threshold ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC-Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

# Track legend entries to avoid duplicates
seen_labels = set()

# Plot Clinical Seizures
for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

# Plot Alarms, SOPs, and Refractory Periods
for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    # 1. The Alarm Trigger
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    # 2. Refractory Period (Red hatched background)
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = "Refractory Period (Snooze)" if "Refractory Period (Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add("Refractory Period (Snooze)")
    
    # 3. SOP (Green expected seizure window)
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    # Plot as a line block slightly above the graph to keep it clean
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"Clinical Device Simulation (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

# Put legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. The Final PLV Goldilocks Parameters ---
target_m = 0.75
REFRACTORY_SEC = 60 * 60  # 60 minute snooze

# --- 2. Re-run the strict device logic ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC+PLV Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

seen_labels = set()

for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
    
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"FINAL Clinical Device Simulation: PLV Edition (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# --- 1. The PLV-Optimized Goldilocks Parameters ---
target_m = 0.80
REFRACTORY_SEC = 60 * 60  # Shortened to 60 minutes to prevent shadowing

# --- 2. Re-run the strict device logic for just this threshold ---
alarm_times_sec = []
next_allowed_alarm_sec = 0.0
alarm_indices = np.where(pre_density > target_m)[0]

for idx in alarm_indices:
    current_sec = idx * WINDOW_SEC
    if current_sec >= next_allowed_alarm_sec:
        alarm_times_sec.append(current_sec)
        next_allowed_alarm_sec = current_sec + REFRACTORY_SEC

# --- 3. Plotting ---
plt.figure(figsize=(18, 7))

# Plot the density and threshold line
plt.plot(t_min, pre_density, label="Pre-Ictal Density (PAC+PLV Optimized)", color="#1f77b4", linewidth=2)
plt.axhline(target_m, color="black", linestyle="--", linewidth=1.5, label=f"Alarm Threshold (m={target_m})")

# Track legend entries to avoid duplicates
seen_labels = set()

# Plot Clinical Seizures
for sz_sec in global_seizure_onsets:
    sz_min = sz_sec / 60.0
    label = "Clinical Seizure Onset" if "Clinical Seizure Onset" not in seen_labels else None
    plt.axvline(sz_min, color="red", linewidth=3, zorder=4, label=label)
    seen_labels.add("Clinical Seizure Onset")

# Plot Alarms, SOPs, and Refractory Periods
for alarm_sec in alarm_times_sec:
    alarm_min = alarm_sec / 60.0
    
    # 1. The Alarm Trigger
    label_alarm = "Alarm Triggered" if "Alarm Triggered" not in seen_labels else None
    plt.scatter(alarm_min, target_m, color="darkorange", s=150, zorder=5, label=label_alarm)
    seen_labels.add("Alarm Triggered")
    
    # 2. Refractory Period (Red hatched background)
    ref_end_min = alarm_min + (REFRACTORY_SEC / 60.0)
    label_ref = f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" if f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)" not in seen_labels else None
    plt.axvspan(alarm_min, ref_end_min, color="red", alpha=0.1, hatch='//', label=label_ref)
    seen_labels.add(f"Refractory Period ({REFRACTORY_SEC//60}m Snooze)")
    
    # 3. SOP (Green expected seizure window)
    sop_start_min = alarm_min + (SPH_SEC / 60.0)
    sop_end_min = alarm_min + ((SPH_SEC + SOP_SEC) / 60.0)
    label_sop = "SOP (Valid Prediction Window)" if "SOP (Valid Prediction Window)" not in seen_labels else None
    plt.plot([sop_start_min, sop_end_min], [1.02, 1.02], color="green", linewidth=8, solid_capstyle="butt", label=label_sop)
    seen_labels.add("SOP (Valid Prediction Window)")

plt.ylim(0, 1.05)
plt.xlabel("Total Time (Minutes)", fontsize=12)
plt.ylabel("Pre-Ictal Density", fontsize=12)
plt.title(f"Clinical Device Simulation: PLV Edition (m={target_m}, SOP={SOP_SEC/60:.0f}m, Refractory={REFRACTORY_SEC/60:.0f}m)", fontsize=14)

# Put legend outside the plot
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5), fontsize=10)
plt.tight_layout()
plt.show()
