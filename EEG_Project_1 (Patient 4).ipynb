# %%
import pandas as pd

def smooth_features(features, window_size=6):
    """
    Applies a rolling mean to features to stabilize HMM states.
    window_size=6 represents a 30-second moving average (6 * 5s).
    """
    df = pd.DataFrame(features)
    # Use Gaussian or simple rolling mean to reduce flicker
    smoothed = df.rolling(window=window_size, min_periods=1, center=False).mean()
    return smoothed.values

# %%
import numpy as np
from scipy.signal import welch
from antropy import perm_entropy

# Left↔Right homologous bipolar pairs (0-based indices) based on EDF channel list
# Left (1–8) pairs with Right (9–16 / 13–16) as appropriate:
PAIRS_LR = [
    (0, 12),  # ch1  FP1-F7  ↔ ch13 FP2-F8
    (1, 13),  # ch2  F7-T7   ↔ ch14 F8-T8
    (2, 14),  # ch3  T7-P7   ↔ ch15 T8-P8
    (3, 15),  # ch4  P7-O1   ↔ ch16 P8-O2
    (4, 8),   # ch5  FP1-F3  ↔ ch9  FP2-F4
    (5, 9),   # ch6  F3-C3   ↔ ch10 F4-C4
    (6, 10),  # ch7  C3-P3   ↔ ch11 C4-P4
    (7, 11),  # ch8  P3-O1   ↔ ch12 P4-O2
]

def get_advanced_state_features(epoch_data, sfreq=256):
    features = []
    eps = 1e-10
    PRIMARY_CH = list(range(18))  # ch1..ch18
    """
    Transforms 5-second EEG windows into a 6D state-space coordinate:
    1. Theta/Alpha Ratio
    2. Permutation Entropy
    3. Line Length (Spikiness)
    4. RMS Amplitude (Power)
    5. Hemispheric Synchronization
    6. Spectral Edge Frequency 95%
    """

    for window in epoch_data:
        X = window[PRIMARY_CH, :]

        freqs, psd = welch(X, sfreq, nperseg=sfreq * 2)
        th_mask = (freqs >= 4) & (freqs < 8)
        al_mask = (freqs >= 8) & (freqs < 13)
        theta = np.trapezoid(psd[:, th_mask], freqs[th_mask], axis=1).mean()
        alpha = np.trapezoid(psd[:, al_mask], freqs[al_mask], axis=1).mean()
        ta_ratio = theta / (alpha + eps)

        complexity = np.mean([perm_entropy(ch, order=4, delay=1, normalize=True) for ch in X])

        sync_scores = []
        for li, ri in PAIRS_LR:
            c = np.corrcoef(X[li], X[ri])[0, 1]
            sync_scores.append(c)
        avg_sync = np.nanmean(sync_scores)
        if not np.isfinite(avg_sync):
            avg_sync = 0.0

        line_length = np.mean(np.sum(np.abs(np.diff(X, axis=1)), axis=1))
        rms = np.mean(np.sqrt(np.mean(X**2, axis=1)))

        df = np.diff(freqs)
        df = np.r_[df, df[-1]]
        power_bins = psd * df
        cumulative_power = np.cumsum(power_bins, axis=1)
        total_power = cumulative_power[:, -1]
        sef_indices = np.argmax(cumulative_power >= 0.95 * total_power[:, None], axis=1)
        avg_sef95 = freqs[sef_indices].mean()

        features.append([ta_ratio, complexity, line_length, rms, avg_sync])

    return np.array(features)

# %% [markdown]
# ## Epoching of the Patient 1 data
# Split the edfs into 5 minute chunks. Each edf is 1-hour long. We choose 01.edf for the baseline data and 03.edf for the data with seizure.

# %%
import mne
import numpy as np

# Patient 1 (chb04) EDF list from your summary
train_files = [
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_01.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_02.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_03.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_04.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_05.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_06.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_07.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_08.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_09.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_10.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_11.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_12.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_13.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_14.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_15.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_16.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_17.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_18.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_19.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_21.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_22.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_23.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_24.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_25.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_26.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_27.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_28.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_29.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_30.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_31.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_32.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_33.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_34.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_35.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_36.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_37.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_38.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_39.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_40.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_41.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_42.edf"},
    {"path": "chb-mit-scalp-eeg-database-1.0.0/chb04/chb04_43.edf"},
]

all_features = []
lengths = []

for i, f_info in enumerate(train_files, start=1):
    path = f_info["path"]

    raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
    raw.rename_channels(lambda x: x.strip("."))

    # Safety: ensure we really have 256 Hz (resample if not)
    if raw.info["sfreq"] != 256:
        raw.resample(256, npad="auto", verbose=False)

    raw.filter(1.0, 40.0, fir_design="firwin", verbose=False)
    raw.notch_filter(freqs=[60], verbose=False)

    # 5s fixed-length epochs
    epochs = mne.make_fixed_length_epochs(raw, duration=5.0, preload=True, verbose=False)
    data = epochs.get_data()  # shape: (n_epochs, n_channels, n_times)

    feats = get_advanced_state_features(data, sfreq=int(raw.info["sfreq"]))
    all_features.append(feats)
    lengths.append(len(feats))

    if i % 5 == 0 or i == len(train_files):
        print(f"Loaded {i}/{len(train_files)} files; last epochs={len(feats)}")

print("Loading complete.")
# Out:
# /opt/anaconda3/envs/eeg_proj/lib/python3.13/site-packages/mne/datasets/eegbci/eegbci.py:8: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 5/42 files; last epochs=1907
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 10/42 files; last epochs=2880
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 15/42 files; last epochs=2880
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# Loaded 20/42 files; last epochs=2880
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)
# /var/folders/zf/_1h962cx0q3dj615fqjpj7bw0000gn/T/ipykernel_84479/3707308478.py:56: RuntimeWarning: Channel names are not unique, found duplicates for: {'T8-P8'}. Applying running numbers for duplicates.
#   raw = mne.io.read_raw_edf(path, preload=True, verbose=False)

# %%
from sklearn.preprocessing import StandardScaler
from hmmlearn import hmm

# 1. Scale and Smooth each file INDIVIDUALLY
# This prevents the 'loudness' of File 01 from being compared to File 03
processed_all_features = []

for f_features in all_features:
    # A. Scale this specific file to its own mean/std
    scaler_local = StandardScaler()
    feat_local_scaled = scaler_local.fit_transform(f_features)
    
    # B. Smooth the normalized data
    # (Using your existing smooth_features function)
    feat_local_smoothed = smooth_features(feat_local_scaled, window_size=6)
    
    processed_all_features.append(feat_local_smoothed)

# 2. Re-combine (Stack) and PCA
# We don't need another StandardScaler here because they are already Z-scored
feat_stack_final = np.vstack(processed_all_features)

#pca = PCA(n_components=3)
#obs_for_hmm_final = pca.fit_transform(feat_stack_final)

obs_for_hmm_final = feat_stack_final

# 3. Re-train HMM
model = hmm.GaussianHMM(
    n_components=3, 
    covariance_type="diag", 
    n_iter=2000, 
    random_state=42
)
model.fit(obs_for_hmm_final, lengths =lengths)

print("Properly Scaled & Smoothed HMM Training Complete.")
# Out:
# Properly Scaled & Smoothed HMM Training Complete.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# The matrix itself
trans_matrix = model.transmat_

# Create a clean DataFrame for viewing
state_labels = ["State 0", "State 1", "State 2"]
df_trans = pd.DataFrame(trans_matrix, columns=state_labels, index=state_labels)

print("Transition Probability Matrix:")
print(df_trans.round(4))

# Heatmap visualization
plt.figure(figsize=(8, 6))
sns.heatmap(df_trans, annot=True, cmap='Blues', fmt='.4f')
plt.title("HMM State Transition Probabilities")
plt.xlabel("To State")
plt.ylabel("From State")
plt.show()
# Out:
# Transition Probability Matrix:
#          State 0  State 1  State 2
# State 0   0.9554   0.0000   0.0446
# State 1   0.0000   0.9469   0.0531
# State 2   0.0423   0.0388   0.9189

# %%
feature_names = ["TA_ratio", "PermEntropy", "LineLength", "RMS", "Avg Sync"]

for i in range(model.n_components):
    print(f"\nState {i} means:")
    for name, val in zip(feature_names, model.means_[i]):
        print(f"  {name:<12}: {val:+.3f}")
# Out:
# State 0 means:
#   TA_ratio    : -0.498
#   PermEntropy : -0.614
#   LineLength  : -0.567
#   RMS         : -0.627
#   Avg Sync    : +0.273
#
# State 1 means:
#   TA_ratio    : +0.673
#   PermEntropy : +0.752
#   LineLength  : +0.962
#   RMS         : +0.950
#   Avg Sync    : -0.382
#
# State 2 means:
#   TA_ratio    : -0.022
#   PermEntropy : +0.030
#   LineLength  : -0.167
#   RMS         : -0.102
#   Avg Sync    : +0.021

# %%
# === Predict hidden states (respect file boundaries) ===
hidden_states = model.predict(obs_for_hmm_final, lengths=lengths)

# === Plot timeline ===
WINDOW_SEC = 5.0  # explicit for safety
time_axis = np.arange(len(hidden_states)) * WINDOW_SEC / 60.0  # minutes

plt.figure(figsize=(18, 6))
plt.scatter(time_axis, hidden_states, c=hidden_states, cmap='viridis', s=5, alpha=0.5)
plt.plot(time_axis, hidden_states, color='black', linewidth=0.5, alpha=0.2)

# === Mark file boundaries ===
current_min = 0.0
for k, length in enumerate(lengths):
    current_min += (length * WINDOW_SEC / 60.0)
    plt.axvline(
        x=current_min,
        color='red',
        linestyle='--',
        alpha=0.5,
        label='File Break' if k == 0 else None
    )
plt.legend()

# === Derive state labels from feature-space means ===
# Feature order:
# [0] TA_ratio, [1] PermEntropy,
# [2] LineLength, [3] RMS

IDX_ENT = 1
IDX_LINELEN = 2
IDX_RMS = 3

# Ictal: high line length + high RMS
ictal_score = model.means_[:, IDX_LINELEN] + model.means_[:, IDX_RMS]
ictal_state = int(np.argmax(ictal_score))

# Baseline: highest entropy among remaining states
remaining_states = [s for s in range(model.n_components) if s != ictal_state]
baseline_state = int(
    remaining_states[np.argmax(model.means_[remaining_states, IDX_ENT])]
)

# Pre-ictal: whatever state is left (for 3-state HMM)
preictal_state = int(
    [s for s in range(model.n_components)
     if s not in (ictal_state, baseline_state)][0]
)

label_map = {
    baseline_state: "Baseline",
    preictal_state: "Pre-Ictal",
    ictal_state: "Ictal"
}

yticklabels = [
    f"{label_map[s]} ({s})" for s in range(model.n_components)
]

plt.yticks(range(model.n_components), yticklabels)

plt.xlabel("Total Time (Minutes)")
plt.title("HMM State Timeline")
plt.tight_layout()
plt.show()

# %%
import os
import numpy as np

WINDOW_SEC = 5.0  # keep consistent with epoch duration

# Expect these from ln[42]:
# - label_map: {state_id: "Baseline"/"Pre-Ictal"/"Ictal"}
# - hidden_states
# - lengths
# - train_files

current_idx = 0

print(f"{'Filename':<15} | {'State':<10} | {'Start (sec)':<12} | {'End (sec)':<12}")
print("-" * 60)

for i, length in enumerate(lengths):
    file_states = hidden_states[current_idx : current_idx + length]
    filename = os.path.basename(train_files[i]["path"])

    # indices where state changes (boundary starts at these indices)
    transitions = np.where(np.diff(file_states) != 0)[0] + 1
    endpoints = np.concatenate(([0], transitions, [length]))

    for j in range(len(endpoints) - 1):
        start_win = int(endpoints[j])
        end_win = int(endpoints[j + 1])
        state = int(file_states[start_win])

        start_sec = start_win * WINDOW_SEC
        end_sec = end_win * WINDOW_SEC

        state_label = label_map.get(state, f"State {state}")

        # Print only Pre-Ictal and Ictal segments
        if state_label in ("Pre-Ictal", "Ictal"):
            print(f"{filename:<15} | {state_label:<10} | {start_sec:<12.0f} | {end_sec:<12.0f}")

    current_idx += length
# Out:
# Filename        | State      | Start (sec)  | End (sec)
# ------------------------------------------------------------
# chb04_01.edf    | Ictal      | 55           | 230
# chb04_01.edf    | Ictal      | 255          | 360
# chb04_01.edf    | Ictal      | 450          | 475
# chb04_01.edf    | Pre-Ictal  | 725          | 750
# chb04_01.edf    | Pre-Ictal  | 900          | 925
# chb04_01.edf    | Pre-Ictal  | 985          | 1045
# chb04_01.edf    | Pre-Ictal  | 1105         | 1125
# chb04_01.edf    | Pre-Ictal  | 1270         | 1465
# chb04_01.edf    | Ictal      | 1470         | 1500
# chb04_01.edf    | Pre-Ictal  | 1520         | 1610
# chb04_01.edf    | Ictal      | 1650         | 1675
# chb04_01.edf    | Pre-Ictal  | 1685         | 1715
# chb04_01.edf    | Ictal      | 1725         | 1935
# chb04_01.edf    | Pre-Ictal  | 1960         | 1985
# chb04_01.edf    | Ictal      | 2010         | 2060
# chb04_01.edf    | Pre-Ictal  | 2095         | 2145
# chb04_01.edf    | Pre-Ictal  | 2240         | 2280
# chb04_01.edf    | Ictal      | 2405         | 2440
# chb04_01.edf    | Ictal      | 2525         | 2575
# chb04_01.edf    | Ictal      | 2600         | 2850
# chb04_01.edf    | Ictal      | 2885         | 2985
# chb04_01.edf    | Pre-Ictal  | 3010         | 3020
# chb04_01.edf    | Pre-Ictal  | 3085         | 3265
# chb04_01.edf    | Ictal      | 3320         | 3345
# chb04_01.edf    | Ictal      | 3390         | 3420
# chb04_01.edf    | Ictal      | 3440         | 3505
# chb04_01.edf    | Ictal      | 3755         | 3790
# chb04_01.edf    | Ictal      | 3830         | 3895
# chb04_01.edf    | Pre-Ictal  | 3915         | 3965
# chb04_01.edf    | Pre-Ictal  | 4010         | 4050
# chb04_01.edf    | Pre-Ictal  | 4170         | 4190
# chb04_01.edf    | Ictal      | 4255         | 4430
# chb04_01.edf    | Pre-Ictal  | 4470         | 4525
# chb04_01.edf    | Ictal      | 4565         | 4585
# chb04_01.edf    | Pre-Ictal  | 4745         | 4870
# chb04_01.edf    | Ictal      | 4890         | 4910
# chb04_01.edf    | Pre-Ictal  | 4925         | 5105
# chb04_01.edf    | Pre-Ictal  | 5120         | 5280
# chb04_01.edf    | Pre-Ictal  | 5305         | 5395
# chb04_01.edf    | Pre-Ictal  | 5435         | 5575
# chb04_01.edf    | Pre-Ictal  | 5605         | 5760
# chb04_01.edf    | Ictal      | 5790         | 5820
# chb04_01.edf    | Ictal      | 5950         | 6025
# chb04_01.edf    | Ictal      | 6050         | 6125
# chb04_01.edf    | Ictal      | 6185         | 6235
# chb04_01.edf    | Pre-Ictal  | 6285         | 6305
# chb04_01.edf    | Pre-Ictal  | 6420         | 6465
# chb04_01.edf    | Ictal      | 6475         | 6495
# chb04_01.edf    | Ictal      | 6540         | 6635
# chb04_01.edf    | Pre-Ictal  | 6650         | 6685
# chb04_01.edf    | Ictal      | 6690         | 7165
# chb04_01.edf    | Ictal      | 7195         | 7260
# chb04_01.edf    | Ictal      | 7320         | 7465
# chb04_01.edf    | Ictal      | 7485         | 7675
# chb04_01.edf    | Pre-Ictal  | 7770         | 7790
# chb04_01.edf    | Ictal      | 7885         | 7930
# chb04_01.edf    | Ictal      | 7965         | 8000
# chb04_01.edf    | Pre-Ictal  | 8015         | 8145
# chb04_01.edf    | Pre-Ictal  | 8170         | 8235
# chb04_01.edf    | Pre-Ictal  | 8395         | 8425
# chb04_01.edf    | Pre-Ictal  | 8590         | 8630
# chb04_01.edf    | Ictal      | 8645         | 8820
# chb04_01.edf    | Ictal      | 8845         | 8960
# chb04_01.edf    | Pre-Ictal  | 8975         | 9130
# chb04_01.edf    | Pre-Ictal  | 9215         | 9440
# chb04_01.edf    | Pre-Ictal  | 9470         | 9720
# chb04_01.edf    | Pre-Ictal  | 9740         | 9825
# chb04_01.edf    | Pre-Ictal  | 10180        | 10250
# chb04_01.edf    | Pre-Ictal  | 10285        | 10335
# chb04_01.edf    | Pre-Ictal  | 10420        | 10495
# chb04_01.edf    | Ictal      | 10510        | 10570
# chb04_01.edf    | Pre-Ictal  | 10615        | 10655
# chb04_01.edf    | Pre-Ictal  | 10785        | 10935
# chb04_01.edf    | Pre-Ictal  | 10985        | 11020
# chb04_01.edf    | Ictal      | 11080        | 11100
# chb04_01.edf    | Ictal      | 11125        | 11265
# chb04_01.edf    | Ictal      | 11300        | 11335
# chb04_01.edf    | Pre-Ictal  | 11380        | 11410
# chb04_01.edf    | Pre-Ictal  | 11435        | 11460
# chb04_01.edf    | Pre-Ictal  | 11515        | 11625
# chb04_01.edf    | Pre-Ictal  | 11650        | 11855
# chb04_01.edf    | Pre-Ictal  | 11885        | 11895
# chb04_01.edf    | Ictal      | 11905        | 12005
# chb04_01.edf    | Pre-Ictal  | 12020        | 12050
# chb04_01.edf    | Ictal      | 12075        | 12145
# chb04_01.edf    | Pre-Ictal  | 12235        | 12270
# chb04_01.edf    | Ictal      | 12305        | 12365
# chb04_01.edf    | Pre-Ictal  | 12430        | 12775
# chb04_01.edf    | Pre-Ictal  | 12860        | 13170
# chb04_01.edf    | Pre-Ictal  | 13205        | 13335
# chb04_01.edf    | Pre-Ictal  | 13430        | 13445
# chb04_01.edf    | Pre-Ictal  | 13550        | 13695
# chb04_01.edf    | Ictal      | 13750        | 13785
# chb04_01.edf    | Pre-Ictal  | 13800        | 13870
# chb04_01.edf    | Ictal      | 13895        | 14055
# chb04_01.edf    | Pre-Ictal  | 14180        | 14225
# chb04_01.edf    | Pre-Ictal  | 14350        | 14395
# chb04_02.edf    | Ictal      | 260          | 395
# chb04_02.edf    | Pre-Ictal  | 405          | 435
# chb04_02.edf    | Ictal      | 445          | 675
# chb04_02.edf    | Ictal      | 710          | 745
# chb04_02.edf    | Ictal      | 765          | 840
# chb04_02.edf    | Pre-Ictal  | 865          | 1015
# chb04_02.edf    | Pre-Ictal  | 1230         | 1295
# chb04_02.edf    | Pre-Ictal  | 1325         | 1370
# chb04_02.edf    | Ictal      | 1430         | 1480
# chb04_02.edf    | Pre-Ictal  | 1530         | 1560
# chb04_02.edf    | Ictal      | 1595         | 1630
# chb04_02.edf    | Ictal      | 1725         | 1750
# chb04_02.edf    | Pre-Ictal  | 1755         | 1890
# chb04_02.edf    | Ictal      | 1895         | 1930
# chb04_02.edf    | Ictal      | 1955         | 2015
# chb04_02.edf    | Pre-Ictal  | 2075         | 2190
# chb04_02.edf    | Ictal      | 2195         | 2235
# chb04_02.edf    | Pre-Ictal  | 2245         | 2340
# chb04_02.edf    | Pre-Ictal  | 2370         | 2485
# chb04_02.edf    | Ictal      | 2495         | 2660
# chb04_02.edf    | Ictal      | 2675         | 2730
# chb04_02.edf    | Pre-Ictal  | 2735         | 2850
# chb04_02.edf    | Ictal      | 2855         | 2880
# chb04_02.edf    | Pre-Ictal  | 2885         | 3100
# chb04_02.edf    | Ictal      | 3125         | 3170
# chb04_02.edf    | Ictal      | 3190         | 3225
# chb04_02.edf    | Pre-Ictal  | 3245         | 3295
# chb04_02.edf    | Ictal      | 3480         | 3630
# chb04_02.edf    | Ictal      | 3650         | 3690
# chb04_02.edf    | Ictal      | 3775         | 3930
# chb04_02.edf    | Pre-Ictal  | 3995         | 4030
# chb04_02.edf    | Ictal      | 4045         | 4070
# chb04_02.edf    | Pre-Ictal  | 4195         | 4395
# chb04_02.edf    | Pre-Ictal  | 4425         | 4560
# chb04_02.edf    | Pre-Ictal  | 4670         | 4840
# chb04_02.edf    | Ictal      | 4895         | 5205
# chb04_02.edf    | Pre-Ictal  | 5435         | 5600
# chb04_02.edf    | Pre-Ictal  | 5695         | 5835
# chb04_02.edf    | Ictal      | 5855         | 5885
# chb04_02.edf    | Ictal      | 5955         | 5985
# chb04_02.edf    | Pre-Ictal  | 6075         | 6195
# chb04_02.edf    | Ictal      | 6215         | 6245
# chb04_02.edf    | Pre-Ictal  | 6260         | 6320
# chb04_02.edf    | Ictal      | 6420         | 6455
# chb04_02.edf    | Pre-Ictal  | 6490         | 6610
# chb04_02.edf    | Ictal      | 6625         | 6730
# chb04_02.edf    | Ictal      | 6740         | 6785
# chb04_02.edf    | Pre-Ictal  | 6795         | 6865
# chb04_02.edf    | Ictal      | 6875         | 6930
# chb04_02.edf    | Ictal      | 6970         | 7010
# chb04_02.edf    | Pre-Ictal  | 7035         | 7205
# chb04_02.edf    | Pre-Ictal  | 7310         | 8250
# chb04_02.edf    | Pre-Ictal  | 8310         | 8325
# chb04_02.edf    | Pre-Ictal  | 8355         | 8390
# chb04_02.edf    | Ictal      | 8860         | 8900
# chb04_02.edf    | Ictal      | 8980         | 9010
# chb04_02.edf    | Ictal      | 9060         | 9070
# chb04_02.edf    | Pre-Ictal  | 9090         | 9105
# chb04_02.edf    | Pre-Ictal  | 9160         | 9195
# chb04_02.edf    | Pre-Ictal  | 9210         | 9260
# chb04_02.edf    | Ictal      | 9265         | 9290
# chb04_02.edf    | Pre-Ictal  | 9295         | 9580
# chb04_02.edf    | Pre-Ictal  | 9630         | 9855
# chb04_02.edf    | Ictal      | 10000        | 10040
# chb04_02.edf    | Pre-Ictal  | 10055        | 10065
# chb04_02.edf    | Ictal      | 10075        | 10410
# chb04_02.edf    | Ictal      | 10435        | 10480
# chb04_02.edf    | Ictal      | 10555        | 10590
# chb04_02.edf    | Pre-Ictal  | 10600        | 10690
# chb04_02.edf    | Ictal      | 10705        | 10730
# chb04_02.edf    | Pre-Ictal  | 10745        | 10785
# chb04_02.edf    | Pre-Ictal  | 10815        | 11345
# chb04_02.edf    | Ictal      | 11355        | 11485
# chb04_02.edf    | Pre-Ictal  | 11520        | 11715
# chb04_02.edf    | Pre-Ictal  | 11745        | 11815
# chb04_02.edf    | Ictal      | 13280        | 13315
# chb04_02.edf    | Pre-Ictal  | 13325        | 13365
# chb04_02.edf    | Pre-Ictal  | 13405        | 13470
# chb04_02.edf    | Pre-Ictal  | 13580        | 13600
# chb04_02.edf    | Pre-Ictal  | 13645        | 13745
# chb04_02.edf    | Pre-Ictal  | 13805        | 13835
# chb04_02.edf    | Pre-Ictal  | 13875        | 13905
# chb04_02.edf    | Ictal      | 13915        | 14005
# chb04_02.edf    | Ictal      | 14040        | 14125
# chb04_02.edf    | Pre-Ictal  | 14145        | 14345
# chb04_03.edf    | Pre-Ictal  | 0            | 370
# chb04_03.edf    | Pre-Ictal  | 400          | 650
# chb04_03.edf    | Ictal      | 655          | 685
# chb04_03.edf    | Pre-Ictal  | 690          | 815
# chb04_03.edf    | Pre-Ictal  | 855          | 905
# chb04_03.edf    | Pre-Ictal  | 925          | 1065
# chb04_03.edf    | Ictal      | 1305         | 1345
# chb04_03.edf    | Ictal      | 1355         | 1380
# chb04_03.edf    | Ictal      | 1405         | 1430
# chb04_03.edf    | Pre-Ictal  | 1490         | 1545
# chb04_03.edf    | Ictal      | 1915         | 1960
# chb04_03.edf    | Ictal      | 2025         | 2055
# chb04_03.edf    | Ictal      | 2515         | 2610
# chb04_03.edf    | Ictal      | 2620         | 2660
# chb04_03.edf    | Ictal      | 2715         | 2765
# chb04_03.edf    | Ictal      | 2810         | 2850
# chb04_03.edf    | Ictal      | 2880         | 2910
# chb04_03.edf    | Pre-Ictal  | 3000         | 3035
# chb04_03.edf    | Ictal      | 3615         | 3645
# chb04_03.edf    | Ictal      | 3665         | 3700
# chb04_03.edf    | Ictal      | 4375         | 4405
# chb04_03.edf    | Ictal      | 4585         | 4715
# chb04_03.edf    | Ictal      | 4780         | 4805
# chb04_03.edf    | Ictal      | 4860         | 5115
# chb04_03.edf    | Ictal      | 5155         | 5215
# chb04_03.edf    | Ictal      | 5250         | 5280
# chb04_03.edf    | Ictal      | 5475         | 5505
# chb04_03.edf    | Ictal      | 5685         | 5715
# chb04_03.edf    | Ictal      | 5935         | 5970
# chb04_03.edf    | Ictal      | 6190         | 6240
# chb04_03.edf    | Ictal      | 6460         | 6505
# chb04_03.edf    | Ictal      | 6645         | 6675
# chb04_03.edf    | Ictal      | 6950         | 6975
# chb04_03.edf    | Pre-Ictal  | 6980         | 7515
# chb04_03.edf    | Pre-Ictal  | 7545         | 7560
# chb04_03.edf    | Pre-Ictal  | 7585         | 7650
# chb04_03.edf    | Pre-Ictal  | 7680         | 7925
# chb04_03.edf    | Ictal      | 7930         | 8010
# chb04_03.edf    | Pre-Ictal  | 8020         | 8115
# chb04_03.edf    | Pre-Ictal  | 8150         | 8175
# chb04_03.edf    | Pre-Ictal  | 8275         | 8520
# chb04_03.edf    | Ictal      | 8605         | 8640
# chb04_03.edf    | Ictal      | 9105         | 9130
# chb04_03.edf    | Ictal      | 9185         | 9215
# chb04_03.edf    | Pre-Ictal  | 9315         | 9360
# chb04_03.edf    | Ictal      | 9795         | 9835
# chb04_03.edf    | Ictal      | 9860         | 10000
# chb04_03.edf    | Pre-Ictal  | 10135        | 10175
# chb04_03.edf    | Ictal      | 10460        | 10500
# chb04_03.edf    | Ictal      | 11050        | 11085
# chb04_03.edf    | Ictal      | 11100        | 11165
# chb04_03.edf    | Pre-Ictal  | 11170        | 11215
# chb04_03.edf    | Ictal      | 11220        | 11265
# chb04_03.edf    | Ictal      | 11295        | 11350
# chb04_03.edf    | Pre-Ictal  | 11360        | 11445
# chb04_03.edf    | Ictal      | 11695        | 11725
# chb04_03.edf    | Ictal      | 11745        | 11775
# chb04_03.edf    | Ictal      | 11830        | 11875
# chb04_03.edf    | Ictal      | 11890        | 11905
# chb04_03.edf    | Pre-Ictal  | 12085        | 12135
# chb04_03.edf    | Ictal      | 12485        | 12520
# chb04_03.edf    | Ictal      | 12550        | 12580
# chb04_03.edf    | Ictal      | 12610        | 12640
# chb04_03.edf    | Ictal      | 12780        | 12885
# chb04_03.edf    | Pre-Ictal  | 12925        | 12970
# chb04_03.edf    | Ictal      | 13630        | 13700
# chb04_03.edf    | Ictal      | 13725        | 13755
# chb04_03.edf    | Ictal      | 13920        | 13950
# chb04_03.edf    | Ictal      | 14360        | 14400
# chb04_04.edf    | Ictal      | 0            | 5
# chb04_04.edf    | Ictal      | 25           | 70
# chb04_04.edf    | Ictal      | 100          | 280
# chb04_04.edf    | Pre-Ictal  | 300          | 445
# chb04_04.edf    | Pre-Ictal  | 475          | 570
# chb04_04.edf    | Ictal      | 575          | 600
# chb04_04.edf    | Pre-Ictal  | 605          | 745
# chb04_04.edf    | Ictal      | 755          | 835
# chb04_04.edf    | Pre-Ictal  | 890          | 1205
# chb04_04.edf    | Ictal      | 1220         | 1250
# chb04_04.edf    | Ictal      | 1285         | 1320
# chb04_04.edf    | Ictal      | 1350         | 1635
# chb04_04.edf    | Pre-Ictal  | 1645         | 1780
# chb04_04.edf    | Ictal      | 1795         | 1855
# chb04_04.edf    | Pre-Ictal  | 1870         | 1985
# chb04_04.edf    | Ictal      | 1995         | 2035
# chb04_04.edf    | Pre-Ictal  | 2080         | 2630
# chb04_04.edf    | Ictal      | 2635         | 2705
# chb04_04.edf    | Pre-Ictal  | 2770         | 2795
# chb04_04.edf    | Pre-Ictal  | 2835         | 3195
# chb04_04.edf    | Ictal      | 3205         | 3255
# chb04_04.edf    | Pre-Ictal  | 3370         | 3440
# chb04_04.edf    | Pre-Ictal  | 3475         | 3555
# chb04_04.edf    | Pre-Ictal  | 3615         | 3810
# chb04_04.edf    | Pre-Ictal  | 3845         | 3980
# chb04_04.edf    | Pre-Ictal  | 4010         | 4135
# chb04_04.edf    | Ictal      | 4140         | 4185
# chb04_04.edf    | Pre-Ictal  | 4220         | 4365
# chb04_04.edf    | Pre-Ictal  | 4415         | 5005
# chb04_04.edf    | Ictal      | 5010         | 5125
# chb04_04.edf    | Pre-Ictal  | 5135         | 5805
# chb04_04.edf    | Ictal      | 5810         | 5860
# chb04_04.edf    | Ictal      | 5875         | 5915
# chb04_04.edf    | Pre-Ictal  | 5925         | 5980
# chb04_04.edf    | Pre-Ictal  | 6015         | 6135
# chb04_04.edf    | Ictal      | 6140         | 6540
# chb04_04.edf    | Pre-Ictal  | 6550         | 6620
# chb04_04.edf    | Pre-Ictal  | 6665         | 6725
# chb04_04.edf    | Pre-Ictal  | 6790         | 6825
# chb04_04.edf    | Ictal      | 6840         | 6855
# chb04_04.edf    | Ictal      | 6875         | 6905
# chb04_04.edf    | Pre-Ictal  | 6965         | 7035
# chb04_04.edf    | Ictal      | 7090         | 7115
# chb04_04.edf    | Pre-Ictal  | 7180         | 7295
# chb04_04.edf    | Ictal      | 7300         | 7330
# chb04_04.edf    | Pre-Ictal  | 7345         | 7470
# chb04_04.edf    | Pre-Ictal  | 7505         | 7590
# chb04_04.edf    | Ictal      | 7615         | 7645
# chb04_04.edf    | Pre-Ictal  | 7650         | 7785
# chb04_04.edf    | Pre-Ictal  | 7830         | 7850
# chb04_04.edf    | Ictal      | 7860         | 7900
# chb04_04.edf    | Pre-Ictal  | 7920         | 7935
# chb04_04.edf    | Ictal      | 7945         | 7975
# chb04_04.edf    | Pre-Ictal  | 7985         | 8005
# chb04_04.edf    | Ictal      | 8045         | 8070
# chb04_04.edf    | Pre-Ictal  | 8105         | 8145
# chb04_04.edf    | Ictal      | 8150         | 8205
# chb04_04.edf    | Pre-Ictal  | 8210         | 8225
# chb04_04.edf    | Ictal      | 8245         | 8285
# chb04_04.edf    | Ictal      | 8320         | 8340
# chb04_04.edf    | Pre-Ictal  | 8360         | 8500
# chb04_04.edf    | Ictal      | 8510         | 8605
# chb04_04.edf    | Pre-Ictal  | 8615         | 8650
# chb04_04.edf    | Pre-Ictal  | 8700         | 8715
# chb04_04.edf    | Pre-Ictal  | 8775         | 8790
# chb04_04.edf    | Pre-Ictal  | 8855         | 8885
# chb04_04.edf    | Pre-Ictal  | 8920         | 8940
# chb04_04.edf    | Pre-Ictal  | 8970         | 9165
# chb04_04.edf    | Ictal      | 9180         | 9230
# chb04_04.edf    | Pre-Ictal  | 9270         | 9440
# chb04_04.edf    | Pre-Ictal  | 9495         | 9590
# chb04_04.edf    | Ictal      | 9605         | 9640
# chb04_04.edf    | Ictal      | 9700         | 9825
# chb04_04.edf    | Ictal      | 9890         | 9905
# chb04_04.edf    | Pre-Ictal  | 10010        | 10025
# chb04_04.edf    | Ictal      | 10035        | 10065
# chb04_04.edf    | Pre-Ictal  | 10070        | 10350
# chb04_04.edf    | Ictal      | 10360        | 10385
# chb04_04.edf    | Pre-Ictal  | 10550        | 10620
# chb04_04.edf    | Ictal      | 10635        | 10795
# chb04_04.edf    | Ictal      | 10830        | 10895
# chb04_04.edf    | Ictal      | 11020        | 11055
# chb04_04.edf    | Ictal      | 11100        | 11220
# chb04_04.edf    | Ictal      | 11250        | 11275
# chb04_04.edf    | Pre-Ictal  | 11295        | 11635
# chb04_04.edf    | Pre-Ictal  | 11670        | 11700
# chb04_04.edf    | Ictal      | 11715        | 12105
# chb04_04.edf    | Pre-Ictal  | 12200        | 12215
# chb04_04.edf    | Ictal      | 12235        | 12330
# chb04_04.edf    | Ictal      | 12355        | 12390
# chb04_04.edf    | Ictal      | 12430        | 12490
# chb04_04.edf    | Ictal      | 12525        | 12560
# chb04_04.edf    | Pre-Ictal  | 12640        | 12750
# chb04_04.edf    | Ictal      | 12785        | 12825
# chb04_04.edf    | Ictal      | 12840        | 12945
# chb04_04.edf    | Ictal      | 12965        | 13485
# chb04_04.edf    | Ictal      | 13505        | 13560
# chb04_04.edf    | Ictal      | 13585        | 13615
# chb04_04.edf    | Ictal      | 13665        | 14045
# chb04_04.edf    | Ictal      | 14070        | 14265
# chb04_04.edf    | Ictal      | 14360        | 14390
# chb04_05.edf    | Ictal      | 0            | 9535
# chb04_06.edf    | Ictal      | 30           | 110
# chb04_06.edf    | Pre-Ictal  | 130          | 205
# chb04_06.edf    | Pre-Ictal  | 390          | 405
# chb04_06.edf    | Ictal      | 415          | 445
# chb04_06.edf    | Pre-Ictal  | 450          | 500
# chb04_06.edf    | Ictal      | 520          | 560
# chb04_06.edf    | Pre-Ictal  | 605          | 685
# chb04_06.edf    | Ictal      | 725          | 760
# chb04_06.edf    | Ictal      | 795          | 825
# chb04_06.edf    | Ictal      | 895          | 925
# chb04_06.edf    | Pre-Ictal  | 1125         | 1205
# chb04_06.edf    | Pre-Ictal  | 1255         | 1370
# chb04_06.edf    | Ictal      | 1385         | 1430
# chb04_06.edf    | Ictal      | 1515         | 1545
# chb04_06.edf    | Ictal      | 1585         | 1620
# chb04_06.edf    | Ictal      | 1660         | 1730
# chb04_06.edf    | Ictal      | 1760         | 2645
# chb04_06.edf    | Pre-Ictal  | 2765         | 2805
# chb04_06.edf    | Ictal      | 2835         | 2850
# chb04_06.edf    | Pre-Ictal  | 2870         | 2895
# chb04_06.edf    | Ictal      | 2920         | 2950
# chb04_06.edf    | Ictal      | 3055         | 3220
# chb04_06.edf    | Ictal      | 3235         | 3320
# chb04_06.edf    | Ictal      | 3500         | 3525
# chb04_06.edf    | Ictal      | 3545         | 3710
# chb04_06.edf    | Ictal      | 3745         | 3835
# chb04_06.edf    | Ictal      | 3920         | 3955
# chb04_06.edf    | Ictal      | 4190         | 4230
# chb04_06.edf    | Ictal      | 4275         | 4370
# chb04_06.edf    | Pre-Ictal  | 4675         | 4705
# chb04_06.edf    | Ictal      | 4735         | 4775
# chb04_06.edf    | Ictal      | 4835         | 4975
# chb04_06.edf    | Ictal      | 5050         | 5150
# chb04_06.edf    | Ictal      | 5180         | 5230
# chb04_06.edf    | Ictal      | 5290         | 5320
# chb04_06.edf    | Pre-Ictal  | 5455         | 5505
# chb04_06.edf    | Pre-Ictal  | 5640         | 5670
# chb04_06.edf    | Ictal      | 5740         | 5785
# chb04_06.edf    | Pre-Ictal  | 5830         | 5870
# chb04_06.edf    | Pre-Ictal  | 6030         | 6270
# chb04_06.edf    | Ictal      | 6295         | 6325
# chb04_06.edf    | Pre-Ictal  | 6345         | 6440
# chb04_06.edf    | Pre-Ictal  | 6470         | 6575
# chb04_06.edf    | Ictal      | 6610         | 6640
# chb04_06.edf    | Pre-Ictal  | 6785         | 7025
# chb04_06.edf    | Ictal      | 7040         | 7185
# chb04_06.edf    | Pre-Ictal  | 7250         | 7310
# chb04_06.edf    | Pre-Ictal  | 7405         | 7430
# chb04_06.edf    | Pre-Ictal  | 7460         | 7480
# chb04_06.edf    | Ictal      | 7490         | 7515
# chb04_06.edf    | Pre-Ictal  | 7555         | 8295
# chb04_06.edf    | Ictal      | 8305         | 8355
# chb04_06.edf    | Ictal      | 8380         | 8415
# chb04_06.edf    | Ictal      | 8530         | 8570
# chb04_06.edf    | Ictal      | 8650         | 8695
# chb04_06.edf    | Ictal      | 8840         | 8990
# chb04_06.edf    | Ictal      | 9110         | 9140
# chb04_06.edf    | Ictal      | 9180         | 9210
# chb04_06.edf    | Pre-Ictal  | 9225         | 9315
# chb04_06.edf    | Ictal      | 9325         | 9355
# chb04_06.edf    | Pre-Ictal  | 9450         | 9990
# chb04_06.edf    | Ictal      | 9995         | 10075
# chb04_06.edf    | Pre-Ictal  | 10170        | 10990
# chb04_06.edf    | Pre-Ictal  | 11020        | 11120
# chb04_06.edf    | Pre-Ictal  | 11235        | 11285
# chb04_06.edf    | Ictal      | 11290        | 11315
# chb04_06.edf    | Pre-Ictal  | 11400        | 11665
# chb04_06.edf    | Pre-Ictal  | 11695        | 11870
# chb04_06.edf    | Ictal      | 11890        | 11925
# chb04_06.edf    | Pre-Ictal  | 11960        | 12010
# chb04_06.edf    | Pre-Ictal  | 12070        | 12235
# chb04_06.edf    | Ictal      | 12245        | 12305
# chb04_06.edf    | Pre-Ictal  | 12350        | 13130
# chb04_06.edf    | Ictal      | 13140        | 13170
# chb04_06.edf    | Ictal      | 13190        | 13220
# chb04_06.edf    | Ictal      | 13235        | 13250
# chb04_06.edf    | Pre-Ictal  | 13270        | 13575
# chb04_06.edf    | Pre-Ictal  | 13610        | 13800
# chb04_06.edf    | Pre-Ictal  | 13830        | 13920
# chb04_06.edf    | Pre-Ictal  | 13985        | 14280
# chb04_06.edf    | Ictal      | 14325        | 14340
# chb04_06.edf    | Pre-Ictal  | 14355        | 14400
# chb04_07.edf    | Ictal      | 5            | 10
# chb04_07.edf    | Pre-Ictal  | 35           | 210
# chb04_07.edf    | Ictal      | 215          | 235
# chb04_07.edf    | Pre-Ictal  | 240          | 265
# chb04_07.edf    | Pre-Ictal  | 295          | 590
# chb04_07.edf    | Ictal      | 605          | 675
# chb04_07.edf    | Pre-Ictal  | 690          | 720
# chb04_07.edf    | Ictal      | 725          | 835
# chb04_07.edf    | Pre-Ictal  | 840          | 1680
# chb04_07.edf    | Pre-Ictal  | 1730         | 1760
# chb04_07.edf    | Pre-Ictal  | 1790         | 1830
# chb04_07.edf    | Pre-Ictal  | 1895         | 2020
# chb04_07.edf    | Ictal      | 2655         | 2695
# chb04_07.edf    | Ictal      | 2710         | 2770
# chb04_07.edf    | Pre-Ictal  | 2785         | 2930
# chb04_07.edf    | Pre-Ictal  | 2955         | 2990
# chb04_07.edf    | Pre-Ictal  | 3015         | 3075
# chb04_07.edf    | Pre-Ictal  | 3110         | 3160
# chb04_07.edf    | Ictal      | 3190         | 3220
# chb04_07.edf    | Pre-Ictal  | 3225         | 3250
# chb04_07.edf    | Pre-Ictal  | 3280         | 3405
# chb04_07.edf    | Pre-Ictal  | 3435         | 3520
# chb04_07.edf    | Ictal      | 3540         | 3660
# chb04_07.edf    | Ictal      | 3705         | 4330
# chb04_07.edf    | Pre-Ictal  | 4370         | 4385
# chb04_07.edf    | Pre-Ictal  | 4510         | 4565
# chb04_07.edf    | Ictal      | 4575         | 4690
# chb04_07.edf    | Ictal      | 4730         | 4770
# chb04_07.edf    | Pre-Ictal  | 4785         | 4880
# chb04_07.edf    | Pre-Ictal  | 4915         | 4990
# chb04_07.edf    | Ictal      | 4995         | 5050
# chb04_07.edf    | Pre-Ictal  | 5065         | 5125
# chb04_07.edf    | Ictal      | 5145         | 5295
# chb04_07.edf    | Pre-Ictal  | 5325         | 5345
# chb04_07.edf    | Ictal      | 5390         | 5415
# chb04_07.edf    | Ictal      | 5440         | 5475
# chb04_07.edf    | Pre-Ictal  | 5485         | 5550
# chb04_07.edf    | Ictal      | 5565         | 5640
# chb04_07.edf    | Pre-Ictal  | 5700         | 5740
# chb04_07.edf    | Pre-Ictal  | 5770         | 5835
# chb04_07.edf    | Pre-Ictal  | 5865         | 5890
# chb04_07.edf    | Ictal      | 5950         | 6085
# chb04_07.edf    | Ictal      | 6150         | 6225
# chb04_07.edf    | Pre-Ictal  | 6270         | 6355
# chb04_07.edf    | Pre-Ictal  | 6430         | 6475
# chb04_07.edf    | Pre-Ictal  | 6520         | 6565
# chb04_07.edf    | Ictal      | 6600         | 6620
# chb04_07.edf    | Pre-Ictal  | 6690         | 6840
# chb04_07.edf    | Ictal      | 6885         | 6965
# chb04_07.edf    | Ictal      | 7055         | 7110
# chb04_07.edf    | Pre-Ictal  | 7135         | 7160
# chb04_07.edf    | Ictal      | 7230         | 7245
# chb04_07.edf    | Pre-Ictal  | 7310         | 7340
# chb04_07.edf    | Ictal      | 7360         | 7495
# chb04_08.edf    | Ictal      | 45           | 135
# chb04_08.edf    | Ictal      | 260          | 310
# chb04_08.edf    | Pre-Ictal  | 330          | 360
# chb04_08.edf    | Ictal      | 725          | 765
# chb04_08.edf    | Pre-Ictal  | 800          | 855
# chb04_08.edf    | Pre-Ictal  | 890          | 910
# chb04_08.edf    | Ictal      | 940          | 990
# chb04_08.edf    | Ictal      | 1000         | 2430
# chb04_08.edf    | Pre-Ictal  | 2485         | 2575
# chb04_08.edf    | Pre-Ictal  | 2625         | 2655
# chb04_08.edf    | Pre-Ictal  | 2765         | 2785
# chb04_08.edf    | Pre-Ictal  | 2805         | 2835
# chb04_08.edf    | Pre-Ictal  | 2870         | 2900
# chb04_08.edf    | Pre-Ictal  | 3000         | 3020
# chb04_08.edf    | Pre-Ictal  | 3085         | 3195
# chb04_08.edf    | Ictal      | 3265         | 3330
# chb04_08.edf    | Pre-Ictal  | 3395         | 3470
# chb04_08.edf    | Pre-Ictal  | 3505         | 3660
# chb04_08.edf    | Ictal      | 3780         | 3800
# chb04_08.edf    | Pre-Ictal  | 3820         | 3835
# chb04_08.edf    | Pre-Ictal  | 3945         | 3990
# chb04_08.edf    | Ictal      | 4010         | 4030
# chb04_08.edf    | Ictal      | 4080         | 4120
# chb04_08.edf    | Pre-Ictal  | 4250         | 4315
# chb04_08.edf    | Pre-Ictal  | 4355         | 4420
# chb04_08.edf    | Pre-Ictal  | 4475         | 4550
# chb04_08.edf    | Ictal      | 4590         | 4650
# chb04_08.edf    | Ictal      | 4730         | 4760
# chb04_08.edf    | Pre-Ictal  | 4775         | 4790
# chb04_08.edf    | Ictal      | 4945         | 5085
# chb04_08.edf    | Pre-Ictal  | 5110         | 5170
# chb04_08.edf    | Ictal      | 5205         | 5340
# chb04_08.edf    | Ictal      | 5395         | 5430
# chb04_08.edf    | Pre-Ictal  | 5440         | 5465
# chb04_08.edf    | Pre-Ictal  | 5550         | 5570
# chb04_08.edf    | Pre-Ictal  | 5600         | 5645
# chb04_08.edf    | Pre-Ictal  | 5705         | 5740
# chb04_08.edf    | Ictal      | 5755         | 5785
# chb04_08.edf    | Pre-Ictal  | 5835         | 5915
# chb04_08.edf    | Pre-Ictal  | 5970         | 6105
# chb04_08.edf    | Pre-Ictal  | 6150         | 6190
# chb04_08.edf    | Pre-Ictal  | 6275         | 6295
# chb04_08.edf    | Pre-Ictal  | 6375         | 6415
# chb04_08.edf    | Ictal      | 6465         | 6610
# chb04_08.edf    | Ictal      | 6655         | 6760
# chb04_08.edf    | Ictal      | 6815         | 6850
# chb04_08.edf    | Ictal      | 6870         | 6920
# chb04_08.edf    | Pre-Ictal  | 6940         | 7155
# chb04_08.edf    | Ictal      | 7160         | 7225
# chb04_08.edf    | Pre-Ictal  | 7255         | 7465
# chb04_08.edf    | Ictal      | 7510         | 7545
# chb04_08.edf    | Pre-Ictal  | 7570         | 7910
# chb04_08.edf    | Ictal      | 7915         | 7945
# chb04_08.edf    | Pre-Ictal  | 7960         | 8775
# chb04_08.edf    | Ictal      | 8780         | 8810
# chb04_08.edf    | Pre-Ictal  | 8820         | 9080
# chb04_08.edf    | Pre-Ictal  | 9110         | 9300
# chb04_08.edf    | Ictal      | 9320         | 9355
# chb04_08.edf    | Ictal      | 9380         | 9425
# chb04_08.edf    | Pre-Ictal  | 9440         | 9470
# chb04_08.edf    | Ictal      | 9485         | 9510
# chb04_08.edf    | Pre-Ictal  | 9530         | 10135
# chb04_08.edf    | Pre-Ictal  | 10170        | 10785
# chb04_08.edf    | Ictal      | 10795        | 10815
# chb04_08.edf    | Pre-Ictal  | 10825        | 10845
# chb04_08.edf    | Ictal      | 10905        | 11070
# chb04_08.edf    | Ictal      | 11085        | 11115
# chb04_08.edf    | Pre-Ictal  | 11150        | 11180
# chb04_08.edf    | Ictal      | 11200        | 11210
# chb04_08.edf    | Pre-Ictal  | 11225        | 11360
# chb04_08.edf    | Ictal      | 11475        | 11495
# chb04_08.edf    | Pre-Ictal  | 11525        | 11685
# chb04_08.edf    | Ictal      | 11695        | 11720
# chb04_08.edf    | Pre-Ictal  | 11745        | 11790
# chb04_08.edf    | Ictal      | 11865        | 11900
# chb04_08.edf    | Pre-Ictal  | 11930        | 12195
# chb04_08.edf    | Pre-Ictal  | 12225        | 12285
# chb04_08.edf    | Ictal      | 12305        | 12385
# chb04_08.edf    | Pre-Ictal  | 12415        | 12455
# chb04_08.edf    | Pre-Ictal  | 12550        | 12565
# chb04_08.edf    | Ictal      | 12675        | 12770
# chb04_08.edf    | Ictal      | 12810        | 12905
# chb04_08.edf    | Pre-Ictal  | 12985        | 13000
# chb04_08.edf    | Pre-Ictal  | 13050        | 13120
# chb04_08.edf    | Pre-Ictal  | 13165        | 13185
# chb04_08.edf    | Ictal      | 13195        | 13245
# chb04_08.edf    | Pre-Ictal  | 13340        | 13515
# chb04_08.edf    | Ictal      | 13525        | 13590
# chb04_08.edf    | Ictal      | 13610        | 13665
# chb04_08.edf    | Pre-Ictal  | 13675        | 13710
# chb04_08.edf    | Pre-Ictal  | 13735        | 13750
# chb04_08.edf    | Pre-Ictal  | 13775        | 13925
# chb04_08.edf    | Ictal      | 13935        | 13970
# chb04_08.edf    | Pre-Ictal  | 13975        | 14110
# chb04_08.edf    | Ictal      | 14125        | 14255
# chb04_08.edf    | Ictal      | 14280        | 14400
# chb04_09.edf    | Ictal      | 70           | 115
# chb04_09.edf    | Ictal      | 135          | 265
# chb04_09.edf    | Ictal      | 340          | 380
# chb04_09.edf    | Ictal      | 425          | 455
# chb04_09.edf    | Ictal      | 600          | 645
# chb04_09.edf    | Pre-Ictal  | 895          | 950
# chb04_09.edf    | Ictal      | 975          | 1050
# chb04_09.edf    | Pre-Ictal  | 1090         | 1165
# chb04_09.edf    | Pre-Ictal  | 1200         | 1295
# chb04_09.edf    | Pre-Ictal  | 1325         | 1380
# chb04_09.edf    | Ictal      | 1400         | 1435
# chb04_09.edf    | Ictal      | 1530         | 1570
# chb04_09.edf    | Ictal      | 1605         | 1630
# chb04_09.edf    | Pre-Ictal  | 1685         | 1720
# chb04_09.edf    | Pre-Ictal  | 1810         | 1840
# chb04_09.edf    | Ictal      | 1850         | 1970
# chb04_09.edf    | Pre-Ictal  | 2030         | 2050
# chb04_09.edf    | Ictal      | 2085         | 2115
# chb04_09.edf    | Ictal      | 2210         | 2230
# chb04_09.edf    | Pre-Ictal  | 2250         | 2285
# chb04_09.edf    | Pre-Ictal  | 2320         | 2365
# chb04_09.edf    | Ictal      | 2380         | 2405
# chb04_09.edf    | Ictal      | 2485         | 2690
# chb04_09.edf    | Ictal      | 2740         | 2775
# chb04_09.edf    | Pre-Ictal  | 2860         | 2920
# chb04_09.edf    | Ictal      | 2935         | 2990
# chb04_09.edf    | Ictal      | 3040         | 3065
# chb04_09.edf    | Ictal      | 3145         | 3185
# chb04_09.edf    | Ictal      | 3210         | 3300
# chb04_09.edf    | Ictal      | 3610         | 3660
# chb04_09.edf    | Ictal      | 3785         | 3805
# chb04_09.edf    | Ictal      | 3835         | 3870
# chb04_09.edf    | Ictal      | 3885         | 3980
# chb04_09.edf    | Pre-Ictal  | 4085         | 4175
# chb04_09.edf    | Ictal      | 4210         | 4265
# chb04_09.edf    | Ictal      | 4305         | 4375
# chb04_09.edf    | Pre-Ictal  | 4400         | 4430
# chb04_09.edf    | Pre-Ictal  | 4465         | 4550
# chb04_09.edf    | Pre-Ictal  | 4590         | 4630
# chb04_09.edf    | Ictal      | 4665         | 4770
# chb04_09.edf    | Ictal      | 4835         | 4920
# chb04_09.edf    | Ictal      | 4940         | 5175
# chb04_09.edf    | Pre-Ictal  | 5235         | 5280
# chb04_09.edf    | Ictal      | 5285         | 5330
# chb04_09.edf    | Pre-Ictal  | 5440         | 5515
# chb04_09.edf    | Pre-Ictal  | 5550         | 5575
# chb04_09.edf    | Ictal      | 5695         | 5740
# chb04_09.edf    | Ictal      | 5785         | 5845
# chb04_09.edf    | Ictal      | 5910         | 6020
# chb04_09.edf    | Ictal      | 6045         | 6150
# chb04_09.edf    | Pre-Ictal  | 6175         | 6200
# chb04_09.edf    | Pre-Ictal  | 6230         | 6295
# chb04_09.edf    | Ictal      | 6325         | 6345
# chb04_09.edf    | Pre-Ictal  | 6355         | 6410
# chb04_09.edf    | Ictal      | 6435         | 6475
# chb04_09.edf    | Pre-Ictal  | 6500         | 6550
# chb04_09.edf    | Ictal      | 6615         | 6640
# chb04_09.edf    | Pre-Ictal  | 6650         | 6730
# chb04_09.edf    | Ictal      | 6735         | 6770
# chb04_09.edf    | Ictal      | 6795         | 6875
# chb04_09.edf    | Pre-Ictal  | 6935         | 6985
# chb04_09.edf    | Pre-Ictal  | 7205         | 7220
# chb04_09.edf    | Ictal      | 7230         | 7250
# chb04_09.edf    | Ictal      | 7300         | 7425
# chb04_09.edf    | Ictal      | 7485         | 7570
# chb04_09.edf    | Ictal      | 7620         | 7695
# chb04_09.edf    | Ictal      | 7750         | 7790
# chb04_09.edf    | Pre-Ictal  | 7810         | 8020
# chb04_09.edf    | Pre-Ictal  | 8050         | 8100
# chb04_09.edf    | Pre-Ictal  | 8180         | 8225
# chb04_09.edf    | Pre-Ictal  | 8285         | 8305
# chb04_09.edf    | Ictal      | 8320         | 8345
# chb04_09.edf    | Pre-Ictal  | 8365         | 8530
# chb04_09.edf    | Ictal      | 8545         | 8580
# chb04_09.edf    | Pre-Ictal  | 8585         | 8740
# chb04_09.edf    | Pre-Ictal  | 8795         | 8910
# chb04_09.edf    | Ictal      | 8940         | 9020
# chb04_09.edf    | Ictal      | 9035         | 9065
# chb04_09.edf    | Pre-Ictal  | 9085         | 9680
# chb04_09.edf    | Pre-Ictal  | 10155        | 10220
# chb04_09.edf    | Pre-Ictal  | 10290        | 10410
# chb04_09.edf    | Pre-Ictal  | 10440        | 10605
# chb04_09.edf    | Ictal      | 10775        | 10800
# chb04_09.edf    | Pre-Ictal  | 10845        | 10965
# chb04_09.edf    | Pre-Ictal  | 11035        | 11070
# chb04_09.edf    | Ictal      | 11145        | 11175
# chb04_09.edf    | Pre-Ictal  | 11185        | 11215
# chb04_09.edf    | Pre-Ictal  | 11245        | 11405
# chb04_09.edf    | Ictal      | 11725        | 11760
# chb04_09.edf    | Pre-Ictal  | 11775        | 11880
# chb04_09.edf    | Pre-Ictal  | 11910        | 12045
# chb04_09.edf    | Pre-Ictal  | 12285        | 12315
# chb04_09.edf    | Pre-Ictal  | 12595        | 13035
# chb04_09.edf    | Pre-Ictal  | 13065        | 13615
# chb04_09.edf    | Pre-Ictal  | 13645        | 13870
# chb04_09.edf    | Pre-Ictal  | 13900        | 14100
# chb04_09.edf    | Pre-Ictal  | 14120        | 14290
# chb04_09.edf    | Pre-Ictal  | 14345        | 14400
# chb04_10.edf    | Ictal      | 0            | 30
# chb04_10.edf    | Pre-Ictal  | 50           | 85
# chb04_10.edf    | Pre-Ictal  | 240          | 375
# chb04_10.edf    | Ictal      | 560          | 590
# chb04_10.edf    | Ictal      | 1440         | 1570
# chb04_10.edf    | Ictal      | 2315         | 2345
# chb04_10.edf    | Ictal      | 2640         | 2705
# chb04_10.edf    | Ictal      | 2715         | 2750
# chb04_10.edf    | Pre-Ictal  | 2880         | 2930
# chb04_10.edf    | Ictal      | 3075         | 3140
# chb04_10.edf    | Ictal      | 3215         | 3245
# chb04_10.edf    | Ictal      | 3895         | 3935
# chb04_10.edf    | Ictal      | 4365         | 4425
# chb04_10.edf    | Ictal      | 4495         | 4560
# chb04_10.edf    | Pre-Ictal  | 5195         | 5530
# chb04_10.edf    | Pre-Ictal  | 5645         | 6015
# chb04_10.edf    | Pre-Ictal  | 6095         | 6400
# chb04_10.edf    | Ictal      | 6410         | 6440
# chb04_10.edf    | Pre-Ictal  | 6455         | 6530
# chb04_10.edf    | Ictal      | 7115         | 7645
# chb04_10.edf    | Ictal      | 7985         | 8035
# chb04_10.edf    | Ictal      | 8235         | 8265
# chb04_10.edf    | Ictal      | 9005         | 9030
# chb04_10.edf    | Ictal      | 9575         | 9605
# chb04_10.edf    | Ictal      | 10225        | 10280
# chb04_10.edf    | Ictal      | 10660        | 10695
# chb04_10.edf    | Ictal      | 11155        | 11190
# chb04_10.edf    | Ictal      | 11660        | 11755
# chb04_10.edf    | Ictal      | 12385        | 12415
# chb04_10.edf    | Pre-Ictal  | 12685        | 12720
# chb04_10.edf    | Pre-Ictal  | 12750        | 12810
# chb04_10.edf    | Pre-Ictal  | 12840        | 12880
# chb04_10.edf    | Pre-Ictal  | 12910        | 12940
# chb04_10.edf    | Ictal      | 12945        | 12975
# chb04_10.edf    | Pre-Ictal  | 12980        | 13050
# chb04_10.edf    | Ictal      | 13075        | 13160
# chb04_10.edf    | Pre-Ictal  | 13165        | 13300
# chb04_10.edf    | Pre-Ictal  | 13325        | 13410
# chb04_10.edf    | Pre-Ictal  | 13435        | 13760
# chb04_11.edf    | Ictal      | 285          | 340
# chb04_11.edf    | Pre-Ictal  | 435          | 465
# chb04_11.edf    | Pre-Ictal  | 510          | 1020
# chb04_11.edf    | Pre-Ictal  | 1155         | 1475
# chb04_11.edf    | Pre-Ictal  | 1520         | 1760
# chb04_11.edf    | Pre-Ictal  | 1820         | 1900
# chb04_11.edf    | Ictal      | 1915         | 1945
# chb04_11.edf    | Ictal      | 1960         | 1990
# chb04_11.edf    | Pre-Ictal  | 2000         | 2340
# chb04_11.edf    | Pre-Ictal  | 2380         | 2475
# chb04_11.edf    | Ictal      | 2520         | 2715
# chb04_11.edf    | Pre-Ictal  | 2735         | 3060
# chb04_11.edf    | Pre-Ictal  | 3105         | 3330
# chb04_11.edf    | Ictal      | 3335         | 3365
# chb04_11.edf    | Ictal      | 3470         | 3495
# chb04_11.edf    | Pre-Ictal  | 3500         | 3620
# chb04_11.edf    | Ictal      | 3735         | 3875
# chb04_11.edf    | Ictal      | 3915         | 4040
# chb04_11.edf    | Ictal      | 4060         | 4385
# chb04_11.edf    | Ictal      | 4430         | 4475
# chb04_11.edf    | Ictal      | 4590         | 4830
# chb04_12.edf    | Ictal      | 0            | 70
# chb04_12.edf    | Ictal      | 115          | 185
# chb04_12.edf    | Ictal      | 210          | 295
# chb04_12.edf    | Ictal      | 385          | 420
# chb04_12.edf    | Ictal      | 490          | 520
# chb04_12.edf    | Pre-Ictal  | 540          | 555
# chb04_12.edf    | Ictal      | 575          | 600
# chb04_12.edf    | Pre-Ictal  | 625          | 780
# chb04_12.edf    | Pre-Ictal  | 920          | 980
# chb04_12.edf    | Ictal      | 1005         | 1025
# chb04_12.edf    | Ictal      | 1080         | 1150
# chb04_12.edf    | Pre-Ictal  | 1300         | 1330
# chb04_12.edf    | Pre-Ictal  | 1385         | 1405
# chb04_12.edf    | Pre-Ictal  | 1440         | 1590
# chb04_12.edf    | Pre-Ictal  | 1620         | 1640
# chb04_12.edf    | Ictal      | 1685         | 1745
# chb04_12.edf    | Ictal      | 1785         | 1805
# chb04_12.edf    | Ictal      | 1830         | 1845
# chb04_12.edf    | Pre-Ictal  | 1860         | 1890
# chb04_12.edf    | Pre-Ictal  | 1920         | 2050
# chb04_12.edf    | Pre-Ictal  | 2115         | 2155
# chb04_12.edf    | Pre-Ictal  | 2285         | 2425
# chb04_12.edf    | Pre-Ictal  | 2455         | 2565
# chb04_12.edf    | Ictal      | 2580         | 2600
# chb04_12.edf    | Ictal      | 2625         | 2685
# chb04_12.edf    | Ictal      | 2945         | 2975
# chb04_12.edf    | Ictal      | 3010         | 3075
# chb04_12.edf    | Ictal      | 3145         | 3180
# chb04_12.edf    | Ictal      | 3265         | 3295
# chb04_12.edf    | Ictal      | 3380         | 3425
# chb04_12.edf    | Ictal      | 3445         | 3475
# chb04_12.edf    | Ictal      | 3495         | 4340
# chb04_12.edf    | Pre-Ictal  | 4500         | 4545
# chb04_12.edf    | Ictal      | 4720         | 4760
# chb04_12.edf    | Pre-Ictal  | 4990         | 5005
# chb04_12.edf    | Ictal      | 5015         | 5035
# chb04_12.edf    | Pre-Ictal  | 5045         | 5215
# chb04_12.edf    | Ictal      | 5230         | 5255
# chb04_12.edf    | Pre-Ictal  | 5275         | 5350
# chb04_12.edf    | Ictal      | 5380         | 5420
# chb04_12.edf    | Pre-Ictal  | 5440         | 5495
# chb04_12.edf    | Pre-Ictal  | 5530         | 5675
# chb04_12.edf    | Pre-Ictal  | 5715         | 5980
# chb04_12.edf    | Ictal      | 6155         | 6170
# chb04_12.edf    | Ictal      | 6300         | 6325
# chb04_12.edf    | Pre-Ictal  | 6375         | 6415
# chb04_12.edf    | Ictal      | 6455         | 6485
# chb04_12.edf    | Ictal      | 6505         | 6525
# chb04_12.edf    | Ictal      | 6565         | 6600
# chb04_12.edf    | Ictal      | 6620         | 6650
# chb04_12.edf    | Pre-Ictal  | 6700         | 6735
# chb04_12.edf    | Pre-Ictal  | 6955         | 6970
# chb04_12.edf    | Ictal      | 6985         | 7045
# chb04_12.edf    | Pre-Ictal  | 7080         | 7520
# chb04_12.edf    | Ictal      | 7530         | 7580
# chb04_12.edf    | Pre-Ictal  | 7615         | 7630
# chb04_12.edf    | Pre-Ictal  | 7655         | 7685
# chb04_12.edf    | Ictal      | 7730         | 7770
# chb04_12.edf    | Ictal      | 7880         | 7895
# chb04_12.edf    | Pre-Ictal  | 7925         | 7975
# chb04_12.edf    | Pre-Ictal  | 8000         | 8020
# chb04_12.edf    | Ictal      | 8040         | 8050
# chb04_12.edf    | Ictal      | 8075         | 8105
# chb04_12.edf    | Pre-Ictal  | 8115         | 9280
# chb04_12.edf    | Ictal      | 9285         | 9365
# chb04_12.edf    | Pre-Ictal  | 9490         | 10120
# chb04_12.edf    | Ictal      | 10140        | 10170
# chb04_12.edf    | Ictal      | 10205        | 10235
# ...
# chb04_22.edf    | Ictal      | 10715        | 10745
# chb04_22.edf    | Pre-Ictal  | 10760        | 10935
# chb04_22.edf    | Ictal      | 10975        | 11040
# chb04_22.edf    | Pre-Ictal  | 11070        | 11115
# chb04_22.edf    | Ictal      | 11135        | 11165
# chb04_22.edf    | Pre-Ictal  | 11215        | 11295
# chb04_22.edf    | Ictal      | 11300        | 11330
# chb04_22.edf    | Ictal      | 11355        | 11400
# chb04_22.edf    | Ictal      | 11500        | 11565
# chb04_22.edf    | Ictal      | 11585        | 11650
# chb04_22.edf    | Pre-Ictal  | 11660        | 11680
# chb04_22.edf    | Ictal      | 11695        | 11715
# chb04_22.edf    | Pre-Ictal  | 11730        | 11780
# chb04_22.edf    | Ictal      | 11795        | 11810
# chb04_22.edf    | Pre-Ictal  | 11820        | 12185
# chb04_22.edf    | Pre-Ictal  | 12220        | 12600
# chb04_22.edf    | Pre-Ictal  | 12625        | 12875
# chb04_22.edf    | Pre-Ictal  | 12905        | 12930
# chb04_22.edf    | Pre-Ictal  | 13010        | 13085
# chb04_22.edf    | Ictal      | 14140        | 14215
# chb04_22.edf    | Pre-Ictal  | 14225        | 14260
# chb04_22.edf    | Pre-Ictal  | 14275        | 14375
# chb04_23.edf    | Pre-Ictal  | 20           | 105
# chb04_23.edf    | Ictal      | 1715         | 1745
# chb04_23.edf    | Pre-Ictal  | 1775         | 1860
# chb04_23.edf    | Pre-Ictal  | 1910         | 1960
# chb04_23.edf    | Pre-Ictal  | 2015         | 2390
# chb04_23.edf    | Pre-Ictal  | 2420         | 3005
# chb04_23.edf    | Pre-Ictal  | 3030         | 3110
# chb04_23.edf    | Ictal      | 3115         | 3135
# chb04_23.edf    | Pre-Ictal  | 3140         | 4470
# chb04_23.edf    | Ictal      | 4485         | 4535
# chb04_23.edf    | Pre-Ictal  | 4545         | 4570
# chb04_23.edf    | Ictal      | 4595         | 4635
# chb04_23.edf    | Pre-Ictal  | 4655         | 4695
# chb04_23.edf    | Pre-Ictal  | 4730         | 4745
# chb04_23.edf    | Pre-Ictal  | 4800         | 4830
# chb04_23.edf    | Ictal      | 4845         | 4915
# chb04_23.edf    | Ictal      | 4940         | 5580
# chb04_23.edf    | Ictal      | 5620         | 5650
# chb04_23.edf    | Ictal      | 5695         | 5880
# chb04_23.edf    | Ictal      | 5985         | 6025
# chb04_23.edf    | Ictal      | 6105         | 6215
# chb04_23.edf    | Ictal      | 6250         | 6335
# chb04_23.edf    | Ictal      | 6375         | 6400
# chb04_23.edf    | Ictal      | 6470         | 6495
# chb04_23.edf    | Ictal      | 6605         | 6690
# chb04_23.edf    | Pre-Ictal  | 6860         | 6895
# chb04_23.edf    | Ictal      | 6910         | 6940
# chb04_23.edf    | Pre-Ictal  | 6965         | 6985
# chb04_23.edf    | Ictal      | 7225         | 7260
# chb04_23.edf    | Ictal      | 7295         | 7340
# chb04_23.edf    | Pre-Ictal  | 7570         | 7635
# chb04_23.edf    | Pre-Ictal  | 7670         | 7730
# chb04_23.edf    | Ictal      | 7760         | 7795
# chb04_23.edf    | Pre-Ictal  | 7805         | 7820
# chb04_23.edf    | Ictal      | 7875         | 7915
# chb04_23.edf    | Ictal      | 7960         | 8410
# chb04_23.edf    | Pre-Ictal  | 8535         | 8560
# chb04_23.edf    | Pre-Ictal  | 8700         | 8725
# chb04_23.edf    | Pre-Ictal  | 8830         | 8900
# chb04_23.edf    | Pre-Ictal  | 8950         | 8995
# chb04_23.edf    | Ictal      | 9200         | 9245
# chb04_23.edf    | Ictal      | 9365         | 9385
# chb04_23.edf    | Pre-Ictal  | 9440         | 9485
# chb04_23.edf    | Pre-Ictal  | 9625         | 9665
# chb04_23.edf    | Pre-Ictal  | 9695         | 9740
# chb04_23.edf    | Ictal      | 9870         | 9945
# chb04_23.edf    | Pre-Ictal  | 10145        | 10175
# chb04_23.edf    | Ictal      | 10195        | 10220
# chb04_23.edf    | Ictal      | 10245        | 10305
# chb04_23.edf    | Ictal      | 10430        | 10460
# chb04_23.edf    | Ictal      | 10490        | 10580
# chb04_24.edf    | Ictal      | 0            | 15
# chb04_24.edf    | Pre-Ictal  | 125          | 250
# chb04_24.edf    | Pre-Ictal  | 305          | 500
# chb04_24.edf    | Pre-Ictal  | 530          | 680
# chb04_24.edf    | Pre-Ictal  | 720          | 795
# chb04_24.edf    | Ictal      | 1030         | 1055
# chb04_24.edf    | Pre-Ictal  | 1075         | 1310
# chb04_24.edf    | Ictal      | 1315         | 1340
# chb04_24.edf    | Pre-Ictal  | 1345         | 1490
# chb04_24.edf    | Pre-Ictal  | 1590         | 1880
# chb04_24.edf    | Ictal      | 1890         | 1920
# chb04_24.edf    | Pre-Ictal  | 1995         | 2030
# chb04_24.edf    | Pre-Ictal  | 2065         | 2120
# chb04_24.edf    | Pre-Ictal  | 2265         | 2390
# chb04_24.edf    | Ictal      | 2425         | 2510
# chb04_24.edf    | Ictal      | 2540         | 2615
# chb04_24.edf    | Ictal      | 2715         | 2760
# chb04_24.edf    | Ictal      | 2790         | 2820
# chb04_24.edf    | Ictal      | 2945         | 2970
# chb04_24.edf    | Pre-Ictal  | 3030         | 3170
# chb04_24.edf    | Ictal      | 3440         | 3480
# chb04_24.edf    | Ictal      | 3500         | 3530
# chb04_24.edf    | Pre-Ictal  | 3645         | 3685
# chb04_24.edf    | Pre-Ictal  | 3730         | 3800
# chb04_24.edf    | Pre-Ictal  | 3860         | 3895
# chb04_24.edf    | Pre-Ictal  | 3925         | 3975
# chb04_24.edf    | Pre-Ictal  | 4040         | 4080
# chb04_24.edf    | Ictal      | 4100         | 4145
# chb04_24.edf    | Pre-Ictal  | 4205         | 4295
# chb04_24.edf    | Pre-Ictal  | 4400         | 4415
# chb04_24.edf    | Pre-Ictal  | 4445         | 4475
# chb04_24.edf    | Ictal      | 4485         | 4535
# chb04_24.edf    | Pre-Ictal  | 4650         | 4670
# chb04_24.edf    | Ictal      | 5035         | 5080
# chb04_24.edf    | Ictal      | 5125         | 5225
# chb04_24.edf    | Ictal      | 5285         | 5560
# chb04_24.edf    | Ictal      | 5580         | 5605
# chb04_24.edf    | Ictal      | 5635         | 5685
# chb04_24.edf    | Ictal      | 5705         | 5760
# chb04_24.edf    | Pre-Ictal  | 5975         | 6085
# chb04_24.edf    | Ictal      | 6295         | 6340
# chb04_24.edf    | Ictal      | 6470         | 6625
# chb04_24.edf    | Ictal      | 6680         | 7430
# chb04_24.edf    | Ictal      | 7480         | 7590
# chb04_24.edf    | Pre-Ictal  | 7605         | 7635
# chb04_24.edf    | Ictal      | 7650         | 7690
# chb04_24.edf    | Pre-Ictal  | 7720         | 7780
# chb04_24.edf    | Pre-Ictal  | 7810         | 7825
# chb04_24.edf    | Pre-Ictal  | 7860         | 7895
# chb04_24.edf    | Ictal      | 7940         | 8070
# chb04_24.edf    | Pre-Ictal  | 8110         | 8130
# chb04_24.edf    | Ictal      | 8430         | 8455
# chb04_24.edf    | Ictal      | 8520         | 8580
# chb04_24.edf    | Ictal      | 8610         | 8640
# chb04_24.edf    | Ictal      | 8775         | 8805
# chb04_24.edf    | Pre-Ictal  | 8835         | 8880
# chb04_24.edf    | Pre-Ictal  | 8985         | 9000
# chb04_24.edf    | Pre-Ictal  | 9030         | 9065
# chb04_24.edf    | Ictal      | 9205         | 9240
# chb04_24.edf    | Ictal      | 9275         | 9390
# chb04_24.edf    | Ictal      | 9495         | 9520
# chb04_24.edf    | Ictal      | 9610         | 9795
# chb04_24.edf    | Pre-Ictal  | 9965         | 9985
# chb04_24.edf    | Ictal      | 10035        | 10060
# chb04_24.edf    | Pre-Ictal  | 10185        | 10200
# chb04_24.edf    | Pre-Ictal  | 10225        | 10290
# chb04_24.edf    | Pre-Ictal  | 10330        | 10350
# chb04_24.edf    | Ictal      | 10370        | 10475
# chb04_24.edf    | Ictal      | 10505        | 10555
# chb04_24.edf    | Pre-Ictal  | 10700        | 10815
# chb04_24.edf    | Ictal      | 10825        | 10855
# chb04_24.edf    | Ictal      | 10975        | 11005
# chb04_24.edf    | Pre-Ictal  | 11145        | 11170
# chb04_24.edf    | Ictal      | 11295        | 11330
# chb04_24.edf    | Pre-Ictal  | 11430        | 11465
# chb04_24.edf    | Ictal      | 11490        | 11515
# chb04_24.edf    | Pre-Ictal  | 11555        | 11595
# chb04_24.edf    | Ictal      | 11610        | 11640
# chb04_24.edf    | Ictal      | 11705        | 11760
# chb04_24.edf    | Ictal      | 11805        | 11840
# chb04_24.edf    | Pre-Ictal  | 11925        | 12015
# chb04_24.edf    | Pre-Ictal  | 12125        | 12155
# chb04_24.edf    | Pre-Ictal  | 12190        | 12220
# chb04_24.edf    | Ictal      | 12315        | 12345
# chb04_24.edf    | Pre-Ictal  | 12390        | 12515
# chb04_24.edf    | Pre-Ictal  | 12545        | 12695
# chb04_24.edf    | Pre-Ictal  | 12725        | 12755
# chb04_24.edf    | Ictal      | 12765        | 12790
# chb04_24.edf    | Pre-Ictal  | 12825        | 13640
# chb04_24.edf    | Pre-Ictal  | 13710        | 13810
# chb04_24.edf    | Pre-Ictal  | 13835        | 13980
# chb04_24.edf    | Pre-Ictal  | 14025        | 14040
# chb04_24.edf    | Pre-Ictal  | 14070        | 14260
# chb04_24.edf    | Pre-Ictal  | 14290        | 14375
# chb04_24.edf    | Ictal      | 14385        | 14405
# chb04_25.edf    | Ictal      | 0            | 10
# chb04_25.edf    | Pre-Ictal  | 75           | 110
# chb04_25.edf    | Pre-Ictal  | 145          | 230
# chb04_25.edf    | Ictal      | 335          | 425
# chb04_25.edf    | Ictal      | 465          | 505
# chb04_25.edf    | Ictal      | 545          | 585
# chb04_25.edf    | Ictal      | 665          | 715
# chb04_25.edf    | Pre-Ictal  | 760          | 790
# chb04_25.edf    | Ictal      | 805          | 850
# chb04_25.edf    | Pre-Ictal  | 855          | 865
# chb04_25.edf    | Pre-Ictal  | 900          | 1010
# chb04_25.edf    | Ictal      | 1015         | 1045
# chb04_25.edf    | Pre-Ictal  | 1050         | 1205
# chb04_25.edf    | Ictal      | 1220         | 1250
# chb04_25.edf    | Pre-Ictal  | 1275         | 1355
# chb04_25.edf    | Ictal      | 1430         | 1490
# chb04_25.edf    | Ictal      | 1515         | 1590
# chb04_25.edf    | Pre-Ictal  | 1605         | 1710
# chb04_25.edf    | Ictal      | 1720         | 1795
# chb04_25.edf    | Pre-Ictal  | 1835         | 1850
# chb04_25.edf    | Ictal      | 1855         | 1880
# chb04_25.edf    | Pre-Ictal  | 1885         | 1960
# chb04_25.edf    | Ictal      | 1975         | 2020
# chb04_25.edf    | Pre-Ictal  | 2060         | 2105
# chb04_25.edf    | Ictal      | 2155         | 2285
# chb04_25.edf    | Pre-Ictal  | 2300         | 2335
# chb04_25.edf    | Pre-Ictal  | 2360         | 2425
# chb04_25.edf    | Pre-Ictal  | 2480         | 2520
# chb04_25.edf    | Pre-Ictal  | 2545         | 2560
# chb04_25.edf    | Pre-Ictal  | 2650         | 2675
# chb04_25.edf    | Ictal      | 2685         | 2705
# chb04_25.edf    | Ictal      | 2750         | 2785
# chb04_25.edf    | Ictal      | 2880         | 2895
# chb04_25.edf    | Pre-Ictal  | 3020         | 3115
# chb04_25.edf    | Ictal      | 3125         | 3210
# chb04_25.edf    | Ictal      | 3275         | 3310
# chb04_25.edf    | Ictal      | 3365         | 3395
# chb04_25.edf    | Pre-Ictal  | 3490         | 3525
# chb04_25.edf    | Pre-Ictal  | 3550         | 3590
# chb04_25.edf    | Pre-Ictal  | 3620         | 3665
# chb04_25.edf    | Ictal      | 3815         | 3855
# chb04_25.edf    | Pre-Ictal  | 3900         | 3945
# chb04_25.edf    | Pre-Ictal  | 4085         | 4110
# chb04_25.edf    | Pre-Ictal  | 4240         | 4285
# chb04_25.edf    | Ictal      | 4415         | 4460
# chb04_25.edf    | Ictal      | 4495         | 4735
# chb04_25.edf    | Ictal      | 4770         | 4950
# chb04_25.edf    | Ictal      | 5080         | 5125
# chb04_25.edf    | Ictal      | 5160         | 5195
# chb04_25.edf    | Pre-Ictal  | 5205         | 5290
# chb04_25.edf    | Pre-Ictal  | 5320         | 5425
# chb04_25.edf    | Pre-Ictal  | 5550         | 5670
# chb04_25.edf    | Ictal      | 5685         | 5875
# chb04_25.edf    | Ictal      | 5935         | 6020
# chb04_25.edf    | Ictal      | 6195         | 6225
# chb04_25.edf    | Pre-Ictal  | 6335         | 6375
# chb04_25.edf    | Pre-Ictal  | 6400         | 6595
# chb04_25.edf    | Ictal      | 6630         | 6690
# chb04_25.edf    | Pre-Ictal  | 6740         | 6820
# chb04_25.edf    | Pre-Ictal  | 6920         | 6945
# chb04_25.edf    | Ictal      | 6995         | 7015
# chb04_25.edf    | Ictal      | 7060         | 7140
# chb04_25.edf    | Pre-Ictal  | 7160         | 7210
# chb04_25.edf    | Ictal      | 7495         | 7810
# chb04_25.edf    | Ictal      | 7855         | 8385
# chb04_25.edf    | Pre-Ictal  | 8440         | 8495
# chb04_25.edf    | Pre-Ictal  | 8545         | 8565
# chb04_25.edf    | Ictal      | 8585         | 8645
# chb04_25.edf    | Ictal      | 8715         | 8770
# chb04_25.edf    | Pre-Ictal  | 8950         | 8995
# chb04_25.edf    | Ictal      | 9090         | 9115
# chb04_25.edf    | Pre-Ictal  | 9180         | 9240
# chb04_25.edf    | Pre-Ictal  | 9260         | 9325
# chb04_25.edf    | Ictal      | 9350         | 9390
# chb04_25.edf    | Ictal      | 9580         | 9785
# chb04_25.edf    | Pre-Ictal  | 9795         | 9990
# chb04_25.edf    | Ictal      | 9995         | 10025
# chb04_25.edf    | Pre-Ictal  | 10030        | 10200
# chb04_25.edf    | Ictal      | 10210        | 10245
# chb04_25.edf    | Pre-Ictal  | 10250        | 10270
# chb04_25.edf    | Ictal      | 10285        | 10355
# chb04_25.edf    | Ictal      | 10375        | 10400
# chb04_25.edf    | Ictal      | 10435        | 10495
# chb04_25.edf    | Pre-Ictal  | 10510        | 10560
# chb04_25.edf    | Pre-Ictal  | 10595        | 10640
# chb04_25.edf    | Pre-Ictal  | 10735        | 10825
# chb04_25.edf    | Pre-Ictal  | 10965        | 11000
# chb04_25.edf    | Pre-Ictal  | 11030        | 11110
# chb04_25.edf    | Pre-Ictal  | 11135        | 11320
# chb04_25.edf    | Ictal      | 11335        | 11370
# chb04_25.edf    | Ictal      | 11525        | 11550
# chb04_25.edf    | Pre-Ictal  | 11605        | 11710
# chb04_25.edf    | Ictal      | 11725        | 11740
# chb04_25.edf    | Pre-Ictal  | 11760        | 11850
# chb04_25.edf    | Pre-Ictal  | 11885        | 11895
# chb04_25.edf    | Pre-Ictal  | 11960        | 12260
# chb04_25.edf    | Pre-Ictal  | 12280        | 13060
# chb04_25.edf    | Pre-Ictal  | 13105        | 13135
# chb04_25.edf    | Ictal      | 13180        | 13205
# chb04_25.edf    | Pre-Ictal  | 13235        | 14200
# chb04_25.edf    | Ictal      | 14210        | 14230
# chb04_25.edf    | Pre-Ictal  | 14240        | 14270
# chb04_25.edf    | Pre-Ictal  | 14295        | 14400

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

WINDOW_SEC = 5.0
DENSITY_MIN = 20.0
W = int((DENSITY_MIN * 60.0) / WINDOW_SEC)  # 10 minutes -> 120 windows

# --- Identify which numeric states are Pre-Ictal and Ictal ---
pre_state = next(s for s, name in label_map.items() if name == "Pre-Ictal")
ictal_state = next(s for s, name in label_map.items() if name == "Ictal")

# --- Rolling pre-ictal density (causal) over last W windows ---
pre_indicator = (hidden_states == pre_state).astype(float)
kernel = np.ones(W, dtype=float)
pre_density = np.convolve(pre_indicator, kernel, mode="full")[:len(pre_indicator)] / W
# fix startup so early points are averaged over fewer samples (optional but nicer)
for i in range(min(W-1, len(pre_density))):
    pre_density[i] *= W / (i+1)

# --- Build a global time axis in minutes ---
t_min = (np.arange(len(hidden_states)) * WINDOW_SEC) / 60.0

# --- Build file offsets (start time in windows/minutes for each file in the concatenated series) ---
file_start_win = np.cumsum([0] + lengths[:-1])
file_start_min = file_start_win * WINDOW_SEC / 60.0

# --- Clinical seizure annotations you provided (seconds-from-file-start) ---
# Only for the seizure files here; extend as needed.
clinical = {
    "chb04_05.edf": [(7804, 7853)],
    "chb04_08.edf": [(6446, 6557)],
    "chb04_28.edf": [(1679, 1781), (3782, 3898)],
}

# --- Plot ---
plt.figure(figsize=(18, 6))

# Pre-ictal density line + light fill
plt.plot(t_min, pre_density, linewidth=2, label=f"Pre-Ictal Density ({int(DENSITY_MIN)}m Window)")
plt.fill_between(t_min, 0, pre_density, alpha=0.15)

# Shade predicted ictal windows
ictal_mask = (hidden_states == ictal_state)
plt.fill_between(t_min, 0, 1, where=ictal_mask, alpha=0.12, label="Predicted Ictal State")

# File breaks
for k, startm in enumerate(file_start_min[1:]):  # skip first at 0
    plt.axvline(x=startm, color="gray", linestyle=":", alpha=0.6, label="File Break" if k == 0 else None)

# Clinical seizure start/end markers
# Convert per-file seconds to global minutes using file offset
seen_label_start = False
seen_label_end = False

for i, f in enumerate(train_files):
    fname = os.path.basename(f["path"])
    if fname not in clinical:
        continue
    base_min = file_start_min[i]
    for (s0, s1) in clinical[fname]:
        x0 = base_min + (s0 / 60.0)
        x1 = base_min + (s1 / 60.0)
        plt.axvline(x=x0, color="red", linestyle="--", linewidth=2, alpha=0.9,
                    label="Clinical Seizure Start" if not seen_label_start else None)
        plt.axvline(x=x1, color="red", linestyle="-.", linewidth=2, alpha=0.9,
                    label="Clinical Seizure End" if not seen_label_end else None)
        seen_label_start = True
        seen_label_end = True

plt.ylim(0, 1.05)
plt.xlabel("Time (Total Minutes)")
plt.ylabel("Pre-Ictal Density (fraction of last 10 min)")
plt.title("Pre-Ictal Density (10m) with Predicted Ictal and Clinical Seizure Annotations")
plt.legend(loc="upper left")
plt.tight_layout()
plt.show()
